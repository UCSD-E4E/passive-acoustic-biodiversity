# %% [markdown]
# # K-Means Exploration
# Exploratory notebook for working on birdnet embeddings

# %% [markdown]
# ### Imports and Setup

# %%
import pandas as pd
import os
import numpy as np
from annotation_post_processing import *

# %%
embeddingColumns = [str(i) for i in range(420)]
columnNames = ["START", "END"] + embeddingColumns
path = './input/xc_embeddings/'

# %%
def generate_embeddings_from_file(path, filename):
    with open(path + filename, 'r') as f:
        data = f.read()
    with open(path + filename, 'w') as f:
        f.write(",".join(data.split("\t")))
    file_df = pd.read_csv(path + filename, names = columnNames)
    file_df["IN FILE"] = filename[:filename.index(".birdnet")] + ".wav"
    return file_df

def generate_embeddings(path):
    df = pd.DataFrame()
    for filename in os.listdir(path):
        try:
            df = pd.concat([df, generate_embeddings_from_file(path, filename)], ignore_index = True)
        except Exception as e:
            print("Something went wrong with: " + filename)
    df["PATH"] = path
    columns = df.columns.tolist()
    columns = columns[-2:] + columns[:-2]
    df = df[columns]
    df = df.sort_values(["IN FILE", "START"], ascending = True)
    df = df.reset_index(drop = True)
    return df

# %%
embeddings_df = generate_embeddings(path)
annotations_df = pd.read_csv("xc_annotations.csv")

# removing duplicate annotations
grouped_annotations = annotations_df.groupby(["IN FILE", "OFFSET"])["CONFIDENCE"].max()
annotations_df["MANUAL ID"] = annotations_df.apply(lambda x: x["MANUAL ID"] \
    if grouped_annotations.loc[x["IN FILE"], x["OFFSET"]] == x["CONFIDENCE"] else pd.NA, axis = 1)
annotations_df = annotations_df.dropna(subset = ["MANUAL ID"]).reset_index(drop = True)

# %%
manual_df = pd.read_csv("mixed_bird_sample.csv")
manual_df = pd.DataFrame(annotation_chunker(manual_df, 3))
manual_df["MANUAL ID"] = manual_df["MANUAL ID"].apply(lambda x: " ".join(x.split(" ")[:2]))
manual_df
# Out:
#                            IN FILE  CLIP LENGTH  CHANNEL  OFFSET  DURATION  \
# 0        Amazona-aestiva-52744.wav      19.5657        0     0.0       3.0
# 1        Amazona-aestiva-52744.wav      19.5657        0     3.0       3.0
# 2        Amazona-aestiva-52744.wav      19.5657        0     6.0       3.0
# 3        Amazona-aestiva-52744.wav      19.5657        0     9.0       3.0
# 4        Amazona-aestiva-52744.wav      19.5657        0    12.0       3.0
# ..                             ...          ...      ...     ...       ...
# 976  Zenaida-auriculata-105264.wav      82.9910        0    48.0       3.0
# 977  Zenaida-auriculata-105264.wav      82.9910        0    57.0       3.0
# 978  Zenaida-auriculata-105264.wav      82.9910        0    60.0       3.0
# 979  Zenaida-auriculata-105264.wav      82.9910        0    66.0       3.0
# 980  Zenaida-auriculata-105264.wav      82.9910        0    69.0       3.0
#
#      SAMPLE RATE           MANUAL ID
# 0          44100     Amazona aestiva
# 1          44100     Amazona aestiva
# 2          44100     Amazona aestiva
# 3          44100     Amazona aestiva
# 4          44100     Amazona aestiva
# ..           ...                 ...
# 976        44100  Zenaida auriculata
# 977        44100  Zenaida auriculata
# 978        44100  Zenaida auriculata
# 979        44100  Zenaida auriculata
# 980        44100  Zenaida auriculata
#
# [981 rows x 7 columns]

# %%
# Data cleaning to avoid file does not exist
intersection_files = list(set(embeddings_df["IN FILE"].unique()).intersection(set(annotations_df["IN FILE"])))
embeddings_df = embeddings_df[embeddings_df["IN FILE"].isin(intersection_files)]
annotations_df = annotations_df[annotations_df["IN FILE"].isin(intersection_files)]
manual_df = manual_df[manual_df["IN FILE"].isin(intersection_files)]

# %%
# Adding manual ids to embeddings
k = 0
def embed_id(x):
    filenames = manual_df["IN FILE"] == x["IN FILE"]
    offsets = np.isclose(manual_df["OFFSET"], x["START"])
    both = filenames & offsets
    if not np.any(both):
        return "No bird"
    return manual_df[both]["MANUAL ID"].iloc[0]

embeddings_df["MANUAL ID"] = embeddings_df.apply(embed_id, axis = 1)
embeddings_df["FILE SPECIES"] = embeddings_df["IN FILE"].apply(lambda x: " ".join(x.split("-")[:2]))

# %%
# To change all of the birdnet annotations manual ids to species names
birdnet_species = pd.read_csv("birdnet_species.csv")
birdnet_species.columns = ["SPECIES"]
birdnet_species = birdnet_species.assign(
    SPECIES = birdnet_species["SPECIES"].apply(lambda x: x.split("_")[0]), 
    COMMON = birdnet_species["SPECIES"].apply(lambda x: x.split("_")[1])
)
birdnet_species = birdnet_species.set_index("COMMON").to_dict()["SPECIES"]

annotations_df["MANUAL ID"] = annotations_df["MANUAL ID"].apply(lambda x: birdnet_species[x])

# %%
embeddings_df
# Out:
#                             IN FILE                    PATH  START   END  \
# 0         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    0.0   3.0
# 1         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    3.0   6.0
# 2         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    6.0   9.0
# 3         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    9.0  12.0
# 4         Amazona-aestiva-52744.wav  ./input/xc_embeddings/   12.0  15.0
# ...                             ...                     ...    ...   ...
# 1269  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   66.0  69.0
# 1270  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   69.0  72.0
# 1271  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   72.0  75.0
# 1272  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   75.0  78.0
# 1273  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   78.0  81.0
#
#              0         1         2         3         4         5  ...  \
# 0     0.762929  1.000408  0.432522  0.452946  0.656488  0.737373  ...
# 1     0.503359  1.043012  1.005796  0.746995  0.574083  0.559189  ...
# 2     0.524409  1.336747  0.553674  0.334472  0.743905  0.547638  ...
# 3     0.436074  0.507001  0.915852  0.123285  0.442399  0.537654  ...
# 4     0.433620  1.535415  0.639228  0.053500  0.584404  0.518180  ...
# ...        ...       ...       ...       ...       ...       ...  ...
# 1269  0.774719  0.172968  2.005917  0.446872  0.182429  1.709142  ...
# 1270  0.865834  0.252022  2.261983  0.285904  0.507300  1.582644  ...
# 1271  0.516543  0.430446  2.036958  0.136788  0.701989  1.653021  ...
# 1272  0.243208  0.508803  1.145117  0.905772  0.488338  1.596147  ...
# 1273  0.517802  0.625159  1.547921  0.549589  0.355532  0.995112  ...
#
#            412       413       414       415       416       417       418  \
# 0     0.400595  0.883827  1.193243  0.283634  1.542077  0.981433  0.721521
# 1     0.300669  0.443966  0.643819  0.377903  1.428960  1.383765  1.037601
# 2     0.180524  0.618135  0.340749  0.336239  1.109600  0.923518  0.698893
# 3     0.510933  0.126209  0.478544  0.347008  1.033731  0.530908  0.840781
# 4     0.233526  0.647830  0.581350  0.101694  0.756994  0.921158  1.034858
# ...        ...       ...       ...       ...       ...       ...       ...
# 1269  0.648165  0.610772  0.648035  0.946822  1.422127  0.063739  0.265166
# 1270  0.627719  0.182417  0.545958  0.731052  1.079015  0.151970  0.582425
# 1271  0.402779  0.267759  0.269648  0.489614  0.008608  0.085612  0.132973
# 1272  0.136255  0.410212  0.399387  0.348331  0.103727  0.372924  1.253011
# 1273  0.287556  0.229190  0.320091  0.674256  0.297132  0.309240  0.210873
#
#            419           MANUAL ID        FILE SPECIES
# 0     1.163081     Amazona aestiva     Amazona aestiva
# 1     0.670695     Amazona aestiva     Amazona aestiva
# 2     0.677029     Amazona aestiva     Amazona aestiva
# 3     0.675452     Amazona aestiva     Amazona aestiva
# 4     0.702051     Amazona aestiva     Amazona aestiva
# ...        ...                 ...                 ...
# 1269  0.462670  Zenaida auriculata  Zenaida auriculata
# 1270  0.567783  Zenaida auriculata  Zenaida auriculata
# 1271  0.294987             No bird  Zenaida auriculata
# 1272  0.634606             No bird  Zenaida auriculata
# 1273  0.404575             No bird  Zenaida auriculata
#
# [1274 rows x 426 columns]

# %%
annotations_df
# Out:
#                                                  FOLDER  \
# 0     ../passive-acoustic-biodiversity/BirdnetEmbedd...
# 1     ../passive-acoustic-biodiversity/BirdnetEmbedd...
# 2     ../passive-acoustic-biodiversity/BirdnetEmbedd...
# 3     ../passive-acoustic-biodiversity/BirdnetEmbedd...
# 4     ../passive-acoustic-biodiversity/BirdnetEmbedd...
# ...                                                 ...
# 1103  ../passive-acoustic-biodiversity/BirdnetEmbedd...
# 1104  ../passive-acoustic-biodiversity/BirdnetEmbedd...
# 1105  ../passive-acoustic-biodiversity/BirdnetEmbedd...
# 1106  ../passive-acoustic-biodiversity/BirdnetEmbedd...
# 1107  ../passive-acoustic-biodiversity/BirdnetEmbedd...
#
#                             IN FILE  CLIP LENGTH  CHANNEL  OFFSET  DURATION  \
# 0         Amazona-aestiva-52744.wav    42.592063        1     0.0       3.0
# 1         Amazona-aestiva-52744.wav    42.592063        1     3.0       3.0
# 2         Amazona-aestiva-52744.wav    42.592063        1     6.0       3.0
# 3         Amazona-aestiva-52744.wav    42.592063        1     9.0       3.0
# 4         Amazona-aestiva-52744.wav    42.592063        1    12.0       3.0
# ...                             ...          ...      ...     ...       ...
# 1103  Zenaida-auriculata-105264.wav   180.660726        1    66.0       3.0
# 1104  Zenaida-auriculata-105264.wav   180.660726        1    69.0       3.0
# 1105  Zenaida-auriculata-105264.wav   180.660726        1    72.0       3.0
# 1106  Zenaida-auriculata-105264.wav   180.660726        1    75.0       3.0
# 1107  Zenaida-auriculata-105264.wav   180.660726        1    78.0       3.0
#
#       SAMPLE RATE             MANUAL ID  CONFIDENCE
# 0           48000  Amazona ochrocephala      0.4382
# 1           48000       Amazona aestiva      0.9149
# 2           48000  Amazona ochrocephala      0.3460
# 3           48000       Amazona aestiva      0.8246
# 4           48000       Amazona aestiva      0.8547
# ...           ...                   ...         ...
# 1103        48000    Zenaida auriculata      0.9999
# 1104        48000    Zenaida auriculata      0.9994
# 1105        48000    Zenaida auriculata      0.5543
# 1106        48000         Columba oenas      0.2265
# 1107        48000   Podilymbus podiceps      0.4580
#
# [1108 rows x 9 columns]

# %%
manual_df
# Out:
#                            IN FILE  CLIP LENGTH  CHANNEL  OFFSET  DURATION  \
# 0        Amazona-aestiva-52744.wav      19.5657        0     0.0       3.0
# 1        Amazona-aestiva-52744.wav      19.5657        0     3.0       3.0
# 2        Amazona-aestiva-52744.wav      19.5657        0     6.0       3.0
# 3        Amazona-aestiva-52744.wav      19.5657        0     9.0       3.0
# 4        Amazona-aestiva-52744.wav      19.5657        0    12.0       3.0
# ..                             ...          ...      ...     ...       ...
# 976  Zenaida-auriculata-105264.wav      82.9910        0    48.0       3.0
# 977  Zenaida-auriculata-105264.wav      82.9910        0    57.0       3.0
# 978  Zenaida-auriculata-105264.wav      82.9910        0    60.0       3.0
# 979  Zenaida-auriculata-105264.wav      82.9910        0    66.0       3.0
# 980  Zenaida-auriculata-105264.wav      82.9910        0    69.0       3.0
#
#      SAMPLE RATE           MANUAL ID
# 0          44100     Amazona aestiva
# 1          44100     Amazona aestiva
# 2          44100     Amazona aestiva
# 3          44100     Amazona aestiva
# 4          44100     Amazona aestiva
# ..           ...                 ...
# 976        44100  Zenaida auriculata
# 977        44100  Zenaida auriculata
# 978        44100  Zenaida auriculata
# 979        44100  Zenaida auriculata
# 980        44100  Zenaida auriculata
#
# [981 rows x 7 columns]

# %%
# Checking to see if same number of files are in all of the dataframes
print(len(embeddings_df["IN FILE"].unique()), len(annotations_df["IN FILE"].unique()), len(manual_df["IN FILE"].unique()))
# Out:
# 99 99 99

# %% [markdown]
# ### K-Means Exploration

# %%
from sklearn.cluster import KMeans
import pickle

# Uploading all KMeans models
model_dir = "./ClusteringModels/"

model_list:list[KMeans] = []
for model in os.listdir(model_dir):
    with open(model_dir + model, "rb") as f:
        model_list.append(pickle.load(f))

wcss_data = pd.read_csv("kmeans_wcss.csv", names=["WCSS Score"])
wcss_data["i"] = wcss_data.index * 10 + 10
wcss_data
# Out:
#       WCSS Score    i
# 0   84863.071048   10
# 1   74156.221513   20
# 2   66279.401569   30
# 3   61064.587748   40
# 4   56551.308363   50
# 5   51676.033288   60
# 6   48386.166079   70
# 7   45939.091929   80
# 8   43393.969898   90
# 9   41740.063919  100
# 10  39917.757887  110
# 11  38539.610449  120
# 12  37203.960515  130
# 13  36017.979752  140
# 14  34771.008203  150
# 15  34068.401567  160
# 16  32859.295190  170
# 17  32150.282263  180
# 18  31319.706226  190
# 19  30599.775265  200
# 20  29896.722536  210
# 21  29020.210648  220
# 22  28455.748738  230
# 23  27753.173194  240
# 24  27149.824061  250
# 25  26554.931666  260
# 26  25916.477596  270
# 27  25524.105020  280
# 28  24927.904124  290
# 29  24438.712863  300

# %%
import seaborn as sns
sns.lineplot(data = wcss_data, x = "i", y = "WCSS Score")
# Out:
# <AxesSubplot:xlabel='i', ylabel='WCSS Score'>

# %% [markdown]
# ### K-Means with n_clusters = n_species

# %%
# Model trained on only embeddings that have a label from Manual ID
with open("./ClusteringModels/kmeans_model.pkl", "rb") as f:
    kmeans_model:KMeans = pickle.load(f)

# %%
embeddings_df["KMEANS PREDICTIONS"] = kmeans_model.predict(embeddings_df[embeddingColumns])
embeddings_df
# Out:
#                             IN FILE                    PATH  START   END  \
# 0         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    0.0   3.0
# 1         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    3.0   6.0
# 2         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    6.0   9.0
# 3         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    9.0  12.0
# 4         Amazona-aestiva-52744.wav  ./input/xc_embeddings/   12.0  15.0
# ...                             ...                     ...    ...   ...
# 1269  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   66.0  69.0
# 1270  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   69.0  72.0
# 1271  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   72.0  75.0
# 1272  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   75.0  78.0
# 1273  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   78.0  81.0
#
#              0         1         2         3         4         5  ...  \
# 0     0.762929  1.000408  0.432522  0.452946  0.656488  0.737373  ...
# 1     0.503359  1.043012  1.005796  0.746995  0.574083  0.559189  ...
# 2     0.524409  1.336747  0.553674  0.334472  0.743905  0.547638  ...
# 3     0.436074  0.507001  0.915852  0.123285  0.442399  0.537654  ...
# 4     0.433620  1.535415  0.639228  0.053500  0.584404  0.518180  ...
# ...        ...       ...       ...       ...       ...       ...  ...
# 1269  0.774719  0.172968  2.005917  0.446872  0.182429  1.709142  ...
# 1270  0.865834  0.252022  2.261983  0.285904  0.507300  1.582644  ...
# 1271  0.516543  0.430446  2.036958  0.136788  0.701989  1.653021  ...
# 1272  0.243208  0.508803  1.145117  0.905772  0.488338  1.596147  ...
# 1273  0.517802  0.625159  1.547921  0.549589  0.355532  0.995112  ...
#
#            413       414       415       416       417       418       419  \
# 0     0.883827  1.193243  0.283634  1.542077  0.981433  0.721521  1.163081
# 1     0.443966  0.643819  0.377903  1.428960  1.383765  1.037601  0.670695
# 2     0.618135  0.340749  0.336239  1.109600  0.923518  0.698893  0.677029
# 3     0.126209  0.478544  0.347008  1.033731  0.530908  0.840781  0.675452
# 4     0.647830  0.581350  0.101694  0.756994  0.921158  1.034858  0.702051
# ...        ...       ...       ...       ...       ...       ...       ...
# 1269  0.610772  0.648035  0.946822  1.422127  0.063739  0.265166  0.462670
# 1270  0.182417  0.545958  0.731052  1.079015  0.151970  0.582425  0.567783
# 1271  0.267759  0.269648  0.489614  0.008608  0.085612  0.132973  0.294987
# 1272  0.410212  0.399387  0.348331  0.103727  0.372924  1.253011  0.634606
# 1273  0.229190  0.320091  0.674256  0.297132  0.309240  0.210873  0.404575
#
#                MANUAL ID        FILE SPECIES  KMEANS PREDICTIONS
# 0        Amazona aestiva     Amazona aestiva                   1
# 1        Amazona aestiva     Amazona aestiva                   1
# 2        Amazona aestiva     Amazona aestiva                   1
# 3        Amazona aestiva     Amazona aestiva                   2
# 4        Amazona aestiva     Amazona aestiva                   1
# ...                  ...                 ...                 ...
# 1269  Zenaida auriculata  Zenaida auriculata                  79
# 1270  Zenaida auriculata  Zenaida auriculata                  79
# 1271             No bird  Zenaida auriculata                  25
# 1272             No bird  Zenaida auriculata                  63
# 1273             No bird  Zenaida auriculata                  25
#
# [1274 rows x 427 columns]

# %%
predicted_labels_kmeans = embeddings_df[embeddings_df["MANUAL ID"] != "No bird"][["MANUAL ID", "KMEANS PREDICTIONS"]].groupby("MANUAL ID")["KMEANS PREDICTIONS"]
predicted_labels_kmeans = predicted_labels_kmeans.agg(pd.Series.mode)
predicted_labels_kmeans = predicted_labels_kmeans.apply(lambda x: int(x) if isinstance(x, int) else int(np.median(x)))
predicted_labels_kmeans
# Out:
# MANUAL ID
# Amazona aestiva            1
# Ara macao                 88
# Ara militaris             47
# Ardea cocoi               62
# Arremon taciturnus        52
#                           ..
# Tyranneutes stolzmanni    52
# Vireo flavoviridis        19
# Vireo olivaceus           10
# Xenops rutilans           65
# Zenaida auriculata        79
# Name: KMEANS PREDICTIONS, Length: 94, dtype: int64

# %%
sns.displot(predicted_labels_kmeans, binwidth = 1)

# %% [markdown]
# #### Conclusion
# The distribution is almost all 1s, though they are instances of >1 count for a cluster. This means that there are many some repeats in the KMeans classification (it did not classify perfectly well).

# %% [markdown]
# ### HDBSCAN with n_clusters = n_species

# %%
import hdbscan
from hdbscan import HDBSCAN

# %%
# Model trained on only embeddings that have a label from Manual ID, min_cluster_size = 8 and min_samples = 1
with open("./ClusteringModels/hdbscan_model.pkl", "rb") as f:
    hdbscan_model:HDBSCAN = pickle.load(f)

# %%
embeddings_df["HDBSCAN PREDICTIONS"] = hdbscan_model.labels_
embeddings_df
# Out:
#                             IN FILE                    PATH  START   END  \
# 0         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    0.0   3.0
# 1         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    3.0   6.0
# 2         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    6.0   9.0
# 3         Amazona-aestiva-52744.wav  ./input/xc_embeddings/    9.0  12.0
# 4         Amazona-aestiva-52744.wav  ./input/xc_embeddings/   12.0  15.0
# ...                             ...                     ...    ...   ...
# 1269  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   66.0  69.0
# 1270  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   69.0  72.0
# 1271  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   72.0  75.0
# 1272  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   75.0  78.0
# 1273  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   78.0  81.0
#
#              0         1         2         3         4         5  ...  \
# 0     0.762929  1.000408  0.432522  0.452946  0.656488  0.737373  ...
# 1     0.503359  1.043012  1.005796  0.746995  0.574083  0.559189  ...
# 2     0.524409  1.336747  0.553674  0.334472  0.743905  0.547638  ...
# 3     0.436074  0.507001  0.915852  0.123285  0.442399  0.537654  ...
# 4     0.433620  1.535415  0.639228  0.053500  0.584404  0.518180  ...
# ...        ...       ...       ...       ...       ...       ...  ...
# 1269  0.774719  0.172968  2.005917  0.446872  0.182429  1.709142  ...
# 1270  0.865834  0.252022  2.261983  0.285904  0.507300  1.582644  ...
# 1271  0.516543  0.430446  2.036958  0.136788  0.701989  1.653021  ...
# 1272  0.243208  0.508803  1.145117  0.905772  0.488338  1.596147  ...
# 1273  0.517802  0.625159  1.547921  0.549589  0.355532  0.995112  ...
#
#            414       415       416       417       418       419  \
# 0     1.193243  0.283634  1.542077  0.981433  0.721521  1.163081
# 1     0.643819  0.377903  1.428960  1.383765  1.037601  0.670695
# 2     0.340749  0.336239  1.109600  0.923518  0.698893  0.677029
# 3     0.478544  0.347008  1.033731  0.530908  0.840781  0.675452
# 4     0.581350  0.101694  0.756994  0.921158  1.034858  0.702051
# ...        ...       ...       ...       ...       ...       ...
# 1269  0.648035  0.946822  1.422127  0.063739  0.265166  0.462670
# 1270  0.545958  0.731052  1.079015  0.151970  0.582425  0.567783
# 1271  0.269648  0.489614  0.008608  0.085612  0.132973  0.294987
# 1272  0.399387  0.348331  0.103727  0.372924  1.253011  0.634606
# 1273  0.320091  0.674256  0.297132  0.309240  0.210873  0.404575
#
#                MANUAL ID        FILE SPECIES  KMEANS PREDICTIONS  \
# 0        Amazona aestiva     Amazona aestiva                   1
# 1        Amazona aestiva     Amazona aestiva                   1
# 2        Amazona aestiva     Amazona aestiva                   1
# 3        Amazona aestiva     Amazona aestiva                   2
# 4        Amazona aestiva     Amazona aestiva                   1
# ...                  ...                 ...                 ...
# 1269  Zenaida auriculata  Zenaida auriculata                  79
# 1270  Zenaida auriculata  Zenaida auriculata                  79
# 1271             No bird  Zenaida auriculata                  25
# 1272             No bird  Zenaida auriculata                  63
# 1273             No bird  Zenaida auriculata                  25
#
#       HDBSCAN PREDICTIONS
# 0                      -1
# 1                      -1
# 2                      -1
# 3                      -1
# 4                      -1
# ...                   ...
# 1269                   30
# 1270                   30
# 1271                   30
# 1272                   -1
# 1273                   -1
#
# [1274 rows x 428 columns]

# %%
predicted_labels_hdbscan = embeddings_df[embeddings_df["MANUAL ID"] != "No bird"][["MANUAL ID", "HDBSCAN PREDICTIONS"]].groupby("MANUAL ID")["HDBSCAN PREDICTIONS"]
predicted_labels_hdbscan = predicted_labels_hdbscan.agg(pd.Series.mode)
predicted_labels_hdbscan = predicted_labels_hdbscan.apply(lambda x: int(x) if isinstance(x, int) else int(np.median(x)))
predicted_labels_hdbscan
# Out:
# MANUAL ID
# Amazona aestiva           -1
# Ara macao                 -1
# Ara militaris             22
# Ardea cocoi               -1
# Arremon taciturnus        -1
#                           ..
# Tyranneutes stolzmanni    -1
# Vireo flavoviridis        14
# Vireo olivaceus           17
# Xenops rutilans           -1
# Zenaida auriculata        30
# Name: HDBSCAN PREDICTIONS, Length: 94, dtype: int64

# %%
sns.displot(predicted_labels_hdbscan, binwidth = 1)

# %% [markdown]
# #### Conclusion
# It seems as if most of the species are classified as noise. However, for the species that it is able to classify, it almost always has only 1 species per cluster number, which is better than KMeans.

# %%
embeddings_df["HDBSCAN PROBABILITIES"] = hdbscan_model.probabilities_
embeddings_df_above_thresh = embeddings_df[embeddings_df["HDBSCAN PROBABILITIES"] >= 0.2]
embeddings_df_above_thresh
# Out:
#                             IN FILE                    PATH  START   END  \
# 20         Ara-militaris-391487.wav  ./input/xc_embeddings/    0.0   3.0
# 21         Ara-militaris-391487.wav  ./input/xc_embeddings/    3.0   6.0
# 22         Ara-militaris-391487.wav  ./input/xc_embeddings/    6.0   9.0
# 23         Ara-militaris-391487.wav  ./input/xc_embeddings/    9.0  12.0
# 24         Ara-militaris-391487.wav  ./input/xc_embeddings/   12.0  15.0
# ...                             ...                     ...    ...   ...
# 1266  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   57.0  60.0
# 1268  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   63.0  66.0
# 1269  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   66.0  69.0
# 1270  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   69.0  72.0
# 1271  Zenaida-auriculata-105264.wav  ./input/xc_embeddings/   72.0  75.0
#
#              0         1         2         3         4         5  ...  \
# 20    1.393441  0.249384  0.864065  0.463565  0.461047  0.933733  ...
# 21    0.542369  0.401923  0.770922  0.599988  0.681402  1.542457  ...
# 22    1.252990  0.119261  1.161548  0.689502  0.625040  1.077501  ...
# 23    1.538273  0.322056  1.171923  0.362280  0.317512  0.352444  ...
# 24    1.170004  0.495953  0.722514  0.483176  0.268308  0.326776  ...
# ...        ...       ...       ...       ...       ...       ...  ...
# 1266  0.675475  0.314947  1.514462  0.318162  0.175607  1.050441  ...
# 1268  0.744341  0.020288  2.066783  0.231072  0.105611  1.293756  ...
# 1269  0.774719  0.172968  2.005917  0.446872  0.182429  1.709142  ...
# 1270  0.865834  0.252022  2.261983  0.285904  0.507300  1.582644  ...
# 1271  0.516543  0.430446  2.036958  0.136788  0.701989  1.653021  ...
#
#            415       416       417       418       419           MANUAL ID  \
# 20    0.845052  0.684784  0.810439  1.184193  1.795609       Ara militaris
# 21    0.622547  0.325624  1.151461  0.485282  1.203520       Ara militaris
# 22    0.836769  0.354353  0.469132  1.833635  1.928144       Ara militaris
# 23    0.792413  0.141057  1.072731  1.496520  1.122524       Ara militaris
# 24    0.839432  0.049983  1.232161  0.947351  1.130225       Ara militaris
# ...        ...       ...       ...       ...       ...                 ...
# 1266  0.598633  0.789171  0.173363  0.460750  0.464910  Zenaida auriculata
# 1268  0.676583  0.257499  0.579896  0.024443  0.292778             No bird
# 1269  0.946822  1.422127  0.063739  0.265166  0.462670  Zenaida auriculata
# 1270  0.731052  1.079015  0.151970  0.582425  0.567783  Zenaida auriculata
# 1271  0.489614  0.008608  0.085612  0.132973  0.294987             No bird
#
#             FILE SPECIES  KMEANS PREDICTIONS  HDBSCAN PREDICTIONS  \
# 20         Ara militaris                  36                   22
# 21         Ara militaris                  47                   22
# 22         Ara militaris                  36                   22
# 23         Ara militaris                  47                   22
# 24         Ara militaris                  47                   22
# ...                  ...                 ...                  ...
# 1266  Zenaida auriculata                  79                   30
# 1268  Zenaida auriculata                  25                   30
# 1269  Zenaida auriculata                  79                   30
# 1270  Zenaida auriculata                  79                   30
# 1271  Zenaida auriculata                  25                   30
#
#       HDBSCAN PROBABILITIES
# 20                 1.000000
# 21                 0.953386
# 22                 0.988769
# 23                 1.000000
# 24                 0.958441
# ...                     ...
# 1266               0.950226
# 1268               1.000000
# 1269               0.950226
# 1270               0.933507
# 1271               1.000000
#
# [713 rows x 429 columns]

# %%
predicted_labels_hdbscan_above_thresh = embeddings_df[embeddings_df["MANUAL ID"] != "No bird"][["MANUAL ID", "HDBSCAN PREDICTIONS"]].groupby("MANUAL ID")["HDBSCAN PREDICTIONS"]
predicted_labels_hdbscan_above_thresh = predicted_labels_hdbscan_above_thresh.agg(pd.Series.mode)
predicted_labels_hdbscan_above_thresh = predicted_labels_hdbscan_above_thresh.apply(lambda x: int(x) if isinstance(x, int) else int(np.median(x)))
predicted_labels_hdbscan_above_thresh
# Out:
# MANUAL ID
# Amazona aestiva           -1
# Ara macao                 -1
# Ara militaris             22
# Ardea cocoi               -1
# Arremon taciturnus        -1
#                           ..
# Tyranneutes stolzmanni    -1
# Vireo flavoviridis        14
# Vireo olivaceus           17
# Xenops rutilans           -1
# Zenaida auriculata        30
# Name: HDBSCAN PREDICTIONS, Length: 94, dtype: int64

# %%
sns.displot(predicted_labels_hdbscan, binwidth = 1)

# %% [markdown]
# #### Conclusion
# It seems as if most of the species are classified as noise (i.e. not much difference from when disregarding the threshold). However, for the species that it is able to classify, it almost always has only 1 species per cluster number, which is better than KMeans.

# %% [markdown]
# ### Visualizations

# %%
# %matplotlib inline
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from sklearn.preprocessing import LabelEncoder

plt.style.use("ggplot")

# %%
# Visualization for all models
pca_2d = PCA(n_components = 2, random_state = 42)
pca_columns_2d = pd.DataFrame(pca_2d.fit_transform(embeddings_df[embeddingColumns])).T
pca_3d = PCA(n_components = 3, random_state = 42)
pca_columns_3d = pd.DataFrame(pca_3d.fit_transform(embeddings_df[embeddingColumns])).T

# %%
# Plotting 2D manual labels
fig = plt.figure(figsize = (10, 7))
ax = plt.axes()

embeddings_df["MANUAL ID NUMS"] = LabelEncoder().fit_transform(embeddings_df["MANUAL ID"])

# MANUAL ID labels
scatter_plot = ax.scatter(pca_columns_2d.iloc[0], pca_columns_2d.iloc[1], c = embeddings_df["MANUAL ID NUMS"])

plt.title("PCA Visualization 2D with Manual ID labels")
# Out:
# Text(0.5, 1.0, 'PCA Visualization 2D with Manual ID labels')

# %%
# Plotting 3D manual labels
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection = '3d')

# MANUAL ID labels
scatter_plot = ax.scatter(pca_columns_3d.iloc[0], pca_columns_3d.iloc[1], pca_columns_3d.iloc[2], c = embeddings_df["MANUAL ID NUMS"])

plt.title("PCA Visualization 3D with Manual ID labels")
# Out:
# Text(0.5, 0.92, 'PCA Visualization 3D with Manual ID labels')

# %%
# Plotting 2D KMeans labels
fig = plt.figure(figsize = (10, 7))
ax = plt.axes()

# KMeans labels
scatter_plot = ax.scatter(pca_columns_2d.iloc[0], pca_columns_2d.iloc[1], c = embeddings_df["KMEANS PREDICTIONS"])

plt.title("PCA Visualization 2D with K-Means labels")
# Out:
# Text(0.5, 1.0, 'PCA Visualization 2D with K-Means labels')

# %%
# Plotting 3D KMeans labels
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection = '3d')

# KMeans labels
scatter_plot = ax.scatter(pca_columns_3d.iloc[0], pca_columns_3d.iloc[1], pca_columns_3d.iloc[2], c = embeddings_df["KMEANS PREDICTIONS"])

plt.title("PCA Visualization 3D with K-Means labels")
# Out:
# Text(0.5, 0.92, 'PCA Visualization 3D with K-Means labels')

# %%
# Plotting 2D HDBSCAN labels
fig = plt.figure(figsize = (10, 7))
ax = plt.axes()

# HDBSCAN labels
scatter_plot = ax.scatter(pca_columns_2d.iloc[0], pca_columns_2d.iloc[1], c = embeddings_df["HDBSCAN PREDICTIONS"])

plt.title("PCA Visualization 2D with HDBSCAN labels")
# Out:
# Text(0.5, 1.0, 'PCA Visualization 2D with HDBSCAN labels')

# %%
# Plotting 3D HDBSCAN labels
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection = '3d')

# HDBSCAN labels
scatter_plot = ax.scatter(pca_columns_3d.iloc[0], pca_columns_3d.iloc[1], pca_columns_3d.iloc[2], c = embeddings_df["HDBSCAN PREDICTIONS"])

plt.title("PCA Visualization 3D with HDBSCAN labels")
# Out:
# Text(0.5, 0.92, 'PCA Visualization 3D with HDBSCAN labels')
