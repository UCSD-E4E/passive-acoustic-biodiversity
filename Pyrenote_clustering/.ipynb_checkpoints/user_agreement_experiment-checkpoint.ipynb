# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import random
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.cluster import DBSCAN
import math
import statistics
pd.options.mode.chained_assignment = None  # default='warn'
import itertools
import json


#Convert CSV to Dataframe
data = pd.read_csv("C:/Users/seanh/Downloads/pairwise_user_experiment (1).csv", header=[0])
data["FOLDER"] = data["IN FILE"].apply(lambda x: "")
data["LAST MOD BY"] = data["LAST MOD BY"].apply(lambda x: x.split(" ")[0])
data
# Out:
#                                                 IN FILE  CLIP LENGTH   OFFSET  \
# 0     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034   1.1839
# 1     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034   6.9715
# 2     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034   8.8594
# 3     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034   9.9393
# 4     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034  15.1890
# ...                                                 ...          ...      ...
# 2243  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  22.3916
# 2244  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  23.7316
# 2245  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  24.2615
# 2246  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  24.7815
# 2247  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  25.3315
#
#       DURATION  MAX FREQ  MIN FREQ  SAMPLE RATE           MANUAL ID  \
# 0       1.3399     24000         0        48000  White-vented Shama
# 1       1.5479     24000         0        48000  White-vented Shama
# 2       0.4500     24000         0        48000  White-vented Shama
# 3       1.0800     24000         0        48000  White-vented Shama
# 4       0.9299     24000         0        48000  White-vented Shama
# ...        ...       ...       ...          ...                 ...
# 2243    0.8100     24000         0        48000                bird
# 2244    0.1600     24000         0        48000                bird
# 2245    0.1200     24000         0        48000                bird
# 2246    0.1600     24000         0        48000                bird
# 2247    0.1400     24000         0        48000                bird
#
#       TIME_SPENT LAST MOD BY  CONFIDENCE  RETIRED  COUNTED FOLDER
# 0        141.864       spres    0.577908    False        0
# 1        141.864       spres    0.577908    False        0
# 2        141.864       spres    0.577908    False        0
# 3        141.864       spres    0.577908    False        0
# 4        141.864       spres    0.577908    False        0
# ...          ...         ...         ...      ...      ...    ...
# 2243     311.194      Anshul    0.300511    False        0
# 2244     311.194      Anshul    0.300511    False        0
# 2245     311.194      Anshul    0.300511    False        0
# 2246     311.194      Anshul    0.300511    False        0
# 2247     311.194      Anshul    0.300511    False        0
#
# [2248 rows x 14 columns]

# %% [markdown]
# #### Import Confidence Functions and Create List of Functions

# %%
from confidence_functions.confidence import *
 
confidence_funcs = [ get_silhoutte_confidence, get_silhoutte_users_confidence, majority_vote, get_pairwise_iou]
confidence_funcs
# Out:
# [<function confidence_functions.confidence.get_silhoutte_confidence(df, users)>,
#  <function confidence_functions.confidence.get_silhoutte_users_confidence(df, users)>,
#  <function confidence_functions.confidence.majority_vote(df, users, chunk_length=1)>,
#  <function confidence_functions.confidence.get_pairwise_iou(df, users)>]

# %% [markdown]
# ### permuatation code

# %%
def permutate_users(df, num_users, clip_name, confidence_func):
    #Get data for indivual clip
    results = []
    df = df[df["IN FILE"] == clip_name]
    users = df["LAST MOD BY"].unique()
    
    for user_permutation in itertools.permutations(users, num_users):
        try:
            results.append(confidence_func(df, user_permutation))
        except:
            pass
        
    results = np.mean(results)
    return results
    
#permutate_users(data, 2, "XC425555_-_Screaming_Piha_-_Lipaugus_vociferans.mp3", get_silhoutte_users_confidence)

# %% [markdown]
# ### Clip Spefific Experiment

# %%
def determine_confidence_by_clip(df, clip_name, confidence_funcs):
    results = {}
    df = df[df["IN FILE"] == clip_name]
    users = df["LAST MOD BY"].unique()
    for confidence_func in confidence_funcs:
        print("working with function: " + confidence_func.__name__)
        results[confidence_func] = {}
        
        for user_count in range(6):
            results[confidence_func][user_count+1]= permutate_users(df, user_count+1, clip_name, confidence_func)
    return results

def determine_confidence_by_func(df, confidence_funcs):
    results = {}
    users = df["LAST MOD BY"].unique()
    files = df["IN FILE"].unique()
    for func in confidence_funcs:
        results[func] = {}
        for user_count in range(6):
            print("USER", user_count)
            confidence = np.array([])
            for file in files:
                if (user_count < len(df[df["IN FILE"] == file]["LAST MOD BY"].unique())):
                       confidence = np.append(confidence, permutate_users(df, user_count+1, file, func))
            print(confidence)
            confidence = confidence.mean()
            results[func][user_count+1] = confidence
    return results
        
#determine_confidence_by_clip(data, "XC425555_-_Screaming_Piha_-_Lipaugus_vociferans.mp3", confidence_funcs)
#determine_confidence_by_func(data, confidence_funcs)

# %% [markdown]
# # Full Experiment

# %%
def run_experiment(df, confidence_funcs):
    #Get the adverage confidence over number of users for each file
    results = {"by_clip": {}, "Over_all_clips": {}}
    filenames = df["IN FILE"].unique()
    #for file in filenames:
    #    print("working with file: " + file)
    #    results["by_clip"][file] = determine_confidence_by_clip(df, file, confidence_funcs)
    
    print("Get adverage over all files")
    results["Over_all_clips"] = determine_confidence_by_func(df, confidence_funcs)
        
        
    
    return results

#experiment_results = run_experiment(data, confidence_funcs)
#experiment_results

# %%
def generate_graph(experiment_results):
    for filename in experiment_results:
        #For each filename, plot the performance of each confidence function
        for confidence_func in experiment_results[filename]:
            confidence_dirc = experiment_results[filename][confidence_func]
            users_count = list(confidence_dirc.keys())
            score = list(confidence_dirc.values())
            plt.plot(users_count, score, label=(confidence_func.__name__))
        
        #Throw in some fancy formatting
        plt.legend(loc='best')
        plt.title(filename)
        plt.xlabel("User Count")
        plt.ylabel("Average Confidence of Function")
        plt.show()

#generate_graph(experiment_results["by_clip"])

# %%
def generate_graph_all(experiment_results):
    #For each filename, plot the performance of each confidence function
    for confidence_func in experiment_results:
        confidence_dirc = experiment_results[confidence_func]
        users_count = list(confidence_dirc.keys())
        score = list(confidence_dirc.values())
        plt.plot(users_count, score, label=(confidence_func.__name__))

    #Throw in some fancy formatting
    plt.legend(loc='best')
    #plt.title(filename)
    plt.xlabel("User Count")
    plt.ylabel("Average Confidence of Function")
    plt.show()
    
    
    
    
#generate_graph_all(experiment_results["Over_all_clips"])
#Experiment Failed -> To Time Complex

# %% [markdown]
# ## Experiment Design 2

# %%
def experiment_via_random_orders(df, confidence_funcs, num_of_orders=1000):
    results = {}
    users = df["LAST MOD BY"].unique()
    files = df["IN FILE"].unique()
    for func in confidence_funcs:
        results[func.__name__] = {}
        for i in range (len(users)):
            results[func.__name__][i] = []
    
    
    for file in files:
        print("on ", file, "of", len(files))
        tmp_df = df[df["IN FILE"] == file]
        users = tmp_df["LAST MOD BY"].unique()

        to_be_randomly_inserted = np.tile(users, (num_of_orders, 1))
        to_be_randomly_inserted = pd.DataFrame(to_be_randomly_inserted)
        to_be_randomly_inserted = to_be_randomly_inserted.apply(lambda x:np.random.shuffle(x) or x, axis=1)
        random_insertion_orders = to_be_randomly_inserted.values
        
        count = 0
        for insertion_order in random_insertion_orders:
            print(count)
            count += 1
            for func in confidence_funcs: 
                for user_count in range(1,len(insertion_order)):
                    curr_insert = insertion_order[:user_count+1]
                    tmp_df_users = tmp_df[tmp_df["LAST MOD BY"].isin(curr_insert)]
                    try:
                        results[func.__name__][user_count].append(func(tmp_df_users, curr_insert))
                    except:
                        pass
        json_object = json.dumps(results, indent=4)
 
        # Writing to sample.json
        with open("experiment_results.json", "w") as outfile:
            outfile.write(json_object)
    return results

#experiment_results = experiment_via_random_orders(data, confidence_funcs, 1000)
#experiment_results
#Experiment Failed -> To Time Complex

# %% [markdown]
# # Experiment 3, Work to Save Time

# %%
import time

 
confidence_funcs = [ get_silhoutte_confidence, get_silhoutte_users_confidence, fast_majority_vote, get_pairwise_iou]
confidence_funcs

def experiment_3(df, confidence_funcs, num_of_trials=10):
    results = {}
    users = df["LAST MOD BY"].unique()
    files = df["IN FILE"].unique()
    for func in confidence_funcs:
        results[func.__name__] = {}
        for i in range (len(users)):
            results[func.__name__][i] = []
        results[func.__name__]["TIMING"] = []
    
    
    for trial in range(num_of_trials):
        start = time.time()
        print("============================")
        print(trial)
        file  = np.random.choice(files, size=None, replace=True, p=None)
        tmp_df = df[df["IN FILE"] == file]
        users = tmp_df["LAST MOD BY"].unique()

        to_be_randomly_inserted = np.tile(users, (1, 1))
        to_be_randomly_inserted = pd.DataFrame(to_be_randomly_inserted)
        to_be_randomly_inserted = to_be_randomly_inserted.apply(lambda x:np.random.shuffle(x) or x, axis=1)
        random_insertion_orders = to_be_randomly_inserted.values
        
        end = time.time()
        #print("Set Up", end - start)
        
        for insertion_order in random_insertion_orders:
            for func in confidence_funcs:
                start = time.time()
                for user_count in range(1,len(insertion_order)):
                    curr_insert = insertion_order[:user_count+1]
                    tmp_df_users = tmp_df[tmp_df["LAST MOD BY"].isin(curr_insert)]
                    try:
                        results[func.__name__][user_count].append(func(tmp_df_users, curr_insert))
                    except:
                        pass
                end = time.time()
                print(func.__name__, end - start)
                results[func.__name__]["TIMING"].append(end - start)
                    
        results["TRIAL COUNT"] = trial
        json_object = json.dumps(results, indent=4)
 
        # Writing to sample.json
        with open("experiment_results.json", "w") as outfile:
            outfile.write(json_object)
        
    return results

# %%
experiment_results = experiment_3(data, confidence_funcs, num_of_trials=1000)
# Out:
# ============================
# 0
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2010211944580078
# get_silhoutte_users_confidence 0.20261645317077637
# fast_majority_vote 1.0129685401916504
# get_pairwise_iou 2.0383455753326416
# ============================
# 1
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20977783203125
# get_silhoutte_users_confidence 0.22624683380126953
# fast_majority_vote 0.8074069023132324
# get_pairwise_iou 0.8857450485229492
# ============================
# 2
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.1893296241760254
# get_silhoutte_users_confidence
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.18558573722839355
# fast_majority_vote 0.7694127559661865
# get_pairwise_iou 0.7747876644134521
# ============================
# 3
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.18690752983093262
# get_silhoutte_users_confidence 0.20603585243225098
# fast_majority_vote 1.3538732528686523
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 2.9995346069335938
# ============================
# 4
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.21597814559936523
# get_silhoutte_users_confidence 0.23611068725585938
# fast_majority_vote 0.7050673961639404
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.7127983570098877
# ============================
# 5
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20569467544555664
# get_silhoutte_users_confidence 0.2557492256164551
# fast_majority_vote 0.6207196712493896
# get_pairwise_iou 0.9542455673217773
# ============================
# 6
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.27902722358703613
# get_silhoutte_users_confidence 0.3008706569671631
# fast_majority_vote 0.8975164890289307
# get_pairwise_iou 2.5283584594726562
# ============================
# 7
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6794431209564209
# get_silhoutte_users_confidence 0.7019975185394287
# fast_majority_vote 4.639221429824829
# get_pairwise_iou 11.970397710800171
# ============================
# 8
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.18101239204406738
# get_silhoutte_users_confidence 0.18551325798034668
# fast_majority_vote 0.48836374282836914
# get_pairwise_iou 0.7902350425720215
# ============================
# 9
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3605360984802246
# get_silhoutte_users_confidence 0.37257838249206543
# fast_majority_vote 1.663597583770752
# get_pairwise_iou 3.2476308345794678
# ============================
# 10
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20709729194641113
# get_silhoutte_users_confidence 0.24098920822143555
# fast_majority_vote 0.4746863842010498
# get_pairwise_iou 0.9588193893432617
# ============================
# 11
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3366363048553467
# get_silhoutte_users_confidence 0.3484385013580322
# fast_majority_vote 0.9271280765533447
# get_pairwise_iou 1.3587989807128906
# ============================
# 12
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2702059745788574
# get_silhoutte_users_confidence 0.30705761909484863
# fast_majority_vote 0.7705352306365967
# get_pairwise_iou 2.0547263622283936
# ============================
# 13
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2187349796295166
# get_silhoutte_users_confidence 0.25508832931518555
# fast_majority_vote 0.5239367485046387
# get_pairwise_iou 0.8614211082458496
# ============================
# 14
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6830148696899414
# get_silhoutte_users_confidence 0.6366286277770996
# fast_majority_vote 4.955134391784668
# get_pairwise_iou 9.855339527130127
# ============================
# 15
# get_silhoutte_confidence 0.1093285083770752
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_users_confidence 0.10551667213439941
# fast_majority_vote 1.259913444519043
# get_pairwise_iou 2.6780662536621094
# ============================
# 16
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.5470995903015137
# get_silhoutte_users_confidence 0.5252854824066162
# fast_majority_vote 1.62636399269104
# get_pairwise_iou 3.138441801071167
# ============================
# 17
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3181140422821045
# get_silhoutte_users_confidence 0.29045534133911133
# fast_majority_vote 0.940723180770874
# get_pairwise_iou 1.8704931735992432
# ============================
# 18
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20918941497802734
# get_silhoutte_users_confidence 0.2113037109375
# fast_majority_vote 1.0542709827423096
# get_pairwise_iou 2.279087543487549
# ============================
# 19
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3614335060119629
# get_silhoutte_users_confidence 0.4046778678894043
# fast_majority_vote 0.4296839237213135
# get_pairwise_iou 0.986405611038208
# ============================
# 20
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2739541530609131
# get_silhoutte_users_confidence 0.2736043930053711
# fast_majority_vote 1.0673606395721436
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.9755752086639404
# ============================
# 21
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2681925296783447
# get_silhoutte_users_confidence 0.299210786819458
# fast_majority_vote 0.7349796295166016
# get_pairwise_iou 1.9918694496154785
# ============================
# 22
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.25681400299072266
# get_silhoutte_users_confidence 0.26633358001708984
# fast_majority_vote 1.891836166381836
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 4.8838183879852295
# ============================
# 23
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.1905977725982666
# get_silhoutte_users_confidence 0.2324085235595703
# fast_majority_vote 1.0095865726470947
# get_pairwise_iou 2.329033136367798
# ============================
# 24
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.410900354385376
# get_silhoutte_users_confidence 0.40115833282470703
# fast_majority_vote 0.9585983753204346
# get_pairwise_iou 1.4290165901184082
# ============================
# 25
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.26852941513061523
# get_silhoutte_users_confidence 0.2756037712097168
# fast_majority_vote 1.727919340133667
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 5.431126356124878
# ============================
# 26
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6481287479400635
# get_silhoutte_users_confidence 0.645517110824585
# fast_majority_vote 4.494618892669678
# get_pairwise_iou 12.639537334442139
# ============================
# 27
# get_silhoutte_confidence 0.16391825675964355
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_users_confidence 0.19737839698791504
# fast_majority_vote 0.5745832920074463
# get_pairwise_iou 0.8653087615966797
# ============================
# 28
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.1830129623413086
# get_silhoutte_users_confidence 0.21969938278198242
# fast_majority_vote 0.7004320621490479
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.0123474597930908
# ============================
# 29
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.16799664497375488
# get_silhoutte_users_confidence 0.18621587753295898
# fast_majority_vote 0.7086360454559326
# get_pairwise_iou 0.8274991512298584
# ============================
# 30
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.29018712043762207
# get_silhoutte_users_confidence 0.28128981590270996
# fast_majority_vote 0.7407786846160889
# get_pairwise_iou 2.036165475845337
# ============================
# 31
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.319594144821167
# get_silhoutte_users_confidence 0.3548409938812256
# fast_majority_vote 0.4393951892852783
# get_pairwise_iou 0.9268059730529785
# ============================
# 32
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
#  0.17525482177734375
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.2306077480316162
# fast_majority_vote 0.3743588924407959
# get_pairwise_iou 0.7308070659637451
# ============================
# 33
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6566953659057617
# get_silhoutte_users_confidence 0.6592092514038086
# fast_majority_vote 4.868250846862793

# %% [markdown]
# ## Sub work to fix Timing issues

# %%
experiment_results[confidence_funcs[2].__name__]["TIMING"]
# Out:
# [3.519599437713623,
#  3.479569911956787,
#  5.905728816986084,
#  4.7254838943481445,
#  9.114348649978638,
#  7.952856063842773,
#  3.468768358230591,
#  9.345545530319214,
#  7.214634418487549,
#  7.632327318191528]

# %%
experiment_results2 = experiment_3(data, confidence_funcs)
experiment_results2[confidence_funcs[2].__name__]["TIMING"]
# Out:
# ============================
# 0
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# set up XC605853_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.008666276931762695
# start of  Baglafecht Weaver 0.011690139770507812
# end of 1 setting in  Baglafecht Weaver 0.004025459289550781
# end of actually chunking data  Baglafecht Weaver 0.23942923545837402
# start of  bird 0.2541358470916748
# end of 1 setting in  bird 0.0025064945220947266
# end of actually chunking data  bird 0.19861745834350586
# set up XC605853_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.004512786865234375
# start of  bird 0.006863117218017578
# end of 1 setting in  bird 0.002042055130004883
# end of actually chunking data  bird 0.21465396881103516
# start of  Baglafecht Weaver 0.22351884841918945
# end of 1 setting in  Baglafecht Weaver 0.0040547847747802734
# end of actually chunking data  Baglafecht Weaver 0.20532846450805664
# set up XC605853_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.004769325256347656
# start of  Baglafecht Weaver 0.005772113800048828
# end of 1 setting in  Baglafecht Weaver 0.0035970211029052734
# end of actually chunking data  Baglafecht Weaver 0.21570110321044922
# start of  bird 0.22347331047058105
# end of 1 setting in  bird 0.002001047134399414
# end of actually chunking data  bird 0.25682783126831055
# set up XC605853_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.00574946403503418
# start of  Baglafecht Weaver 0.007262706756591797
# end of 1 setting in  Baglafecht Weaver 0.0030906200408935547
# end of actually chunking data  Baglafecht Weaver 0.2500622272491455
# start of  bird 0.2604677677154541
# end of 1 setting in  bird 0.002001523971557617
# end of actually chunking data  bird 0.28200316429138184
# set up XC605853_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.0039980411529541016
# start of  Baglafecht Weaver 0.00599360466003418
# end of 1 setting in  Baglafecht Weaver 0.003005504608154297
# end of actually chunking data  Baglafecht Weaver 0.2673938274383545
# start of  bird 0.27538013458251953
# end of 1 setting in  bird 0.002009153366088867
# end of actually chunking data  bird 0.2956864833831787
# set up XC605853_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.004663228988647461
# start of  Baglafecht Weaver 0.0066602230072021484
# end of 1 setting in  Baglafecht Weaver 0.0030028820037841797
# end of actually chunking data  Baglafecht Weaver 0.2734947204589844
# start of  bird 0.2821536064147949
# end of 1 setting in  bird 0.001997709274291992
# end of actually chunking data  bird 0.35196971893310547
# set up XC605853_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.004822969436645508
# start of  Baglafecht Weaver 0.0068454742431640625
# end of 1 setting in  Baglafecht Weaver 0.0030052661895751953
# end of actually chunking data  Baglafecht Weaver 0.3554084300994873
# start of  bird 0.3642547130584717
# end of 1 setting in  bird 0.003011465072631836
# end of actually chunking data  bird 0.33190464973449707
# ============================
# 1
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.007053852081298828
# start of  Simple Greenbul 0.009056329727172852
# end of 1 setting in  Simple Greenbul 0.005121707916259766
# end of actually chunking data  Simple Greenbul 0.5517051219940186
# set up XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005474090576171875
# start of  Simple Greenbul 0.0074803829193115234
# end of 1 setting in  Simple Greenbul 0.0035521984100341797
# end of actually chunking data  Simple Greenbul 0.6113624572753906
# start of  bird 0.6203765869140625
# end of 1 setting in  bird 0.0025780200958251953
# end of actually chunking data  bird 0.7160208225250244
# set up XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.0049953460693359375
# start of  Simple Greenbul 0.006997108459472656
# end of 1 setting in  Simple Greenbul 0.0035691261291503906
# end of actually chunking data  Simple Greenbul 0.7762296199798584
# start of  bird 0.7852268218994141
# end of 1 setting in  bird 0.003371000289916992
# end of actually chunking data  bird 0.8228921890258789
# set up XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005742788314819336
# start of  Simple Greenbul 0.007741689682006836
# end of 1 setting in  Simple Greenbul 0.004544973373413086
# end of actually chunking data  Simple Greenbul 0.9250624179840088
# start of  bird 0.9348015785217285
# end of 1 setting in  bird 0.005001544952392578
# end of actually chunking data  bird 1.014740228652954
# set up XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.006619691848754883
# start of  Simple Greenbul 0.007613420486450195
# end of 1 setting in  Simple Greenbul 0.0050699710845947266
# end of actually chunking data  Simple Greenbul 1.209761381149292
# start of  bird 1.219144582748413
# end of 1 setting in  bird 0.008597373962402344
# end of actually chunking data  bird 1.3443090915679932
# set up XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005567073822021484
# start of  Simple Greenbul 0.006563901901245117
# end of 1 setting in  Simple Greenbul 0.005558013916015625
# end of actually chunking data  Simple Greenbul 1.4177846908569336
# start of  bird 1.42686128616333
# end of 1 setting in  bird 0.009009599685668945
# end of actually chunking data  bird 1.5510990619659424
# set up XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005794048309326172
# start of  Simple Greenbul 0.008335351943969727
# end of 1 setting in  Simple Greenbul 0.0076007843017578125
# end of actually chunking data  Simple Greenbul 1.745607614517212
# start of  bird 1.7559814453125
# end of 1 setting in  bird 0.007535219192504883
# end of actually chunking data  bird 1.4424726963043213
# set up XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.00400090217590332
# start of  Simple Greenbul 0.0055522918701171875
# end of 1 setting in  Simple Greenbul 0.005815744400024414
# end of actually chunking data  Simple Greenbul 1.6947193145751953
# start of  bird 1.7024011611938477
# end of 1 setting in  bird 0.00799703598022461
# end of actually chunking data  bird 1.862119436264038
# set up XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.007935285568237305
# start of  Simple Greenbul 0.009930849075317383
# end of 1 setting in  Simple Greenbul 0.007154226303100586
# end of actually chunking data  Simple Greenbul 2.260066032409668
# start of  bird 2.271036386489868
# end of 1 setting in  bird 0.008471012115478516
# end of actually chunking data  bird 2.2650344371795654
# ============================
# 2
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.008031368255615234
# start of  White-vented Shama 0.011031866073608398
# end of 1 setting in  White-vented Shama 0.0032896995544433594
# end of actually chunking data  White-vented Shama 1.200538158416748
# start of  bird 1.213606595993042
# end of 1 setting in  bird 0.004548549652099609
# end of actually chunking data  bird 1.285998821258545
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.006547451019287109
# start of  White-vented Shama 0.00854802131652832
# end of 1 setting in  White-vented Shama 0.004706144332885742
# end of actually chunking data  White-vented Shama 1.5650944709777832
# start of  bird 1.5767006874084473
# end of 1 setting in  bird 0.005004167556762695
# end of actually chunking data  bird 1.6429898738861084
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.004002094268798828
# start of  White-vented Shama 0.007045269012451172
# end of 1 setting in  White-vented Shama 0.003038167953491211
# end of actually chunking data  White-vented Shama 1.8167848587036133
# start of  bird 1.8259077072143555
# end of 1 setting in  bird 0.004389047622680664
# end of actually chunking data  bird 1.806366205215454
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.005059003829956055
# start of  White-vented Shama 0.0070650577545166016
# end of 1 setting in  White-vented Shama 0.0035047531127929688
# end of actually chunking data  White-vented Shama 1.7930529117584229
# start of  bird 1.802117109298706
# end of 1 setting in  bird 0.0040018558502197266
# end of actually chunking data  bird 2.235335350036621
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.0055735111236572266
# start of  White-vented Shama 0.0075724124908447266
# end of 1 setting in  White-vented Shama 0.0035140514373779297
# end of actually chunking data  White-vented Shama 2.2965736389160156
# start of  bird 2.3061928749084473
# end of 1 setting in  bird 0.005017280578613281
# end of actually chunking data  bird 2.2647006511688232
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.005233287811279297
# start of  White-vented Shama 0.006231069564819336
# end of 1 setting in  White-vented Shama 0.004125356674194336
# end of actually chunking data  White-vented Shama 2.2500503063201904
# start of  bird 2.258281707763672
# end of 1 setting in  bird 0.004994630813598633
# end of actually chunking data  bird 2.9045937061309814
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.007624149322509766
# start of  White-vented Shama 0.010623693466186523
# end of 1 setting in  White-vented Shama 0.0065724849700927734
# end of actually chunking data  White-vented Shama 3.055145740509033
# start of  bird 3.067805528640747
# end of 1 setting in  bird 0.004631996154785156
# end of actually chunking data  bird 3.1844680309295654
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.004773378372192383
# start of  White-vented Shama 0.005799531936645508
# end of 1 setting in  White-vented Shama 0.005509853363037109
# end of actually chunking data  White-vented Shama 3.2785627841949463
# start of  bird 3.2869458198547363
# end of 1 setting in  bird 0.007582664489746094
# end of actually chunking data  bird 3.82214617729187
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.005126953125
# start of  White-vented Shama 0.007971763610839844
# end of 1 setting in  White-vented Shama 0.005005598068237305
# end of actually chunking data  White-vented Shama 3.5380327701568604
# start of  bird 3.5480363368988037
# end of 1 setting in  bird 0.0049974918365478516
# end of actually chunking data  bird 3.7177248001098633
# ============================
# 3
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.008517980575561523
# start of  No class of interest 0.010518312454223633
# end of 1 setting in  No class of interest 0.0035467147827148438
# end of actually chunking data  No class of interest 0.34334397315979004
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.012102365493774414
# start of  Simple Greenbul 0.014269590377807617
# end of 1 setting in  Simple Greenbul 0.0028829574584960938
# end of actually chunking data  Simple Greenbul 0.33466267585754395
# start of  No class of interest 0.35102081298828125
# end of 1 setting in  No class of interest 0.002505779266357422
# end of actually chunking data  No class of interest 0.34084391593933105
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.006067514419555664
# start of  Simple Greenbul 0.00830698013305664
# end of 1 setting in  Simple Greenbul 0.002509593963623047
# end of actually chunking data  Simple Greenbul 0.34572362899780273
# start of  bird 0.3560292720794678
# end of 1 setting in  bird 0.002549409866333008
# end of actually chunking data  bird 0.39484500885009766
# start of  No class of interest 0.7535223960876465
# end of 1 setting in  No class of interest 0.0010242462158203125
# end of actually chunking data  No class of interest 0.3470752239227295
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.00811624526977539
# start of  Simple Greenbul 0.010664701461791992
# end of 1 setting in  Simple Greenbul 0.0035343170166015625
# end of actually chunking data  Simple Greenbul 0.42578864097595215
# start of  bird 0.43845486640930176
# end of 1 setting in  bird 0.003195524215698242
# end of actually chunking data  bird 0.4548301696777344
# start of  No class of interest 0.8962860107421875
# end of 1 setting in  No class of interest 0.0028595924377441406
# end of actually chunking data  No class of interest 0.4308185577392578
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.0049593448638916016
# start of  Simple Greenbul 0.007501125335693359
# end of 1 setting in  Simple Greenbul 0.002996206283569336
# end of actually chunking data  Simple Greenbul 0.4979708194732666
# start of  White-vented Shama 0.5074653625488281
# end of 1 setting in  White-vented Shama 0.002512693405151367
# end of actually chunking data  White-vented Shama 0.499330997467041
# start of  bird 1.009526252746582
# end of 1 setting in  bird 0.0030007362365722656
# end of actually chunking data  bird 0.49219274520874023
# start of  No class of interest 1.5037264823913574
# end of 1 setting in  No class of interest 0.004000186920166016
# end of actually chunking data  No class of interest 0.5597019195556641
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.006538867950439453
# start of  Simple Greenbul 0.008049249649047852
# end of 1 setting in  Simple Greenbul 0.0025398731231689453
# end of actually chunking data  Simple Greenbul 0.5273926258087158
# start of  White-vented Shama 0.5369703769683838
# end of 1 setting in  White-vented Shama 0.00302886962890625
# end of actually chunking data  White-vented Shama 0.5629680156707764
# start of  bird 1.1019394397735596
# end of 1 setting in  bird 0.0019998550415039062
# end of actually chunking data  bird 0.5147707462310791
# start of  No class of interest 1.617706537246704
# end of 1 setting in  No class of interest 0.0025119781494140625
# end of actually chunking data  No class of interest 0.4480171203613281
# ============================
# 4
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.007028102874755859
# start of  Balearic Warbler 0.010069847106933594
# end of 1 setting in  Balearic Warbler 0.004683971405029297
# end of actually chunking data  Balearic Warbler 0.46582746505737305
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.005621671676635742
# start of  Balearic Warbler 0.0076448917388916016
# end of 1 setting in  Balearic Warbler 0.004000663757324219
# end of actually chunking data  Balearic Warbler 0.7274284362792969
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.006133079528808594
# start of  Balearic Warbler 0.009037256240844727
# end of 1 setting in  Balearic Warbler 0.00412297248840332
# end of actually chunking data  Balearic Warbler 0.726407527923584
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.005769968032836914
# start of  Balearic Warbler 0.006771087646484375
# end of 1 setting in  Balearic Warbler 0.006553173065185547
# end of actually chunking data  Balearic Warbler 1.025329351425171
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.007569313049316406
# start of  Balearic Warbler 0.009093999862670898
# end of 1 setting in  Balearic Warbler 0.00456547737121582
# end of actually chunking data  Balearic Warbler 0.9802193641662598
# start of  bird 0.991877555847168
# end of 1 setting in  bird 0.0019960403442382812
# end of actually chunking data  bird 1.1825220584869385
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.004996776580810547
# start of  Balearic Warbler 0.007035970687866211
# end of 1 setting in  Balearic Warbler 0.004021406173706055
# end of actually chunking data  Balearic Warbler 1.1198809146881104
# start of  bird 1.1279213428497314
# end of 1 setting in  bird 0.0019996166229248047
# end of actually chunking data  bird 1.1279833316802979
# ============================
# 5
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.004614830017089844
# start of  bird 0.007616758346557617
# end of 1 setting in  bird 0.0030002593994140625
# end of actually chunking data  bird 0.2586822509765625
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.0070705413818359375
# start of  bird 0.009362220764160156
# end of 1 setting in  bird 0.004033327102661133
# end of actually chunking data  bird 0.41284680366516113
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.004002094268798828
# start of  bird 0.006000995635986328
# end of 1 setting in  bird 0.003833293914794922
# end of actually chunking data  bird 0.5628962516784668
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.00996088981628418
# start of  bird 0.010959148406982422
# end of 1 setting in  bird 0.004553318023681641
# end of actually chunking data  bird 0.49770545959472656
# start of  Baglafecht Weaver 0.5106267929077148
# end of 1 setting in  Baglafecht Weaver 0.0025103092193603516
# end of actually chunking data  Baglafecht Weaver 0.4586162567138672
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.010896682739257812
# start of  bird 0.013149499893188477
# end of 1 setting in  bird 0.005240678787231445
# end of actually chunking data  bird 0.7149529457092285
# start of  Baglafecht Weaver 0.7304706573486328
# end of 1 setting in  Baglafecht Weaver 0.0025479793548583984
# end of actually chunking data  Baglafecht Weaver 0.5846240520477295
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.006108522415161133
# start of  bird 0.007618427276611328
# end of 1 setting in  bird 0.0029022693634033203
# end of actually chunking data  bird 0.6595368385314941
# start of  Baglafecht Weaver 0.6671552658081055
# end of 1 setting in  Baglafecht Weaver 0.0035398006439208984
# end of actually chunking data  Baglafecht Weaver 0.6419246196746826
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.0040013790130615234
# start of  bird 0.006216526031494141
# end of 1 setting in  bird 0.002541065216064453
# end of actually chunking data  bird 0.7496068477630615
# start of  Baglafecht Weaver 0.757819652557373
# end of 1 setting in  Baglafecht Weaver 0.0031828880310058594
# end of actually chunking data  Baglafecht Weaver 0.8121795654296875
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.0070648193359375
# start of  Baglafecht Weaver 0.008098602294921875
# end of 1 setting in  Baglafecht Weaver 0.0041351318359375
# end of actually chunking data  Baglafecht Weaver 0.9955863952636719
# start of  bird 1.0056827068328857
# end of 1 setting in  bird 0.004126071929931641
# end of actually chunking data  bird 0.9570372104644775
# ============================
# 6
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.009570598602294922
# start of  Baglafecht Weaver 0.011076211929321289
# end of 1 setting in  Baglafecht Weaver 0.004036903381347656
# end of actually chunking data  Baglafecht Weaver 0.39473438262939453
# start of  bird 0.40781188011169434
# end of 1 setting in  bird 0.0027039051055908203
# end of actually chunking data  bird 0.5334200859069824
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.01664423942565918
# start of  bird 0.01864314079284668
# end of 1 setting in  bird 0.004870414733886719
# end of actually chunking data  bird 0.48951077461242676
# start of  Baglafecht Weaver 0.5101497173309326
# end of 1 setting in  Baglafecht Weaver 0.0029954910278320312
# end of actually chunking data  Baglafecht Weaver 0.4480857849121094
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.007527828216552734
# start of  bird 0.010560750961303711
# end of 1 setting in  bird 0.004155158996582031
# end of actually chunking data  bird 0.477710485458374
# start of  Baglafecht Weaver 0.49027347564697266
# end of 1 setting in  Baglafecht Weaver 0.0030717849731445312
# end of actually chunking data  Baglafecht Weaver 0.47742605209350586
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.005636692047119141
# start of  bird 0.007143735885620117
# end of 1 setting in  bird 0.003548860549926758
# end of actually chunking data  bird 0.5227987766265869
# start of  Baglafecht Weaver 0.5319366455078125
# end of 1 setting in  Baglafecht Weaver 0.0030012130737304688
# end of actually chunking data  Baglafecht Weaver 0.5208711624145508
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.0059986114501953125
# start of  bird 0.008544921875
# end of 1 setting in  bird 0.0025424957275390625
# end of actually chunking data  bird 0.6962158679962158
# start of  Baglafecht Weaver 0.7067546844482422
# end of 1 setting in  Baglafecht Weaver 0.0035123825073242188
# end of actually chunking data  Baglafecht Weaver 0.6369259357452393
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.006070852279663086
# start of  bird 0.008069038391113281
# end of 1 setting in  bird 0.0028848648071289062
# end of actually chunking data  bird 0.731835126876831
# start of  Baglafecht Weaver 0.7418990135192871
# end of 1 setting in  Baglafecht Weaver 0.0037419795989990234
# end of actually chunking data  Baglafecht Weaver 0.750842809677124
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.00579380989074707
# start of  Baglafecht Weaver 0.007797718048095703
# end of 1 setting in  Baglafecht Weaver 0.0033495426177978516
# end of actually chunking data  Baglafecht Weaver 0.7821941375732422
# start of  bird 0.7909903526306152
# end of 1 setting in  bird 0.004345893859863281
# end of actually chunking data  bird 0.8021194934844971
# set up XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3 0.006780147552490234
# start of  Baglafecht Weaver 0.007780313491821289
# end of 1 setting in  Baglafecht Weaver 0.0041656494140625
# end of actually chunking data  Baglafecht Weaver 1.1490662097930908
# start of  bird 1.1588449478149414
# end of 1 setting in  bird 0.004349708557128906
# end of actually chunking data  bird 1.03883957862854
# ============================
# 7
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC269330_-_White-vented_Shama_-_Copsychus_niger.mp3 0.010544300079345703
# start of  White-vented Shama 0.013541698455810547
# end of 1 setting in  White-vented Shama 0.005595684051513672
# end of actually chunking data  White-vented Shama 1.3290855884552002
# start of  bird 1.3461697101593018
# end of 1 setting in  bird 0.0031685829162597656
# end of actually chunking data  bird 1.1342203617095947
# set up XC269330_-_White-vented_Shama_-_Copsychus_niger.mp3 0.006550312042236328
# start of  White-vented Shama 0.009345054626464844
# end of 1 setting in  White-vented Shama 0.005356311798095703
# end of actually chunking data  White-vented Shama 1.2429783344268799
# start of  bird 1.2558314800262451
# end of 1 setting in  bird 0.0020368099212646484
# end of actually chunking data  bird 1.1410276889801025
# set up XC269330_-_White-vented_Shama_-_Copsychus_niger.mp3 0.005524158477783203
# start of  White-vented Shama 0.007934093475341797
# end of 1 setting in  White-vented Shama 0.005010128021240234
# end of actually chunking data  White-vented Shama 0.9722714424133301
# start of  bird 0.9822025299072266
# end of 1 setting in  bird 0.0023131370544433594
# end of actually chunking data  bird 1.1786582469940186
# set up XC269330_-_White-vented_Shama_-_Copsychus_niger.mp3 0.004534721374511719
# start of  White-vented Shama 0.006529808044433594
# end of 1 setting in  White-vented Shama 0.004000663757324219
# end of actually chunking data  White-vented Shama 1.1263372898101807
# start of  bird 1.1354601383209229
# end of 1 setting in  bird 0.003998279571533203
# end of actually chunking data  bird 1.1940271854400635
# set up XC269330_-_White-vented_Shama_-_Copsychus_niger.mp3 0.004387855529785156
# start of  White-vented Shama 0.00641179084777832
# end of 1 setting in  White-vented Shama 0.004003763198852539
# end of actually chunking data  White-vented Shama 1.4938857555389404
# start of  bird 1.5028502941131592
# end of 1 setting in  bird 0.0030412673950195312
# end of actually chunking data  bird 1.5126745700836182
# set up XC269330_-_White-vented_Shama_-_Copsychus_niger.mp3 0.005055665969848633
# start of  White-vented Shama 0.007089853286743164
# end of 1 setting in  White-vented Shama 0.006173849105834961
# end of actually chunking data  White-vented Shama 1.7598893642425537
# start of  bird 1.7690117359161377
# end of 1 setting in  bird 0.003000497817993164
# end of actually chunking data  bird 1.5384025573730469
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# ============================
# 8
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.008110284805297852
# start of  Simple Greenbul 0.011120796203613281
# end of 1 setting in  Simple Greenbul 0.002037525177001953
# end of actually chunking data  Simple Greenbul 0.3258554935455322
# start of  bird 0.3395240306854248
# end of 1 setting in  bird 0.002996683120727539
# end of actually chunking data  bird 0.2677643299102783
# start of  No class of interest 0.6103153228759766
# end of 1 setting in  No class of interest 0.002254962921142578
# end of actually chunking data  No class of interest 0.3115839958190918
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.011565923690795898
# start of  Simple Greenbul 0.014114856719970703
# end of 1 setting in  Simple Greenbul 0.0029990673065185547
# end of actually chunking data  Simple Greenbul 0.3393893241882324
# start of  bird 0.3555026054382324
# end of 1 setting in  bird 0.002996683120727539
# end of actually chunking data  bird 0.31445837020874023
# start of  No class of interest 0.6719660758972168
# end of 1 setting in  No class of interest 0.001997709274291992
# end of actually chunking data  No class of interest 0.312427282333374
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.007609367370605469
# start of  Simple Greenbul 0.008771181106567383
# end of 1 setting in  Simple Greenbul 0.004288434982299805
# end of actually chunking data  Simple Greenbul 0.37570762634277344
# start of  bird 0.3860306739807129
# end of 1 setting in  bird 0.003003358840942383
# end of actually chunking data  bird 0.4268374443054199
# start of  No class of interest 0.814887523651123
# end of 1 setting in  No class of interest 0.0025908946990966797
# end of actually chunking data  No class of interest 0.32904577255249023
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005006551742553711
# start of  Simple Greenbul 0.0065135955810546875
# end of 1 setting in  Simple Greenbul 0.003031492233276367
# end of actually chunking data  Simple Greenbul 0.41483521461486816
# start of  White-vented Shama 0.4225480556488037
# end of 1 setting in  White-vented Shama 0.0030777454376220703
# end of actually chunking data  White-vented Shama 0.45955848693847656
# start of  bird 0.8841061592102051
# end of 1 setting in  bird 0.0019974708557128906
# end of actually chunking data  bird 0.4649696350097656
# start of  No class of interest 1.3510777950286865
# end of 1 setting in  No class of interest 0.0019958019256591797
# end of actually chunking data  No class of interest 0.4235107898712158
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.007184267044067383
# start of  Simple Greenbul 0.009184122085571289
# end of 1 setting in  Simple Greenbul 0.002995729446411133
# end of actually chunking data  Simple Greenbul 0.38658809661865234
# start of  White-vented Shama 0.39577221870422363
# end of 1 setting in  White-vented Shama 0.0032286643981933594
# end of actually chunking data  White-vented Shama 0.4609823226928711
# start of  bird 0.8592774868011475
# end of 1 setting in  bird 0.0015537738800048828
# end of actually chunking data  bird 0.4281580448150635
# start of  No class of interest 1.2894330024719238
# end of 1 setting in  No class of interest 0.0020046234130859375
# end of actually chunking data  No class of interest 0.42896199226379395
# set up XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005063533782958984
# start of  Simple Greenbul 0.007143735885620117
# end of 1 setting in  Simple Greenbul 0.003000497817993164
# end of actually chunking data  Simple Greenbul 0.45850038528442383
# start of  White-vented Shama 0.46818995475769043
# end of 1 setting in  White-vented Shama 0.0028514862060546875
# end of actually chunking data  White-vented Shama 0.5438656806945801
# start of  bird 1.0146045684814453
# end of 1 setting in  bird 0.003036975860595703
# end of actually chunking data  bird 0.46763014793395996
# start of  No class of interest 1.4842360019683838
# end of 1 setting in  No class of interest 0.002997159957885742
# end of actually chunking data  No class of interest 0.47885990142822266
# ============================
# 9
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.0076138973236083984
# start of  Silvery-flanked Antwren 0.009618520736694336
# end of 1 setting in  Silvery-flanked Antwren 0.002995729446411133
# end of actually chunking data  Silvery-flanked Antwren 0.7700331211090088
# start of  bird 0.7816605567932129
# end of 1 setting in  bird 0.0035848617553710938
# end of actually chunking data  bird 0.6550476551055908
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.007135152816772461
# start of  Silvery-flanked Antwren 0.008134841918945312
# end of 1 setting in  Silvery-flanked Antwren 0.003507375717163086
# end of actually chunking data  Silvery-flanked Antwren 0.668079137802124
# start of  White-vented Shama 0.679269552230835
# end of 1 setting in  White-vented Shama 0.0029993057250976562
# end of actually chunking data  White-vented Shama 0.9368999004364014
# start of  bird 1.6181681156158447
# end of 1 setting in  bird 0.004786014556884766
# end of actually chunking data  bird 0.7192845344543457
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.006551265716552734
# start of  Silvery-flanked Antwren 0.009055614471435547
# end of 1 setting in  Silvery-flanked Antwren 0.004567146301269531
# end of actually chunking data  Silvery-flanked Antwren 0.8877050876617432
# start of  White-vented Shama 0.8993082046508789
# end of 1 setting in  White-vented Shama 0.0020415782928466797
# end of actually chunking data  White-vented Shama 0.7013027667999268
# start of  bird 1.6026029586791992
# end of 1 setting in  bird 0.0031366348266601562
# end of actually chunking data  bird 0.7328095436096191
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.0049326419830322266
# start of  Silvery-flanked Antwren 0.006438493728637695
# end of 1 setting in  Silvery-flanked Antwren 0.0030362606048583984
# end of actually chunking data  Silvery-flanked Antwren 0.8364300727844238
# start of  White-vented Shama 0.844374418258667
# end of 1 setting in  White-vented Shama 0.002029895782470703
# end of actually chunking data  White-vented Shama 0.9972922801971436
# start of  bird 1.8447937965393066
# end of 1 setting in  bird 0.0040988922119140625
# end of actually chunking data  bird 0.9342000484466553
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.006581783294677734
# start of  Silvery-flanked Antwren 0.00757908821105957
# end of 1 setting in  Silvery-flanked Antwren 0.004004001617431641
# end of actually chunking data  Silvery-flanked Antwren 1.0661332607269287
# start of  White-vented Shama 1.0762524604797363
# end of 1 setting in  White-vented Shama 0.0019965171813964844
# end of actually chunking data  White-vented Shama 1.001960277557373
# start of  bird 2.0802133083343506
# end of 1 setting in  bird 0.0030002593994140625
# end of actually chunking data  bird 1.238729476928711
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.007153034210205078
# start of  Silvery-flanked Antwren 0.009154319763183594
# end of 1 setting in  Silvery-flanked Antwren 0.005217790603637695
# end of actually chunking data  Silvery-flanked Antwren 1.3579826354980469
# start of  White-vented Shama 1.369701862335205
# end of 1 setting in  White-vented Shama 0.003022432327270508
# end of actually chunking data  White-vented Shama 1.3869414329528809
# start of  bird 2.7586400508880615
# end of 1 setting in  bird 0.004068136215209961
# end of actually chunking data  bird 1.2596924304962158
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.005000114440917969
# start of  Silvery-flanked Antwren 0.006110429763793945
# end of 1 setting in  Silvery-flanked Antwren 0.005009651184082031
# end of actually chunking data  Silvery-flanked Antwren 1.4873619079589844
# start of  White-vented Shama 1.4955644607543945
# end of 1 setting in  White-vented Shama 0.002093791961669922
# end of actually chunking data  White-vented Shama 1.6267969608306885
# start of  bird 3.1257216930389404
# end of 1 setting in  bird 0.004539966583251953
# end of actually chunking data  bird 1.5328097343444824
# [3.9969019889831543,
#  23.06023859977722,
#  45.17600226402283,
#  7.842414379119873,
#  7.761072635650635,
#  8.76610803604126,
#  10.994413375854492,
#  16.155023097991943,
#  8.743360996246338,
#  21.404006958007812]

# %%
confidence_funcs
# Out:
# [<function confidence_functions.confidence.get_silhoutte_confidence(df, users)>,
#  <function confidence_functions.confidence.get_silhoutte_users_confidence(df, users)>,
#  <function confidence_functions.confidence.majority_vote(df, users, chunk_length=1)>,
#  <function confidence_functions.confidence.get_pairwise_iou(df, users)>]

# %%
from confidence_functions.confidence import *
experiment_results3 = experiment_3(data, [majority_vote, fast_majority_vote])
print(experiment_results3[majority_vote.__name__]["TIMING"])
print(experiment_results3[fast_majority_vote.__name__]["TIMING"])
# Out:
# ============================
# 0
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC688945_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.0055925846099853516
# start of  Balearic Warbler 0.006585836410522461
# end of 1 setting in  Balearic Warbler 0.002002716064453125
# end of actually chunking data  Balearic Warbler 0.21265554428100586
# set up XC688945_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.0045320987701416016
# start of  Balearic Warbler 0.005534648895263672
# end of 1 setting in  Balearic Warbler 0.0029973983764648438
# end of actually chunking data  Balearic Warbler 0.28162074089050293
# set up XC688945_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.006118297576904297
# start of  Balearic Warbler 0.008127689361572266
# end of 1 setting in  Balearic Warbler 0.0025053024291992188
# end of actually chunking data  Balearic Warbler 0.43256545066833496
# set up XC688945_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.005080699920654297
# start of  Balearic Warbler 0.007078647613525391
# end of 1 setting in  Balearic Warbler 0.001999378204345703
# end of actually chunking data  Balearic Warbler 0.47951531410217285
# set up XC688945_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.004526853561401367
# start of  Balearic Warbler 0.006036281585693359
# end of 1 setting in  Balearic Warbler 0.0015277862548828125
# end of actually chunking data  Balearic Warbler 0.4692819118499756
# start of  No class of interest 0.4778275489807129
# end of 1 setting in  No class of interest 0.0025763511657714844
# end of actually chunking data  No class of interest 0.14084672927856445
# set up XC688945_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.005031585693359375
# start of  Balearic Warbler 0.006036043167114258
# end of 1 setting in  Balearic Warbler 0.0010967254638671875
# end of actually chunking data  Balearic Warbler 0.505091667175293
# start of  Baglafecht Weaver 0.5141253471374512
# end of 1 setting in  Baglafecht Weaver 0.002846240997314453
# end of actually chunking data  Baglafecht Weaver 0.04241538047790527
# start of  No class of interest 0.5585339069366455
# end of 1 setting in  No class of interest 0.00200653076171875
# end of actually chunking data  No class of interest 0.11818480491638184
# set up XC688945_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.004002571105957031
# start of  Balearic Warbler 0.007001161575317383
# end of 1 setting in  Balearic Warbler 0.0019991397857666016
# end of actually chunking data  Balearic Warbler 0.5499153137207031
# start of  Baglafecht Weaver 0.5589151382446289
# end of 1 setting in  Baglafecht Weaver 0.0009963512420654297
# end of actually chunking data  Baglafecht Weaver 0.04081153869628906
# start of  No class of interest 0.6017508506774902
# end of 1 setting in  No class of interest 0.0019986629486083984
# end of actually chunking data  No class of interest 0.12608718872070312
# ============================
# 1
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.0050563812255859375
# start of  bird 0.007055044174194336
# end of 1 setting in  bird 0.001003265380859375
# end of actually chunking data  bird 0.4130854606628418
# start of  Silvery-flanked Antwren 0.42014050483703613
# end of 1 setting in  Silvery-flanked Antwren 0.0009992122650146484
# end of actually chunking data  Silvery-flanked Antwren 0.19394969940185547
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.0065250396728515625
# start of  bird 0.008527994155883789
# end of 1 setting in  bird 0.003088712692260742
# end of actually chunking data  bird 0.4390382766723633
# start of  Silvery-flanked Antwren 0.44956493377685547
# end of 1 setting in  Silvery-flanked Antwren 0.003002166748046875
# end of actually chunking data  Silvery-flanked Antwren 0.43619251251220703
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.008558273315429688
# start of  bird 0.011560916900634766
# end of 1 setting in  bird 0.003004312515258789
# end of actually chunking data  bird 0.532468318939209
# start of  Silvery-flanked Antwren 0.546118974685669
# end of 1 setting in  Silvery-flanked Antwren 0.0030024051666259766
# end of actually chunking data  Silvery-flanked Antwren 0.3744547367095947
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.004574775695800781
# start of  Silvery-flanked Antwren 0.0067636966705322266
# end of 1 setting in  Silvery-flanked Antwren 0.002019643783569336
# end of actually chunking data  Silvery-flanked Antwren 0.5126290321350098
# start of  bird 0.5223979949951172
# end of 1 setting in  bird 0.001997709274291992
# end of actually chunking data  bird 0.5185322761535645
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.0050046443939208984
# start of  Silvery-flanked Antwren 0.0075528621673583984
# end of 1 setting in  Silvery-flanked Antwren 0.0025115013122558594
# end of actually chunking data  Silvery-flanked Antwren 0.7057228088378906
# start of  bird 0.7156734466552734
# end of 1 setting in  bird 0.001999378204345703
# end of actually chunking data  bird 0.6071741580963135
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.004374265670776367
# start of  Silvery-flanked Antwren 0.00537419319152832
# end of 1 setting in  Silvery-flanked Antwren 0.002996683120727539
# end of actually chunking data  Silvery-flanked Antwren 0.8450267314910889
# start of  bird 0.8523914813995361
# end of 1 setting in  bird 0.0031092166900634766
# end of actually chunking data  bird 0.6808207035064697
# set up XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3 0.00499725341796875
# start of  Silvery-flanked Antwren 0.006995677947998047
# end of 1 setting in  Silvery-flanked Antwren 0.002000570297241211
# end of actually chunking data  Silvery-flanked Antwren 0.9544343948364258
# start of  White-vented Shama 0.9639875888824463
# end of 1 setting in  White-vented Shama 0.0019989013671875
# end of actually chunking data  White-vented Shama 0.11236906051635742
# start of  bird 1.078348159790039
# end of 1 setting in  bird 0.002677440643310547
# end of actually chunking data  bird 0.6828584671020508
# ============================
# 2
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.0054776668548583984
# start of  Balearic Warbler 0.008481264114379883
# end of 1 setting in  Balearic Warbler 0.0029952526092529297
# end of actually chunking data  Balearic Warbler 0.40477991104125977
# start of  bird 0.41526150703430176
# end of 1 setting in  bird 0.0020074844360351562
# end of actually chunking data  bird 0.09603047370910645
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.00516963005065918
# start of  Balearic Warbler 0.0061740875244140625
# end of 1 setting in  Balearic Warbler 0.002593994140625
# end of actually chunking data  Balearic Warbler 0.38513994216918945
# start of  bird 0.39331531524658203
# end of 1 setting in  bird 0.003004312515258789
# end of actually chunking data  bird 0.33802199363708496
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.004856109619140625
# start of  Balearic Warbler 0.005861043930053711
# end of 1 setting in  Balearic Warbler 0.00223541259765625
# end of actually chunking data  Balearic Warbler 0.518671989440918
# start of  bird 0.5276310443878174
# end of 1 setting in  bird 0.0020008087158203125
# end of actually chunking data  bird 0.29700541496276855
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.00828242301940918
# start of  Balearic Warbler 0.010282516479492188
# end of 1 setting in  Balearic Warbler 0.0024373531341552734
# end of actually chunking data  Balearic Warbler 0.7622747421264648
# start of  bird 0.7756991386413574
# end of 1 setting in  bird 0.0030727386474609375
# end of actually chunking data  bird 0.32173895835876465
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.007132768630981445
# start of  Balearic Warbler 0.009139776229858398
# end of 1 setting in  Balearic Warbler 0.0028405189514160156
# end of actually chunking data  Balearic Warbler 0.9207594394683838
# start of  bird 0.9319427013397217
# end of 1 setting in  bird 0.000997781753540039
# end of actually chunking data  bird 0.2849740982055664
# set up XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3 0.0050334930419921875
# start of  Balearic Warbler 0.007322788238525391
# end of 1 setting in  Balearic Warbler 0.001005411148071289
# end of actually chunking data  Balearic Warbler 1.0031278133392334
# start of  bird 1.0129568576812744
# end of 1 setting in  bird 0.0011110305786132812
# end of actually chunking data  bird 0.3101627826690674
# ============================
# 3
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC402101_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005466938018798828
# start of  Simple Greenbul 0.008048534393310547
# end of 1 setting in  Simple Greenbul 0.0020394325256347656
# end of actually chunking data  Simple Greenbul 0.18930792808532715
# start of  bird 0.19835495948791504
# end of 1 setting in  bird 0.0009980201721191406
# end of actually chunking data  bird 0.3266885280609131
# set up XC402101_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.007280826568603516
# start of  Simple Greenbul 0.009284734725952148
# end of 1 setting in  Simple Greenbul 0.0019960403442382812
# end of actually chunking data  Simple Greenbul 0.2800605297088623
# start of  bird 0.2915163040161133
# end of 1 setting in  bird 0.0029964447021484375
# end of actually chunking data  bird 0.3762626647949219
# set up XC402101_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005507707595825195
# start of  Simple Greenbul 0.007548093795776367
# end of 1 setting in  Simple Greenbul 0.0019979476928710938
# end of actually chunking data  Simple Greenbul 0.3558382987976074
# start of  bird 0.3653850555419922
# end of 1 setting in  bird 0.0021729469299316406
# end of actually chunking data  bird 0.4057910442352295
# start of  White-vented Shama 0.7732045650482178
# end of 1 setting in  White-vented Shama 0.0019969940185546875
# end of actually chunking data  White-vented Shama 0.09590721130371094
# set up XC402101_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.0053369998931884766
# start of  Simple Greenbul 0.007338762283325195
# end of 1 setting in  Simple Greenbul 0.0009944438934326172
# end of actually chunking data  Simple Greenbul 0.31983137130737305
# start of  bird 0.33022522926330566
# end of 1 setting in  bird 0.002003908157348633
# end of actually chunking data  bird 0.5087242126464844
# start of  White-vented Shama 0.841001033782959
# end of 1 setting in  White-vented Shama 0.002354145050048828
# end of actually chunking data  White-vented Shama 0.10541677474975586
# set up XC402101_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.00518798828125
# start of  Simple Greenbul 0.00718998908996582
# end of 1 setting in  Simple Greenbul 0.0010972023010253906
# end of actually chunking data  Simple Greenbul 0.34264302253723145
# start of  bird 0.3529644012451172
# end of 1 setting in  bird 0.0019958019256591797
# end of actually chunking data  bird 0.6465921401977539
# start of  White-vented Shama 1.0025994777679443
# end of 1 setting in  White-vented Shama 0.0029397010803222656
# end of actually chunking data  White-vented Shama 0.11998653411865234
# set up XC402101_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.004603147506713867
# start of  Simple Greenbul 0.005608320236206055
# end of 1 setting in  Simple Greenbul 0.0009975433349609375
# end of actually chunking data  Simple Greenbul 0.48659586906433105
# start of  bird 0.4947504997253418
# end of 1 setting in  bird 0.001996278762817383
# end of actually chunking data  bird 0.7088358402252197
# start of  White-vented Shama 1.2055835723876953
# end of 1 setting in  White-vented Shama 0.0022301673889160156
# end of actually chunking data  White-vented Shama 0.09081745147705078
# set up XC402101_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005545377731323242
# start of  Simple Greenbul 0.006545305252075195
# end of 1 setting in  Simple Greenbul 0.002541780471801758
# end of actually chunking data  Simple Greenbul 0.571246862411499
# start of  bird 0.5797939300537109
# end of 1 setting in  bird 0.0023407936096191406
# end of actually chunking data  bird 0.8281831741333008
# start of  White-vented Shama 1.4104855060577393
# end of 1 setting in  White-vented Shama 0.0020341873168945312
# end of actually chunking data  White-vented Shama 0.11170625686645508
# ============================
# 4
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC350114_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.00707697868347168
# start of  bird 0.009584426879882812
# end of 1 setting in  bird 0.0025844573974609375
# end of actually chunking data  bird 0.18021702766418457
# set up XC350114_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.0045621395111083984
# start of  Simple Greenbul 0.0065577030181884766
# end of 1 setting in  Simple Greenbul 0.0027456283569335938
# end of actually chunking data  Simple Greenbul 0.14618253707885742
# start of  bird 0.1550154685974121
# end of 1 setting in  bird 0.0020036697387695312
# end of actually chunking data  bird 0.1594092845916748
# set up XC350114_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005569934844970703
# start of  Simple Greenbul 0.006600141525268555
# end of 1 setting in  Simple Greenbul 0.0029997825622558594
# end of actually chunking data  Simple Greenbul 0.15090060234069824
# start of  bird 0.15898990631103516
# end of 1 setting in  bird 0.0010058879852294922
# end of actually chunking data  bird 0.16191649436950684
# set up XC350114_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.003517627716064453
# start of  Simple Greenbul 0.005045413970947266
# end of 1 setting in  Simple Greenbul 0.0
# end of actually chunking data  Simple Greenbul 0.19039535522460938
# start of  bird 0.19643926620483398
# end of 1 setting in  bird 0.002794981002807617
# end of actually chunking data  bird 0.1615467071533203
# set up XC350114_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.005505084991455078
# start of  Simple Greenbul 0.006033420562744141
# end of 1 setting in  Simple Greenbul 0.0010154247283935547
# end of actually chunking data  Simple Greenbul 0.21855950355529785
# start of  bird 0.22757458686828613
# end of 1 setting in  bird 0.0020711421966552734
# end of actually chunking data  bird 0.1584620475769043
# set up XC350114_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.004624605178833008
# start of  Simple Greenbul 0.0056192874908447266
# end of 1 setting in  Simple Greenbul 0.0
# end of actually chunking data  Simple Greenbul 0.2766602039337158
# start of  bird 0.28431248664855957
# end of 1 setting in  bird 0.0025484561920166016
# end of actually chunking data  bird 0.1833951473236084
# set up XC350114_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.004058361053466797
# start of  Simple Greenbul 0.0050640106201171875
# end of 1 setting in  Simple Greenbul 0.0009975433349609375
# end of actually chunking data  Simple Greenbul 0.2958865165710449
# start of  bird 0.3029472827911377
# end of 1 setting in  bird 0.0025146007537841797
# end of actually chunking data  bird 0.19977760314941406
# set up XC350114_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3 0.004007816314697266
# start of  Simple Greenbul 0.007098197937011719
# end of 1 setting in  Simple Greenbul 0.002035379409790039
# end of actually chunking data  Simple Greenbul 0.3488776683807373
# start of  bird 0.35808467864990234
# end of 1 setting in  bird 0.001995563507080078
# end of actually chunking data  bird 0.23365020751953125
# ============================
# 5
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.006821393966674805
# start of  bird 0.00989222526550293
# end of 1 setting in  bird 0.002009153366088867
# end of actually chunking data  bird 0.19445228576660156
# start of  Silvery-flanked Antwren 0.20534515380859375
# end of 1 setting in  Silvery-flanked Antwren 0.003046274185180664
# end of actually chunking data  Silvery-flanked Antwren 0.13124990463256836
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.005179166793823242
# start of  Silvery-flanked Antwren 0.007179975509643555
# end of 1 setting in  Silvery-flanked Antwren 0.003002166748046875
# end of actually chunking data  Silvery-flanked Antwren 0.25344061851501465
# start of  bird 0.2631833553314209
# end of 1 setting in  bird 0.0032274723052978516
# end of actually chunking data  bird 0.2831242084503174
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.004997730255126953
# start of  Silvery-flanked Antwren 0.0075075626373291016
# end of 1 setting in  Silvery-flanked Antwren 0.002050638198852539
# end of actually chunking data  Silvery-flanked Antwren 0.24680328369140625
# start of  bird 0.2553293704986572
# end of 1 setting in  bird 0.0019981861114501953
# end of actually chunking data  bird 0.22699975967407227
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.006066322326660156
# start of  Silvery-flanked Antwren 0.0076007843017578125
# end of 1 setting in  Silvery-flanked Antwren 0.0025839805603027344
# end of actually chunking data  Silvery-flanked Antwren 0.2764620780944824
# start of  bird 0.2870635986328125
# end of 1 setting in  bird 0.002144336700439453
# end of actually chunking data  bird 0.27260708808898926
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.0039942264556884766
# start of  Silvery-flanked Antwren 0.006508350372314453
# end of 1 setting in  Silvery-flanked Antwren 0.00310516357421875
# end of actually chunking data  Silvery-flanked Antwren 0.43749523162841797
# start of  bird 0.44600510597229004
# end of 1 setting in  bird 0.0032088756561279297
# end of actually chunking data  bird 0.3152589797973633
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.0068929195404052734
# start of  Silvery-flanked Antwren 0.009433746337890625
# end of 1 setting in  Silvery-flanked Antwren 0.0025985240936279297
# end of actually chunking data  Silvery-flanked Antwren 0.4641904830932617
# start of  bird 0.4761829376220703
# end of 1 setting in  bird 0.001996278762817383
# end of actually chunking data  bird 0.29749107360839844
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.005312442779541016
# start of  Silvery-flanked Antwren 0.007339000701904297
# end of 1 setting in  Silvery-flanked Antwren 0.0025014877319335938
# end of actually chunking data  Silvery-flanked Antwren 0.5002589225769043
# start of  bird 0.5096561908721924
# end of 1 setting in  bird 0.002001523971557617
# end of actually chunking data  bird 0.33048248291015625
# ============================
# 6
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC320189_-_White-vented_Shama_-_Copsychus_niger.mp3 0.010874032974243164
# start of  White-vented Shama 0.013431310653686523
# end of 1 setting in  White-vented Shama 0.0054090023040771484
# end of actually chunking data  White-vented Shama 0.13170075416564941
# set up XC320189_-_White-vented_Shama_-_Copsychus_niger.mp3 0.006055355072021484
# start of  White-vented Shama 0.00812220573425293
# end of 1 setting in  White-vented Shama 0.0019958019256591797
# end of actually chunking data  White-vented Shama 0.13367581367492676
# start of  bird 0.14386463165283203
# end of 1 setting in  bird 0.0019998550415039062
# end of actually chunking data  bird 0.04961752891540527
# set up XC320189_-_White-vented_Shama_-_Copsychus_niger.mp3 0.0065381526947021484
# start of  White-vented Shama 0.00910186767578125
# end of 1 setting in  White-vented Shama 0.002004861831665039
# end of actually chunking data  White-vented Shama 0.13776683807373047
# start of  bird 0.149871826171875
# end of 1 setting in  bird 0.0025556087493896484
# end of actually chunking data  bird 0.15019702911376953
# set up XC320189_-_White-vented_Shama_-_Copsychus_niger.mp3 0.006564617156982422
# start of  White-vented Shama 0.0076482295989990234
# end of 1 setting in  White-vented Shama 0.001004934310913086
# end of actually chunking data  White-vented Shama 0.24467968940734863
# start of  bird 0.2555251121520996
# end of 1 setting in  bird 0.0029993057250976562
# end of actually chunking data  bird 0.20136356353759766
# set up XC320189_-_White-vented_Shama_-_Copsychus_niger.mp3 0.005084514617919922
# start of  White-vented Shama 0.006079673767089844
# end of 1 setting in  White-vented Shama 0.0015075206756591797
# end of actually chunking data  White-vented Shama 0.14188146591186523
# start of  bird 0.14995336532592773
# end of 1 setting in  bird 0.001001119613647461
# end of actually chunking data  bird 0.14768147468566895
# set up XC320189_-_White-vented_Shama_-_Copsychus_niger.mp3 0.004615068435668945
# start of  White-vented Shama 0.005644083023071289
# end of 1 setting in  White-vented Shama 0.0029990673065185547
# end of actually chunking data  White-vented Shama 0.16521883010864258
# start of  bird 0.17261981964111328
# end of 1 setting in  bird 0.0020494461059570312
# end of actually chunking data  bird 0.14740872383117676
# set up XC320189_-_White-vented_Shama_-_Copsychus_niger.mp3 0.005020618438720703
# start of  White-vented Shama 0.0070247650146484375
# end of 1 setting in  White-vented Shama 0.00299835205078125
# end of actually chunking data  White-vented Shama 0.1928565502166748
# start of  bird 0.2023320198059082
# end of 1 setting in  bird 0.0019989013671875
# end of actually chunking data  bird 0.1292581558227539
# set up XC320189_-_White-vented_Shama_-_Copsychus_niger.mp3 0.007114887237548828
# start of  White-vented Shama 0.008461475372314453
# end of 1 setting in  White-vented Shama 0.0020034313201904297
# end of actually chunking data  White-vented Shama 0.20663857460021973
# start of  bird 0.21811437606811523
# end of 1 setting in  bird 0.0015408992767333984
# end of actually chunking data  bird 0.11538982391357422
# ============================
# 7
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.005577564239501953
# start of  Silvery-flanked Antwren 0.008574485778808594
# end of 1 setting in  Silvery-flanked Antwren 0.002002716064453125
# end of actually chunking data  Silvery-flanked Antwren 0.22242259979248047
# start of  bird 0.23205184936523438
# end of 1 setting in  bird 0.0019989013671875
# end of actually chunking data  bird 0.12329435348510742
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.008062124252319336
# start of  Silvery-flanked Antwren 0.010100841522216797
# end of 1 setting in  Silvery-flanked Antwren 0.003201723098754883
# end of actually chunking data  Silvery-flanked Antwren 0.24935054779052734
# start of  bird 0.26111316680908203
# end of 1 setting in  bird 0.003025531768798828
# end of actually chunking data  bird 0.1320185661315918
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.0072939395904541016
# start of  Silvery-flanked Antwren 0.009289264678955078
# end of 1 setting in  Silvery-flanked Antwren 0.003552675247192383
# end of actually chunking data  Silvery-flanked Antwren 0.2570185661315918
# start of  bird 0.26830530166625977
# end of 1 setting in  bird 0.002002239227294922
# end of actually chunking data  bird 0.22228479385375977
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.004971742630004883
# start of  Silvery-flanked Antwren 0.006978034973144531
# end of 1 setting in  Silvery-flanked Antwren 0.001997232437133789
# end of actually chunking data  Silvery-flanked Antwren 0.333066463470459
# start of  bird 0.3420860767364502
# end of 1 setting in  bird 0.0037500858306884766
# end of actually chunking data  bird 0.23878264427185059
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.005540370941162109
# start of  Silvery-flanked Antwren 0.007506132125854492
# end of 1 setting in  Silvery-flanked Antwren 0.0020241737365722656
# end of actually chunking data  Silvery-flanked Antwren 0.34989333152770996
# start of  bird 0.35939955711364746
# end of 1 setting in  bird 0.0019989013671875
# end of actually chunking data  bird 0.20658612251281738
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.005002498626708984
# start of  Silvery-flanked Antwren 0.007003307342529297
# end of 1 setting in  Silvery-flanked Antwren 0.0019998550415039062
# end of actually chunking data  Silvery-flanked Antwren 0.4995276927947998
# start of  bird 0.5095305442810059
# end of 1 setting in  bird 0.0020580291748046875
# end of actually chunking data  bird 0.3193964958190918
# set up XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.006073951721191406
# start of  Silvery-flanked Antwren 0.008125782012939453
# end of 1 setting in  Silvery-flanked Antwren 0.0035638809204101562
# end of actually chunking data  Silvery-flanked Antwren 0.45295047760009766
# start of  bird 0.463489294052124
# end of 1 setting in  bird 0.0020203590393066406
# end of actually chunking data  bird 0.3470792770385742
# ============================
# 8
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC556442_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.005549430847167969
# start of  Silvery-flanked Antwren 0.0077054500579833984
# end of 1 setting in  Silvery-flanked Antwren 0.003001689910888672
# end of actually chunking data  Silvery-flanked Antwren 0.10401654243469238
# start of  bird 0.11271500587463379
# end of 1 setting in  bird 0.0035457611083984375
# end of actually chunking data  bird 0.12246036529541016
# set up XC556442_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.007222414016723633
# start of  Silvery-flanked Antwren 0.009331226348876953
# end of 1 setting in  Silvery-flanked Antwren 0.0020079612731933594
# end of actually chunking data  Silvery-flanked Antwren 0.15309619903564453
# start of  bird 0.16342473030090332
# end of 1 setting in  bird 0.0
# end of actually chunking data  bird 0.20292973518371582
# set up XC556442_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.004561424255371094
# start of  Silvery-flanked Antwren 0.0060689449310302734
# end of 1 setting in  Silvery-flanked Antwren 0.0010242462158203125
# end of actually chunking data  Silvery-flanked Antwren 0.24280929565429688
# start of  bird 0.2511725425720215
# end of 1 setting in  bird 0.0025358200073242188
# end of actually chunking data  bird 0.16137146949768066
# set up XC556442_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.009161949157714844
# start of  Silvery-flanked Antwren 0.011664390563964844
# end of 1 setting in  Silvery-flanked Antwren 0.002575397491455078
# end of actually chunking data  Silvery-flanked Antwren 0.31128954887390137
# start of  bird 0.32546472549438477
# end of 1 setting in  bird 0.0030384063720703125
# end of actually chunking data  bird 0.1848616600036621
# set up XC556442_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.006243228912353516
# start of  Silvery-flanked Antwren 0.006243228912353516
# end of 1 setting in  Silvery-flanked Antwren 0.0015056133270263672
# end of actually chunking data  Silvery-flanked Antwren 0.3322300910949707
# start of  bird 0.34101414680480957
# end of 1 setting in  bird 0.0030379295349121094
# end of actually chunking data  bird 0.16777729988098145
# set up XC556442_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3 0.0070667266845703125
# start of  Silvery-flanked Antwren 0.009504318237304688
# end of 1 setting in  Silvery-flanked Antwren 0.0025568008422851562
# end of actually chunking data  Silvery-flanked Antwren 0.40746021270751953
# start of  bird 0.4197709560394287
# end of 1 setting in  bird 0.0019941329956054688
# end of actually chunking data  bird 0.14983201026916504
# ============================
# 9
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.008736371994018555
# start of  White-vented Shama 0.009739398956298828
# end of 1 setting in  White-vented Shama 0.0035734176635742188
# end of actually chunking data  White-vented Shama 1.0002467632293701
# start of  bird 1.011991024017334
# end of 1 setting in  bird 0.003541231155395508
# end of actually chunking data  bird 0.2851104736328125
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.004041910171508789
# start of  White-vented Shama 0.006165742874145508
# end of 1 setting in  White-vented Shama 0.0021762847900390625
# end of actually chunking data  White-vented Shama 1.1590349674224854
# start of  bird 1.1680364608764648
# end of 1 setting in  bird 0.0020036697387695312
# end of actually chunking data  bird 0.26010823249816895
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.004682064056396484
# start of  White-vented Shama 0.006723642349243164
# end of 1 setting in  White-vented Shama 0.0019960403442382812
# end of actually chunking data  White-vented Shama 1.4161491394042969
# start of  bird 1.4254729747772217
# end of 1 setting in  bird 0.0009980201721191406
# end of actually chunking data  bird 0.5301446914672852
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.00510859489440918
# start of  White-vented Shama 0.007098197937011719
# end of 1 setting in  White-vented Shama 0.002121448516845703
# end of actually chunking data  White-vented Shama 1.3596994876861572
# start of  bird 1.3687901496887207
# end of 1 setting in  bird 0.0020008087158203125
# end of actually chunking data  bird 1.054694414138794
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.00579524040222168
# start of  White-vented Shama 0.007793426513671875
# end of 1 setting in  White-vented Shama 0.0029993057250976562
# end of actually chunking data  White-vented Shama 1.7274022102355957
# start of  bird 1.7361950874328613
# end of 1 setting in  bird 0.002035856246948242
# end of actually chunking data  bird 0.9332678318023682
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.006219387054443359
# start of  White-vented Shama 0.00837254524230957
# end of 1 setting in  White-vented Shama 0.0009982585906982422
# end of actually chunking data  White-vented Shama 1.6193082332611084
# start of  bird 1.6309213638305664
# end of 1 setting in  bird 0.0020165443420410156
# end of actually chunking data  bird 1.3722100257873535
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.0050013065338134766
# start of  White-vented Shama 0.0050013065338134766
# end of 1 setting in  White-vented Shama 0.0025610923767089844
# end of actually chunking data  White-vented Shama 1.7867727279663086
# start of  bird 1.7943928241729736
# end of 1 setting in  bird 0.003034830093383789
# end of actually chunking data  bird 2.0909476280212402
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.0045757293701171875
# start of  White-vented Shama 0.007567882537841797
# end of 1 setting in  White-vented Shama 0.0015101432800292969
# end of actually chunking data  White-vented Shama 1.964181661605835
# start of  bird 1.973829984664917
# end of 1 setting in  bird 0.001997709274291992
# end of actually chunking data  bird 1.589972734451294
# set up XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3 0.007105350494384766
# start of  White-vented Shama 0.009114742279052734
# end of 1 setting in  White-vented Shama 0.001997709274291992
# end of actually chunking data  White-vented Shama 2.054776668548584
# start of  bird 2.065444231033325
# end of 1 setting in  bird 0.0019943714141845703
# end of actually chunking data  bird 1.711653709411621
# [3.69515061378479, 8.476581811904907, 5.245764493942261, 5.8519086837768555, 3.613874673843384, 4.030338525772095, 2.5483405590057373, 4.282985687255859, 2.560030698776245, 24.94578742980957]
# [3.7007601261138916, 8.549637079238892, 6.09837532043457, 7.338382005691528, 3.3906514644622803, 4.595380783081055, 2.607595682144165, 4.334773302078247, 2.823930025100708, 25.545438528060913]

# %%
from confidence_functions.chunking import annotation_chunker_og, fast_chunker

# %%
start = time.time()
#for i in range(10):
data_chunked_norm = annotation_chunker_og(data, 3)
end = time.time()
print(end-start)
# Out:
# 3.403013229370117

# %%
start = time.time()
#for i in range(10):
data_chunked_faster = fast_chunker(data, 3)
end = time.time()
print(end-start)
# Out:
# 3.7421927452087402

# %%
data_chunked_norm.equals(data_chunked_faster)
# Out:
# True

# %%
data_chunked_norm.equals(data_chunked_faster2)
# Out:
# True

# %%
start = time.time()
#for i in range(10):
data_chunked_faster2 = fast_chunker(data, 3)
end = time.time()
print(end-start)
# Out:
# 3.907845973968506

# %%
# Out:
# <function confidence_functions.confidence.fast_majority_vote(df, users, chunk_length=1)>

# %%
np.unique(data["IN FILE"])
# Out:
# array(['XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3',
#        'XC235919_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3',
#        'XC23899_-_White-vented_Shama_-_Copsychus_niger.mp3',
#        'XC239434_-_White-vented_Shama_-_Copsychus_niger.mp3',
#        'XC249318_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3',
#        'XC269329_-_White-vented_Shama_-_Copsychus_niger.mp3',
#        'XC269330_-_White-vented_Shama_-_Copsychus_niger.mp3',
#        'XC320189_-_White-vented_Shama_-_Copsychus_niger.mp3',
#        'XC341379_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa_luctuosa_ssp_assumed_from_location.mp3',
#        'XC350114_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3',
#        'XC396072_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3',
#        'XC396217_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3',
#        'XC402101_-_Simple_Greenbul_-_Chlorocichla_simplex.mp3',
#        'XC410969_-_Balearic_Warbler_-_Sylvia_balearica.mp3',
#        'XC411039_-_Balearic_Warbler_-_Sylvia_balearica.mp3',
#        'XC411067_-_Balearic_Warbler_-_Sylvia_balearica.mp3',
#        'XC444334_-_Baglafecht_Weaver_-_Ploceus_baglafecht_reichenowi.mp3',
#        'XC450382_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3',
#        'XC490710_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3',
#        'XC504541_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3',
#        'XC556442_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3',
#        'XC581125_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3',
#        'XC605853_-_Baglafecht_Weaver_-_Ploceus_baglafecht.mp3',
#        'XC688945_-_Balearic_Warbler_-_Sylvia_balearica.mp3',
#        'XC688950_-_Balearic_Warbler_-_Sylvia_balearica.mp3'], dtype=object)

# %%
file = data[data["IN FILE"] == 'XC163810_-_Silvery-flanked_Antwren_-_Myrmotherula_luctuosa.mp3']
fast_majority_vote(file, np.unique(file["LAST MOD BY"]))
# Out:
# 0.75

# %%
start = time.time()
data_chunked = fast_chunker(file, 3)
end = time.time()
print(end-start)
data_chunked
# Out:
# 0.0932016372680664
#                                               IN FILE  CLIP LENGTH  CHANNEL  \
# 0   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 1   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 2   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 3   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 4   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 5   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 6   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 7   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 8   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 9   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 10  XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 11  XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
#
#     OFFSET  DURATION  SAMPLE RATE                MANUAL ID  \
# 0      0.0       3.0        44100  Silvery-flanked Antwren
# 1      3.0       3.0        44100  Silvery-flanked Antwren
# 2      6.0       3.0        44100  Silvery-flanked Antwren
# 3      9.0       3.0        44100  Silvery-flanked Antwren
# 4     12.0       3.0        44100  Silvery-flanked Antwren
# 5     15.0       3.0        44100  Silvery-flanked Antwren
# 6      0.0       3.0        44100                     bird
# 7      3.0       3.0        44100                     bird
# 8      6.0       3.0        44100                     bird
# 9      9.0       3.0        44100                     bird
# 10    12.0       3.0        44100                     bird
# 11    15.0       3.0        44100                     bird
#
#                                           LAST MOD BY
# 0                 <Siloux_Admin>,scottswitzer19,spres
# 1   <Siloux_Admin>,emcmwong,idhumphrey,scottswitze...
# 2   <Siloux_Admin>,emcmwong,idhumphrey,scottswitze...
# 3               <Siloux_Admin>,scottswitzer19,vanessa
# 4                                      <Siloux_Admin>
# 5   <Siloux_Admin>,emcmwong,idhumphrey,scottswitze...
# 6                                 emcmwong,idhumphrey
# 7                               fcq,idhumphrey,robert
# 8                         fcq,idhumphrey,robert,spres
# 9         fcq,idhumphrey,scottswitzer19,spres,vanessa
# 10            idhumphrey,scottswitzer19,spres,vanessa
# 11                                                fcq

# %%
start = time.time()
#for i in range(10):
data_chunked_norm = annotation_chunker_og(file, 3)
end = time.time()
print(end-start)
data_chunked_norm
# Out:
# 0.07854890823364258
#                                               IN FILE  CLIP LENGTH  CHANNEL  \
# 0   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 1   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 2   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 3   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 4   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 5   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 6   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 7   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 8   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 9   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 10  XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 11  XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
#
#     OFFSET  DURATION  SAMPLE RATE                MANUAL ID
# 0      0.0       3.0        44100  Silvery-flanked Antwren
# 1      3.0       3.0        44100  Silvery-flanked Antwren
# 2      6.0       3.0        44100  Silvery-flanked Antwren
# 3      9.0       3.0        44100  Silvery-flanked Antwren
# 4     12.0       3.0        44100  Silvery-flanked Antwren
# 5     15.0       3.0        44100  Silvery-flanked Antwren
# 6      0.0       3.0        44100                     bird
# 7      3.0       3.0        44100                     bird
# 8      6.0       3.0        44100                     bird
# 9      9.0       3.0        44100                     bird
# 10    12.0       3.0        44100                     bird
# 11    15.0       3.0        44100                     bird

# %%
df = fast_chunker(file, 3)
df["LAST MOD BY"] = df["LAST MOD BY"].apply(lambda x: len(x.split(",")))
counts = (df["LAST MOD BY"]/len(np.unique(file["LAST MOD BY"]))).mean() #Does mean make sense here?
counts
# Out:
# 0.4583333333333333

# %%
df.groupby(by=["MANUAL ID", "OFFSET"]).max().reset_index()
# Out:
#                   MANUAL ID  OFFSET  \
# 0   Silvery-flanked Antwren     0.0
# 1   Silvery-flanked Antwren     3.0
# 2   Silvery-flanked Antwren     6.0
# 3   Silvery-flanked Antwren     9.0
# 4   Silvery-flanked Antwren    12.0
# 5   Silvery-flanked Antwren    15.0
# 6                      bird     0.0
# 7                      bird     3.0
# 8                      bird     6.0
# 9                      bird     9.0
# 10                     bird    12.0
# 11                     bird    15.0
#
#                                               IN FILE  CLIP LENGTH  CHANNEL  \
# 0   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 1   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 2   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 3   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 4   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 5   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 6   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 7   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 8   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 9   XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 10  XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
# 11  XC163810_-_Silvery-flanked_Antwren_-_Myrmother...      19.6373        0
#
#     DURATION  SAMPLE RATE                                        LAST MOD BY
# 0        3.0        44100            [<Siloux_Admin>, scottswitzer19, spres]
# 1        3.0        44100  [<Siloux_Admin>, emcmwong, idhumphrey, scottsw...
# 2        3.0        44100  [<Siloux_Admin>, emcmwong, idhumphrey, scottsw...
# 3        3.0        44100          [<Siloux_Admin>, scottswitzer19, vanessa]
# 4        3.0        44100                                   [<Siloux_Admin>]
# 5        3.0        44100  [<Siloux_Admin>, emcmwong, idhumphrey, scottsw...
# 6        3.0        44100                             [emcmwong, idhumphrey]
# 7        3.0        44100                          [fcq, idhumphrey, robert]
# 8        3.0        44100                   [fcq, idhumphrey, robert, spres]
# 9        3.0        44100  [fcq, idhumphrey, scottswitzer19, spres, vanessa]
# 10       3.0        44100       [idhumphrey, scottswitzer19, spres, vanessa]
# 11       3.0        44100                                              [fcq]

# %%
df["LAST MOD BY"] = df["LAST MOD BY"].apply(lambda x: len(x.split(",")))
counts = (df["FOLDER"]/len(users)).mean() #Does mean make sense here?
counts
