# %%
from PyHa.statistics import *
from PyHa.IsoAutio import *
from PyHa.visualizations import *
from PyHa.annotation_post_processing import *
import pandas as pd

# %% [markdown]
# `ground_truth`: manually created annotations
# `t2fn` : TweetyNet to Filename
# `t2bnl_chunk` : chunked TweetyNet labels fed into BirdNET Lite
# `t2bnl_exact` : TweetyNet labels, then overlay BirdNET Lite species
# `bnl`: BirdNET-Lite native output

# %%
ground_truth_df = pd.read_csv("COSMOS_Manual_Labels_Anonymized_SRS.csv")
t2fn_df = pd.read_csv("COSMOS_TweetyNet_Labels_SRS.csv")
t2bnl_chunk_df = pd.read_csv("COSMOS_TweetyNet-to-BirdNET_Labels_SRS.csv")
t2bnl_exact_df = pd.read_csv("COSMOS_TweetyNet-BirdNET-Overlay_Labels_SRS.csv")
bnl_df = pd.read_csv("COSMOS_BirdNET-Lite_Labels_SRS.csv")

# %%
df_list = [ground_truth_df,
          t2fn_df,
          t2bnl_chunk_df,
          t2bnl_exact_df,
          bnl_df]
df_names = ["Ground Truth",
           "TweetyNet to Filename",
           "TweetyNet to BirdNET-Lite, Chunked",
           "TweetyNet to BirdNET-Lite, Exact",
           "BirdNET-Lite"]
path = "./cosmos_random_sample_processing/"

# %% [markdown]
# ### Setup and String Parsing

# %%
# replace scientific name with common name
def swap_scientific_common(scientific):
    try:
        return mddd[mddd["Species"] == scientific]["Common"].iloc[0]
    except:
        return scientific
    
# replace common name with scientific name
def swap_common_scientific(common):
    try:
        return mddd[mddd["Common"] == common]["Species"].iloc[0]
    except:
        return common

# fix up the data :D
def string_parsing(df):
    # conforming to naming conventions
    df['MANUAL ID'] = df['MANUAL ID'].replace('Bird', 'bird')
    df['MANUAL ID'] = df['MANUAL ID'].replace(' Rufous-collared Sparrow', 'Rufous-collared Sparrow')
    df['MANUAL ID'] = df['MANUAL ID'].replace(' Southern Nightingale-Wren', 'Southern Nightingale-Wren')
    df['FOLDER'] = path
    # turn manual ids from scientific to common
    df["SCIENTIFIC"] = df["MANUAL ID"]
    df["COMMON"] = df["MANUAL ID"].apply(swap_scientific_common)
    return df

# parse common species name from the file name
def file_to_class_name(df):
    df["CLASS NAME"] = df["IN FILE"].apply(lambda x: x.replace("_", " "))
    df["CLASS NAME"] = df["CLASS NAME"].apply(lambda x: x.split(" - ")[1])
    return df

# use filename to change manual id to scientific, species-specific name
def file_to_scientific_name(df):
    df["MANUAL ID"] = df["IN FILE"].apply(lambda x: " ".join(x.replace("_", " ").split(" - ")[-1].replace(".mp3", "").split()[:2]))
    return df

# %% [markdown]
# ### General Dataset Statistics

# %%
# general dataset statistics
def dataset_statistics(df):
    print("Total number of clips:", df["IN FILE"].nunique())
    print("Total number of annotations made:", df.shape[0])
    print("Total duration of clips:", round(df.groupby(by=["IN FILE"]).mean()["CLIP LENGTH"].sum() / 60 / 60, 4), "hours")
    print("Total duration of annotations made:", round(df['DURATION'].sum() / 60 / 60, 4), "hours")

# Total length of annotations per class labeled
def class_annotation_duration(df) :
    display(pd.DataFrame(df.groupby(by=["IN FILE", "MANUAL ID"]).mean().reset_index().groupby(by=["MANUAL ID"]).sum()["CLIP LENGTH"]).sort_values(by="CLIP LENGTH", ascending=False).head(20))

# %% [markdown]
# ### Class Statistics

# %%
def gen_class_labels(df):
    class_labels = df["CLASS NAME"].unique().tolist()
    class_labels.sort()
    return class_labels

    
# replace any species specific annotations that aren't the class name with "bird"
def replace_all_with_bird(df):
    class_labels = gen_class_labels(df)
    df.loc[~df["COMMON"].isin(class_labels), "COMMON"] = "bird"
    return df

# replace any labels that aren't in the class list
def replace_non_class_labels(df):
    class_labels = gen_class_labels(df)
    df.loc[~df["COMMON"].isin(class_labels), "COMMON"] = "bird"
    display(df.groupby(by=["IN FILE", "COMMON"]).sum())
    return df

# %%
def gen_stacked_bar_chart(df, title=""):
    # filter by duration of each species in each clip class
    class_duration = df.groupby(by=["CLASS NAME", "COMMON"])["DURATION"].sum().reset_index()
    # total duration of ALL annotations for each class
    all_classes = class_duration.groupby(by="CLASS NAME")["DURATION"].sum().to_list()
    # total duration of species-level annotations for each class
    classes_only = class_duration[class_duration["CLASS NAME"] == class_duration["COMMON"]]["DURATION"].to_list()
    # total duration of audio
    class_df_nodupes = df.drop_duplicates(subset=["CLIP LENGTH"], keep='first')
    clip_duration_by_class = class_df_nodupes.groupby("CLASS NAME")["CLIP LENGTH"].sum().to_list()
    # generate list of class labels
    class_labels = gen_class_labels(df)
    
    # generate barchart
    y = np.arange(len(classes_only))

    fig, ax = plt.subplots()
    cd_b_c = ax.barh(y,clip_duration_by_class, label="Unlabeled Audio")
    b_length = ax.barh(y, all_classes, label="Generic Bird Labels")
    cl_length = ax.barh(y, classes_only, label="Species-Specific Labels")


    for bar in ax.patches:
        value = bar.get_height()
        text = f'{value}'

    ax.set_title(title)
    ax.set_xlabel('Duration (s)')
    ax.set_yticks(y)
    ax.set_yticklabels(class_labels)
    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    plt.show()
    return df

# %% [markdown]
# # let's analyze some data :D

# %%
# apply file names to tweety df, since it just outputs "bird"
t2fn_df = file_to_scientific_name(t2fn_df)

# %%
mddd = pd.read_csv("MadreDeDiosXCBirdList.csv")

# %%
ground_truth_df
# Out:
#       Unnamed: 0                                            IN FILE  \
# 0              0  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# 1              1  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# 2              2  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# 3              3  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# 4              4  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# ...          ...                                                ...
# 5187        5187  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
# 5188        5188  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
# 5189        5189  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
# 5190        5190  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
# 5191        5191  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
#
#       CLIP LENGTH   OFFSET  DURATION  MAX FREQ  MIN FREQ  SAMPLE RATE  \
# 0         23.2956   0.7025    0.9199     24000         0        44100
# 1         23.2956   4.6223    0.9400     24000         0        44100
# 2         23.2956  11.4420    0.9300     24000         0        44100
# 3         23.2956  18.4117    0.8700     24000         0        44100
# 4         23.2956  21.9915    0.7600     24000         0        44100
# ...           ...      ...       ...       ...       ...          ...
# 5187      31.3404  15.4774    0.4799     24000         0        44100
# 5188      31.3404   5.4311    0.5899     24000         0        44100
# 5189      31.3404   7.1648    0.6299     24000         0        44100
# 5190      31.3404  10.3063    0.4499     24000         0        44100
# 5191      31.3404  11.5060    0.4900     24000         0        44100
#
#                      MANUAL ID  TIME_SPENT   LAST MOD BY  CONFIDENCE  RETIRED  \
# 0             Celeus grammicus     365.822   Jared Smith           0    False
# 1             Celeus grammicus     365.822   Jared Smith           0    False
# 2             Celeus grammicus     176.450   Jared Smith           0    False
# 3             Celeus grammicus     365.822   Jared Smith           0    False
# 4             Celeus grammicus     176.450   Jared Smith           0    False
# ...                        ...         ...           ...         ...      ...
# 5187  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
# 5188  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
# 5189  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
# 5190  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
# 5191  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
#
#       COUNTED    FOLDER                     COMMON                SCIENTIFIC
# 0           0  ./COSMOS  Scaly-breasted Woodpecker          Celeus grammicus
# 1           0  ./COSMOS  Scaly-breasted Woodpecker          Celeus grammicus
# 2           0  ./COSMOS  Scaly-breasted Woodpecker          Celeus grammicus
# 3           0  ./COSMOS  Scaly-breasted Woodpecker          Celeus grammicus
# 4           0  ./COSMOS  Scaly-breasted Woodpecker          Celeus grammicus
# ...       ...       ...                        ...                       ...
# 5187        0  ./COSMOS      Yellow-olive Flatbill  Tolmomyias sulphurescens
# 5188        0  ./COSMOS      Yellow-olive Flatbill  Tolmomyias sulphurescens
# 5189        0  ./COSMOS      Yellow-olive Flatbill  Tolmomyias sulphurescens
# 5190        0  ./COSMOS      Yellow-olive Flatbill  Tolmomyias sulphurescens
# 5191        0  ./COSMOS      Yellow-olive Flatbill  Tolmomyias sulphurescens
#
# [5192 rows x 17 columns]

# %%
i = 0
for df in df_list:
    print("\n\n" + df_names[i])
    df = string_parsing(df)
    df = file_to_class_name(df)
    dataset_statistics(df)
    display(df)
    i+=1
# Out:
# Ground Truth
# Total number of clips: 498
# Total number of annotations made: 5192
# Total duration of clips: 5.7217 hours
# Total duration of annotations made: 2.6558 hours
#       Unnamed: 0                                            IN FILE  \
# 0              0  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# 1              1  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# 2              2  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# 3              3  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# 4              4  XC87449_-_Scaly-breasted_Woodpecker_-_Celeus_g...
# ...          ...                                                ...
# 5187        5187  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
# 5188        5188  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
# 5189        5189  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
# 5190        5190  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
# 5191        5191  XC27942_-_Yellow-olive_Flatbill_-_Tolmomyias_s...
#
#       CLIP LENGTH   OFFSET  DURATION  MAX FREQ  MIN FREQ  SAMPLE RATE  \
# 0         23.2956   0.7025    0.9199     24000         0        44100
# 1         23.2956   4.6223    0.9400     24000         0        44100
# 2         23.2956  11.4420    0.9300     24000         0        44100
# 3         23.2956  18.4117    0.8700     24000         0        44100
# 4         23.2956  21.9915    0.7600     24000         0        44100
# ...           ...      ...       ...       ...       ...          ...
# 5187      31.3404  15.4774    0.4799     24000         0        44100
# 5188      31.3404   5.4311    0.5899     24000         0        44100
# 5189      31.3404   7.1648    0.6299     24000         0        44100
# 5190      31.3404  10.3063    0.4499     24000         0        44100
# 5191      31.3404  11.5060    0.4900     24000         0        44100
#
#                      MANUAL ID  TIME_SPENT   LAST MOD BY  CONFIDENCE  RETIRED  \
# 0             Celeus grammicus     365.822   Jared Smith           0    False
# 1             Celeus grammicus     365.822   Jared Smith           0    False
# 2             Celeus grammicus     176.450   Jared Smith           0    False
# 3             Celeus grammicus     365.822   Jared Smith           0    False
# 4             Celeus grammicus     176.450   Jared Smith           0    False
# ...                        ...         ...           ...         ...      ...
# 5187  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
# 5188  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
# 5189  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
# 5190  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
# 5191  Tolmomyias sulphurescens      76.420  Jason Benson           0    False
#
#       COUNTED                              FOLDER                     COMMON  \
# 0           0  ./cosmos_random_sample_processing/  Scaly-breasted Woodpecker
# 1           0  ./cosmos_random_sample_processing/  Scaly-breasted Woodpecker
# 2           0  ./cosmos_random_sample_processing/  Scaly-breasted Woodpecker
# 3           0  ./cosmos_random_sample_processing/  Scaly-breasted Woodpecker
# 4           0  ./cosmos_random_sample_processing/  Scaly-breasted Woodpecker
# ...       ...                                 ...                        ...
# 5187        0  ./cosmos_random_sample_processing/      Yellow-olive Flatbill
# 5188        0  ./cosmos_random_sample_processing/      Yellow-olive Flatbill
# 5189        0  ./cosmos_random_sample_processing/      Yellow-olive Flatbill
# 5190        0  ./cosmos_random_sample_processing/      Yellow-olive Flatbill
# 5191        0  ./cosmos_random_sample_processing/      Yellow-olive Flatbill
#
#                     SCIENTIFIC                 CLASS NAME
# 0             Celeus grammicus  Scaly-breasted Woodpecker
# 1             Celeus grammicus  Scaly-breasted Woodpecker
# 2             Celeus grammicus  Scaly-breasted Woodpecker
# 3             Celeus grammicus  Scaly-breasted Woodpecker
# 4             Celeus grammicus  Scaly-breasted Woodpecker
# ...                        ...                        ...
# 5187  Tolmomyias sulphurescens      Yellow-olive Flatbill
# 5188  Tolmomyias sulphurescens      Yellow-olive Flatbill
# 5189  Tolmomyias sulphurescens      Yellow-olive Flatbill
# 5190  Tolmomyias sulphurescens      Yellow-olive Flatbill
# 5191  Tolmomyias sulphurescens      Yellow-olive Flatbill
#
# [5192 rows x 18 columns]
# TweetyNet to Filename
# Total number of clips: 482
# Total number of annotations made: 9319
# Total duration of clips: 5.6235 hours
# Total duration of annotations made: 3.0937 hours
#       Unnamed: 0    OFFSET  DURATION                              FOLDER  \
# 0              0  0.558140  1.767442  ./cosmos_random_sample_processing/
# 1              1  4.325581  0.093023  ./cosmos_random_sample_processing/
# 2              2  6.046512  8.000000  ./cosmos_random_sample_processing/
# 3              3  1.441860  0.558140  ./cosmos_random_sample_processing/
# 4              4  2.000000  0.232558  ./cosmos_random_sample_processing/
# ...          ...       ...       ...                                 ...
# 9314        9314  6.488372  0.441860  ./cosmos_random_sample_processing/
# 9315        9315  6.953488  0.162791  ./cosmos_random_sample_processing/
# 9316        9316  7.116279  0.046512  ./cosmos_random_sample_processing/
# 9317        9317  7.790698  0.930233  ./cosmos_random_sample_processing/
# 9318        9318  9.906977  0.069767  ./cosmos_random_sample_processing/
#
#                                                 IN FILE  CHANNEL  CLIP LENGTH  \
# 0     XC100864 - Rufous-collared Sparrow - Zonotrich...        0     9.299592
# 1     XC100864 - Rufous-collared Sparrow - Zonotrich...        0     9.299592
# 2     XC100864 - Rufous-collared Sparrow - Zonotrich...        0     9.299592
# 3     XC101469 - Pale-breasted Thrush - Turdus leuco...        0   137.377959
# 4     XC101469 - Pale-breasted Thrush - Turdus leuco...        0   137.377959
# ...                                                 ...      ...          ...
# 9314  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0    11.232653
# 9315  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0    11.232653
# 9316  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0    11.232653
# 9317  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0    11.232653
# 9318  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0    11.232653
#
#       SAMPLE RATE             MANUAL ID  CONFIDENCE            SCIENTIFIC  \
# 0           44100  Zonotrichia capensis    0.914495  Zonotrichia capensis
# 1           44100  Zonotrichia capensis    0.157588  Zonotrichia capensis
# 2           44100  Zonotrichia capensis    1.000000  Zonotrichia capensis
# 3           44100     Turdus leucomelas    0.743005     Turdus leucomelas
# 4           44100     Turdus leucomelas    0.706071     Turdus leucomelas
# ...           ...                   ...         ...                   ...
# 9314        44100  Zonotrichia capensis    0.355972  Zonotrichia capensis
# 9315        44100  Zonotrichia capensis    0.233995  Zonotrichia capensis
# 9316        44100  Zonotrichia capensis    0.271501  Zonotrichia capensis
# 9317        44100  Zonotrichia capensis    0.668926  Zonotrichia capensis
# 9318        44100  Zonotrichia capensis    0.286341  Zonotrichia capensis
#
#                        COMMON               CLASS NAME
# 0     Rufous-collared Sparrow  Rufous-collared Sparrow
# 1     Rufous-collared Sparrow  Rufous-collared Sparrow
# 2     Rufous-collared Sparrow  Rufous-collared Sparrow
# 3        Pale-breasted Thrush     Pale-breasted Thrush
# 4        Pale-breasted Thrush     Pale-breasted Thrush
# ...                       ...                      ...
# 9314  Rufous-collared Sparrow  Rufous-collared Sparrow
# 9315  Rufous-collared Sparrow  Rufous-collared Sparrow
# 9316  Rufous-collared Sparrow  Rufous-collared Sparrow
# 9317  Rufous-collared Sparrow  Rufous-collared Sparrow
# 9318  Rufous-collared Sparrow  Rufous-collared Sparrow
#
# [9319 rows x 13 columns]
# TweetyNet to BirdNET-Lite, Chunked
# Total number of clips: 476
# Total number of annotations made: 5086
# Total duration of clips: 5.6179 hours
# Total duration of annotations made: 4.2383 hours
#       Unnamed: 0                              FOLDER  \
# 0              0  ./cosmos_random_sample_processing/
# 1              1  ./cosmos_random_sample_processing/
# 2              2  ./cosmos_random_sample_processing/
# 3              3  ./cosmos_random_sample_processing/
# 4              4  ./cosmos_random_sample_processing/
# ...          ...                                 ...
# 5081        5081  ./cosmos_random_sample_processing/
# 5082        5082  ./cosmos_random_sample_processing/
# 5083        5083  ./cosmos_random_sample_processing/
# 5084        5084  ./cosmos_random_sample_processing/
# 5085        5085  ./cosmos_random_sample_processing/
#
#                                                 IN FILE  CLIP LENGTH  CHANNEL  \
# 0     XC100864 - Rufous-collared Sparrow - Zonotrich...     9.299604        0
# 1     XC100864 - Rufous-collared Sparrow - Zonotrich...     9.299604        0
# 2     XC100864 - Rufous-collared Sparrow - Zonotrich...     9.299604        0
# 3     XC101469 - Pale-breasted Thrush - Turdus leuco...   137.377979        0
# 4     XC101469 - Pale-breasted Thrush - Turdus leuco...   137.377979        0
# ...                                                 ...          ...      ...
# 5081  XC97532 - Blue-grey Tanager - Thraupis episcop...    20.297146        0
# 5082  XC97542 - Slate-throated Whitestart - Myioboru...     4.362458        0
# 5083  XC9766 - Rufous-collared Sparrow - Zonotrichia...    11.232667        0
# 5084  XC9766 - Rufous-collared Sparrow - Zonotrichia...    11.232667        0
# 5085  XC9766 - Rufous-collared Sparrow - Zonotrichia...    11.232667        0
#
#       OFFSET  DURATION  SAMPLE RATE                   MANUAL ID  CONFIDENCE  \
# 0        0.0       3.0        48000        Zonotrichia capensis    0.981316
# 1        3.0       3.0        48000        Zonotrichia capensis    0.455129
# 2        6.0       3.0        48000        Zonotrichia capensis    0.958481
# 3        0.0       3.0        48000                Mimus gilvus    0.130503
# 4        3.0       3.0        48000                Mimus gilvus    0.066429
# ...      ...       ...          ...                         ...         ...
# 5081    15.0       3.0        48000             Bubo ascalaphus    0.013156
# 5082     0.0       3.0        48000          Thlypopsis sordida    0.023451
# 5083     0.0       3.0        48000          Empidonax traillii    0.121914
# 5084     3.0       3.0        48000             Merops pusillus    0.040642
# 5085     6.0       3.0        48000  Pardirallus sanguinolentus    0.059656
#
#                       SCIENTIFIC                      COMMON  \
# 0           Zonotrichia capensis     Rufous-collared Sparrow
# 1           Zonotrichia capensis     Rufous-collared Sparrow
# 2           Zonotrichia capensis     Rufous-collared Sparrow
# 3                   Mimus gilvus                Mimus gilvus
# 4                   Mimus gilvus                Mimus gilvus
# ...                          ...                         ...
# 5081             Bubo ascalaphus             Bubo ascalaphus
# 5082          Thlypopsis sordida       Orange-headed Tanager
# 5083          Empidonax traillii          Empidonax traillii
# 5084             Merops pusillus             Merops pusillus
# 5085  Pardirallus sanguinolentus  Pardirallus sanguinolentus
#
#                      CLASS NAME
# 0       Rufous-collared Sparrow
# 1       Rufous-collared Sparrow
# 2       Rufous-collared Sparrow
# 3          Pale-breasted Thrush
# 4          Pale-breasted Thrush
# ...                         ...
# 5081          Blue-grey Tanager
# 5082  Slate-throated Whitestart
# 5083    Rufous-collared Sparrow
# 5084    Rufous-collared Sparrow
# 5085    Rufous-collared Sparrow
#
# [5086 rows x 13 columns]
# TweetyNet to BirdNET-Lite, Exact
# Total number of clips: 482
# Total number of annotations made: 12946
# Total duration of clips: 5.6235 hours
# Total duration of annotations made: 3.0937 hours
#        Unnamed: 0.1  Unnamed: 0     OFFSET  DURATION  \
# 0                 0           0   0.558140  1.767442
# 1                 1           1   4.325581  0.093023
# 2                 2           2   6.046512  2.953488
# 3                 3           2   9.000000  3.000000
# 4                 4           2  12.000000  2.046512
# ...             ...         ...        ...       ...
# 12941         12941        9314   6.488372  0.441860
# 12942         12942        9315   6.953488  0.162791
# 12943         12943        9316   7.116279  0.046512
# 12944         12944        9317   7.790698  0.930233
# 12945         12945        9318   9.906977  0.069767
#
#                                    FOLDER  \
# 0      ./cosmos_random_sample_processing/
# 1      ./cosmos_random_sample_processing/
# 2      ./cosmos_random_sample_processing/
# 3      ./cosmos_random_sample_processing/
# 4      ./cosmos_random_sample_processing/
# ...                                   ...
# 12941  ./cosmos_random_sample_processing/
# 12942  ./cosmos_random_sample_processing/
# 12943  ./cosmos_random_sample_processing/
# 12944  ./cosmos_random_sample_processing/
# 12945  ./cosmos_random_sample_processing/
#
#                                                  IN FILE  CHANNEL  \
# 0      XC100864 - Rufous-collared Sparrow - Zonotrich...        0
# 1      XC100864 - Rufous-collared Sparrow - Zonotrich...        0
# 2      XC100864 - Rufous-collared Sparrow - Zonotrich...        0
# 3      XC100864 - Rufous-collared Sparrow - Zonotrich...        0
# 4      XC100864 - Rufous-collared Sparrow - Zonotrich...        0
# ...                                                  ...      ...
# 12941  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0
# 12942  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0
# 12943  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0
# 12944  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0
# 12945  XC9766 - Rufous-collared Sparrow - Zonotrichia...        0
#
#        CLIP LENGTH  SAMPLE RATE                   MANUAL ID  CONFIDENCE  \
# 0         9.299592        44100        Zonotrichia capensis    0.914495
# 1         9.299592        44100        Zonotrichia capensis    0.157588
# 2         9.299592        44100        Zonotrichia capensis    1.000000
# 3         9.299592        44100                        bird    1.000000
# 4         9.299592        44100                        bird    1.000000
# ...            ...          ...                         ...         ...
# 12941    11.232653        44100  Pardirallus sanguinolentus    0.355972
# 12942    11.232653        44100  Pardirallus sanguinolentus    0.233995
# 12943    11.232653        44100  Pardirallus sanguinolentus    0.271501
# 12944    11.232653        44100  Pardirallus sanguinolentus    0.668926
# 12945    11.232653        44100          Passerina caerulea    0.286341
#
#         END_TIME                     SPLIT   FILEKEY  START_TIME  \
# 0       2.325581                       NaN  XC100864    0.558140
# 1       4.418605                       NaN  XC100864    4.325581
# 2       9.000000    [6.046511627906977, 9]  XC100864    6.046512
# 3      12.000000                   [9, 12]  XC100864    9.000000
# 4      14.046512  [12, 14.046511627906977]  XC100864   12.000000
# ...          ...                       ...       ...         ...
# 12941   6.930233                       NaN    XC9766    6.488372
# 12942   7.116279                       NaN    XC9766    6.953488
# 12943   7.162791                       NaN    XC9766    7.116279
# 12944   8.720930                       NaN    XC9766    7.790698
# 12945   9.976744                       NaN    XC9766    9.906977
#
#                        SCIENTIFIC                      COMMON  \
# 0            Zonotrichia capensis     Rufous-collared Sparrow
# 1            Zonotrichia capensis     Rufous-collared Sparrow
# 2            Zonotrichia capensis     Rufous-collared Sparrow
# 3                            bird                        bird
# 4                            bird                        bird
# ...                           ...                         ...
# 12941  Pardirallus sanguinolentus  Pardirallus sanguinolentus
# 12942  Pardirallus sanguinolentus  Pardirallus sanguinolentus
# 12943  Pardirallus sanguinolentus  Pardirallus sanguinolentus
# 12944  Pardirallus sanguinolentus  Pardirallus sanguinolentus
# 12945          Passerina caerulea          Passerina caerulea
#
#                     CLASS NAME
# 0      Rufous-collared Sparrow
# 1      Rufous-collared Sparrow
# 2      Rufous-collared Sparrow
# 3      Rufous-collared Sparrow
# 4      Rufous-collared Sparrow
# ...                        ...
# 12941  Rufous-collared Sparrow
# 12942  Rufous-collared Sparrow
# 12943  Rufous-collared Sparrow
# 12944  Rufous-collared Sparrow
# 12945  Rufous-collared Sparrow
#
# [12946 rows x 18 columns]
# BirdNET-Lite
# Total number of clips: 495
# Total number of annotations made: 6812
# Total duration of clips: 5.6798 hours
# Total duration of annotations made: 5.6767 hours
#       Unnamed: 0                              FOLDER  \
# 0              0  ./cosmos_random_sample_processing/
# 1              1  ./cosmos_random_sample_processing/
# 2              2  ./cosmos_random_sample_processing/
# 3              3  ./cosmos_random_sample_processing/
# 4              4  ./cosmos_random_sample_processing/
# ...          ...                                 ...
# 6807        6807  ./cosmos_random_sample_processing/
# 6808        6808  ./cosmos_random_sample_processing/
# 6809        6809  ./cosmos_random_sample_processing/
# 6810        6810  ./cosmos_random_sample_processing/
# 6811        6811  ./cosmos_random_sample_processing/
#
#                                                 IN FILE  CLIP LENGTH  CHANNEL  \
# 0     XC100864 - Rufous-collared Sparrow - Zonotrich...     9.299604        0
# 1     XC100864 - Rufous-collared Sparrow - Zonotrich...     9.299604        0
# 2     XC100864 - Rufous-collared Sparrow - Zonotrich...     9.299604        0
# 3     XC101469 - Pale-breasted Thrush - Turdus leuco...   137.377979        0
# 4     XC101469 - Pale-breasted Thrush - Turdus leuco...   137.377979        0
# ...                                                 ...          ...      ...
# 6807  XC97542 - Slate-throated Whitestart - Myioboru...     4.362458        0
# 6808  XC9766 - Rufous-collared Sparrow - Zonotrichia...    11.232667        0
# 6809  XC9766 - Rufous-collared Sparrow - Zonotrichia...    11.232667        0
# 6810  XC9766 - Rufous-collared Sparrow - Zonotrichia...    11.232667        0
# 6811  XC9766 - Rufous-collared Sparrow - Zonotrichia...    11.232667        0
#
#       OFFSET  DURATION  SAMPLE RATE                   MANUAL ID  CONFIDENCE  \
# 0        0.0       3.0        48000        Zonotrichia capensis    0.981316
# 1        3.0       3.0        48000        Zonotrichia capensis    0.455129
# 2        6.0       3.0        48000        Zonotrichia capensis    0.958481
# 3        0.0       3.0        48000                Mimus gilvus    0.130503
# 4        3.0       3.0        48000                Mimus gilvus    0.066429
# ...      ...       ...          ...                         ...         ...
# 6807     0.0       3.0        48000          Thlypopsis sordida    0.023451
# 6808     0.0       3.0        48000          Empidonax traillii    0.121914
# 6809     3.0       3.0        48000             Merops pusillus    0.040642
# 6810     6.0       3.0        48000  Pardirallus sanguinolentus    0.059656
# 6811     9.0       3.0        48000          Passerina caerulea    0.075821
#
#                       SCIENTIFIC                      COMMON  \
# 0           Zonotrichia capensis     Rufous-collared Sparrow
# 1           Zonotrichia capensis     Rufous-collared Sparrow
# 2           Zonotrichia capensis     Rufous-collared Sparrow
# 3                   Mimus gilvus                Mimus gilvus
# 4                   Mimus gilvus                Mimus gilvus
# ...                          ...                         ...
# 6807          Thlypopsis sordida       Orange-headed Tanager
# 6808          Empidonax traillii          Empidonax traillii
# 6809             Merops pusillus             Merops pusillus
# 6810  Pardirallus sanguinolentus  Pardirallus sanguinolentus
# 6811          Passerina caerulea          Passerina caerulea
#
#                      CLASS NAME
# 0       Rufous-collared Sparrow
# 1       Rufous-collared Sparrow
# 2       Rufous-collared Sparrow
# 3          Pale-breasted Thrush
# 4          Pale-breasted Thrush
# ...                         ...
# 6807  Slate-throated Whitestart
# 6808    Rufous-collared Sparrow
# 6809    Rufous-collared Sparrow
# 6810    Rufous-collared Sparrow
# 6811    Rufous-collared Sparrow
#
# [6812 rows x 13 columns]

# %%
gen_stacked_bar_chart(ground_truth_df, "Ground Truth Label Duration");
gen_stacked_bar_chart(t2fn_df, "TweetyNet to Filename Label Duration");
gen_stacked_bar_chart(bnl_df, "BirdNET Label Duration");
gen_stacked_bar_chart(t2bnl_chunk_df, "TweetyNet to BirdNET, Chunked Label Duration");
gen_stacked_bar_chart(t2bnl_exact_df, "TweetyNet to BirdNET, Exact Label Duration");

# %%
# class_df_species = manual_df.copy()
# class_df_species["IN FILE"] = class_df_species["IN FILE"].apply(lambda x: x.replace("_", " "))
# class_df_species["IN FILE"] = class_df_species["IN FILE"].apply(lambda x: x.split(" - ")[1])
# cols = [0,1,2]
# class_df_species.drop(class_df_species.columns[cols],axis = 1, inplace=True)
# class_labels = class_df_species["IN FILE"].unique().tolist()
# class_labels.sort()
# class_df_species.loc[~class_df_species["COMMON"].isin(class_labels), "COMMON"] = "bird"
# #class_df_species
# class_df_species.groupby(by=["IN FILE", "COMMON"]).sum()
# Out:
#                                                         DURATION  CHANNEL  \
# IN FILE                   COMMON
# Blue-grey Tanager         Blue-grey Tanager           444.976744        0
#                           Buff-throated Woodcreeper     1.441860        0
#                           bird                        519.046512        0
# Buff-throated Woodcreeper Buff-throated Woodcreeper   495.837209        0
#                           Green-backed Trogon           9.581395        0
#                           White-throated Toucan         5.093023        0
#                           bird                       1190.581395        0
# Green-backed Trogon       Green-backed Trogon         443.883721        0
#                           Scaly-breasted Woodpecker     0.116279        0
#                           bird                        855.813953        0
# Pale-breasted Thrush      Blue-grey Tanager             1.093023        0
#                           Pale-breasted Thrush        475.813953        0
#                           bird                        878.790698        0
# Rufous-collared Sparrow   Rufous-collared Sparrow     387.093023        0
#                           bird                        610.093023        0
# Scaly-breasted Woodpecker Buff-throated Woodcreeper     2.790698        0
#                           Green-backed Trogon          11.000000        0
#                           Scaly-breasted Woodpecker   159.731623        0
#                           bird                        598.488372        0
# Slate-throated Whitestart Blue-grey Tanager             0.488372        0
#                           Slate-throated Whitestart   230.790698        0
#                           bird                        793.372093        0
# Southern Nightingale-Wren Southern Nightingale-Wren   308.906977        0
#                           White-throated Toucan         0.023256        0
#                           bird                        443.162791        0
# White-throated Toucan     White-throated Toucan       992.651163        0
#                           bird                        466.395349        0
# Yellow-olive Flatbill     Buff-throated Woodcreeper     0.162791        0
#                           Yellow-olive Flatbill       234.488372        0
#                           bird                        575.534884        0
#
#                                                        CLIP LENGTH  \
# IN FILE                   COMMON
# Blue-grey Tanager         Blue-grey Tanager           51447.441769
#                           Buff-throated Woodcreeper     153.474082
#                           bird                        47096.504762
# Buff-throated Woodcreeper Buff-throated Woodcreeper   27036.694331
#                           Green-backed Trogon          5032.367800
#                           White-throated Toucan         421.773061
#                           bird                       100501.642857
# Green-backed Trogon       Green-backed Trogon         66699.759025
#                           Scaly-breasted Woodpecker      96.156735
#                           bird                        63783.823946
# Pale-breasted Thrush      Blue-grey Tanager            1025.339002
#                           Pale-breasted Thrush        54901.640023
#                           bird                        79707.284921
# Rufous-collared Sparrow   Rufous-collared Sparrow     27129.069070
#                           bird                        43995.750431
# Scaly-breasted Woodpecker Buff-throated Woodcreeper     186.413333
#                           Green-backed Trogon          1023.666667
#                           Scaly-breasted Woodpecker   25436.916599
#                           bird                        71024.665828
# Slate-throated Whitestart Blue-grey Tanager              51.860476
#                           Slate-throated Whitestart   14507.603243
#                           bird                        49073.684263
# Southern Nightingale-Wren Southern Nightingale-Wren   62378.780499
#                           White-throated Toucan          95.927982
#                           bird                        85635.328345
# White-throated Toucan     White-throated Toucan      100300.979116
#                           bird                        16217.147392
# Yellow-olive Flatbill     Buff-throated Woodcreeper     142.890748
#                           Yellow-olive Flatbill       22932.682698
#                           bird                        37598.128413
#
#                                                      SAMPLE RATE  CONFIDENCE  \
# IN FILE                   COMMON
# Blue-grey Tanager         Blue-grey Tanager             26107200  374.871992
#                           Buff-throated Woodcreeper       132300    1.422582
#                           bird                          29017800  394.260443
# Buff-throated Woodcreeper Buff-throated Woodcreeper     17728200  292.069826
#                           Green-backed Trogon             970200   12.177980
#                           White-throated Toucan           220500    4.469859
#                           bird                          41409900  606.991069
# Green-backed Trogon       Green-backed Trogon           31046400  441.482161
#                           Scaly-breasted Woodpecker        44100    0.529241
#                           bird                          27959400  440.411766
# Pale-breasted Thrush      Blue-grey Tanager               441000    3.981908
#                           Pale-breasted Thrush          29017800  435.131137
#                           bird                          42115500  619.456097
# Rufous-collared Sparrow   Rufous-collared Sparrow       20594700  326.407467
#                           bird                          31002300  403.672473
# Scaly-breasted Woodpecker Buff-throated Woodcreeper        44100    0.790494
#                           Green-backed Trogon            1102500   15.423929
#                           Scaly-breasted Woodpecker     15743700  215.057213
#                           bird                          34221600  470.048505
# Slate-throated Whitestart Blue-grey Tanager               132300    1.865006
#                           Slate-throated Whitestart     13626900  208.280906
#                           bird                          37485000  523.720779
# Southern Nightingale-Wren Southern Nightingale-Wren     20109600  309.331019
#                           White-throated Toucan            44100    1.000000
#                           bird                          23461200  323.242520
# White-throated Toucan     White-throated Toucan         61651800  971.110931
#                           bird                          12744900  196.447910
# Yellow-olive Flatbill     Buff-throated Woodcreeper        88200    0.761343
#                           Yellow-olive Flatbill         20947500  305.727072
#                           bird                          31707900  426.872444
#
#                                                          END_TIME  \
# IN FILE                   COMMON
# Blue-grey Tanager         Blue-grey Tanager          25784.837209
#                           Buff-throated Woodcreeper    145.860465
#                           bird                       25448.279070
# Buff-throated Woodcreeper Buff-throated Woodcreeper  12788.581395
#                           Green-backed Trogon         4648.395349
#                           White-throated Toucan        266.953488
#                           bird                       79415.837209
# Green-backed Trogon       Green-backed Trogon        34326.581395
#                           Scaly-breasted Woodpecker      9.116279
#                           bird                       49245.186047
# Pale-breasted Thrush      Blue-grey Tanager            685.488372
#                           Pale-breasted Thrush       28843.813953
#                           bird                       43786.767442
# Rufous-collared Sparrow   Rufous-collared Sparrow    12599.348837
#                           bird                       34263.651163
# Scaly-breasted Woodpecker Buff-throated Woodcreeper      9.000000
#                           Green-backed Trogon          425.604651
#                           Scaly-breasted Woodpecker  13114.819567
#                           bird                       48923.023256
# Slate-throated Whitestart Blue-grey Tanager             32.255814
#                           Slate-throated Whitestart   7027.511628
#                           bird                       34254.697674
# Southern Nightingale-Wren Southern Nightingale-Wren  26516.162791
#                           White-throated Toucan         60.000000
#                           bird                       56210.720930
# White-throated Toucan     White-throated Toucan      48114.953488
#                           bird                       16684.651163
# Yellow-olive Flatbill     Buff-throated Woodcreeper     11.883721
#                           Yellow-olive Flatbill      11380.232558
#                           bird                       24058.906977
#
#                                                        START_TIME
# IN FILE                   COMMON
# Blue-grey Tanager         Blue-grey Tanager          25339.860465
#                           Buff-throated Woodcreeper    144.418605
#                           bird                       24929.232558
# Buff-throated Woodcreeper Buff-throated Woodcreeper  12292.744186
#                           Green-backed Trogon         4638.813953
#                           White-throated Toucan        261.860465
#                           bird                       78225.255814
# Green-backed Trogon       Green-backed Trogon        33882.697674
#                           Scaly-breasted Woodpecker      9.000000
#                           bird                       48389.372093
# Pale-breasted Thrush      Blue-grey Tanager            684.395349
#                           Pale-breasted Thrush       28368.000000
#                           bird                       42907.976744
# Rufous-collared Sparrow   Rufous-collared Sparrow    12212.255814
#                           bird                       33653.558140
# Scaly-breasted Woodpecker Buff-throated Woodcreeper      6.209302
#                           Green-backed Trogon          414.604651
#                           Scaly-breasted Woodpecker  12955.087944
#                           bird                       48324.534884
# Slate-throated Whitestart Blue-grey Tanager             31.767442
#                           Slate-throated Whitestart   6796.720930
#                           bird                       33461.325581
# Southern Nightingale-Wren Southern Nightingale-Wren  26207.255814
#                           White-throated Toucan         59.976744
#                           bird                       55767.558140
# White-throated Toucan     White-throated Toucan      47122.302326
#                           bird                       16218.255814
# Yellow-olive Flatbill     Buff-throated Woodcreeper     11.720930
#                           Yellow-olive Flatbill      11145.744186
#                           bird                       23483.372093

# %% [markdown]
# # Annotation Duration Histograms and Statistics

# %%
annotation_duration_statistics(manual_df)

# %%
# All annotations
annotation_duration_histogram(manual_df, n_bins = 100, title = "T2B Annotation Lengths")

# %%
# Species-specific labels
classes_only_df = class_df[class_df["IN FILE"] == class_df["COMMON"]]
classes_only_df_99 = classes_only_df[classes_only_df["DURATION"] < classes_only_df["DURATION"].quantile(0.99)]
annotation_duration_histogram(classes_only_df_99, n_bins=100, title="Species-Specific Annotation Lengths")
annotation_duration_statistics(classes_only_df)

# %%
# Generic bird labels
bird_only_df = class_df[class_df["MANUAL ID"] == "bird"]
bird_only_df_99 = bird_only_df[bird_only_df["DURATION"] < bird_only_df["DURATION"].quantile(0.99)]
annotation_duration_histogram(bird_only_df_99, n_bins=100, title="Generic Bird Annotation Lengths")
annotation_duration_statistics(bird_only_df)

# %%
# Annotation duration lengths per specific classes
list_of_classes = class_df["MANUAL ID"].unique().tolist()
list_of_classes.sort()

for species in list_of_classes:
    species_df = class_df[class_df["MANUAL ID"] == species]
    annotation_duration_histogram(species_df, n_bins=100, title=swap_scientific_common(species) + " Annotation Lengths")
