# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import random
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import csv
from sklearn.cluster import DBSCAN
import math
import statistics
pd.options.mode.chained_assignment = None  # default='warn'
import itertools
import json


#Convert CSV to Dataframe
data = pd.read_csv("C:/Users/seanh/Downloads/pairwise_user_experiment (1).csv", header=[0])
data["FOLDER"] = data["IN FILE"].apply(lambda x: "")
data["LAST MOD BY"] = data["LAST MOD BY"].apply(lambda x: x.split(" ")[0])
data
# Out:
#                                                 IN FILE  CLIP LENGTH   OFFSET  \
# 0     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034   1.1839
# 1     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034   6.9715
# 2     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034   8.8594
# 3     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034   9.9393
# 4     XC23899_-_White-vented_Shama_-_Copsychus_niger...      61.1034  15.1890
# ...                                                 ...          ...      ...
# 2243  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  22.3916
# 2244  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  23.7316
# 2245  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  24.2615
# 2246  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  24.7815
# 2247  XC688950_-_Balearic_Warbler_-_Sylvia_balearica...      25.9531  25.3315
#
#       DURATION  MAX FREQ  MIN FREQ  SAMPLE RATE           MANUAL ID  \
# 0       1.3399     24000         0        48000  White-vented Shama
# 1       1.5479     24000         0        48000  White-vented Shama
# 2       0.4500     24000         0        48000  White-vented Shama
# 3       1.0800     24000         0        48000  White-vented Shama
# 4       0.9299     24000         0        48000  White-vented Shama
# ...        ...       ...       ...          ...                 ...
# 2243    0.8100     24000         0        48000                bird
# 2244    0.1600     24000         0        48000                bird
# 2245    0.1200     24000         0        48000                bird
# 2246    0.1600     24000         0        48000                bird
# 2247    0.1400     24000         0        48000                bird
#
#       TIME_SPENT LAST MOD BY  CONFIDENCE  RETIRED  COUNTED FOLDER
# 0        141.864       spres    0.577908    False        0
# 1        141.864       spres    0.577908    False        0
# 2        141.864       spres    0.577908    False        0
# 3        141.864       spres    0.577908    False        0
# 4        141.864       spres    0.577908    False        0
# ...          ...         ...         ...      ...      ...    ...
# 2243     311.194      Anshul    0.300511    False        0
# 2244     311.194      Anshul    0.300511    False        0
# 2245     311.194      Anshul    0.300511    False        0
# 2246     311.194      Anshul    0.300511    False        0
# 2247     311.194      Anshul    0.300511    False        0
#
# [2248 rows x 14 columns]

# %% [markdown]
# #### Import Confidence Functions and Create List of Functions

# %%
from confidence_functions.confidence import *
 
confidence_funcs = [ get_silhoutte_confidence, get_silhoutte_users_confidence, fast_majority_vote, get_pairwise_iou]
confidence_funcs
# Out:
# [<function confidence_functions.confidence.get_silhoutte_confidence(df, users)>,
#  <function confidence_functions.confidence.get_silhoutte_users_confidence(df, users)>,
#  <function confidence_functions.confidence.majority_vote(df, users, chunk_length=1)>,
#  <function confidence_functions.confidence.get_pairwise_iou(df, users)>]

# %% [markdown]
# ### permuatation code

# %%
def permutate_users(df, num_users, clip_name, confidence_func):
    #Get data for indivual clip
    results = []
    df = df[df["IN FILE"] == clip_name]
    users = df["LAST MOD BY"].unique()
    
    for user_permutation in itertools.permutations(users, num_users):
        try:
            results.append(confidence_func(df, user_permutation))
        except:
            pass
        
    results = np.mean(results)
    return results
    
#permutate_users(data, 2, "XC425555_-_Screaming_Piha_-_Lipaugus_vociferans.mp3", get_silhoutte_users_confidence)

# %% [markdown]
# ### Clip Spefific Experiment

# %%
def determine_confidence_by_clip(df, clip_name, confidence_funcs):
    results = {}
    df = df[df["IN FILE"] == clip_name]
    users = df["LAST MOD BY"].unique()
    for confidence_func in confidence_funcs:
        print("working with function: " + confidence_func.__name__)
        results[confidence_func] = {}
        
        for user_count in range(6):
            results[confidence_func][user_count+1]= permutate_users(df, user_count+1, clip_name, confidence_func)
    return results

def determine_confidence_by_func(df, confidence_funcs):
    results = {}
    users = df["LAST MOD BY"].unique()
    files = df["IN FILE"].unique()
    for func in confidence_funcs:
        results[func] = {}
        for user_count in range(6):
            print("USER", user_count)
            confidence = np.array([])
            for file in files:
                if (user_count < len(df[df["IN FILE"] == file]["LAST MOD BY"].unique())):
                       confidence = np.append(confidence, permutate_users(df, user_count+1, file, func))
            print(confidence)
            confidence = confidence.mean()
            results[func][user_count+1] = confidence
    return results
        
#determine_confidence_by_clip(data, "XC425555_-_Screaming_Piha_-_Lipaugus_vociferans.mp3", confidence_funcs)
#determine_confidence_by_func(data, confidence_funcs)

# %% [markdown]
# # Full Experiment

# %%
def run_experiment(df, confidence_funcs):
    #Get the adverage confidence over number of users for each file
    results = {"by_clip": {}, "Over_all_clips": {}}
    filenames = df["IN FILE"].unique()
    #for file in filenames:
    #    print("working with file: " + file)
    #    results["by_clip"][file] = determine_confidence_by_clip(df, file, confidence_funcs)
    
    print("Get adverage over all files")
    results["Over_all_clips"] = determine_confidence_by_func(df, confidence_funcs)
        
        
    
    return results

#experiment_results = run_experiment(data, confidence_funcs)
#experiment_results

# %%
def generate_graph(experiment_results):
    for filename in experiment_results:
        #For each filename, plot the performance of each confidence function
        for confidence_func in experiment_results[filename]:
            confidence_dirc = experiment_results[filename][confidence_func]
            users_count = list(confidence_dirc.keys())
            score = list(confidence_dirc.values())
            plt.plot(users_count, score, label=(confidence_func.__name__))
        
        #Throw in some fancy formatting
        plt.legend(loc='best')
        plt.title(filename)
        plt.xlabel("User Count")
        plt.ylabel("Average Confidence of Function")
        plt.show()

#generate_graph(experiment_results["by_clip"])

# %%
def generate_graph_all(experiment_results):
    #For each filename, plot the performance of each confidence function
    for confidence_func in experiment_results:
        confidence_dirc = experiment_results[confidence_func]
        users_count = list(confidence_dirc.keys())
        score = list(confidence_dirc.values())
        plt.plot(users_count, score, label=(confidence_func.__name__))

    #Throw in some fancy formatting
    plt.legend(loc='best')
    #plt.title(filename)
    plt.xlabel("User Count")
    plt.ylabel("Average Confidence of Function")
    plt.show()
    
    
    
    
#generate_graph_all(experiment_results["Over_all_clips"])
#Experiment Failed -> To Time Complex

# %% [markdown]
# ## Experiment Design 2

# %%
def experiment_via_random_orders(df, confidence_funcs, num_of_orders=1000):
    results = {}
    users = df["LAST MOD BY"].unique()
    files = df["IN FILE"].unique()
    for func in confidence_funcs:
        results[func.__name__] = {}
        for i in range (len(users)):
            results[func.__name__][i] = []
    
    
    for file in files:
        print("on ", file, "of", len(files))
        tmp_df = df[df["IN FILE"] == file]
        users = tmp_df["LAST MOD BY"].unique()

        to_be_randomly_inserted = np.tile(users, (num_of_orders, 1))
        to_be_randomly_inserted = pd.DataFrame(to_be_randomly_inserted)
        to_be_randomly_inserted = to_be_randomly_inserted.apply(lambda x:np.random.shuffle(x) or x, axis=1)
        random_insertion_orders = to_be_randomly_inserted.values
        
        count = 0
        for insertion_order in random_insertion_orders:
            print(count)
            count += 1
            for func in confidence_funcs: 
                for user_count in range(1,len(insertion_order)):
                    curr_insert = insertion_order[:user_count+1]
                    tmp_df_users = tmp_df[tmp_df["LAST MOD BY"].isin(curr_insert)]
                    try:
                        results[func.__name__][user_count].append(func(tmp_df_users, curr_insert))
                    except:
                        pass
        json_object = json.dumps(results, indent=4)
 
        # Writing to sample.json
        with open("experiment_results.json", "w") as outfile:
            outfile.write(json_object)
    return results

#experiment_results = experiment_via_random_orders(data, confidence_funcs, 1000)
#experiment_results
#Experiment Failed -> To Time Complex

# %% [markdown]
# # Experiment 3, Work to Save Time

# %%
import time

 
confidence_funcs = [ get_silhoutte_confidence, get_silhoutte_users_confidence, fast_majority_vote, get_pairwise_iou]
confidence_funcs

def experiment_3(df, confidence_funcs, num_of_trials=10):
    results = {}
    users = df["LAST MOD BY"].unique()
    files = df["IN FILE"].unique()
    for func in confidence_funcs:
        results[func.__name__] = {}
        for i in range (len(users)):
            results[func.__name__][i] = []
        results[func.__name__]["TIMING"] = []
    
    
    for trial in range(num_of_trials):
        start = time.time()
        print("============================")
        print(trial)
        file  = np.random.choice(files, size=None, replace=True, p=None)
        tmp_df = df[df["IN FILE"] == file]
        users = tmp_df["LAST MOD BY"].unique()

        to_be_randomly_inserted = np.tile(users, (1, 1))
        to_be_randomly_inserted = pd.DataFrame(to_be_randomly_inserted)
        to_be_randomly_inserted = to_be_randomly_inserted.apply(lambda x:np.random.shuffle(x) or x, axis=1)
        random_insertion_orders = to_be_randomly_inserted.values
        
        end = time.time()
        #print("Set Up", end - start)
        
        for insertion_order in random_insertion_orders:
            for func in confidence_funcs:
                start = time.time()
                for user_count in range(1,len(insertion_order)):
                    curr_insert = insertion_order[:user_count+1]
                    tmp_df_users = tmp_df[tmp_df["LAST MOD BY"].isin(curr_insert)]
                    try:
                        results[func.__name__][user_count].append(func(tmp_df_users, curr_insert))
                    except:
                        pass
                end = time.time()
                print(func.__name__, end - start)
                results[func.__name__]["TIMING"].append(end - start)
                    
        results["TRIAL COUNT"] = trial
        json_object = json.dumps(results, indent=4)
 
        # Writing to sample.json
        with open("experiment_results.json", "w") as outfile:
            outfile.write(json_object)
        
    return results

# %%
experiment_results = experiment_3(data, confidence_funcs, num_of_trials=1000)
# Out:
# ============================
# 0
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2010211944580078
# get_silhoutte_users_confidence 0.20261645317077637
# fast_majority_vote 1.0129685401916504
# get_pairwise_iou 2.0383455753326416
# ============================
# 1
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20977783203125
# get_silhoutte_users_confidence 0.22624683380126953
# fast_majority_vote 0.8074069023132324
# get_pairwise_iou 0.8857450485229492
# ============================
# 2
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.1893296241760254
# get_silhoutte_users_confidence
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.18558573722839355
# fast_majority_vote 0.7694127559661865
# get_pairwise_iou 0.7747876644134521
# ============================
# 3
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.18690752983093262
# get_silhoutte_users_confidence 0.20603585243225098
# fast_majority_vote 1.3538732528686523
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 2.9995346069335938
# ============================
# 4
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.21597814559936523
# get_silhoutte_users_confidence 0.23611068725585938
# fast_majority_vote 0.7050673961639404
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.7127983570098877
# ============================
# 5
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20569467544555664
# get_silhoutte_users_confidence 0.2557492256164551
# fast_majority_vote 0.6207196712493896
# get_pairwise_iou 0.9542455673217773
# ============================
# 6
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.27902722358703613
# get_silhoutte_users_confidence 0.3008706569671631
# fast_majority_vote 0.8975164890289307
# get_pairwise_iou 2.5283584594726562
# ============================
# 7
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6794431209564209
# get_silhoutte_users_confidence 0.7019975185394287
# fast_majority_vote 4.639221429824829
# get_pairwise_iou 11.970397710800171
# ============================
# 8
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.18101239204406738
# get_silhoutte_users_confidence 0.18551325798034668
# fast_majority_vote 0.48836374282836914
# get_pairwise_iou 0.7902350425720215
# ============================
# 9
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3605360984802246
# get_silhoutte_users_confidence 0.37257838249206543
# fast_majority_vote 1.663597583770752
# get_pairwise_iou 3.2476308345794678
# ============================
# 10
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20709729194641113
# get_silhoutte_users_confidence 0.24098920822143555
# fast_majority_vote 0.4746863842010498
# get_pairwise_iou 0.9588193893432617
# ============================
# 11
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3366363048553467
# get_silhoutte_users_confidence 0.3484385013580322
# fast_majority_vote 0.9271280765533447
# get_pairwise_iou 1.3587989807128906
# ============================
# 12
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2702059745788574
# get_silhoutte_users_confidence 0.30705761909484863
# fast_majority_vote 0.7705352306365967
# get_pairwise_iou 2.0547263622283936
# ============================
# 13
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2187349796295166
# get_silhoutte_users_confidence 0.25508832931518555
# fast_majority_vote 0.5239367485046387
# get_pairwise_iou 0.8614211082458496
# ============================
# 14
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6830148696899414
# get_silhoutte_users_confidence 0.6366286277770996
# fast_majority_vote 4.955134391784668
# get_pairwise_iou 9.855339527130127
# ============================
# 15
# get_silhoutte_confidence 0.1093285083770752
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_users_confidence 0.10551667213439941
# fast_majority_vote 1.259913444519043
# get_pairwise_iou 2.6780662536621094
# ============================
# 16
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.5470995903015137
# get_silhoutte_users_confidence 0.5252854824066162
# fast_majority_vote 1.62636399269104
# get_pairwise_iou 3.138441801071167
# ============================
# 17
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3181140422821045
# get_silhoutte_users_confidence 0.29045534133911133
# fast_majority_vote 0.940723180770874
# get_pairwise_iou 1.8704931735992432
# ============================
# 18
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20918941497802734
# get_silhoutte_users_confidence 0.2113037109375
# fast_majority_vote 1.0542709827423096
# get_pairwise_iou 2.279087543487549
# ============================
# 19
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3614335060119629
# get_silhoutte_users_confidence 0.4046778678894043
# fast_majority_vote 0.4296839237213135
# get_pairwise_iou 0.986405611038208
# ============================
# 20
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2739541530609131
# get_silhoutte_users_confidence 0.2736043930053711
# fast_majority_vote 1.0673606395721436
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.9755752086639404
# ============================
# 21
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2681925296783447
# get_silhoutte_users_confidence 0.299210786819458
# fast_majority_vote 0.7349796295166016
# get_pairwise_iou 1.9918694496154785
# ============================
# 22
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.25681400299072266
# get_silhoutte_users_confidence 0.26633358001708984
# fast_majority_vote 1.891836166381836
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 4.8838183879852295
# ============================
# 23
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.1905977725982666
# get_silhoutte_users_confidence 0.2324085235595703
# fast_majority_vote 1.0095865726470947
# get_pairwise_iou 2.329033136367798
# ============================
# 24
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.410900354385376
# get_silhoutte_users_confidence 0.40115833282470703
# fast_majority_vote 0.9585983753204346
# get_pairwise_iou 1.4290165901184082
# ============================
# 25
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.26852941513061523
# get_silhoutte_users_confidence 0.2756037712097168
# fast_majority_vote 1.727919340133667
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 5.431126356124878
# ============================
# 26
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6481287479400635
# get_silhoutte_users_confidence 0.645517110824585
# fast_majority_vote 4.494618892669678
# get_pairwise_iou 12.639537334442139
# ============================
# 27
# get_silhoutte_confidence 0.16391825675964355
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_users_confidence 0.19737839698791504
# fast_majority_vote 0.5745832920074463
# get_pairwise_iou 0.8653087615966797
# ============================
# 28
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.1830129623413086
# get_silhoutte_users_confidence 0.21969938278198242
# fast_majority_vote 0.7004320621490479
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.0123474597930908
# ============================
# 29
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.16799664497375488
# get_silhoutte_users_confidence 0.18621587753295898
# fast_majority_vote 0.7086360454559326
# get_pairwise_iou 0.8274991512298584
# ============================
# 30
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.29018712043762207
# get_silhoutte_users_confidence 0.28128981590270996
# fast_majority_vote 0.7407786846160889
# get_pairwise_iou 2.036165475845337
# ============================
# 31
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.319594144821167
# get_silhoutte_users_confidence 0.3548409938812256
# fast_majority_vote 0.4393951892852783
# get_pairwise_iou 0.9268059730529785
# ============================
# 32
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
#  0.17525482177734375
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.2306077480316162
# fast_majority_vote 0.3743588924407959
# get_pairwise_iou 0.7308070659637451
# ============================
# 33
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6566953659057617
# get_silhoutte_users_confidence 0.6592092514038086
# fast_majority_vote 4.868250846862793
# get_pairwise_iou 14.258041143417358
# ============================
# 34
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.24255728721618652
# get_silhoutte_users_confidence 0.24916887283325195
# fast_majority_vote 0.9662890434265137
# get_pairwise_iou 1.6982171535491943
# ============================
# 35
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2172253131866455
# get_silhoutte_users_confidence 0.2351067066192627
# fast_majority_vote 0.6957259178161621
# get_pairwise_iou 0.8091843128204346
# ============================
# 36
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.31794238090515137
# get_silhoutte_users_confidence 0.3365914821624756
# fast_majority_vote 0.7847476005554199
# get_pairwise_iou 1.1129002571105957
# ============================
# 37
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.4641845226287842
# get_silhoutte_users_confidence 0.4431116580963135
# fast_majority_vote 1.5587000846862793
# get_pairwise_iou 2.974386692047119
# ============================
# 38
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6123111248016357
# get_silhoutte_users_confidence 0.6664323806762695
# fast_majority_vote 4.4605185985565186
# get_pairwise_iou 12.680914163589478
# ============================
# 39
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.19563770294189453
# get_silhoutte_users_confidence 0.21080565452575684
# fast_majority_vote 0.6209232807159424
# get_pairwise_iou 1.5913183689117432
# ============================
# 40
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20943355560302734
# get_silhoutte_users_confidence 0.21386981010437012
# fast_majority_vote 0.7418687343597412
# get_pairwise_iou 1.6394314765930176
# ============================
# 41
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20858120918273926
# get_silhoutte_users_confidence 0.25641822814941406
# fast_majority_vote 0.579667329788208
# get_pairwise_iou 0.8547153472900391
# ============================
# 42
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.30008673667907715
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.31114721298217773
# fast_majority_vote 0.7678709030151367
# get_pairwise_iou 1.2052350044250488
# ============================
# 43
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20851850509643555
# get_silhoutte_users_confidence 0.2315201759338379
# fast_majority_vote 0.6763956546783447
# get_pairwise_iou 1.517237901687622
# ============================
# 44
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.25818586349487305
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.2711014747619629
# fast_majority_vote 0.8997838497161865
# get_pairwise_iou 1.5896990299224854
# ============================
# 45
# get_silhoutte_confidence 0.16221165657043457
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_users_confidence 0.22928118705749512
# fast_majority_vote 0.5411491394042969
# get_pairwise_iou 1.0189828872680664
# ============================
# 46
# get_silhoutte_confidence 0.13309645652770996
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.17264485359191895
# fast_majority_vote 0.6741607189178467
# get_pairwise_iou 0.6898083686828613
# ============================
# 47
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.27854228019714355
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.3030574321746826
# fast_majority_vote 0.7797207832336426
# get_pairwise_iou 1.233855962753296
# ============================
# 48
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3748354911804199
# get_silhoutte_users_confidence 0.39840245246887207
# fast_majority_vote 1.5593597888946533
# get_pairwise_iou 3.4999473094940186
# ============================
# 49
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.17679524421691895
# get_silhoutte_users_confidence
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.19331097602844238
# fast_majority_vote 0.6398453712463379
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 0.9219863414764404
# ============================
# 50
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.24188232421875
# get_silhoutte_users_confidence 0.24937939643859863
# fast_majority_vote 0.79854416847229
# get_pairwise_iou 1.8332841396331787
# ============================
# 51
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.17732620239257812
# get_silhoutte_users_confidence 0.2156684398651123
# fast_majority_vote 0.4194345474243164
# get_pairwise_iou 0.8233127593994141
# ============================
# 52
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.18367791175842285
# get_silhoutte_users_confidence
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.19634246826171875
# fast_majority_vote 0.5680973529815674
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.003969430923462
# ============================
# 53
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2139899730682373
# get_silhoutte_users_confidence 0.23396944999694824
# fast_majority_vote 0.9893918037414551
# get_pairwise_iou 1.637549877166748
# ============================
# 54
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.36098504066467285
# get_silhoutte_users_confidence 0.39978694915771484
# fast_majority_vote 2.0382490158081055
# get_pairwise_iou 3.255307197570801
# ============================
# 55
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.22509121894836426
# get_silhoutte_users_confidence 0.2716972827911377
# fast_majority_vote 0.7214646339416504
# get_pairwise_iou 1.5794713497161865
# ============================
# 56
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.20108556747436523
# get_silhoutte_users_confidence 0.24240946769714355
# fast_majority_vote 0.6925933361053467
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.9457001686096191
# ============================
# 57
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3114652633666992
# get_silhoutte_users_confidence 0.3341057300567627
# fast_majority_vote 0.4134337902069092
# get_pairwise_iou 0.8983418941497803
# ============================
# 58
# get_silhoutte_confidence 0.16202855110168457
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.20348620414733887
# fast_majority_vote 0.27845311164855957
# get_pairwise_iou 0.6651766300201416
# ============================
# 59
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.5904567241668701
# get_silhoutte_users_confidence 0.6433281898498535
# fast_majority_vote 4.686545372009277
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 12.42331051826477
# ============================
# 60
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3506319522857666
# get_silhoutte_users_confidence 0.3671875
# fast_majority_vote 1.2467124462127686
# get_pairwise_iou 1.382950782775879
# ============================
# 61
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.28214097023010254
# get_silhoutte_users_confidence 0.28089070320129395
# fast_majority_vote 0.7798285484313965
# get_pairwise_iou 1.6803579330444336
# ============================
# 62
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
# ...
# ============================
# 977
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.1294238567352295
# get_silhoutte_users_confidence 0.13108205795288086
# fast_majority_vote 1.1535718441009521
# get_pairwise_iou 2.5918731689453125
# ============================
# 978
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6407322883605957
# get_silhoutte_users_confidence 0.643190860748291
# fast_majority_vote 4.2858216762542725
# get_pairwise_iou 9.926619052886963
# ============================
# 979
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.19124269485473633
# get_silhoutte_users_confidence 0.210068941116333
# fast_majority_vote 0.7144980430603027
# get_pairwise_iou 1.5970897674560547
# ============================
# 980
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.34953880310058594
# get_silhoutte_users_confidence 0.37993478775024414
# fast_majority_vote 1.6251304149627686
# get_pairwise_iou 3.4639227390289307
# ============================
# 981
# get_silhoutte_confidence 0.1074066162109375
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_users_confidence 0.11321020126342773
# fast_majority_vote 1.2635366916656494
# get_pairwise_iou 2.866924524307251
# ============================
# 982
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.39844179153442383
# get_silhoutte_users_confidence 0.3527834415435791
# fast_majority_vote 1.4440810680389404
# get_pairwise_iou 2.850372076034546
# ============================
# 983
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.1933586597442627
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.21602082252502441
# fast_majority_vote 0.28261494636535645
# get_pairwise_iou 0.7515175342559814
# ============================
# 984
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.5503363609313965
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.5665183067321777
# fast_majority_vote 4.623714923858643
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 11.168641805648804
# ============================
# 985
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3104972839355469
# get_silhoutte_users_confidence 0.3485836982727051
# fast_majority_vote 0.44152212142944336
# get_pairwise_iou 0.8989651203155518
# ============================
# 986
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.19105076789855957
# get_silhoutte_users_confidence 0.2075941562652588
# fast_majority_vote 0.7703461647033691
# get_pairwise_iou 0.7665314674377441
# ============================
# 987
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.4666910171508789
# get_silhoutte_users_confidence 0.4990725517272949
# fast_majority_vote 2.4218032360076904
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 5.354650974273682
# ============================
# 988
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2516038417816162
# get_silhoutte_users_confidence 0.26354002952575684
# fast_majority_vote 1.2439301013946533
# get_pairwise_iou 1.8965835571289062
# ============================
# 989
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2681562900543213
# get_silhoutte_users_confidence 0.26451778411865234
# fast_majority_vote 0.9937536716461182
# get_pairwise_iou 1.8525207042694092
# ============================
# 990
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.19123244285583496
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.23732256889343262
# fast_majority_vote 0.34595489501953125
# get_pairwise_iou 0.7106361389160156
# ============================
# 991
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.19502973556518555
# get_silhoutte_users_confidence 0.22503066062927246
# fast_majority_vote 0.8956179618835449
# get_pairwise_iou 1.6988716125488281
# ============================
# 992
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.12666082382202148
# get_silhoutte_users_confidence 0.12212634086608887
# fast_majority_vote 1.3672263622283936
# get_pairwise_iou 3.409719467163086
# ============================
# 993
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.23301100730895996
# get_silhoutte_users_confidence 0.25890517234802246
# fast_majority_vote 0.5740208625793457
# get_pairwise_iou 0.985832691192627
# ============================
# 994
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.370441198348999
# get_silhoutte_users_confidence 0.44077420234680176
# fast_majority_vote 2.5564463138580322
# get_pairwise_iou 3.9778480529785156
# ============================
# 995
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.34107184410095215
# get_silhoutte_users_confidence 0.35756897926330566
# fast_majority_vote 1.5852341651916504
# get_pairwise_iou 3.6405506134033203
# ============================
# 996
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.19761109352111816
# get_silhoutte_users_confidence 0.23894214630126953
# fast_majority_vote 0.9001035690307617
# get_pairwise_iou 2.104267120361328
# ============================
# 997
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.14980173110961914
# get_silhoutte_users_confidence 0.1743924617767334
# fast_majority_vote 0.5449843406677246
# get_pairwise_iou 0.762963056564331
# ============================
# 998
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.20929217338562012
# get_silhoutte_users_confidence 0.20426726341247559
# fast_majority_vote 1.1583738327026367
# get_pairwise_iou 2.5395121574401855
# ============================
# 999
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.26763343811035156
# get_silhoutte_users_confidence 0.25227928161621094
# fast_majority_vote 0.5287775993347168
# get_pairwise_iou 1.027540683746338

# %%
experiment_results
# Out:
# {'get_silhoutte_confidence': {0: [],
#   1: [0.9916037176479734,
#    0.7942171218220669,
#    0,
#    0.5159792040259197,
#    0.6026790941999319,
#    0.643378110345052,
#    0.9413737676593945,
#    0.39864128234507135,
#    0.7639739994918491,
#    0.7198294431111723,
#    0.684880347368954,
#    0.5317057818695885,
#    0.9156879844789101,
#    0.8352280859422829,
#    0.4604368446921037,
#    0.9219667742953079,
#    0.5185014674691367,
#    0.9604842539940721,
#    0.7112031186581722,
#    0.7510969299619114,
#    0.9219747776483043,
#    0.43242700021975855,
#    0.9663652711781985,
#    0.7780729537686466,
#    0.3893812103688059,
#    0.9941836766182516,
#    0,
#    0.7817258098133049,
#    0.7327466899529297,
#    0.9219747776483043,
#    0.5591496265843613,
#    0,
#    0.5729509988628831,
#    0.6261575860635057,
#    0.9233723679117118,
#    0.546128111162963,
#    0.8115913188534805,
#    0.856512064020615,
#    0.8893598762336601,
#    0.9425174197544821,
#    0.6657346457769384,
#    0,
#    0.991675310801823,
#    0,
#    0.9780170440641369,
#    0,
#    0,
#    0.7345268005468326,
#    0,
#    0.9855109100996613,
#    0.7477705478668213,
#    1.5759501457214355,
#    5.812360763549805,
#    3.1901695728302,
#    1.669492483139038,
#    2.065247058868408,
#    2.597688913345337,
#    1.4761648178100586,
#    1.4545493125915527,
#    1.9675862789154053,
#    1.5202155113220215,
#    1.8579721450805664,
#    9.774410963058472,
#    0.9512035846710205,
#    0.66005539894104,
#    0.8341479301452637,
#    1.1743838787078857,
#    0.7802343368530273,
#    1.9522035121917725,
#    2.433100938796997,
#    1.8500902652740479,
#    0.8348162174224854,
#    2.7134897708892822,
#    0.9437525272369385,
#    0.913130521774292,
#    11.761560678482056,
#    1.6406373977661133,
#    0.6993825435638428,
#    10.646210670471191,
#    1.2271857261657715,
#    1.8439745903015137,
#    4.589974403381348,
#    0.8737120628356934,
#    1.9512536525726318,
#    2.5918731689453125,
#    9.926619052886963,
#    1.5970897674560547,
#    3.4639227390289307,
#    2.866924524307251,
#    2.850372076034546,
#    0.7515175342559814,
#    11.168641805648804,
#    0.8989651203155518,
#    0.7665314674377441,
#    5.354650974273682,
#    1.8965835571289062,
#    1.8525207042694092,
#    0.7106361389160156,
#    1.6988716125488281,
#    3.409719467163086,
#    0.985832691192627,
#    3.9778480529785156,
#    3.6405506134033203,
#    2.104267120361328,
#    0.762963056564331,
#    2.5395121574401855,
#    1.027540683746338]},
#  'TRIAL COUNT': 999}

# %%
def generate_graph_all(experiment_results):
    #For each filename, plot the performance of each confidence function
    for confidence_func in experiment_results:
        confidence_dirc = experiment_results[confidence_func]
        
        users_count = list(confidence_dirc.keys())
        score = list(confidence_dirc.values())
        plt.plot(users_count, score, label=(confidence_func))

    #Throw in some fancy formatting
    plt.legend(bbox_to_anchor=(1.04,1), loc="upper left")
    #plt.title(filename)
    plt.xlabel("Number of users who annotated")
    plt.ylabel("Average Confidence of Function For Number Of Users")
    plt.show()
generate_graph_all(experiment_results)

# %%
def process_results(experiment_results):
    print(experiment_results)
    print ("trails ran",  experiment_results["TRIAL COUNT"])
    del experiment_results["TRIAL COUNT"]
    
    for confidence_func in experiment_results:
        confidence_dirc = experiment_results[confidence_func]
        print("Time for ", confidence_func, " was ", confidence_dirc["TIMING"])
        del confidence_dirc["TIMING"]
        users_count = list(confidence_dirc.keys())
        for count in users_count:
            experiment_results[confidence_func][count] = np.array(confidence_dirc[count]).mean()
    return experiment_results

processed = process_results(experiment_results)
generate_graph_all(processed)
# Out:
# {'get_silhoutte_confidence': {0: nan, 1: 0.6707766682590056, 2: 0.7534597883486456, 3: 0.7807681283120604, 4: 0.8020158073315871, 5: 0.815639587975904, 6: 0.8231357076666826, 7: 0.8368230604948389, 8: 0.8777613028203562, 9: 0.7831482280118865, 10: 0.8954703071781938, 11: nan}, 'get_silhoutte_users_confidence': {0: nan, 1: 0.63308652423836, 2: 0.6970773700932777, 3: 0.7047147210976449, 4: 0.7032146033464969, 5: 0.6983648167440016, 6: 0.6932402256613217, 7: 0.6782613153401693, 8: 0.7014368568464303, 9: 0.6311393313972476, 10: 0.7277351535890969, 11: nan}, 'fast_majority_vote': {0: nan, 1: 0.7294598946195906, 2: 0.6369361056706127, 3: 0.5830456260590829, 4: 0.5424531805988034, 5: 0.5154034921511982, 6: 0.48371449737454403, 7: 0.4572970756598004, 8: 0.44954623675123656, 9: 0.4606610871156785, 10: 0.45454545454545464, 11: nan}, 'get_pairwise_iou': {0: nan, 1: 0.4094713750259913, 2: 0.5168449747417097, 3: 0.5489098784799014, 4: 0.5574940112481026, 5: 0.5574606856928906, 6: 0.5570100341019468, 7: 0.5263023980889616, 8: 0.5838636718471811, 9: 0.5824626187422213, 10: 0.4396509407044953, 11: nan}}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-155-18686eabed8c> in <module>
#      13     return experiment_results
#      14
# ---> 15 processed = process_results(experiment_results)
#      16 generate_graph_all(processed)
#
# <ipython-input-155-18686eabed8c> in process_results(experiment_results)
#       1 def process_results(experiment_results):
#       2     print(experiment_results)
# ----> 3     print ("trails ran",  experiment_results["TRIAL COUNT"])
#       4     del experiment_results["TRIAL COUNT"]
#       5
#
# KeyError: 'TRIAL COUNT'

# %% [markdown]
# # Experiment 4: Alternative Parameters

# %%
confidence_funcs = [ get_silhoutte_confidence, get_silhoutte_users_confidence, fast_majority_vote, get_pairwise_iou]
experiment_results = experiment_3(data, confidence_funcs, num_of_trials=5000)
processed = process_results(experiment_results)
generate_graph_all(processed)
# Out:
# ============================
# 0
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.2038881778717041
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.21965289115905762
# fast_majority_vote 0.7719783782958984
# get_pairwise_iou 1.621032953262329
# ============================
# 1
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.8330481052398682
# get_silhoutte_users_confidence 0.7239224910736084
# fast_majority_vote 1.5880074501037598
# get_pairwise_iou 3.8279759883880615
# ============================
# 2
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.1727287769317627
# get_silhoutte_users_confidence 0.21774077415466309
# fast_majority_vote 0.8553617000579834
# get_pairwise_iou 1.0799744129180908
# ============================
# 3
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.28733038902282715
# get_silhoutte_users_confidence 0.328718900680542
# fast_majority_vote 0.7259087562561035
# get_pairwise_iou 2.0596628189086914
# ============================
# 4
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6919028759002686
# get_silhoutte_users_confidence 0.7300159931182861
# fast_majority_vote 1.6864943504333496
# get_pairwise_iou 2.919806718826294
# ============================
# 5
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.35359907150268555
# get_silhoutte_users_confidence 0.35004687309265137
# fast_majority_vote 0.9535176753997803
# get_pairwise_iou 1.2885851860046387
# ============================
# 6
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.37815237045288086
# get_silhoutte_users_confidence 0.3797323703765869
# fast_majority_vote 1.6359617710113525
# get_pairwise_iou 3.910635471343994
# ============================
# 7
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.4029116630554199
# get_silhoutte_users_confidence 0.36869215965270996
# fast_majority_vote 0.9970669746398926
# get_pairwise_iou 1.2478792667388916
# ============================
# 8
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.19708800315856934
# get_silhoutte_users_confidence 0.23797059059143066
# fast_majority_vote 0.7185821533203125
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.855297565460205
# ============================
# 9
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.24434590339660645
# get_silhoutte_users_confidence 0.2486109733581543
# fast_majority_vote 0.7549314498901367
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 2.086082935333252
# ============================
# 10
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.17737102508544922
# get_silhoutte_users_confidence 0.16854262351989746
# fast_majority_vote 0.5205304622650146
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 0.8959109783172607
# ============================
# 11
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.45323848724365234
# get_silhoutte_users_confidence 0.432025671005249
# fast_majority_vote 1.574425458908081
# get_pairwise_iou 3.191314697265625
# ============================
# 12
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.24036884307861328
# get_silhoutte_users_confidence 0.2790360450744629
# fast_majority_vote 0.6693451404571533
# get_pairwise_iou 1.8833084106445312
# ============================
# 13
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.6125977039337158
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.651423454284668
# fast_majority_vote 5.001649618148804
# get_pairwise_iou 12.75827145576477
# ============================
# 14
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6907069683074951
# get_silhoutte_users_confidence 0.6897902488708496
# fast_majority_vote 4.952922582626343
# get_pairwise_iou 10.176870107650757
# ============================
# 15
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.41869378089904785
# get_silhoutte_users_confidence 0.45107316970825195
# fast_majority_vote 1.6228492259979248
# get_pairwise_iou 3.1861050128936768
# ============================
# 16
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.20357990264892578
# get_silhoutte_users_confidence 0.21802425384521484
# fast_majority_vote 0.5116298198699951
# get_pairwise_iou 0.9752895832061768
# ============================
# 17
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.4019505977630615
# get_silhoutte_users_confidence 0.4024965763092041
# fast_majority_vote 1.9887807369232178
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 4.001393795013428
# ============================
# 18
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.23274922370910645
# get_silhoutte_users_confidence 0.25293469429016113
# fast_majority_vote 1.6780102252960205
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 4.8555004596710205
# ============================
# 19
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6825704574584961
# get_silhoutte_users_confidence 0.6515049934387207
# fast_majority_vote 4.401660919189453
# get_pairwise_iou 12.386181116104126
# ============================
# 20
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.26018643379211426
# get_silhoutte_users_confidence 0.26876020431518555
# fast_majority_vote 1.4769940376281738
# get_pairwise_iou 2.1900463104248047
# ============================
# 21
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.5803370475769043
# get_silhoutte_users_confidence 0.6492316722869873
# fast_majority_vote 5.026468753814697
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 11.232630729675293
# ============================
# 22
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3703601360321045
# get_silhoutte_users_confidence 0.41668057441711426
# fast_majority_vote 1.7789292335510254
# get_pairwise_iou 3.526082992553711
# ============================
# 23
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6822152137756348
# get_silhoutte_users_confidence 0.6886947154998779
# fast_majority_vote 3.9628865718841553
# get_pairwise_iou 13.708980560302734
# ============================
# 24
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.44921183586120605
# get_silhoutte_users_confidence 0.44620656967163086
# fast_majority_vote 2.282606363296509
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 6.067728757858276
# ============================
# 25
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2673952579498291
# get_silhoutte_users_confidence 0.26579713821411133
# fast_majority_vote 1.3006069660186768
# get_pairwise_iou 1.9192235469818115
# ============================
# 26
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.37503504753112793
# get_silhoutte_users_confidence 0.37691187858581543
# fast_majority_vote 1.8386831283569336
# get_pairwise_iou 3.3918912410736084
# ============================
# 27
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.27997827529907227
# get_silhoutte_users_confidence 0.270768404006958
# fast_majority_vote 0.9271483421325684
# get_pairwise_iou 2.0589823722839355
# ============================
# 28
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.24322891235351562
# get_silhoutte_users_confidence 0.2575089931488037
# fast_majority_vote 1.4018166065216064
# get_pairwise_iou 2.1610562801361084
# ============================
# 29
# get_silhoutte_confidence 0.16739845275878906
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_users_confidence 0.19508099555969238
# fast_majority_vote 0.5833494663238525
# get_pairwise_iou 0.7503640651702881
# ============================
# 30
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.25425243377685547
# get_silhoutte_users_confidence 0.2504737377166748
# fast_majority_vote 0.9523270130157471
# get_pairwise_iou 2.0679686069488525
# ============================
# 31
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.4216029644012451
# get_silhoutte_users_confidence 0.42633628845214844
# fast_majority_vote 2.1423113346099854
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 5.901729106903076
# ============================
# 32
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.329815149307251
# get_silhoutte_users_confidence 0.35237956047058105
# fast_majority_vote 0.8110041618347168
# get_pairwise_iou 1.1654725074768066
# ============================
# 33
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.2094266414642334
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.24549078941345215
# fast_majority_vote 0.4049549102783203
# get_pairwise_iou 0.7011897563934326
# ============================
# 34
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.361652135848999
# get_silhoutte_users_confidence 0.33107471466064453
# fast_majority_vote 1.0035736560821533
# get_pairwise_iou 1.7991416454315186
# ============================
# 35
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3901982307434082
# get_silhoutte_users_confidence 0.4296684265136719
# fast_majority_vote 2.0451548099517822
# get_pairwise_iou 3.62404203414917
# ============================
# 36
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.35219526290893555
# get_silhoutte_users_confidence 0.33318448066711426
# fast_majority_vote 0.9127907752990723
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_pairwise_iou 1.2706918716430664
# ============================
# 37
# get_silhoutte_confidence 0.6074283123016357
# get_silhoutte_users_confidence 0.6642436981201172
# fast_majority_vote 4.393518686294556
# get_pairwise_iou 9.837337732315063
# ============================
# 38
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.1854875087738037
# get_silhoutte_users_confidence 0.21270227432250977
# fast_majority_vote 0.8950774669647217
# get_pairwise_iou 1.7607107162475586
# ============================
# 39
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.35825085639953613
# get_silhoutte_users_confidence 0.3713068962097168
# fast_majority_vote 2.289205551147461
# get_pairwise_iou 3.4776556491851807
# ============================
# 40
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.27097153663635254
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.27264833450317383
# fast_majority_vote 1.002129316329956
# get_pairwise_iou 1.7124848365783691
# ============================
# 41
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3264155387878418
# get_silhoutte_users_confidence 0.3328080177307129
# fast_majority_vote 0.7975778579711914
# get_pairwise_iou 1.2468616962432861
# ============================
# 42
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.21679401397705078
# get_silhoutte_users_confidence 0.24916434288024902
# fast_majority_vote 0.5191929340362549
# get_pairwise_iou 0.8281435966491699
# ============================
# 43
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.22315001487731934
# get_silhoutte_users_confidence 0.25357747077941895
# fast_majority_vote 0.33286237716674805
# get_pairwise_iou 0.6843969821929932
# ============================
# 44
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.6793239116668701
# get_silhoutte_users_confidence 0.6760790348052979
# fast_majority_vote 4.667339563369751
# get_pairwise_iou 10.124758958816528
# ============================
# 45
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2854123115539551
# get_silhoutte_users_confidence 0.3080878257751465
# fast_majority_vote 0.9133131504058838
# get_pairwise_iou 2.066598415374756
# ============================
# 46
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2292180061340332
# get_silhoutte_users_confidence 0.24527931213378906
# fast_majority_vote 0.7941515445709229
# get_pairwise_iou 1.8918304443359375
# ============================
# 47
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.20411181449890137
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.23152995109558105
# fast_majority_vote 0.5537943840026855
# get_pairwise_iou 0.8943657875061035
# ============================
# 48
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.1753542423248291
# get_silhoutte_users_confidence 0.20974135398864746
# fast_majority_vote 0.6003623008728027
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 0.9803256988525391
# ============================
# 49
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3477752208709717
# get_silhoutte_users_confidence 0.3552522659301758
# fast_majority_vote 1.1020941734313965
# get_pairwise_iou 2.2545289993286133
# ============================
# 50
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.19725584983825684
# get_silhoutte_users_confidence 0.20674753189086914
# fast_majority_vote 0.6885330677032471
# get_pairwise_iou 0.8149929046630859
# ============================
# 51
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.33029961585998535
# get_silhoutte_users_confidence 0.34282755851745605
# fast_majority_vote 0.942340612411499
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 3.2240371704101562
# ============================
# 52
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2463223934173584
# get_silhoutte_users_confidence 0.3267824649810791
# fast_majority_vote 0.9532294273376465
# get_pairwise_iou 1.3824059963226318
# ============================
# 53
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.3012871742248535
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.33943986892700195
# fast_majority_vote 0.6364679336547852
# get_pairwise_iou 1.2046277523040771
# ============================
# 54
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.19551944732666016
# get_silhoutte_users_confidence 0.2103884220123291
# fast_majority_vote 0.5325329303741455
# get_pairwise_iou 1.0843276977539062
# ============================
# 55
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3891177177429199
# get_silhoutte_users_confidence 0.41479015350341797
# fast_majority_vote 0.5042815208435059
# get_pairwise_iou 1.244152545928955
# ============================
# 56
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3344576358795166
# get_silhoutte_users_confidence 0.3470578193664551
# fast_majority_vote 1.852365255355835
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 5.380585432052612
# ============================
# 57
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.5057201385498047
# get_silhoutte_users_confidence 0.5990636348724365
# fast_majority_vote 2.3603434562683105
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 5.642664194107056
# ============================
# 58
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2667837142944336
# get_silhoutte_users_confidence 0.2826368808746338
# fast_majority_vote 1.2832729816436768
# get_pairwise_iou 1.8714921474456787
# ============================
# 59
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.2086656093597412
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.24626588821411133
# fast_majority_vote 0.3434004783630371
# get_pairwise_iou 0.6713330745697021
# ============================
# 60
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3434293270111084
# get_silhoutte_users_confidence 0.41831231117248535
# fast_majority_vote 1.1432220935821533
# get_pairwise_iou 1.674806833267212
# ============================
# 61
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3873748779296875
# get_silhoutte_users_confidence 0.41852426528930664
# fast_majority_vote 2.45940899848938
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 4.1776955127716064
# ============================
# 62
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.2016770839691162
# get_silhoutte_users_confidence 0.20937657356262207
# fast_majority_vote 0.47237133979797363
# get_pairwise_iou 0.9909143447875977
# ============================
# 63
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.27399706840515137
# get_silhoutte_users_confidence 0.26456737518310547
# fast_majority_vote 1.0511138439178467
# get_pairwise_iou 2.0103869438171387
# ============================
# 64
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.208817720413208
# get_silhoutte_users_confidence 0.2056441307067871
# fast_majority_vote 0.6508805751800537
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.0396480560302734
# ============================
# 65
# get_silhoutte_confidence 0.14887666702270508
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# ...
# fast_majority_vote 0.7104835510253906
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.8492622375488281
# ============================
# 295
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.16596150398254395
# get_silhoutte_users_confidence 0.19887351989746094
# fast_majority_vote 0.41170191764831543
# get_pairwise_iou 0.9158515930175781
# ============================
# 296
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.23508191108703613
# get_silhoutte_users_confidence 0.3104512691497803
# fast_majority_vote 0.713996410369873
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# Error calculating statistics, likely due
#         to zero division, setting values to zero
# get_pairwise_iou 1.775744915008545
# ============================
# 297
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2561509609222412
# get_silhoutte_users_confidence 0.2795877456665039
# fast_majority_vote 0.7366924285888672
# get_pairwise_iou 1.7450063228607178
# ============================
# 298
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.2560915946960449
# get_silhoutte_users_confidence 0.30556416511535645
# fast_majority_vote 1.4320688247680664
# get_pairwise_iou 2.214553117752075
# ============================
# 299
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.18007779121398926
# get_silhoutte_users_confidence
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
#  0.2005162239074707
# fast_majority_vote 0.9173970222473145
# get_pairwise_iou 0.7627384662628174
# ============================
# 300
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.18514204025268555
# get_silhoutte_users_confidence 0.20717310905456543
# fast_majority_vote 0.5929355621337891
# get_pairwise_iou 0.8941950798034668
# ============================
# 301
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.19313883781433105
# get_silhoutte_users_confidence 0.2563962936401367
# fast_majority_vote 0.8014369010925293
# get_pairwise_iou 2.0767736434936523
# ============================
# 302
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.2733652591705322
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.27947258949279785
# fast_majority_vote 1.0285913944244385
# get_pairwise_iou 1.7024126052856445
# ============================
# 303
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.19315886497497559
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.2362508773803711
# fast_majority_vote 0.34331774711608887
# get_pairwise_iou 0.6661450862884521
# ============================
# 304
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.3401660919189453
# get_silhoutte_users_confidence 0.35205984115600586
# fast_majority_vote 0.8853421211242676
# get_pairwise_iou 1.4269466400146484
# ============================
# 305
# get_silhoutte_confidence
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
#  0.1684858798980713
# get_silhoutte_users_confidence 0.2017669677734375
# fast_majority_vote 0.5966503620147705
# get_pairwise_iou 0.7721846103668213
# ============================
# 306
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.26371335983276367
# get_silhoutte_users_confidence 0.29071474075317383
# fast_majority_vote 0.725994348526001
# get_pairwise_iou 1.9361286163330078
# ============================
# 307
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.1929607391357422
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.21614360809326172
# fast_majority_vote 0.8058030605316162
# get_pairwise_iou 1.4722039699554443
# ============================
# 308
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_confidence 0.1804046630859375
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:76: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_cluster_count /= (max(clusters) + 1)
# C:\Users\seanh\Desktop\e4e\passive-acoustic-biodiversity\Pyrenote_clustering\confidence_functions\clustering.py:77: RuntimeWarning: invalid value encountered in longlong_scalars
#   adv_num_unique_users /=  (max(clusters) + 1) #TEMP FIX INVESTIAGE HERE
# get_silhoutte_users_confidence 0.2683601379394531
# fast_majority_vote 0.5264549255371094
# get_pairwise_iou 1.0628423690795898
# ============================
# 309
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.5742030143737793
# get_silhoutte_users_confidence 0.5481142997741699
# fast_majority_vote 1.716543436050415
# get_pairwise_iou 3.274683952331543
# ============================
# 310
# C:\ProgramData\Miniconda3\envs\species-id\lib\site-packages\pandas\core\apply.py:290: UserWarning: `x` isn't a recognized object; `shuffle` is not guaranteed to behave correctly. E.g., non-numpy array/tensor objects with view semantics may contain duplicates after shuffling.
#   results[i] = self.f(v)
# get_silhoutte_confidence 0.7151391506195068
# get_silhoutte_users_confidence 0.6500787734985352
# fast_majority_vote 4.699666738510132
