# %%
import pandas as pd
file_df2 = pd.read_csv("./all_meta_data.csv")
madreDeDios_species = pd.read_csv("C:/Users/Siloux/Downloads/MadreDeDiosBirdsXCList - MadreDeDiosBirdsXCList.csv")

# %%
file_df = file_df2

# %%
madreDeDios_species
# Out:
#         ID          Order      Family        Genus        Epithet  \
# 0        1   Tinamiformes   Tinamidae  Nothocercus  nigrocapillus
# 1        2   Tinamiformes   Tinamidae      Tinamus            tao
# 2        3   Tinamiformes   Tinamidae      Tinamus        osgoodi
# 3        4   Tinamiformes   Tinamidae      Tinamus          major
# 4        5   Tinamiformes   Tinamidae      Tinamus       guttatus
# ...    ...            ...         ...          ...            ...
# 1030  1031  Passeriformes  Thraupidae  Ixothraupis       punctata
# 1031  1032  Passeriformes  Thraupidae  Lamprospiza    melanoleuca
# 1032    ID          Order      Family        Genus        Epithet
# 1033   NaN            NaN         NaN          NaN            NaN
# 1034   NaN            NaN         NaN          NaN            NaN
#
#                         Species                   Common            CommonES  \
# 0     Nothocercus nigrocapillus           Hooded Tinamou  Tinamú Cabecinegro
# 1                   Tinamus tao             Grey Tinamou          Tinamú Tao
# 2               Tinamus osgoodi            Black Tinamou        Tinamú Negro
# 3                 Tinamus major            Great Tinamou     Tinamú Oliváceo
# 4              Tinamus guttatus   White-throated Tinamou      Tinamú Moteado
# ...                         ...                      ...                 ...
# 1030       Ixothraupis punctata                      NaN     Tangara Puntosa
# 1031    Lamprospiza melanoleuca  Red-billed Pied Tanager  Tangara Piquirroja
# 1032                    Species                   Common            CommonES
# 1033                        NaN                      NaN                 NaN
# 1034                        NaN                      NaN                 NaN
#
#               Status  XCRecordings  VoucherMUSM-Orn  Priority
# 0         Vulnerable            14              NaN       NaN
# 1         Vulnerable            54        amazoncam         1
# 2         Vulnerable            11              NaN       NaN
# 3     Casi amenazada           107     1, amazoncam         1
# 4     Casi amenazada            47              NaN       NaN
# ...              ...           ...              ...       ...
# 1030             NaN             0              NaN       NaN
# 1031             NaN            56              NaN       NaN
# 1032          Status  XCRecordings  VoucherMUSM-Orn  Priority
# 1033             NaN           NaN              NaN       NaN
# 1034             NaN         93416              NaN       NaN
#
# [1035 rows x 12 columns]

# %%
file_df["Common"] = file_df["Common name / Scientific"].apply(lambda x: x.split(" ")[0] + " "+ x.split(" ")[1])
file_df
# Out:
#         Unnamed: 0                           Common name / Scientific Length  \
# 0                0        Common Ostrich (Struthio camelus australis)   0:53
# 1                1                  Common Ostrich (Struthio camelus)   0:26
# 2                2                  Common Ostrich (Struthio camelus)   0:04
# 3                3                  Common Ostrich (Struthio camelus)   0:11
# 4                4                  Common Ostrich (Struthio camelus)   1:47
# ...            ...                                                ...    ...
# 686325      686325  Kilombero Cisticola (Cisticola tax.nov.kilombe...   1:58
# 686326      686326  Kilombero Cisticola (Cisticola tax.nov.kilombe...   0:34
# 686327      686327  Kilombero Cisticola (Cisticola tax.nov.kilombe...   0:21
# 686328      686328  Kilombero Cisticola (Cisticola tax.nov.kilombe...   0:06
# 686329      686329      Bismarck Flyrobin (Microeca tax.nov.Bismarck)   0:06
#
#                             Recordist        Date   Time           Country  \
# 0                       Frank Lambert  2019-10-30  08:05      South Africa
# 1                        Jeremy Hegge  2014-11-20  04:00      South Africa
# 2                        Jeremy Hegge  2014-11-21  06:00      South Africa
# 3                       Derek Solomon  2010-02-09  07:00      South Africa
# 4       Morioka Zoological Park ZOOMO  2021-09-06  17:00             Japan
# ...                               ...         ...    ...               ...
# 686325                Louis A. Hansen  2019-06-29  15:12          Tanzania
# 686326                Louis A. Hansen  2019-06-29  12:00          Tanzania
# 686327                Louis A. Hansen  2019-06-29  09:28          Tanzania
# 686328                Louis A. Hansen  2019-06-29  10:56          Tanzania
# 686329                Joshua Bergmark  2018-07-28  09:00  Papua New Guinea
#
#                                                  Location Elev. (m)  \
# 0              Polokwane Game Reserve, Polokwane, Limpopo      1300
# 1                              Mmabolela Reserve, Limpopo       750
# 2                              Mmabolela Reserve, Limpopo       750
# 3                                              Hoedspruit       523
# 4       Morioka Zoological Park ZOOMO, Morioka City, I...       260
# ...                                                   ...       ...
# 686325                                                  -       240
# 686326                                                  -       245
# 686327                                                  -       245
# 686328                                                  -       245
# 686329                               New Ireland Province       750
#
#                                                      Type  \
# 0                                          call, juvenile
# 1                                                    call
# 2                                                    call
# 3                                                    Call
# 4       adult, female, voice during egg laying, zoo co...
# ...                                                   ...
# 686325                                               song
# 686326                                               song
# 686327                                               song
# 686328                                               call
# 686329                                               song
#
#                                                   Remarks Actions   Cat.nr.  \
# 0       A small juvenile, evidently separated from its...   ABCDE  XC516153
# 1       Recording modified: Frequencies above 640hz re...   ABCDE  XC208209
# 2       Recording modified: Frequencies above 640hz br...   ABCDE  XC208128
# 3       African Rock Python hissing in foreground\n [s...   ABCDE   XC46725
# 4       Although this is a zoo collection, I share the...   ABCDE  XC675445
# ...                                                   ...     ...       ...
# 686325  Sailing on the river in a dugout canoe.\n  [al...   ABCDE  XC511336
# 686326  Sailing on the river in a dugout canoe. Duet s...   ABCDE  XC511326
# 686327  Sailing on the river in a dugout canoe. Duet s...   ABCDE  XC511308
# 686328         Volume increase\nplayback-used:no\n [sono]   ABCDE  XC515823
# 686329  Pair present above the road, called intermitte...   ABCDE  XC459087
#
#                                                 copyright  \
# 0       Creative Commons Attribution-NonCommercial-NoD...
# 1       Creative Commons Attribution-NonCommercial-Sha...
# 2       Creative Commons Attribution-NonCommercial-Sha...
# 3       Creative Commons Attribution-NonCommercial-NoD...
# 4       Creative Commons Attribution-NonCommercial-Sha...
# ...                                                   ...
# 686325  Creative Commons Attribution-NonCommercial-Sha...
# 686326  Creative Commons Attribution-NonCommercial-Sha...
# 686327  Creative Commons Attribution-NonCommercial-Sha...
# 686328  Creative Commons Attribution-NonCommercial-Sha...
# 686329  Creative Commons Attribution-NonCommercial-Sha...
#
#                                                  filename  \
# 0       XC516153 - Common Ostrich - Struthio camelus a...
# 1        XC208209 - Common Ostrich - Struthio camelus.mp3
# 2        XC208128 - Common Ostrich - Struthio camelus.mp3
# 3         XC46725 - Common Ostrich - Struthio camelus.mp3
# 4        XC675445 - Common Ostrich - Struthio camelus.mp3
# ...                                                   ...
# 686325                                  PROTECTED SPECIES
# 686326                                  PROTECTED SPECIES
# 686327                                  PROTECTED SPECIES
# 686328                                  PROTECTED SPECIES
# 686329  XC459087 - Bismarck Flyrobin - Microeca tax.no...
#
#                           download url               Common
# 0                     /516153/download       Common Ostrich
# 1                     /208209/download       Common Ostrich
# 2                     /208128/download       Common Ostrich
# 3                      /46725/download       Common Ostrich
# 4                     /675445/download       Common Ostrich
# ...                                ...                  ...
# 686325  /new_thread.php?frontID=511336  Kilombero Cisticola
# 686326  /new_thread.php?frontID=511326  Kilombero Cisticola
# 686327  /new_thread.php?frontID=511308  Kilombero Cisticola
# 686328  /new_thread.php?frontID=515823  Kilombero Cisticola
# 686329                /459087/download    Bismarck Flyrobin
#
# [686330 rows x 17 columns]

# %%
file_MDD_XC2 = file_df.merge(madreDeDios_species, left_on="Common", right_on="Common")
file_MDD_XC = file_df.merge(madreDeDios_species, left_on="Common", right_on="Common")
file_MDD_XC = file_MDD_XC[file_MDD_XC["Country"].isin(["Brazil", "Bolivia", "Peru", "Ecuador", "Colombia", "Venezuela", "Guyana", "Suriname", "French Guiana"])] 
file_MDD_XC
# Out:
#        Unnamed: 0                           Common name / Scientific Length  \
# 0             120                     Grey Tinamou (Tinamus tao tao)   0:50
# 1             121                         Grey Tinamou (Tinamus tao)   0:27
# 2             122                         Grey Tinamou (Tinamus tao)   3:43
# 3             123                         Grey Tinamou (Tinamus tao)   0:47
# 4             124                         Grey Tinamou (Tinamus tao)   0:04
# ...           ...                                                ...    ...
# 93561      686010  Yellow-shouldered Grosbeak (Parkerthraustes hu...   0:52
# 93562      686011  Yellow-shouldered Grosbeak (Parkerthraustes hu...   0:09
# 93563      686012  Yellow-shouldered Grosbeak (Parkerthraustes hu...   0:37
# 93564      686013  Yellow-shouldered Grosbeak (Parkerthraustes hu...   0:31
# 93565      686014  Yellow-shouldered Grosbeak (Parkerthraustes hu...   0:31
#
#                   Recordist        Date   Time   Country  \
# 0             GABRIEL LEITE  2020-10-13  06:30    Brazil
# 1           Fabrice Schmitt  2016-02-19  07:30  Colombia
# 2              Niels Krabbe  2007-02-05  07:20  Colombia
# 3              Jeremy Minns  2005-10-26  06:48    Brazil
# 4      A. Bennett Hennessey  1998-10-22   6:12   Bolivia
# ...                     ...         ...    ...       ...
# 93561       Eduardo Patrial  2013-10-15  10:00    Brazil
# 93562  A. Bennett Hennessey  1998-09-25   8:37   Bolivia
# 93563          Roger Ahlman  2011-08-14  16:50   Ecuador
# 93564             Huw Lloyd  2008-06-15  16:30      Peru
# 93565             Huw Lloyd  2002-09-00  ??:??      Peru
#
#                                                 Location   Elev. (m)  \
# 0                                      Parauapebas, Pará         500
# 1        RNA El Dorado, Sierra de Santa Marta, Magdalena        2000
# 2      Magdalena: San Lorenzo ridge, Sierra Nevada de...        1750
# 3                        Serra dos Carajás. Águas Claras         550
# 4      Serranía Cuchilla, Pilón Lajas Biosphere Reser...   500 - 900
# ...                                                  ...         ...
# 93561                        Cristalino Jungle Lodge, MT         260
# 93562  Serranías Beu & Chepete,  Pilón Lajas Biospher...  750 - 1450
# 93563                            Miazi, Zamora-Chinchipe         940
# 93564                Manu Wildlife Centre, Madre de Dios         320
# 93565                Manu Wildlife Centre, Madre de Dios         320
#
#                                                    Type  ...          Order  \
# 0      adult, life stage uncertain, sex uncertain, song  ...   Tinamiformes
# 1                                                  song  ...   Tinamiformes
# 2                                          tremolo song  ...   Tinamiformes
# 3                                          tremolo song  ...   Tinamiformes
# 4                                         A single song  ...   Tinamiformes
# ...                                                 ...  ...            ...
# 93561                                              song  ...  Passeriformes
# 93562                                              call  ...  Passeriformes
# 93563                                        call, song  ...  Passeriformes
# 93564                              Response to playback  ...  Passeriformes
# 93565                                              Song  ...  Passeriformes
#
#            Family            Genus    Epithet                    Species  \
# 0       Tinamidae          Tinamus        tao                Tinamus tao
# 1       Tinamidae          Tinamus        tao                Tinamus tao
# 2       Tinamidae          Tinamus        tao                Tinamus tao
# 3       Tinamidae          Tinamus        tao                Tinamus tao
# 4       Tinamidae          Tinamus        tao                Tinamus tao
# ...           ...              ...        ...                        ...
# 93561  Thraupidae  Parkerthraustes  humeralis  Parkerthraustes humeralis
# 93562  Thraupidae  Parkerthraustes  humeralis  Parkerthraustes humeralis
# 93563  Thraupidae  Parkerthraustes  humeralis  Parkerthraustes humeralis
# 93564  Thraupidae  Parkerthraustes  humeralis  Parkerthraustes humeralis
# 93565  Thraupidae  Parkerthraustes  humeralis  Parkerthraustes humeralis
#
#                  CommonES      Status XCRecordings VoucherMUSM-Orn Priority
# 0              Tinamú Tao  Vulnerable           54       amazoncam        1
# 1              Tinamú Tao  Vulnerable           54       amazoncam        1
# 2              Tinamú Tao  Vulnerable           54       amazoncam        1
# 3              Tinamú Tao  Vulnerable           54       amazoncam        1
# 4              Tinamú Tao  Vulnerable           54       amazoncam        1
# ...                   ...         ...          ...             ...      ...
# 93561  Picogrueso Humeral         NaN           26             NaN      NaN
# 93562  Picogrueso Humeral         NaN           26             NaN      NaN
# 93563  Picogrueso Humeral         NaN           26             NaN      NaN
# 93564  Picogrueso Humeral         NaN           26             NaN      NaN
# 93565  Picogrueso Humeral         NaN           26             NaN      NaN
#
# [69037 rows x 28 columns]

# %%
birdnet_species = pd.read_csv("C:/Users/Siloux/Desktop/E4E/PyHa/PyHa/birdnet_lite/model/labels.csv", header=None)

# %%
import numpy as np
np.unique(file_MDD_XC["Country"])
# Out:
# array(['Bolivia', 'Brazil', 'Colombia', 'Ecuador', 'French Guiana',
#        'Guyana', 'Peru', 'Suriname', 'Venezuela'], dtype=object)

# %%
file_MDD_XC["TIME"] = file_MDD_XC["Length"].apply(lambda x : int(x.split(":")[0]) * 60 + int(x.split(":")[1]))
file_MDD_XC.groupby("Common").sum()
# Out:
#                     Unnamed: 0  TIME
# Common
# Acre Tody-Tyrant       3506048   897
# Agami Heron            1217068   233
# Alder Flycatcher       3899764   290
# Amazon Kingfisher     10959550  1006
# Amazonian Antpitta    16801749  2820
# ...                        ...   ...
# Yungas Antwren          701196   102
# Yungas Manakin        19724973  3417
# Zigzag Heron           7185256  2849
# Zimmer's Flatbill     29846707  3295
# Zone-tailed Hawk       2463595   516
#
# [855 rows x 2 columns]

# %%
birdnet_species["Common"] = birdnet_species[0].apply(lambda x: x.split("_")[1])

# %%
birdnet_species_download = file_MDD_XC[file_MDD_XC["Common"].isin(birdnet_species["Common"])].groupby("Common").sum().sort_values(by="TIME", ascending=False).head(20).sample(5).index

# %%
nonbird_species_download = file_MDD_XC[~file_MDD_XC["Common"].isin(birdnet_species["Common"])].groupby("Common").sum().sort_values(by="TIME", ascending=False).head(20).sample(5).index

# %%
species_download = file_MDD_XC[(file_MDD_XC["Common"].isin(birdnet_species_download)) | (file_MDD_XC["Common"].isin(nonbird_species_download))]

# %%
species_download.groupby("Common").sum()
# Out:
#                            Unnamed: 0   TIME
# Common
# Blue-grey Tanager           106874651   5540
# Buff-throated Woodcreeper    89469165  14663
# Green-backed Trogon          42874826  12939
# Pale-breasted Thrush        164739224  13669
# Rufous-collared Sparrow     332521281  18685
# Scaly-breasted Woodpecker    18155472   3979
# Slate-throated Whitestart   135947969   7042
# Southern Nightingale-Wren   126647849  18620
# White-throated Toucan        40852272  12623
# Yellow-olive Flatbill       114034068  15785

# %%
import numpy as np
# Out:
# array(['Bolivia', 'Brazil', 'Colombia', 'Ecuador', 'French Guiana',
#        'Guyana', 'Peru', 'Suriname', 'Venezuela'], dtype=object)

# %%
def download_by_url(file_data, download_folder):
    print(file_data)
    url = file_data[1]
    url = 'https://xeno-canto.org' + url
    r = requests.get(url, allow_redirects=True)
    path = download_folder+file_data[0]
    try:
        open(path, "wb").write(r.content)
    except:
        return "ERROR,"+path
    return path

def download_data(species_df, num_of_files, download_folder):
    print("downloading data")
    if (num_of_files != -1 and species_df.shape[0] > num_of_files):
        species_df = species_df.sample(num_of_files, replace=False)
    species_df["file_location"] = species_df[["filename","download url"]].apply(download_by_url,axis=1, args=(tuple([download_folder])))
    return species_df

#download_data(test2, 100, "./data/")

# %%
np.unique(species_download["Country"])
# Out:
# array(['Bolivia', 'Brazil', 'Colombia', 'Ecuador', 'French Guiana',
#        'Guyana', 'Peru', 'Suriname', 'Venezuela'], dtype=object)

# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd
for species in np.unique(species_download["Common"]):
    tmp_df = species_download[species_download["Common"] == species]
    os.makedirs("./cosmos_data/"+species + "/") 
    meta = download_data(tmp_df, -1, "./cosmos_data/"+species + "/")
    meta.to_csv("./cosmos_metadata.csv")
# Out:
# downloading data
# filename        XC618486 - Blue-grey Tanager - Thraupis episco...
# download url                                     /618486/download
# Name: 88880, dtype: object
# filename        XC618485 - Blue-grey Tanager - Thraupis episco...
# download url                                     /618485/download
# Name: 88881, dtype: object
# filename        XC559797 - Blue-grey Tanager - Thraupis episco...
# download url                                     /559797/download
# Name: 88883, dtype: object
# filename        XC552690 - Blue-grey Tanager - Thraupis episco...
# download url                                     /552690/download
# Name: 88884, dtype: object
# filename        XC542034 - Blue-grey Tanager - Thraupis episco...
# download url                                     /542034/download
# Name: 88885, dtype: object
# filename        XC541886 - Blue-grey Tanager - Thraupis episco...
# download url                                     /541886/download
# Name: 88886, dtype: object
# filename        XC521293 - Blue-grey Tanager - Thraupis episco...
# download url                                     /521293/download
# Name: 88888, dtype: object
# filename        XC513927 - Blue-grey Tanager - Thraupis episco...
# download url                                     /513927/download
# Name: 88889, dtype: object
# filename        XC497126 - Blue-grey Tanager - Thraupis episco...
# download url                                     /497126/download
# Name: 88890, dtype: object
# filename        XC493840 - Blue-grey Tanager - Thraupis episco...
# download url                                     /493840/download
# Name: 88891, dtype: object
# filename        XC480423 - Blue-grey Tanager - Thraupis episco...
# download url                                     /480423/download
# Name: 88892, dtype: object
# filename        XC480420 - Blue-grey Tanager - Thraupis episco...
# download url                                     /480420/download
# Name: 88893, dtype: object
# filename        XC457248 - Blue-grey Tanager - Thraupis episco...
# download url                                     /457248/download
# Name: 88894, dtype: object
# filename        XC449317 - Blue-grey Tanager - Thraupis episco...
# download url                                     /449317/download
# Name: 88895, dtype: object
# filename        XC439061 - Blue-grey Tanager - Thraupis episco...
# download url                                     /439061/download
# Name: 88896, dtype: object
# filename        XC432832 - Blue-grey Tanager - Thraupis episco...
# download url                                     /432832/download
# Name: 88898, dtype: object
# filename        XC424378 - Blue-grey Tanager - Thraupis episco...
# download url                                     /424378/download
# Name: 88899, dtype: object
# filename        XC421098 - Blue-grey Tanager - Thraupis episco...
# download url                                     /421098/download
# Name: 88900, dtype: object
# filename        XC344202 - Blue-grey Tanager - Thraupis episco...
# download url                                     /344202/download
# Name: 88904, dtype: object
# filename        XC341349 - Blue-grey Tanager - Thraupis episco...
# download url                                     /341349/download
# Name: 88905, dtype: object
# filename        XC302355 - Blue-grey Tanager - Thraupis episco...
# download url                                     /302355/download
# Name: 88906, dtype: object
# filename        XC275641 - Blue-grey Tanager - Thraupis episco...
# download url                                     /275641/download
# Name: 88907, dtype: object
# filename        XC275640 - Blue-grey Tanager - Thraupis episco...
# download url                                     /275640/download
# Name: 88908, dtype: object
# filename        XC262618 - Blue-grey Tanager - Thraupis episco...
# download url                                     /262618/download
# Name: 88912, dtype: object
# filename        XC261222 - Blue-grey Tanager - Thraupis episco...
# download url                                     /261222/download
# Name: 88913, dtype: object
# filename        XC261221 - Blue-grey Tanager - Thraupis episco...
# download url                                     /261221/download
# Name: 88914, dtype: object
# filename        XC259686 - Blue-grey Tanager - Thraupis episco...
# download url                                     /259686/download
# Name: 88915, dtype: object
# filename        XC259685 - Blue-grey Tanager - Thraupis episco...
# download url                                     /259685/download
# Name: 88916, dtype: object
# filename        XC259684 - Blue-grey Tanager - Thraupis episco...
# download url                                     /259684/download
# Name: 88917, dtype: object
# filename        XC259683 - Blue-grey Tanager - Thraupis episco...
# download url                                     /259683/download
# Name: 88918, dtype: object
# filename        XC259682 - Blue-grey Tanager - Thraupis episco...
# download url                                     /259682/download
# Name: 88919, dtype: object
# filename        XC259681 - Blue-grey Tanager - Thraupis episco...
# download url                                     /259681/download
# Name: 88920, dtype: object
# filename        XC259680 - Blue-grey Tanager - Thraupis episco...
# download url                                     /259680/download
# Name: 88921, dtype: object
# filename        XC259679 - Blue-grey Tanager - Thraupis episco...
# download url                                     /259679/download
# Name: 88922, dtype: object
# filename        XC245125 - Blue-grey Tanager - Thraupis episco...
# download url                                     /245125/download
# Name: 88923, dtype: object
# filename        XC243187 - Blue-grey Tanager - Thraupis episco...
# download url                                     /243187/download
# Name: 88924, dtype: object
# filename        XC236212 - Blue-grey Tanager - Thraupis episco...
# download url                                     /236212/download
# Name: 88925, dtype: object
# filename        XC236211 - Blue-grey Tanager - Thraupis episco...
# download url                                     /236211/download
# Name: 88926, dtype: object
# filename        XC230895 - Blue-grey Tanager - Thraupis episco...
# download url                                     /230895/download
# Name: 88927, dtype: object
# filename        XC217227 - Blue-grey Tanager - Thraupis episco...
# download url                                     /217227/download
# Name: 88928, dtype: object
# filename        XC213745 - Blue-grey Tanager - Thraupis episco...
# download url                                     /213745/download
# Name: 88929, dtype: object
# filename        XC212073 - Blue-grey Tanager - Thraupis episco...
# download url                                     /212073/download
# Name: 88930, dtype: object
# filename        XC212072 - Blue-grey Tanager - Thraupis episco...
# download url                                     /212072/download
# Name: 88931, dtype: object
# filename        XC209776 - Blue-grey Tanager - Thraupis episco...
# download url                                     /209776/download
# Name: 88932, dtype: object
# filename        XC207197 - Blue-grey Tanager - Thraupis episco...
# download url                                     /207197/download
# Name: 88933, dtype: object
# filename        XC206828 - Blue-grey Tanager - Thraupis episco...
# download url                                     /206828/download
# Name: 88934, dtype: object
# filename        XC204380 - Blue-grey Tanager - Thraupis episco...
# download url                                     /204380/download
# Name: 88935, dtype: object
# filename        XC201179 - Blue-grey Tanager - Thraupis episco...
# download url                                     /201179/download
# Name: 88936, dtype: object
# filename        XC198509 - Blue-grey Tanager - Thraupis episco...
# download url                                     /198509/download
# Name: 88937, dtype: object
# filename        XC198508 - Blue-grey Tanager - Thraupis episco...
# download url                                     /198508/download
# Name: 88938, dtype: object
# filename        XC198505 - Blue-grey Tanager - Thraupis episco...
# download url                                     /198505/download
# Name: 88939, dtype: object
# filename        XC197566 - Blue-grey Tanager - Thraupis episco...
# download url                                     /197566/download
# Name: 88940, dtype: object
# filename        XC167938 - Blue-grey Tanager - Thraupis episco...
# download url                                     /167938/download
# Name: 88941, dtype: object
# filename        XC167894 - Blue-grey Tanager - Thraupis episco...
# download url                                     /167894/download
# Name: 88942, dtype: object
# filename        XC163749 - Blue-grey Tanager - Thraupis episco...
# download url                                     /163749/download
# Name: 88943, dtype: object
# filename        XC144295 - Blue-grey Tanager - Thraupis episco...
# download url                                     /144295/download
# Name: 88944, dtype: object
# filename        XC144291 - Blue-grey Tanager - Thraupis episco...
# download url                                     /144291/download
# Name: 88945, dtype: object
# filename        XC129721 - Blue-grey Tanager - Thraupis episco...
# download url                                     /129721/download
# Name: 88946, dtype: object
# filename        XC128392 - Blue-grey Tanager - Thraupis episco...
# download url                                     /128392/download
# Name: 88947, dtype: object
# filename        XC120827 - Blue-grey Tanager - Thraupis episco...
# download url                                     /120827/download
# Name: 88948, dtype: object
# filename        XC110667 - Blue-grey Tanager - Thraupis episco...
# download url                                     /110667/download
# Name: 88950, dtype: object
# filename        XC100092 - Blue-grey Tanager - Thraupis episco...
# download url                                     /100092/download
# Name: 88951, dtype: object
# filename        XC100073 - Blue-grey Tanager - Thraupis episco...
# download url                                     /100073/download
# Name: 88952, dtype: object
# filename        XC98079 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /98079/download
# Name: 88953, dtype: object
# filename        XC88386 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /88386/download
# Name: 88954, dtype: object
# filename        XC57493 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /57493/download
# Name: 88956, dtype: object
# filename        XC47508 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /47508/download
# Name: 88957, dtype: object
# filename        XC18236 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /18236/download
# Name: 88959, dtype: object
# filename        XC12180 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /12180/download
# Name: 88960, dtype: object
# filename        XC12179 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /12179/download
# Name: 88961, dtype: object
# filename        XC5558 - Blue-grey Tanager - Thraupis episcopu...
# download url                                       /5558/download
# Name: 88962, dtype: object
# filename        XC673385 - Blue-grey Tanager - Thraupis episco...
# download url                                     /673385/download
# Name: 88965, dtype: object
# filename        XC664437 - Blue-grey Tanager - Thraupis episco...
# download url                                     /664437/download
# Name: 88966, dtype: object
# filename        XC610293 - Blue-grey Tanager - Thraupis episco...
# download url                                     /610293/download
# Name: 88967, dtype: object
# filename        XC570678 - Blue-grey Tanager - Thraupis episco...
# download url                                     /570678/download
# Name: 88968, dtype: object
# filename        XC549443 - Blue-grey Tanager - Thraupis episco...
# download url                                     /549443/download
# Name: 88969, dtype: object
# filename        XC533160 - Blue-grey Tanager - Thraupis episco...
# download url                                     /533160/download
# Name: 88970, dtype: object
# filename        XC461765 - Blue-grey Tanager - Thraupis episco...
# download url                                     /461765/download
# Name: 88973, dtype: object
# filename        XC450785 - Blue-grey Tanager - Thraupis episco...
# download url                                     /450785/download
# Name: 88974, dtype: object
# filename        XC446774 - Blue-grey Tanager - Thraupis episco...
# download url                                     /446774/download
# Name: 88975, dtype: object
# filename        XC438173 - Blue-grey Tanager - Thraupis episco...
# download url                                     /438173/download
# Name: 88976, dtype: object
# filename        XC433380 - Blue-grey Tanager - Thraupis episco...
# download url                                     /433380/download
# Name: 88977, dtype: object
# filename        XC428288 - Blue-grey Tanager - Thraupis episco...
# download url                                     /428288/download
# Name: 88978, dtype: object
# filename        XC387104 - Blue-grey Tanager - Thraupis episco...
# download url                                     /387104/download
# Name: 88981, dtype: object
# filename        XC360660 - Blue-grey Tanager - Thraupis episco...
# download url                                     /360660/download
# Name: 88986, dtype: object
# filename        XC352973 - Blue-grey Tanager - Thraupis episco...
# download url                                     /352973/download
# Name: 88987, dtype: object
# filename        XC335018 - Blue-grey Tanager - Thraupis episco...
# download url                                     /335018/download
# Name: 88988, dtype: object
# filename        XC316131 - Blue-grey Tanager - Thraupis episco...
# download url                                     /316131/download
# Name: 88990, dtype: object
# filename        XC315080 - Blue-grey Tanager - Thraupis episco...
# download url                                     /315080/download
# Name: 88991, dtype: object
# filename        XC299425 - Blue-grey Tanager - Thraupis episco...
# download url                                     /299425/download
# Name: 88993, dtype: object
# filename        XC275639 - Blue-grey Tanager - Thraupis episco...
# download url                                     /275639/download
# Name: 88994, dtype: object
# filename        XC261223 - Blue-grey Tanager - Thraupis episco...
# download url                                     /261223/download
# Name: 88995, dtype: object
# filename        XC245325 - Blue-grey Tanager - Thraupis episco...
# download url                                     /245325/download
# Name: 88996, dtype: object
# filename        XC245127 - Blue-grey Tanager - Thraupis episco...
# download url                                     /245127/download
# Name: 88997, dtype: object
# filename        XC243186 - Blue-grey Tanager - Thraupis episco...
# download url                                     /243186/download
# Name: 88998, dtype: object
# filename        XC240116 - Blue-grey Tanager - Thraupis episco...
# download url                                     /240116/download
# Name: 88999, dtype: object
# filename        XC230897 - Blue-grey Tanager - Thraupis episco...
# download url                                     /230897/download
# Name: 89000, dtype: object
# filename        XC230896 - Blue-grey Tanager - Thraupis episco...
# download url                                     /230896/download
# Name: 89001, dtype: object
# filename        XC199962 - Blue-grey Tanager - Thraupis episco...
# download url                                     /199962/download
# Name: 89002, dtype: object
# filename        XC180766 - Blue-grey Tanager - Thraupis episco...
# download url                                     /180766/download
# Name: 89003, dtype: object
# filename        XC180765 - Blue-grey Tanager - Thraupis episco...
# download url                                     /180765/download
# Name: 89004, dtype: object
# filename        XC180764 - Blue-grey Tanager - Thraupis episco...
# download url                                     /180764/download
# Name: 89005, dtype: object
# filename        XC165754 - Blue-grey Tanager - Thraupis episco...
# download url                                     /165754/download
# Name: 89006, dtype: object
# filename        XC163746 - Blue-grey Tanager - Thraupis episco...
# download url                                     /163746/download
# Name: 89007, dtype: object
# filename        XC163745 - Blue-grey Tanager - Thraupis episco...
# download url                                     /163745/download
# Name: 89008, dtype: object
# filename        XC156278 - Blue-grey Tanager - Thraupis episco...
# download url                                     /156278/download
# Name: 89009, dtype: object
# filename        XC152846 - Blue-grey Tanager - Thraupis episco...
# download url                                     /152846/download
# Name: 89010, dtype: object
# filename        XC119815 - Blue-grey Tanager - Thraupis episco...
# download url                                     /119815/download
# Name: 89012, dtype: object
# filename        XC119223 - Blue-grey Tanager - Thraupis episco...
# download url                                     /119223/download
# Name: 89013, dtype: object
# filename        XC94792 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /94792/download
# Name: 89016, dtype: object
# filename        XC94204 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /94204/download
# Name: 89017, dtype: object
# filename        XC93770 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /93770/download
# Name: 89018, dtype: object
# filename        XC92333 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /92333/download
# Name: 89019, dtype: object
# filename        XC90560 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /90560/download
# Name: 89020, dtype: object
# filename        XC75254 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /75254/download
# Name: 89021, dtype: object
# filename        XC74707 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /74707/download
# Name: 89022, dtype: object
# filename        XC65965 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /65965/download
# Name: 89024, dtype: object
# filename        XC64264 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /64264/download
# Name: 89025, dtype: object
# filename        XC64135 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /64135/download
# Name: 89026, dtype: object
# filename        XC36849 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /36849/download
# Name: 89028, dtype: object
# filename        XC14594 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /14594/download
# Name: 89029, dtype: object
# filename        XC694914 - Blue-grey Tanager - Thraupis episco...
# download url                                     /694914/download
# Name: 89031, dtype: object
# filename        XC694905 - Blue-grey Tanager - Thraupis episco...
# download url                                     /694905/download
# Name: 89032, dtype: object
# filename        XC679714 - Blue-grey Tanager - Thraupis episco...
# download url                                     /679714/download
# Name: 89033, dtype: object
# filename        XC673386 - Blue-grey Tanager - Thraupis episco...
# download url                                     /673386/download
# Name: 89034, dtype: object
# filename        XC529586 - Blue-grey Tanager - Thraupis episco...
# download url                                     /529586/download
# Name: 89035, dtype: object
# filename        XC529585 - Blue-grey Tanager - Thraupis episco...
# download url                                     /529585/download
# Name: 89036, dtype: object
# filename        XC482123 - Blue-grey Tanager - Thraupis episco...
# download url                                     /482123/download
# Name: 89037, dtype: object
# filename        XC480422 - Blue-grey Tanager - Thraupis episco...
# download url                                     /480422/download
# Name: 89038, dtype: object
# filename        XC352970 - Blue-grey Tanager - Thraupis episco...
# download url                                     /352970/download
# Name: 89041, dtype: object
# filename        XC343255 - Blue-grey Tanager - Thraupis episco...
# download url                                     /343255/download
# Name: 89042, dtype: object
# filename        XC340081 - Blue-grey Tanager - Thraupis episco...
# download url                                     /340081/download
# Name: 89043, dtype: object
# filename        XC325954 - Blue-grey Tanager - Thraupis episco...
# download url                                     /325954/download
# Name: 89046, dtype: object
# filename        XC320171 - Blue-grey Tanager - Thraupis episco...
# download url                                     /320171/download
# Name: 89047, dtype: object
# filename        XC254249 - Blue-grey Tanager - Thraupis episco...
# download url                                     /254249/download
# Name: 89049, dtype: object
# filename        XC244931 - Blue-grey Tanager - Thraupis episco...
# download url                                     /244931/download
# Name: 89050, dtype: object
# filename        XC206967 - Blue-grey Tanager - Thraupis episco...
# download url                                     /206967/download
# Name: 89052, dtype: object
# filename        XC202849 - Blue-grey Tanager - Thraupis episco...
# download url                                     /202849/download
# Name: 89053, dtype: object
# filename        XC156379 - Blue-grey Tanager - Thraupis episco...
# download url                                     /156379/download
# Name: 89055, dtype: object
# filename        XC155834 - Blue-grey Tanager - Thraupis episco...
# download url                                     /155834/download
# Name: 89056, dtype: object
# filename        XC155784 - Blue-grey Tanager - Thraupis episco...
# download url                                     /155784/download
# Name: 89057, dtype: object
# filename        XC118988 - Blue-grey Tanager - Thraupis episco...
# download url                                     /118988/download
# Name: 89058, dtype: object
# filename        XC107585 - Blue-grey Tanager - Thraupis episco...
# download url                                     /107585/download
# Name: 89059, dtype: object
# filename        XC106254 - Blue-grey Tanager - Thraupis episco...
# download url                                     /106254/download
# Name: 89060, dtype: object
# filename        XC97532 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /97532/download
# Name: 89061, dtype: object
# filename        XC96253 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /96253/download
# Name: 89062, dtype: object
# filename        XC93285 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /93285/download
# Name: 89063, dtype: object
# filename        XC85530 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /85530/download
# Name: 89064, dtype: object
# filename        XC77138 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /77138/download
# Name: 89065, dtype: object
# filename        XC74265 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /74265/download
# Name: 89066, dtype: object
# filename        XC58872 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /58872/download
# Name: 89067, dtype: object
# filename        XC9881 - Blue-grey Tanager - Thraupis episcopu...
# download url                                       /9881/download
# Name: 89068, dtype: object
# filename        XC549995 - Blue-grey Tanager - Thraupis episco...
# download url                                     /549995/download
# Name: 89069, dtype: object
# filename        XC493210 - Blue-grey Tanager - Thraupis episco...
# download url                                     /493210/download
# Name: 89070, dtype: object
# filename        XC433515 - Blue-grey Tanager - Thraupis episco...
# download url                                     /433515/download
# Name: 89071, dtype: object
# filename        XC302298 - Blue-grey Tanager - Thraupis episco...
# download url                                     /302298/download
# Name: 89072, dtype: object
# filename        XC97520 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /97520/download
# Name: 89073, dtype: object
# filename        XC24097 - Blue-grey Tanager - Thraupis episcop...
# download url                                      /24097/download
# Name: 89074, dtype: object
# filename        XC537890 - Blue-grey Tanager - Thraupis episco...
# download url                                     /537890/download
# Name: 89075, dtype: object
# C:\Users\Siloux\.conda\envs\species-id\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# downloading data
# filename        XC547305 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /547305/download
# Name: 31611, dtype: object
# filename        XC537632 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /537632/download
# Name: 31612, dtype: object
# filename        XC537631 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /537631/download
# Name: 31613, dtype: object
# filename        XC535989 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /535989/download
# Name: 31614, dtype: object
# filename        XC535988 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /535988/download
# Name: 31615, dtype: object
# filename        XC535986 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /535986/download
# Name: 31616, dtype: object
# filename        XC524795 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /524795/download
# Name: 31617, dtype: object
# filename        XC524794 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /524794/download
# Name: 31618, dtype: object
# filename        XC727462 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /727462/download
# Name: 31619, dtype: object
# filename        XC727461 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /727461/download
# Name: 31620, dtype: object
# filename        XC724406 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /724406/download
# Name: 31621, dtype: object
# filename        XC715906 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /715906/download
# Name: 31622, dtype: object
# filename        XC711259 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /711259/download
# Name: 31623, dtype: object
# filename        XC709003 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /709003/download
# Name: 31624, dtype: object
# filename        XC708993 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /708993/download
# Name: 31625, dtype: object
# filename        XC708992 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /708992/download
# Name: 31626, dtype: object
# filename        XC704934 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /704934/download
# Name: 31627, dtype: object
# filename        XC704590 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /704590/download
# Name: 31628, dtype: object
# filename        XC704325 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /704325/download
# Name: 31629, dtype: object
# filename        XC699626 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /699626/download
# Name: 31630, dtype: object
# filename        XC699597 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /699597/download
# Name: 31631, dtype: object
# filename        XC697137 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /697137/download
# Name: 31632, dtype: object
# filename        XC691974 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /691974/download
# Name: 31633, dtype: object
# filename        XC689907 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /689907/download
# Name: 31634, dtype: object
# filename        XC686137 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /686137/download
# Name: 31635, dtype: object
# filename        XC685471 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /685471/download
# Name: 31636, dtype: object
# filename        XC682992 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /682992/download
# Name: 31637, dtype: object
# filename        XC673865 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /673865/download
# Name: 31638, dtype: object
# filename        XC672634 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /672634/download
# Name: 31639, dtype: object
# filename        XC656965 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /656965/download
# Name: 31640, dtype: object
# filename        XC656964 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /656964/download
# Name: 31641, dtype: object
# filename        XC656094 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /656094/download
# Name: 31642, dtype: object
# filename        XC612240 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /612240/download
# Name: 31643, dtype: object
# filename        XC599669 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /599669/download
# Name: 31644, dtype: object
# filename        XC556681 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /556681/download
# Name: 31645, dtype: object
# filename        XC556679 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /556679/download
# Name: 31646, dtype: object
# filename        XC537439 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /537439/download
# Name: 31647, dtype: object
# filename        XC506368 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /506368/download
# Name: 31648, dtype: object
# filename        XC504255 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /504255/download
# Name: 31649, dtype: object
# filename        XC500031 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /500031/download
# Name: 31650, dtype: object
# filename        XC499902 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /499902/download
# Name: 31651, dtype: object
# filename        XC493421 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /493421/download
# Name: 31652, dtype: object
# filename        XC493228 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /493228/download
# Name: 31653, dtype: object
# filename        XC493226 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /493226/download
# Name: 31654, dtype: object
# filename        XC493225 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /493225/download
# Name: 31655, dtype: object
# filename        XC483186 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /483186/download
# Name: 31656, dtype: object
# filename        XC479864 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /479864/download
# Name: 31657, dtype: object
# filename        XC478403 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /478403/download
# Name: 31658, dtype: object
# filename        XC463707 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /463707/download
# Name: 31659, dtype: object
# filename        XC456307 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /456307/download
# Name: 31660, dtype: object
# filename        XC445966 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /445966/download
# Name: 31661, dtype: object
# filename        XC441309 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /441309/download
# Name: 31662, dtype: object
# filename        XC436772 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /436772/download
# Name: 31663, dtype: object
# filename        XC431950 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /431950/download
# Name: 31664, dtype: object
# filename        XC428164 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /428164/download
# Name: 31665, dtype: object
# filename        XC428162 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /428162/download
# Name: 31666, dtype: object
# filename        XC428161 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /428161/download
# Name: 31667, dtype: object
# filename        XC421411 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /421411/download
# Name: 31668, dtype: object
# filename        XC419269 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /419269/download
# Name: 31669, dtype: object
# filename        XC407285 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /407285/download
# Name: 31670, dtype: object
# filename        XC404925 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /404925/download
# Name: 31671, dtype: object
# filename        XC404608 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /404608/download
# Name: 31672, dtype: object
# filename        XC404593 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /404593/download
# Name: 31673, dtype: object
# filename        XC403811 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /403811/download
# Name: 31674, dtype: object
# filename        XC403810 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /403810/download
# Name: 31675, dtype: object
# filename        XC403809 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /403809/download
# Name: 31676, dtype: object
# filename        XC403808 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /403808/download
# Name: 31677, dtype: object
# filename        XC399422 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /399422/download
# Name: 31678, dtype: object
# filename        XC397557 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /397557/download
# Name: 31679, dtype: object
# filename        XC386484 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /386484/download
# Name: 31680, dtype: object
# filename        XC384289 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /384289/download
# Name: 31681, dtype: object
# filename        XC384285 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /384285/download
# Name: 31682, dtype: object
# filename        XC344000 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /344000/download
# Name: 31683, dtype: object
# filename        XC330086 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /330086/download
# Name: 31684, dtype: object
# filename        XC307925 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /307925/download
# Name: 31685, dtype: object
# filename        XC307019 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /307019/download
# Name: 31686, dtype: object
# filename        XC306338 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /306338/download
# Name: 31687, dtype: object
# filename        XC305393 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /305393/download
# Name: 31688, dtype: object
# filename        XC305391 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /305391/download
# Name: 31689, dtype: object
# filename        XC301344 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /301344/download
# Name: 31690, dtype: object
# filename        XC287952 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /287952/download
# Name: 31691, dtype: object
# filename        XC276659 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /276659/download
# Name: 31692, dtype: object
# filename        XC272150 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /272150/download
# Name: 31693, dtype: object
# filename        XC272149 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /272149/download
# Name: 31694, dtype: object
# filename        XC272148 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /272148/download
# Name: 31695, dtype: object
# filename        XC271810 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /271810/download
# Name: 31696, dtype: object
# filename        XC271016 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /271016/download
# Name: 31697, dtype: object
# filename        XC269251 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /269251/download
# Name: 31698, dtype: object
# filename        XC269250 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /269250/download
# Name: 31699, dtype: object
# filename        XC269095 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /269095/download
# Name: 31700, dtype: object
# filename        XC269090 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /269090/download
# Name: 31701, dtype: object
# filename        XC269051 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /269051/download
# Name: 31702, dtype: object
# filename        XC269050 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /269050/download
# Name: 31703, dtype: object
# filename        XC264574 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /264574/download
# Name: 31704, dtype: object
# filename        XC258306 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /258306/download
# Name: 31705, dtype: object
# filename        XC258305 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /258305/download
# Name: 31706, dtype: object
# filename        XC258304 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /258304/download
# Name: 31707, dtype: object
# filename        XC258303 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /258303/download
# Name: 31708, dtype: object
# filename        XC258302 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /258302/download
# Name: 31709, dtype: object
# filename        XC258301 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /258301/download
# Name: 31710, dtype: object
# filename        XC251781 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /251781/download
# Name: 31711, dtype: object
# filename        XC249546 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /249546/download
# Name: 31712, dtype: object
# filename        XC249545 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /249545/download
# Name: 31713, dtype: object
# filename        XC249052 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /249052/download
# Name: 31714, dtype: object
# filename        XC247133 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /247133/download
# Name: 31715, dtype: object
# filename        XC247026 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /247026/download
# Name: 31716, dtype: object
# filename        XC232407 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232407/download
# Name: 31717, dtype: object
# filename        XC232406 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232406/download
# Name: 31718, dtype: object
# filename        XC232405 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232405/download
# Name: 31719, dtype: object
# filename        XC232404 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232404/download
# Name: 31720, dtype: object
# filename        XC232403 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232403/download
# Name: 31721, dtype: object
# filename        XC232402 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232402/download
# Name: 31722, dtype: object
# filename        XC232401 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232401/download
# Name: 31723, dtype: object
# filename        XC232400 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232400/download
# Name: 31724, dtype: object
# filename        XC232399 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232399/download
# Name: 31725, dtype: object
# filename        XC232398 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232398/download
# Name: 31726, dtype: object
# filename        XC232397 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232397/download
# Name: 31727, dtype: object
# filename        XC232396 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232396/download
# Name: 31728, dtype: object
# filename        XC232395 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232395/download
# Name: 31729, dtype: object
# filename        XC232387 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /232387/download
# Name: 31730, dtype: object
# filename        XC195167 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /195167/download
# Name: 31731, dtype: object
# filename        XC178118 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /178118/download
# Name: 31732, dtype: object
# filename        XC169577 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /169577/download
# Name: 31733, dtype: object
# filename        XC142670 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /142670/download
# Name: 31734, dtype: object
# filename        XC141660 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /141660/download
# Name: 31735, dtype: object
# filename        XC130232 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /130232/download
# Name: 31736, dtype: object
# filename        XC122734 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /122734/download
# Name: 31737, dtype: object
# filename        XC108506 - Buff-throated Woodcreeper - Xiphorh...
# download url                                     /108506/download
# Name: 31738, dtype: object
# filename        XC91433 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /91433/download
# Name: 31739, dtype: object
# filename        XC91432 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /91432/download
# Name: 31740, dtype: object
# filename        XC91431 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /91431/download
# Name: 31741, dtype: object
# filename        XC91428 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /91428/download
# Name: 31742, dtype: object
# filename        XC91427 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /91427/download
# Name: 31743, dtype: object
# filename        XC91426 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /91426/download
# Name: 31744, dtype: object
# filename        XC91425 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /91425/download
# Name: 31745, dtype: object
# filename        XC91422 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /91422/download
# Name: 31746, dtype: object
# filename        XC91418 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /91418/download
# Name: 31747, dtype: object
# filename        XC85918 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /85918/download
# Name: 31748, dtype: object
# filename        XC80509 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /80509/download
# Name: 31749, dtype: object
# filename        XC80508 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /80508/download
# Name: 31750, dtype: object
# filename        XC77320 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /77320/download
# Name: 31751, dtype: object
# filename        XC74940 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /74940/download
# Name: 31752, dtype: object
# filename        XC74326 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /74326/download
# Name: 31753, dtype: object
# filename        XC64610 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /64610/download
# Name: 31754, dtype: object
# filename        XC64608 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /64608/download
# Name: 31755, dtype: object
# filename        XC56094 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /56094/download
# Name: 31756, dtype: object
# filename        XC44179 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /44179/download
# Name: 31757, dtype: object
# filename        XC44102 - Buff-throated Woodcreeper - Xiphorhy...
# download url                                      /44102/download
# Name: 31758, dtype: object
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-98-04428485a86d> in <module>
#       6     tmp_df = species_download[species_download["Common"] == species]
#       7     os.makedirs("./cosmos_data/"+species + "/")
# ----> 8     meta = download_data(tmp_df, -1, "./cosmos_data/"+species + "/")
#       9     meta.to_csv("./cosmos_metadata.csv")
#
# <ipython-input-93-c46fd63d2e75> in download_data(species_df, num_of_files, download_folder)
#      12     if (num_of_files != -1 and species_df.shape[0] > num_of_files):
#      13         species_df = species_df.sample(num_of_files, replace=False)
# ---> 14     species_df["file_location"] = species_df[["filename","download url"]].apply(download_by_url,axis=1, args=(tuple([download_folder])))
#      15     return species_df
#      16
#
# ~\.conda\envs\species-id\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# ~\.conda\envs\species-id\lib\site-packages\pandas\core\apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# ~\.conda\envs\species-id\lib\site-packages\pandas\core\apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# --> 812         results, res_index = self.apply_series_generator()
#     813
#     814         # wrap results
#
# ~\.conda\envs\species-id\lib\site-packages\pandas\core\apply.py in apply_series_generator(self)
#     826             for i, v in enumerate(series_gen):
#     827                 # ignore SettingWithCopy here in case the user mutates
# --> 828                 results[i] = self.f(v)
#     829                 if isinstance(results[i], ABCSeries):
#     830                     # If we have a view on v, we need to make a copy because
#
# ~\.conda\envs\species-id\lib\site-packages\pandas\core\apply.py in f(x)
#     129
#     130             def f(x):
# --> 131                 return func(x, *args, **kwargs)
#     132
#     133         else:
#
# <ipython-input-93-c46fd63d2e75> in download_by_url(file_data, download_folder)
#       5     r = requests.get(url, allow_redirects=True)
#       6     path = download_folder+file_data[0]
# ----> 7     open(path, "wb").write(r.content)
#       8     return path
#       9
#
# OSError: [Errno 22] Invalid argument: './cosmos_data/Buff-throated Woodcreeper/XC44102 - Buff-throated Woodcreeper - Xiphorhynchus guttatus connectens ?.mp3'
