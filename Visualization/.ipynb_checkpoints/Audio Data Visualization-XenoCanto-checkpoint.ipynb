# %%
from __future__ import division

import glob
import os
import numpy as np
import pandas as pd
import sounddevice as sd
import pylab as pl
import random

from scipy.io import wavfile
import matplotlib.pyplot as plt
from python_speech_features import mfcc
from sklearn.cluster import MiniBatchKMeans

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_similarity
from adjustText import adjust_text
from collections import Counter
from scipy.io.wavfile import write
from sklearn.cluster import AgglomerativeClustering

from pyAudioAnalysis import audioBasicIO
from pyAudioAnalysis import ShortTermFeatures

import librosa
import pydub
from pydub import AudioSegment
import soundfile as sf
import tempfile
from pydub.utils import which
from scipy.io.wavfile import write
import scipy
import warnings 

AudioSegment.converter = which("ffmpeg")
# %matplotlib inline

# %%
# Returns all clip indexes within a cluster
def get_clip_indexes(cluster_label, clusters):
    clips_i = []
    for i in range(len(clusters)):
        if clusters[i] == cluster_label:
            clips_i.append(i)
    return clips_i

# Plays a random clip in a given cluster
def play_random_clip_in_cluster(index, clusters, option='cluster'):
    assert(option == 'cluster' or option == 'clip')
    if option == 'clip':
        index = find_cluster(index, clusters) # Get cluster index
    
    clips = get_clip_indexes(index, clusters)
    clip_i = clips[random.randint(0, len(clips) - 1)]
    print('Playing clip index %d ' % clip_i)
    play_clip(clip_i)
        
# Returns the cluster label that a clip belongs to
def find_cluster(clip_index, clusters):
    return clusters[clip_index]

# Plays an audio clip given the clip index
def play_clip(clip_index):
    samples = shorter_clips[clip_index]
    sd.play(samples, samplerate)

# Flattens a given list
def list_flatten(l):
    flat_list = []
    for sublist in l:
        for item in sublist:
            flat_list.append(item)
    return flat_list

# Saves clip as a wav file
def save_clip(filename, wav_array):
#     assert('.' not in filename)
    write(filename + '.wav', samplerate, wav_array)
    
# Saves all clips to a directory
def save_clips_to_dir(shorter_clips, dirname):
    for i, clip in enumerate(shorter_clips):
        save_clip(dirname + '/%d' % i, clip) 
            
def convert_mp3_to_wav(mp3_path, sr=44100, mono=True, overwrite=False, dtype='float32'): 
    # Need to change sample rate to 44.1kHz if using audiomoths
    # since mono=True by default, unless you pass mono=False, 
    # this function will save the wav as mono
#     print("entering convert_mp3_to_wav")
    """
    Parts of code from 
    https://github.com/bill317996/Audio-to-midi/blob/master/cfp.py
    """
    warnings.warn("deprecated", DeprecationWarning)
    
    # in case there is an .MP3
    assert mp3_path.lower().endswith('.mp3'), 'filename indicates not mp3'
    wav_path_to_write = os.path.splitext(mp3_path)[0] + '.wav'
#     print(wav_path_to_write)
    
    if not overwrite and os.path.exists(wav_path_to_write):
        return
    
    mp3 = AudioSegment.from_file(mp3_path)
    
    _, temp_path = tempfile.mkstemp() 
    mp3.export(temp_path, format='wav')
#     print(temp_path)
    del mp3
    x, fs = sf.read(temp_path)
    os.remove(temp_path)
    
    if mono and len(x.shape)>1: 
        x = np.mean(x, axis = 1) 
    if sr:
        x = scipy.signal.resample_poly(x, sr, fs)
        fs = sr 
    x = x.astype(dtype)
#     print(fs)
    write(wav_path_to_write, fs, x)
    return x, fs

def read(f, normalized=False):
    """MP3 to numpy array"""
    a = pydub.AudioSegment.from_file(f)
    y = np.array(a.get_array_of_samples())
    if a.channels == 2:
        y = y.reshape((-1, 2))
    if normalized:
        return a.frame_rate, np.float32(y) / 2**15
    else:
        return a.frame_rate, y

# %% [markdown]
# ### (Optional) testing convert_mp3_to_wav function with one file
# This is an extra step that I made to quickly check and troubleshoot the convert_mp3_to_wav function

# %%
dir_path = '/Volumes/Elements/Madre_de_Dios_Xeno_Canto_Birdcalls/'
file_path = dir_path + 'XC431125 - Rufous Twistwing - Cnipodectes superrufus.mp3'
# file_path = dir_path + 'XC91323 - White-eyed Parakeet - Psittacara leucophthalmus.mp3'

x, fs = convert_mp3_to_wav(file_path, overwrite=True)

# %%
# Graphs to sanity check output of load_audio with online mp3 to wav converter 

fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.plot(x)

print(x.shape)

# This file is from a random mp3 to wav convert I found here
# https://online-audio-converter.com/ and then downloaded on Desktop
check_dir_path = '/Users/yoo-jin/Desktop/XC431125 - Rufous Twistwing - Cnipodectes superrufus.wav'
x_test, fs_test = sf.read(check_dir_path)

x_test = np.mean(x_test, axis = 1) 
print(x_test.shape)

ax2.plot(x_test)

# %% [markdown]
# ## Load Audio Data

# %%
dir_path = '/Volumes/Elements/Madre_de_Dios_Xeno_Canto_Birdcalls/'
# dir_path = '/Volumes/Elements/Test/'
samplerate = None
wav_data = []
wav_names = []

for file in glob.glob(os.path.join(dir_path, '*.mp3')):
#     print(file)
#     convert_mp3_to_wav(file, overwrite=True)
    
    try: 
        data, rate = convert_mp3_to_wav(file, overwrite=True)
#         data = data.astype(int)
        samplerate = rate
        if wav_data == []:
            wav_data = data
        else:
            wav_data = np.concatenate((wav_data, data))
        clip_len = len(data) / samplerate
        
        # Input only bird species
        bird_species_name = file.split(' - ')[2][:-4].replace(' ', '_')
        wav_names.append([bird_species_name, clip_len])
#         print(file)
        
        # TO DO: deal with deprecation warning, don't suppress
        warnings.filterwarnings("ignore", category=DeprecationWarning) 
    except Exception as e:
        print('(failed) ' + file)
        print('\t' + str(e))
        pass

# %%
print("shape of wav_data", wav_data.shape)
print("sample rate", samplerate)
print("type of wav_data", type(wav_data))
print('sample rate = %d' % samplerate)
length = wav_data.shape[0] / samplerate
print('length = %.1fs' % length)
# Out:
# shape of wav_data (645859892,)
# sample rate 44100
# type of wav_data <class 'numpy.ndarray'>
# sample rate = 44100
# length = 14645.3s

# %% [markdown]
# ## Split Audio Data

# %%
# Get n-minute clips
def split_into_minutes(wav_data, samplerate, n=1):
    length_in_seconds = len(wav_data) / samplerate
    length_in_minutes = length_in_seconds / 60
    length_in_minutes = int(length_in_minutes / n)

    cut_wav_data = wav_data[:-((len(wav_data)) % length_in_minutes)]
    shorter_clips = np.split(cut_wav_data, length_in_minutes)
    print('%d %d-minute clips' % (len(shorter_clips), n))
    return shorter_clips

# Get n-second clips
def split_into_n_seconds(wav_data, wav_names, samplerate, n=10):
    file_names = []
    
    length_in_seconds = len(wav_data) / samplerate
#     print("length in seconds",length_in_seconds)
    length_in_minutes = length_in_seconds / 60
    length_in_minutes = length_in_minutes
#     print(length_in_minutes)
    shorter_len = int(length_in_minutes / (1/(60/n)))
#     print("shorter length", shorter_len)
    
    n_real = length_in_seconds/shorter_len
#     print("n real", n_real)
    
    second_clips = None
    
    try:
        second_clips = np.split(wav_data, shorter_len)
    except:
        cut_wav_data = wav_data[:-((len(wav_data)) % shorter_len)]
        second_clips = np.split(cut_wav_data, shorter_len)

    # wav_name[0][0]="Versasilles birdopolus", wav_name[0][1]=12
    # wav_name[1][0]="Amazilia lactea",        wav_name[1][1]=9
    # wav_name[2][0]="Ramphastos vitellinus",  wav_name[2][1]=7
    # 'Versasilles_birdopolus_Split.wav', 'Versasilles_birdopolus2_Amazilia_lactea_Split.wav', 'Ramphastos_vitellinus7_Split.wav'

    i = 0
    amount_left = 0
    first_case_count = 0 
    while i < len(wav_names):
#         print(wav_names[i][1], "wav_names")
#         print(i)
        # create new clip from just one bird
#         print(wav_names[i][1], "wav_names[i][1]")
        if wav_names[i][1] >= n_real and amount_left == 0:
#             print("first test case")
#             print("i", i)
#             print("amount_left", amount_left)
#             print("first_case_count", first_case_count)
#             print()
            file_names.append(wav_names[i][0] + "_Split_%d" % first_case_count)
            wav_names[i][1] -= n_real
            first_case_count+=1
        
        # create new clip and leave it unfinished
        elif 0 < int(wav_names[i][1]) < n_real and amount_left == 0:
#             print("second test case")
#             print("i", i)
#             print("amount_left", amount_left)
#             print()
            file_names.append(wav_names[i][0] + str(int(wav_names[i][1])) + "_")
            amount_left = n_real - wav_names[i][1]
            wav_names[i][1] = 0
            i+=1
            
        # finish prev clip
        elif wav_names[i][1] >= amount_left and amount_left > 0:
#             print("third test case")
#             print("i", i)
#             print("amount_left", amount_left)
#             print()
            file_names[-1] += wav_names[i][0] + "_Split"
            wav_names[i][1] -= amount_left
            amount_left = 0
        
        # if length is 0
        elif int(wav_names[i][1]) == 0:
#             print("Hits zero case")
#             print("i", i)
#             print("amount_left", amount_left)
#             print()
            i+=1
            
        elif wav_names[i][1] < amount_left and amount_left > 0: 
#             print("contribute to previous clip and not ending clip")
#             print("i", i)
#             print("amount_left", amount_left)
#             print()
            file_names[-1] += wav_names[i][0] + str(int(wav_names[i][1])) + "_"
            amount_left = n_real - wav_names[i][1]
            wav_names[i][1] = 0
            i+=1
    
#     file_names[-1] += "_Split.wav"
#     print(file_names)
    print('%d %d-second clips' % (len(second_clips), n_real))
    return second_clips, file_names

# %%
#shorter_clips = split_into_minutes(wav_data, samplerate, 1)

shorter_clips, file_names = split_into_n_seconds(wav_data, wav_names, samplerate, 10)
# Out:
# 1464 10-second clips

# %% [markdown]
# # Spectrograms

# %%
def plot_spectrogram(samplerate, shorter_clips, clip_index, separate_channels=False):
    left_channel = shorter_clips[clip_index][:, 0]
    right_channel = shorter_clips[clip_index][:, 1]
    
    plt.rcParams["figure.figsize"] = (100, 100)
    plt.rcParams.update({'font.size': 50})
    plt.xlabel('Time')
    plt.ylabel('Frequency')
    
    plt.subplot(211)
    if separate_channels:
        plt.title('Clip #%d (Left Channel)' % clip_index)
        plt.specgram(left_channel, Fs=samplerate)
        plt.subplot(212)
        plt.title('Clip #%d (Right Channel)' % clip_index)
        plt.specgram(right_channel, Fs=samplerate)
    else:
        plt.title('Clip #%d' % clip_index)
        both_channels = left_channel + right_channel
        plt.specgram(both_channels, Fs=samplerate)

    plt.show()
    
def plot_spectrogram_of_cluster(samplerate, shorter_clips, cluster_i, clusters, separate_channels=False):
    clip_indexes = get_clip_indexes(cluster_i, clusters)
    
    left_channel = shorter_clips[clip_indexes[0]][:, 0]
    right_channel = shorter_clips[clip_indexes[0]][:, 1]
    
    for i in range(1, len(clip_indexes)):
        left_channel = np.append(left_channel, shorter_clips[clip_indexes[i]][:, 0])
        right_channel = np.append(right_channel, shorter_clips[clip_indexes[i]][:, 1])
    
    plt.rcParams["figure.figsize"] = (100, 100)
    plt.rcParams.update({'font.size': 50})
    plt.xlabel('Time')
    plt.ylabel('Frequency')
    
    plt.subplot(211)
    if separate_channels:
        plt.title('Cluster #%d (Left Channel)' % cluster_i)
        plt.specgram(left_channel, Fs=samplerate)
        plt.subplot(212)
        plt.title('Cluster #%d (Right Channel)' % cluster_i)
        plt.specgram(right_channel, Fs=samplerate)
    else:
        plt.title('Cluster #%d' % cluster_i)
        both_channels = left_channel + right_channel
        plt.specgram(both_channels, Fs=samplerate)

    plt.show()

# %%
# TO DO: plot_spectrogram isn't working with Xeno Canto files
# plot_spectrogram(samplerate, shorter_clips)

# plt.specgram(wav_data, Fs=samplerate)

# %% [markdown]
# # Feature Extraction

# %%
# TODO: Add a way to select and evaluate features

def extract_features(shorter_clips, mfcc_only=False, mono=False):
    feat_clips = []

    print('Extracting features for each of the %d audio clips' % len(shorter_clips))
    for clip in shorter_clips:
        if mono == False:
            clip = clip[:, 0] + clip[:, 1] # Merging left and right channels

        mfcc_feat=None
        if mfcc_only:
            mfcc_feat = mfcc(clip, samplerate, winlen=0.023, nfft = 1024).flatten()

        else:
            mfcc_feat = ShortTermFeatures.feature_extraction(clip, samplerate, 0.050*samplerate, 0.025*samplerate)
            print('')
            print(mfcc_feat[1])

        # Append the features
        if mfcc_only:
            feat_clips.append(mfcc_feat)
        else:
            feat_clips.append(list_flatten(mfcc_feat[0]))

    print('done')
    return feat_clips
    
# Set mfcc_only to True to shorten runtime
mfcc_clips = extract_features(shorter_clips, mfcc_only=True, mono=True)
#all_feat_clips = extract_features(shorter_clips)
# Out:
# Extracting features for each of the 1464 audio clips
# done

# %% [markdown]
# # Clustering

# %%
dist = 1 - cosine_similarity(mfcc_clips)
mds = PCA(n_components=2, random_state=1)
pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

X = pos

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

linked = linkage(X, 'single')

labelList = range(len(X))

plt.figure(figsize=(16, 16))
dendro = dendrogram(linked,
#             p=7,
            orientation='top',
            #labels=labelList,
            truncate_mode='level',
            distance_sort='descending',
            show_leaf_counts=True)
plt.show()

# %%
def cluster_plot(pos, title='', without_labels=False, width=20, height=20, savepath=''):
    plt.rc('font', size=15)
    
    xs, ys = pos[:, 0], pos[:, 1]
    
    labels = range(len(shorter_clips))

    # Data frame with TSNE data, the cluster numbers and titles
    cluster_df = pd.DataFrame(dict(x=xs, y=ys, clusters=clusters, labels=labels)) 

    fig, ax = plt.subplots(figsize=(width, height))
    ax.margins(0.05)
    ax.set_title(title)

    groups = cluster_df.groupby('clusters')
    for name, group in groups:
        ax.plot(group.x, group.y, marker='o', linestyle='', ms=12, mec='none', label=name)
        ax.set_aspect('auto')
        ax.tick_params(axis= 'x', which='both', bottom='off', top='off', labelbottom='off')
        ax.tick_params(axis= 'y', which='both', left='off', top='off', labelleft='off')

    ax.legend(numpoints=1)
    ax.legend(bbox_to_anchor=(1.1, 1.05))

    #Add labels
    if not without_labels:
        texts = []
        for i in range(len(cluster_df)):
            texts.append(ax.text(cluster_df.loc[i, 'x'], cluster_df.loc[i, 'y'], cluster_df.loc[i,'labels'], size=10)) 

        #adjust_text(texts, arrowprops=dict(arrowstyle='->', color='red'))
    
    if savepath != '':
        plt.savefig(savepath, dpi=200, bbox_inches="tight")

    plt.show()

# %% [markdown]
# ### Optional: For K-means clustsering
# The function, find_optimal_clusters is used to find the optimal number of clusters for K-means clustering. Take a look at this link for more information: https://hlab.stanford.edu/brian/number_of_clusters_.html.

# %%
## TODO: plot.ly

def find_optimal_clusters(data, min_k, max_k): 
    iters= range(min_k, max_k+1, 2)
    
    sse = [] 
    for k in iters: 
        sse.append(MiniBatchKMeans(n_clusters=k, init_size=1024, batch_size=2048, random_state=20).fit(data).inertia_)
    
#     import pandas as pd
#     sse_pct_diff = pd.Series(sse)
#     sse_pct_diff.pct_change()
#     print(sse_pct_diff)
    
    f, ax = plt.subplots(1,1)
    ax.plot(iters, sse, marker = 'o')
    ax.set_xlabel('Cluster Centers')
#     ax.set_xticks(iters)
#     f.autofmt_xdate()
#     ax.set_xtickslabels(iters)
    ax.set_ylabel('SSE')
    ax.set_title('SSE by Number of Clusters')
    
#     ax[0].plot(iters, sse, marker = 'o')
#     ax[0].set_xlabel('Cluster Centers')
# #     ax.set_xticks(iters)
# #     f.autofmt_xdate()
# #     ax.set_xtickslabels(iters)
#     ax[0].set_ylabel('SSE')
#     ax[0].set_title('SSE by Number of Clusters')
    
#     ax[1].plot(iters, sse_pct_diff, marker = 'o')
#     ax[1].set_xlabel('Cluster Centers')
# #     ax.set_xticks(iters)
# #     f.autofmt_xdate()
# #     ax.set_xtickslabels(iters)
#     ax[1].set_ylabel('Percentage Change of SSE')
#     ax[1].set_title('Percentage Change of SSE by Number of Clusters')
    
    plt.tight_layout()

        
# Change the range here: 
find_optimal_clusters(X, 1, 150)

# %%
# Choose number of clusters: 
n_clusters = 134 
# Chose 134 from the number of bird species in the XenoCanto data

# Fit clustering model
clusters = AgglomerativeClustering(n_clusters=n_clusters, affinity='euclidean', linkage='ward').fit_predict(mfcc_clips)

# %%
plt.savefig(savepath, dpi=200, bbox_inches="tight")

# %% [markdown]
# ### Optional: list all bird species included in the file

# %%
dir_path = '/Volumes/Elements/Madre_de_Dios_Xeno_Canto_Birdcalls/'
list_of_species = []

for f in glob.glob(os.path.join(dir_path, '*.mp3')): 
    bird_name = os.path.splitext(f)[0].split(" - ", 1)[1].strip()
    if list_of_species == []: 
        list_of_species = [bird_name]
    elif bird_name in list_of_species: 
        pass 
    else: 
        list_of_species.append(bird_name)

# print(list_of_species)
print(len(list_of_species))
# Out:
# 134

# %%
# Project the data onto 2D graph - 10 clusters
dist = 1 - cosine_similarity(mfcc_clips)
mds = PCA(n_components=2, random_state=1)
pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

# /Volumes/Elements/Madre_de_Dios_Xeno_Canto_Birdcalls/

cluster_plot(pos, 'PCA Cluster Plot', without_labels=True, savepath='/Volumes/Elements/Madre_de_Dios_Xeno_Canto_Birdcalls/Clusters_XenoCanto/pca.png')
spe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-d1145e2213df> in <module>
#       7
#       8 cluster_plot(pos, 'PCA Cluster Plot', without_labels=True, savepath='/Volumes/Elements/Madre_de_Dios_Xeno_Canto_Birdcalls/Clusters_XenoCanto/pca.png')
# ----> 9 spe
#
# NameError: name 'spe' is not defined

# %%
# Project the data onto 2D graph - 10 clusters
dist = 1 - cosine_similarity(mfcc_clips)
mds = TSNE(n_components=2, random_state=1)
pos = mds.fit_transform(dist)  # shape (n_components, n_samples)

cluster_plot(pos, 'TSNE Cluster Plot', without_labels=True, savepath='/Volumes/Elements/Madre_de_Dios_Xeno_Canto_Birdcalls/Clusters_XenoCanto/tsne.png')

# %% [markdown]
# # Cluster Interpretation

# %%
# Prints: (Cluster number, count of clips in cluster)
Counter(clusters).most_common()

# %%
play_random_clip_in_cluster(6, clusters) # Play random clip in a cluster

# %%
sd.stop() # Stop playing

# %%
# Can assign a label to each cluster here
#cluster_names = ['quiet', 'loud', 'quiet', 'rain', 'birds', 'crickets', 'birds', 'quiet', 'quiet', 'loud']

# %%
# See clip indexes of all clips inside cluster
clip_indexes = get_clip_indexes(0, clusters)
print(clip_indexes)

# %%
play_clip(36)

# %%
## TO-DO: delete ##

# # Save all clusters
# dirname = '/Volumes/Elements/Madre_de_Dios_Xeno_Canto_Birdcalls/Clusters_XenoCanto/'

# # TODO: play around with number of clusters
# n_clusters = 134

# # Fit clustering model
# clusters = AgglomerativeClustering(n_clusters=n_clusters, affinity='euclidean', linkage='ward').fit_predict(mfcc_clips)
# print(type(clusters))
# print(clusters.shape)
# print(clusters)

# %% [markdown]
# ## Save clusters of audio files

# %%
dirname = '/Volumes/Elements/Madre_de_Dios_Xeno_Canto_Birdcalls/Clusters_XenoCanto/'

for i in range(len(np.unique(clusters))):
    # if file already exists, then delete it and overwrite it
    os.mkdir(dirname + 'cluster_%d' % i)
    for j in get_clip_indexes(i, clusters):
        print("i",i)
        print('j', j)
        print("file_names[j]", file_names[j])
        print("shorter_clips[j]", len(shorter_clips[j]))
        print()
#         save_clip(dirname + 'cluster_%d/%s' % (i, j), file_names[j])
        save_clip(dirname + 'cluster_%d/%s' % (i, file_names[j]), shorter_clips[j])
#         save_clip(dirname + 'cluster_%d/%s' % i, file_names[j]), shorter_clips[j])
#         save_clip(dirname + 'cluster_%d/%s' % (i, j), file_names[j]))
# Out:
# i 0
# j 303
# file_names[j] Brachygalba_albogularis_Split_251
# shorter_clips[j] 441161
#
# i 0
# j 304
# file_names[j] Brachygalba_albogularis_Split_252
# shorter_clips[j] 441161
#
# i 0
# j 305
# file_names[j] Brachygalba_albogularis_Split_253
# shorter_clips[j] 441161
#
# i 0
# j 309
# file_names[j] Brachygalba_albogularis_Split_255
# shorter_clips[j] 441161
#
# i 0
# j 866
# file_names[j] Myrmotherula_sclateri_Split_721
# shorter_clips[j] 441161
#
# i 0
# j 1038
# file_names[j] Ramphotrigon_megacephalum_Split_871
# shorter_clips[j] 441161
#
# i 0
# j 1043
# file_names[j] Ramphotrigon_megacephalum_Split_876
# shorter_clips[j] 441161
#
# i 0
# j 1044
# file_names[j] Ramphotrigon_megacephalum_Split_877
# shorter_clips[j] 441161
#
# i 1
# j 17
# file_names[j] Conioptilon_mcilhennyi3_Psarocolius_bifasciatus_yuracares_Split
# shorter_clips[j] 441161
#
# i 1
# j 18
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_16
# shorter_clips[j] 441161
#
# i 1
# j 19
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_17
# shorter_clips[j] 441161
#
# i 1
# j 20
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_18
# shorter_clips[j] 441161
#
# i 1
# j 21
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_19
# shorter_clips[j] 441161
#
# i 1
# j 22
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_20
# shorter_clips[j] 441161
#
# i 1
# j 23
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_21
# shorter_clips[j] 441161
#
# i 1
# j 24
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_22
# shorter_clips[j] 441161
#
# i 1
# j 25
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_23
# shorter_clips[j] 441161
#
# i 1
# j 26
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_24
# shorter_clips[j] 441161
#
# i 1
# j 187
# file_names[j] Cercomacra_manu2_Hylopezus_berlepschi_Split
# shorter_clips[j] 441161
#
# i 1
# j 188
# file_names[j] Hylopezus_berlepschi_Split_166
# shorter_clips[j] 441161
#
# i 1
# j 189
# file_names[j] Hylopezus_berlepschi_Split_167
# shorter_clips[j] 441161
#
# i 1
# j 190
# file_names[j] Hylopezus_berlepschi_Split_168
# shorter_clips[j] 441161
#
# i 1
# j 191
# file_names[j] Hylopezus_berlepschi_Split_169
# shorter_clips[j] 441161
#
# i 1
# j 192
# file_names[j] Hylopezus_berlepschi_Split_170
# shorter_clips[j] 441161
#
# i 1
# j 193
# file_names[j] Hylopezus_berlepschi_Split_171
# shorter_clips[j] 441161
#
# i 1
# j 194
# file_names[j] Hylopezus_berlepschi_Split_172
# shorter_clips[j] 441161
#
# i 1
# j 195
# file_names[j] Hylopezus_berlepschi9_Hemitriccus_cohnhafti_Split
# shorter_clips[j] 441161
#
# i 1
# j 390
# file_names[j] Syndactyla_ucayalae_Split_323
# shorter_clips[j] 441161
#
# i 1
# j 1406
# file_names[j] Phyllomyias_weedeni_Split_1196
# shorter_clips[j] 441161
#
# i 1
# j 1407
# file_names[j] Phyllomyias_weedeni_Split_1197
# shorter_clips[j] 441161
#
# i 1
# j 1408
# file_names[j] Phyllomyias_weedeni1_Hemitriccus_cohnhafti_Split
# shorter_clips[j] 441161
#
# i 1
# j 1409
# file_names[j] Hemitriccus_cohnhafti_Split_1198
# shorter_clips[j] 441161
#
# i 2
# j 569
# file_names[j] Neocrex_erythrops_Split_461
# shorter_clips[j] 441161
#
# i 2
# j 571
# file_names[j] Neocrex_erythrops_Split_463
# shorter_clips[j] 441161
#
# i 2
# j 572
# file_names[j] Neocrex_erythrops_Split_464
# shorter_clips[j] 441161
#
# i 2
# j 573
# file_names[j] Neocrex_erythrops_Split_465
# shorter_clips[j] 441161
#
# i 2
# j 574
# file_names[j] Neocrex_erythrops_Split_466
# shorter_clips[j] 441161
#
# i 2
# j 575
# file_names[j] Neocrex_erythrops_Split_467
# shorter_clips[j] 441161
#
# i 2
# j 576
# file_names[j] Neocrex_erythrops_Split_468
# shorter_clips[j] 441161
#
# i 2
# j 577
# file_names[j] Neocrex_erythrops9_Psittacara_leucophthalmus_Split
# shorter_clips[j] 441161
#
# i 2
# j 578
# file_names[j] Psittacara_leucophthalmus8_Myrmotherula_longicauda_Split
# shorter_clips[j] 441161
#
# i 2
# j 1054
# file_names[j] Capsiempis_flaveola_flaveola__Split_885
# shorter_clips[j] 441161
#
# i 2
# j 1146
# file_names[j] Megarynchus_pitangua_Split_965
# shorter_clips[j] 441161
#
# i 2
# j 1147
# file_names[j] Megarynchus_pitangua_Split_966
# shorter_clips[j] 441161
#
# i 2
# j 1148
# file_names[j] Megarynchus_pitangua_Split_967
# shorter_clips[j] 441161
#
# i 2
# j 1149
# file_names[j] Megarynchus_pitangua_Split_968
# shorter_clips[j] 441161
#
# i 2
# j 1150
# file_names[j] Megarynchus_pitangua_Split_969
# shorter_clips[j] 441161
#
# i 2
# j 1151
# file_names[j] Megarynchus_pitangua_Split_970
# shorter_clips[j] 441161
#
# i 2
# j 1152
# file_names[j] Megarynchus_pitangua3_Hypocnemis_subflava_Split
# shorter_clips[j] 441161
#
# i 2
# j 1153
# file_names[j] Hypocnemis_subflava_Split_971
# shorter_clips[j] 441161
#
# i 3
# j 328
# file_names[j] Helicolestes_hamatus_Split_271
# shorter_clips[j] 441161
#
# i 3
# j 441
# file_names[j] Myrmelastes_hyperythrus_Split_362
# shorter_clips[j] 441161
#
# i 3
# j 990
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_832
# shorter_clips[j] 441161
#
# i 3
# j 1301
# file_names[j] Formicarius_rufifrons_Split_1100
# shorter_clips[j] 441161
#
# i 3
# j 1304
# file_names[j] Formicarius_rufifrons_Split_1103
# shorter_clips[j] 441161
#
# i 3
# j 1307
# file_names[j] Cnipodectes_superrufus_Split_1104
# shorter_clips[j] 441161
#
# i 4
# j 349
# file_names[j] Cnipodectes_superrufus_Split_289
# shorter_clips[j] 441161
#
# i 4
# j 350
# file_names[j] Cnipodectes_superrufus_Split_290
# shorter_clips[j] 441161
#
# i 4
# j 351
# file_names[j] Cnipodectes_superrufus_Split_291
# shorter_clips[j] 441161
#
# i 4
# j 352
# file_names[j] Cnipodectes_superrufus3_Hemitriccus_cohnhafti_Split
# shorter_clips[j] 441161
#
# i 4
# j 442
# file_names[j] Myrmelastes_hyperythrus_Split_363
# shorter_clips[j] 441161
#
# i 4
# j 444
# file_names[j] Myrmelastes_hyperythrus_Split_365
# shorter_clips[j] 441161
#
# i 4
# j 445
# file_names[j] Myrmelastes_hyperythrus_Split_366
# shorter_clips[j] 441161
#
# i 5
# j 353
# file_names[j] Hemitriccus_cohnhafti2_Cnipodectes_superrufus_Split
# shorter_clips[j] 441161
#
# i 5
# j 1154
# file_names[j] Hypocnemis_subflava_Split_972
# shorter_clips[j] 441161
#
# i 5
# j 1155
# file_names[j] Hypocnemis_subflava_Split_973
# shorter_clips[j] 441161
#
# i 5
# j 1156
# file_names[j] Hypocnemis_subflava_Split_974
# shorter_clips[j] 441161
#
# i 5
# j 1157
# file_names[j] Hypocnemis_subflava_Split_975
# shorter_clips[j] 441161
#
# i 5
# j 1158
# file_names[j] Hypocnemis_subflava3_Psarocolius_bifasciatus_yuracares_Split
# shorter_clips[j] 441161
#
# i 5
# j 1159
# file_names[j] Psarocolius_bifasciatus_yuracares_Split_976
# shorter_clips[j] 441161
#
# i 5
# j 1422
# file_names[j] Hemitriccus_cohnhafti_Split_1210
# shorter_clips[j] 441161
#
# i 5
# j 1423
# file_names[j] Hemitriccus_cohnhafti_Split_1211
# shorter_clips[j] 441161
#
# i 5
# j 1424
# file_names[j] Hemitriccus_cohnhafti_Split_1212
# shorter_clips[j] 441161
#
# i 5
# j 1425
# file_names[j] Hemitriccus_cohnhafti_Split_1213
# shorter_clips[j] 441161
#
# i 5
# j 1426
# file_names[j] Hemitriccus_cohnhafti_Split_1214
# shorter_clips[j] 441161
#
# i 5
# j 1427
# file_names[j] Hemitriccus_cohnhafti_Split_1215
# shorter_clips[j] 441161
#
# i 5
# j 1428
# file_names[j] Hemitriccus_cohnhafti_Split_1216
# shorter_clips[j] 441161
#
# i 5
# j 1429
# file_names[j] Hemitriccus_cohnhafti_Split_1217
# shorter_clips[j] 441161
#
# i 5
# j 1430
# file_names[j] Hemitriccus_cohnhafti_Split_1218
# shorter_clips[j] 441161
#
# i 5
# j 1431
# file_names[j] Hemitriccus_cohnhafti_Split_1219
# shorter_clips[j] 441161
#
# i 5
# j 1432
# file_names[j] Hemitriccus_cohnhafti_Split_1220
# shorter_clips[j] 441161
#
# i 5
# j 1433
# file_names[j] Hemitriccus_cohnhafti8_Hemitriccus_cohnhafti_Split
# shorter_clips[j] 441161
#
# i 5
# j 1434
# file_names[j] Hemitriccus_cohnhafti_Split_1221
# shorter_clips[j] 441161
#
# i 5
# j 1435
# file_names[j] Hemitriccus_cohnhafti_Split_1222
# shorter_clips[j] 441161
#
# i 6
# j 382
# file_names[j] Galbula_cyanescens_Split_317
# shorter_clips[j] 441161
#
# i 6
# j 383
# file_names[j] Galbula_cyanescens_Split_318
# shorter_clips[j] 441161
#
# i 6
# j 385
# file_names[j] Galbula_cyanescens9_Syndactyla_ucayalae_Split
# shorter_clips[j] 441161
#
# i 6
# j 386
# file_names[j] Syndactyla_ucayalae_Split_320
# shorter_clips[j] 441161
#
# i 6
# j 415
# file_names[j] Hypocnemis_subflava_Split_344
# shorter_clips[j] 441161
#
# i 6
# j 433
# file_names[j] Buteo_nitidus_Split_356
# shorter_clips[j] 441161
#
# i 6
# j 461
# file_names[j] Todirostrum_maculatum1_Brotogeris_sanctithomae_Split
# shorter_clips[j] 441161
#
# i 7
# j 15
# file_names[j] Conopias_trivirgatus3_Conioptilon_mcilhennyi_Split
# shorter_clips[j] 441161
#
# i 7
# j 16
# file_names[j] Conioptilon_mcilhennyi_Split_15
# shorter_clips[j] 441161
#
# i 7
# j 28
# file_names[j] Chaetura_viridipennis7_Saltator_maximus_Split
# shorter_clips[j] 441161
#
# i 7
# j 932
# file_names[j] Tyrannopsis_sulphurea_Split_779
# shorter_clips[j] 441161
#
# i 7
# j 933
# file_names[j] Tyrannopsis_sulphurea_Split_780
# shorter_clips[j] 441161
#
# i 7
# j 934
# file_names[j] Tyrannopsis_sulphurea_Split_781
# shorter_clips[j] 441161
#
# i 7
# j 935
# file_names[j] Tyrannopsis_sulphurea_Split_782
# shorter_clips[j] 441161
#
# i 7
# j 1221
# file_names[j] Coereba_flaveola_Split_1029
# shorter_clips[j] 441161
#
# i 7
# j 1222
# file_names[j] Coereba_flaveola_Split_1030
# shorter_clips[j] 441161
#
# i 7
# j 1223
# file_names[j] Coereba_flaveola_Split_1031
# shorter_clips[j] 441161
#
# i 7
# j 1224
# file_names[j] Coereba_flaveola_Split_1032
# shorter_clips[j] 441161
#
# i 7
# j 1225
# file_names[j] Coereba_flaveola4_Cotinga_maynana_Split
# shorter_clips[j] 441161
#
# i 7
# j 1226
# file_names[j] Formicarius_rufifrons_Split_1033
# shorter_clips[j] 441161
#
# i 7
# j 1227
# file_names[j] Formicarius_rufifrons_Split_1034
# shorter_clips[j] 441161
#
# i 7
# j 1244
# file_names[j] Neopelma_sulphureiventer_Split_1049
# shorter_clips[j] 441161
#
# i 7
# j 1245
# file_names[j] Neopelma_sulphureiventer_Split_1050
# shorter_clips[j] 441161
#
# i 7
# j 1246
# file_names[j] Neopelma_sulphureiventer_Split_1051
# shorter_clips[j] 441161
#
# i 7
# j 1247
# file_names[j] Neopelma_sulphureiventer_Split_1052
# shorter_clips[j] 441161
#
# i 7
# j 1248
# file_names[j] Neopelma_sulphureiventer_Split_1053
# shorter_clips[j] 441161
#
# i 7
# j 1249
# file_names[j] Neopelma_sulphureiventer_Split_1054
# shorter_clips[j] 441161
#
# i 7
# j 1250
# file_names[j] Neopelma_sulphureiventer_Split_1055
# shorter_clips[j] 441161
#
# i 7
# j 1251
# file_names[j] Neopelma_sulphureiventer_Split_1056
# shorter_clips[j] 441161
#
# i 7
# j 1252
# file_names[j] Neopelma_sulphureiventer_Split_1057
# shorter_clips[j] 441161
#
# i 7
# j 1253
# file_names[j] Celeus_spectabilis_Split_1058
# shorter_clips[j] 441161
#
# i 7
# j 1254
# file_names[j] Celeus_spectabilis_Split_1059
# shorter_clips[j] 441161
#
# i 8
# j 391
# file_names[j] Syndactyla_ucayalae2_Syndactyla_ucayalae_Split
# shorter_clips[j] 441161
#
# i 8
# j 477
# file_names[j] Ammodramus_aurifrons_Split_389
# shorter_clips[j] 441161
#
# i 8
# j 478
# file_names[j] Ammodramus_aurifrons_Split_390
# shorter_clips[j] 441161
#
# i 8
# j 479
# file_names[j] Ammodramus_aurifrons2_Saltator_coerulescens_azarae_Split
# shorter_clips[j] 441161
#
# i 8
# j 480
# file_names[j] Saltator_coerulescens_azarae3_Cyanocorax_violaceus_Split
# shorter_clips[j] 441161
#
# i 8
# j 671
# file_names[j] Saltator_coerulescens_Split_550
# shorter_clips[j] 441161
#
# i 9
# j 371
# file_names[j] Cercomacroides_fuscicauda_Split_308
# shorter_clips[j] 441161
#
# i 9
# j 372
# file_names[j] Cercomacroides_fuscicauda_Split_309
# shorter_clips[j] 441161
#
# i 9
# j 417
# file_names[j] Cercomacroides_fuscicauda_Split_345
# shorter_clips[j] 441161
#
# i 9
# j 447
# file_names[j] Picumnus_rufiventris_Split_367
# shorter_clips[j] 441161
#
# i 9
# j 449
# file_names[j] Picumnus_rufiventris_Split_368
# shorter_clips[j] 441161
#
# i 9
# j 450
# file_names[j] Picumnus_rufiventris_Split_369
# shorter_clips[j] 441161
#
# i 9
# j 451
# file_names[j] Picumnus_rufiventris_Split_370
# shorter_clips[j] 441161
#
# i 9
# j 452
# file_names[j] Picumnus_rufiventris9_Picumnus_rufiventris_Split
# shorter_clips[j] 441161
#
# i 9
# j 470
# file_names[j] Pachyramphus_polychopterus_nigriventris_Split_383
# shorter_clips[j] 441161
# i 9
# j 471
# file_names[j] Pachyramphus_polychopterus_nigriventris_Split_384
# shorter_clips[j] 441161
#
# i 9
# j 472
# file_names[j] Pachyramphus_polychopterus_nigriventris_Split_385
# shorter_clips[j] 441161
#
# i 9
# j 473
# file_names[j] Pachyramphus_polychopterus_nigriventris_Split_386
# shorter_clips[j] 441161
#
# i 9
# j 474
# file_names[j] Pachyramphus_polychopterus_nigriventris_Split_387
# shorter_clips[j] 441161
#
# i 9
# j 475
# file_names[j] Pachyramphus_polychopterus_nigriventris_Split_388
# shorter_clips[j] 441161
#
# i 9
# j 481
# file_names[j] Cyanocorax_violaceus_Split_391
# shorter_clips[j] 441161
#
# i 9
# j 483
# file_names[j] Glaucis_hirsutus7_Myrmoborus_lophotes_Split
# shorter_clips[j] 441161
#
# i 9
# j 825
# file_names[j] Pyrrhura_rupicola_lowlands_Split_687
# shorter_clips[j] 441161
#
# i 10
# j 655
# file_names[j] Nonnula_ruficapilla_Split_537
# shorter_clips[j] 441161
#
# i 10
# j 656
# file_names[j] Nonnula_ruficapilla_Split_538
# shorter_clips[j] 441161
#
# i 10
# j 657
# file_names[j] Nonnula_ruficapilla_Split_539
# shorter_clips[j] 441161
#
# i 10
# j 658
# file_names[j] Nonnula_ruficapilla_Split_540
# shorter_clips[j] 441161
#
# i 10
# j 659
# file_names[j] Nonnula_ruficapilla_Split_541
# shorter_clips[j] 441161
#
# i 10
# j 660
# file_names[j] Nonnula_ruficapilla_Split_542
# shorter_clips[j] 441161
#
# i 10
# j 661
# file_names[j] Nonnula_ruficapilla_Split_543
# shorter_clips[j] 441161
#
# i 10
# j 662
# file_names[j] Nonnula_ruficapilla_Split_544
# shorter_clips[j] 441161
#
# i 10
# j 663
# file_names[j] Nonnula_ruficapilla6_Heliomaster_longirostris_Split
# shorter_clips[j] 441161
#
# i 10
# j 664
# file_names[j] Heliomaster_longirostris_Split_545
# shorter_clips[j] 441161
#
# i 10
# j 1140
# file_names[j] Megarynchus_pitangua_Split_960
# shorter_clips[j] 441161
#
# i 10
# j 1141
# file_names[j] Megarynchus_pitangua_Split_961
# shorter_clips[j] 441161
#
# i 10
# j 1142
# file_names[j] Megarynchus_pitangua_Split_962
# shorter_clips[j] 441161
#
# i 10
# j 1143
# file_names[j] Megarynchus_pitangua_Split_963
# shorter_clips[j] 441161
#
# i 10
# j 1144
# file_names[j] Megarynchus_pitangua5_Megarynchus_pitangua_Split
# shorter_clips[j] 441161
#
# i 10
# j 1145
# file_names[j] Megarynchus_pitangua_Split_964
# shorter_clips[j] 441161
#
# i 10
# j 1229
# file_names[j] Formicarius_rufifrons_Split_1036
# shorter_clips[j] 441161
#
# i 10
# j 1230
# file_names[j] Formicarius_rufifrons_Split_1037
# shorter_clips[j] 441161
#
# i 10
# j 1232
# file_names[j] Formicarius_rufifrons_Split_1039
# shorter_clips[j] 441161
#
# i 10
# j 1234
# file_names[j] Formicarius_rufifrons_Split_1041
# shorter_clips[j] 441161
#
# i 10
# j 1236
# file_names[j] Neopelma_sulphureiventer_Split_1042
# shorter_clips[j] 441161
#
# i 11
# j 531
# file_names[j] Myiozetetes_cayanensis_Split_425
# shorter_clips[j] 441161
#
# i 11
# j 533
# file_names[j] Myiozetetes_cayanensis_Split_427
# shorter_clips[j] 441161
#
# i 11
# j 534
# file_names[j] Myiozetetes_cayanensis_Split_428
# shorter_clips[j] 441161
#
# i 11
# j 535
# file_names[j] Myiozetetes_cayanensis_Split_429
# shorter_clips[j] 441161
#
# i 11
# j 536
# file_names[j] Myiozetetes_cayanensis_Split_430
# shorter_clips[j] 441161
#
# i 11
# j 537
# file_names[j] Myiozetetes_cayanensis_Split_431
# shorter_clips[j] 441161
#
# i 11
# j 538
# file_names[j] Myiozetetes_cayanensis_Split_432
# shorter_clips[j] 441161
#
# i 11
# j 539
# file_names[j] Myiozetetes_cayanensis_Split_433
# shorter_clips[j] 441161
#
# i 11
# j 540
# file_names[j] Myiozetetes_cayanensis_Split_434
# shorter_clips[j] 441161
#
# i 11
# j 541
# file_names[j] Myiozetetes_cayanensis_Split_435
# shorter_clips[j] 441161
#
# i 11
# j 542
# file_names[j] Myiozetetes_cayanensis_Split_436
# shorter_clips[j] 441161
#
# i 11
# j 543
# file_names[j] Myiozetetes_cayanensis4_Neocrex_erythrops_Split
# shorter_clips[j] 441161
#
# i 11
# j 1067
# file_names[j] Cymbilaimus_sanctaemariae_Split_895
# shorter_clips[j] 441161
#
# i 12
# j 493
# file_names[j] Jacamerops_aureus_Split_397
# shorter_clips[j] 441161
#
# i 12
# j 495
# file_names[j] Cercomacroides_fuscicauda_Split_399
# shorter_clips[j] 441161
#
# i 12
# j 1045
# file_names[j] Ramphotrigon_megacephalum_Split_878
# shorter_clips[j] 441161
#
# i 12
# j 1056
# file_names[j] Capsiempis_flaveola_flaveola__Split_887
# shorter_clips[j] 441161
#
# i 12
# j 1057
# file_names[j] Capsiempis_flaveola_flaveola__Split_888
# shorter_clips[j] 441161
#
# i 12
# j 1058
# file_names[j] Capsiempis_flaveola_flaveola__Split_889
# shorter_clips[j] 441161
#
# i 12
# j 1060
# file_names[j] Contopus_cooperi_Split_890
# shorter_clips[j] 441161
#
# i 13
# j 379
# file_names[j] Galbula_cyanescens_Split_314
# shorter_clips[j] 441161
#
# i 13
# j 437
# file_names[j] Hemitriccus_iohannis_Split_360
# shorter_clips[j] 441161
#
# i 13
# j 438
# file_names[j] Hemitriccus_iohannis_Split_361
# shorter_clips[j] 441161
#
# i 13
# j 439
# file_names[j] Hemitriccus_iohannis7_Nasica_longirostris_Split
# shorter_clips[j] 441161
#
# i 13
# j 440
# file_names[j] Nasica_longirostris7_Myrmelastes_hyperythrus_Split
# shorter_clips[j] 441161
#
# i 13
# j 600
# file_names[j] Colaptes_punctigula_Split_488
# shorter_clips[j] 441161
#
# i 13
# j 601
# file_names[j] Colaptes_punctigula_Split_489
# shorter_clips[j] 441161
#
# i 13
# j 602
# file_names[j] Colaptes_punctigula_Split_490
# shorter_clips[j] 441161
#
# i 13
# j 604
# file_names[j] Colaptes_punctigula_Split_492
# shorter_clips[j] 441161
#
# i 13
# j 605
# file_names[j] Colaptes_punctigula8_Oryzoborus_angolensis_Split
# shorter_clips[j] 441161
#
# i 13
# j 606
# file_names[j] Oryzoborus_angolensis_Split_493
# shorter_clips[j] 441161
#
# i 13
# j 666
# file_names[j] Heliomaster_longirostris_Split_547
# shorter_clips[j] 441161
#
# i 13
# j 667
# file_names[j] Heliomaster_longirostris1_Pachyramphus_xanthogenys_Split
# shorter_clips[j] 441161
#
# i 13
# j 1279
# file_names[j] Piranga_olivacea_Split_1081
# shorter_clips[j] 441161
#
# i 13
# j 1280
# file_names[j] Piranga_olivacea_Split_1082
# shorter_clips[j] 441161
#
# i 13
# j 1281
# file_names[j] Piranga_olivacea_Split_1083
# shorter_clips[j] 441161
#
# i 13
# j 1282
# file_names[j] Piranga_olivacea6_Myiodynastes_maculatus_solitarius_Split
# shorter_clips[j] 441161
#
# i 13
# j 1283
# file_names[j] Myiodynastes_maculatus_solitarius_Split_1084
# shorter_clips[j] 441161
#
# i 14
# j 521
# file_names[j] Phaeomyias_murina_wagae_Split_417
# shorter_clips[j] 441161
#
# i 14
# j 524
# file_names[j] Phaeomyias_murina_wagae_Split_420
# shorter_clips[j] 441161
#
# i 14
# j 526
# file_names[j] Phaeomyias_murina_wagae_Split_422
# shorter_clips[j] 441161
#
# i 14
# j 527
# file_names[j] Phaeomyias_murina_wagae8_Poecilotriccus_latirostris_Split
# shorter_clips[j] 441161
#
# i 14
# j 528
# file_names[j] Poecilotriccus_latirostris_Split_423
# shorter_clips[j] 441161
#
# i 15
# j 718
# file_names[j] Ammodramus_aurifrons_Split_593
# shorter_clips[j] 441161
#
# i 15
# j 719
# file_names[j] Ammodramus_aurifrons_Split_594
# shorter_clips[j] 441161
#
# i 15
# j 720
# file_names[j] Ammodramus_aurifrons_Split_595
# shorter_clips[j] 441161
#
# i 15
# j 721
# file_names[j] Ammodramus_aurifrons_Split_596
# shorter_clips[j] 441161
#
# i 15
# j 722
# file_names[j] Ammodramus_aurifrons_Split_597
# shorter_clips[j] 441161
#
# i 15
# j 723
# file_names[j] Ammodramus_aurifrons_Split_598
# shorter_clips[j] 441161
#
# i 15
# j 1309
# file_names[j] Cnipodectes_superrufus_Split_1106
# shorter_clips[j] 441161
#
# i 15
# j 1310
# file_names[j] Cnipodectes_superrufus_Split_1107
# shorter_clips[j] 441161
#
# i 15
# j 1311
# file_names[j] Cnipodectes_superrufus_Split_1108
# shorter_clips[j] 441161
#
# i 15
# j 1312
# file_names[j] Cnipodectes_superrufus_Split_1109
# shorter_clips[j] 441161
#
# i 15
# j 1314
# file_names[j] Cnipodectes_superrufus_Split_1111
# shorter_clips[j] 441161
#
# i 15
# j 1315
# file_names[j] Cnipodectes_superrufus_Split_1112
# shorter_clips[j] 441161
#
# i 15
# j 1316
# file_names[j] Cnipodectes_superrufus3_Cnipodectes_superrufus_Split
# shorter_clips[j] 441161
#
# i 15
# j 1317
# file_names[j] Cnipodectes_superrufus_Split_1113
# shorter_clips[j] 441161
#
# i 15
# j 1330
# file_names[j] Cnipodectes_superrufus_Split_1125
# shorter_clips[j] 441161
#
# i 15
# j 1331
# file_names[j] Cnipodectes_superrufus_Split_1126
# shorter_clips[j] 441161
#
# i 15
# j 1332
# file_names[j] Cnipodectes_superrufus_Split_1127
# shorter_clips[j] 441161
#
# i 15
# j 1333
# file_names[j] Cnipodectes_superrufus_Split_1128
# shorter_clips[j] 441161
#
# i 15
# j 1334
# file_names[j] Cnipodectes_superrufus2_Cnipodectes_superrufus_Split
# shorter_clips[j] 441161
#
# i 15
# j 1335
# file_names[j] Cnipodectes_superrufus_Split_1129
# shorter_clips[j] 441161
#
# i 15
# j 1336
# file_names[j] Cnipodectes_superrufus_Split_1130
# shorter_clips[j] 441161
#
# i 15
# j 1337
# file_names[j] Cnipodectes_superrufus_Split_1131
# shorter_clips[j] 441161
#
# i 15
# j 1338
# file_names[j] Cnipodectes_superrufus_Split_1132
# shorter_clips[j] 441161
#
# i 15
# j 1339
# file_names[j] Cnipodectes_superrufus_Split_1133
# shorter_clips[j] 441161
#
# i 15
# j 1340
# file_names[j] Cnipodectes_superrufus_Split_1134
# shorter_clips[j] 441161
#
# i 15
# j 1341
# file_names[j] Cnipodectes_superrufus_Split_1135
# shorter_clips[j] 441161
#
# i 15
# j 1342
# file_names[j] Cnipodectes_superrufus_Split_1136
# shorter_clips[j] 441161
#
# i 15
# j 1343
# file_names[j] Cnipodectes_superrufus_Split_1137
# shorter_clips[j] 441161
#
# i 15
# j 1344
# file_names[j] Cnipodectes_superrufus_Split_1138
# shorter_clips[j] 441161
#
# i 15
# j 1345
# file_names[j] Cnipodectes_superrufus_Split_1139
# shorter_clips[j] 441161
#
# i 15
# j 1346
# file_names[j] Cnipodectes_superrufus_Split_1140
# shorter_clips[j] 441161
#
# i 15
# j 1347
# file_names[j] Cnipodectes_superrufus_Split_1141
# shorter_clips[j] 441161
#
# i 15
# j 1348
# file_names[j] Cnipodectes_superrufus_Split_1142
# shorter_clips[j] 441161
#
# i 15
# j 1349
# file_names[j] Cnipodectes_superrufus_Split_1143
# shorter_clips[j] 441161
#
# i 15
# j 1350
# file_names[j] Cnipodectes_superrufus6_Cnipodectes_superrufus_Split
# shorter_clips[j] 441161
#
# i 15
# j 1351
# file_names[j] Cnipodectes_superrufus_Split_1144
# shorter_clips[j] 441161
#
# i 16
# j 419
# file_names[j] Myrmophylax_atrothorax_Split_346
# shorter_clips[j] 441161
#
# i 16
# j 420
# file_names[j] Myrmophylax_atrothorax_Split_347
# shorter_clips[j] 441161
#
# i 16
# j 421
# file_names[j] Myrmophylax_atrothorax_Split_348
# shorter_clips[j] 441161
#
# i 16
# j 422
# file_names[j] Myrmophylax_atrothorax2_Myrmophylax_atrothorax_Split
# shorter_clips[j] 441161
#
# i 16
# j 423
# file_names[j] Myrmophylax_atrothorax_Split_349
# shorter_clips[j] 441161
#
# i 16
# j 424
# file_names[j] Myrmophylax_atrothorax_Split_350
# shorter_clips[j] 441161
#
# i 16
# j 425
# file_names[j] Myrmophylax_atrothorax_Split_351
# shorter_clips[j] 441161
#
# i 16
# j 426
# file_names[j] Myrmophylax_atrothorax3_Automolus_rufipileatus_Split
# shorter_clips[j] 441161
#
# i 16
# j 427
# file_names[j] Automolus_rufipileatus_Split_352
# shorter_clips[j] 441161
#
# i 16
# j 428
# file_names[j] Attila_bolivianus_Split_353
# shorter_clips[j] 441161
#
# i 17
# j 1031
# file_names[j] Myrmophylax_atrothorax_Split_865
# shorter_clips[j] 441161
#
# i 17
# j 1036
# file_names[j] Myrmophylax_atrothorax_Split_870
# shorter_clips[j] 441161
#
# i 17
# j 1037
# file_names[j] Myrmophylax_atrothorax4_Ramphotrigon_megacephalum_Split
# shorter_clips[j] 441161
#
# i 17
# j 1039
# file_names[j] Ramphotrigon_megacephalum_Split_872
# shorter_clips[j] 441161
#
# i 17
# j 1040
# file_names[j] Ramphotrigon_megacephalum_Split_873
# shorter_clips[j] 441161
#
# i 17
# j 1041
# file_names[j] Ramphotrigon_megacephalum_Split_874
# shorter_clips[j] 441161
#
# i 18
# j 354
# file_names[j] Cnipodectes_superrufus_Split_292
# shorter_clips[j] 441161
#
# i 18
# j 355
# file_names[j] Cnipodectes_superrufus_Split_293
# shorter_clips[j] 441161
#
# i 18
# j 356
# file_names[j] Cnipodectes_superrufus_Split_294
# shorter_clips[j] 441161
#
# i 18
# j 357
# file_names[j] Cnipodectes_superrufus_Split_295
# shorter_clips[j] 441161
#
# i 18
# j 358
# file_names[j] Cnipodectes_superrufus_Split_296
# shorter_clips[j] 441161
#
# i 18
# j 359
# file_names[j] Cnipodectes_superrufus2_Cnipodectes_superrufus_Split
# shorter_clips[j] 441161
#
# i 18
# j 360
# file_names[j] Cnipodectes_superrufus_Split_297
# shorter_clips[j] 441161
#
# i 18
# j 361
# file_names[j] Cnipodectes_superrufus_Split_298
# shorter_clips[j] 441161
#
# i 18
# j 362
# file_names[j] Cnipodectes_superrufus_Split_299
# shorter_clips[j] 441161
#
# i 18
# j 363
# file_names[j] Hemitriccus_cohnhafti_Split_300
# shorter_clips[j] 441161
#
# i 19
# j 381
# file_names[j] Galbula_cyanescens_Split_316
# shorter_clips[j] 441161
#
# i 19
# j 384
# file_names[j] Galbula_cyanescens_Split_319
# shorter_clips[j] 441161
#
# i 19
# j 400
# file_names[j] Hypocnemis_subflava_Split_330
# shorter_clips[j] 441161
#
# i 19
# j 401
# file_names[j] Hypocnemis_subflava_Split_331
# shorter_clips[j] 441161
#
# i 19
# j 402
# file_names[j] Hypocnemis_subflava_Split_332
# shorter_clips[j] 441161
#
# i 19
# j 404
# file_names[j] Hypocnemis_subflava_Split_334
# shorter_clips[j] 441161
#
# i 19
# j 453
# file_names[j] Picumnus_rufiventris_Split_371
# shorter_clips[j] 441161
#
# i 20
# j 223
# file_names[j] Platyrinchus_platyrhynchos2_Rhytipterna_simplex4_Cercomacroides_serva_Split
# shorter_clips[j] 441161
#
# i 20
# j 224
# file_names[j] Cercomacroides_serva_Split_189
# shorter_clips[j] 441161
#
# i 20
# j 225
# file_names[j] Cercomacroides_serva5_Epinecrophylla_leucophthalma_Split
# shorter_clips[j] 441161
#
# i 20
# j 228
# file_names[j] Myrmoborus_myotherinus1_Sciaphylax_hemimelaena_Split
# shorter_clips[j] 441161
#
# i 20
# j 229
# file_names[j] Sciaphylax_hemimelaena_Split_191
# shorter_clips[j] 441161
#
# i 20
# j 230
# file_names[j] Sciaphylax_hemimelaena5_Lipaugus_vociferans_Split
# shorter_clips[j] 441161
#
# i 20
# j 242
# file_names[j] Tangara_chilensis_Split_198
# shorter_clips[j] 441161
#
# i 20
# j 243
# file_names[j] Tangara_chilensis8_Psarocolius_angustifrons_Split
# shorter_clips[j] 441161
#
# i 21
# j 831
# file_names[j] Capsiempis_flaveola_flaveola__Split_689
# shorter_clips[j] 441161
#
# i 21
# j 1002
# file_names[j] Poecilotriccus_latirostris_Split_842
# shorter_clips[j] 441161
#
# i 21
# j 1308
# file_names[j] Cnipodectes_superrufus_Split_1105
# shorter_clips[j] 441161
#
# i 22
# j 580
# file_names[j] Myrmotherula_longicauda_Split_470
# shorter_clips[j] 441161
#
# i 22
# j 582
# file_names[j] Myrmotherula_longicauda_Split_472
# shorter_clips[j] 441161
# i 22
# j 583
# file_names[j] Myrmotherula_longicauda_Split_473
# shorter_clips[j] 441161
#
# i 22
# j 584
# file_names[j] Myrmotherula_longicauda_Split_474
# shorter_clips[j] 441161
#
# i 22
# j 586
# file_names[j] Myrmotherula_longicauda_Split_476
# shorter_clips[j] 441161
#
# i 22
# j 587
# file_names[j] Myrmotherula_longicauda_Split_477
# shorter_clips[j] 441161
#
# i 22
# j 588
# file_names[j] Myrmotherula_longicauda_Split_478
# shorter_clips[j] 441161
#
# i 22
# j 590
# file_names[j] Myrmotherula_longicauda_Split_480
# shorter_clips[j] 441161
#
# i 22
# j 591
# file_names[j] Myrmotherula_longicauda_Split_481
# shorter_clips[j] 441161
#
# i 22
# j 592
# file_names[j] Myrmotherula_longicauda_Split_482
# shorter_clips[j] 441161
#
# i 22
# j 593
# file_names[j] Myrmotherula_longicauda_Split_483
# shorter_clips[j] 441161
#
# i 22
# j 596
# file_names[j] Myrmotherula_longicauda_Split_486
# shorter_clips[j] 441161
#
# i 22
# j 598
# file_names[j] Amazona_farinosa_Split_487
# shorter_clips[j] 441161
#
# i 22
# j 709
# file_names[j] Cacicus_cela_Split_584
# shorter_clips[j] 441161
#
# i 22
# j 710
# file_names[j] Cacicus_cela_Split_585
# shorter_clips[j] 441161
#
# i 22
# j 711
# file_names[j] Cacicus_cela_Split_586
# shorter_clips[j] 441161
#
# i 22
# j 712
# file_names[j] Cacicus_cela_Split_587
# shorter_clips[j] 441161
#
# i 22
# j 714
# file_names[j] Cacicus_cela_Split_589
# shorter_clips[j] 441161
#
# i 22
# j 715
# file_names[j] Cacicus_cela_Split_590
# shorter_clips[j] 441161
#
# i 22
# j 716
# file_names[j] Cacicus_cela_Split_591
# shorter_clips[j] 441161
#
# i 22
# j 717
# file_names[j] Ammodramus_aurifrons_Split_592
# shorter_clips[j] 441161
#
# i 22
# j 960
# file_names[j] Brotogeris_sanctithomae_Split_805
# shorter_clips[j] 441161
#
# i 22
# j 1284
# file_names[j] Myiodynastes_maculatus_solitarius_Split_1085
# shorter_clips[j] 441161
#
# i 23
# j 603
# file_names[j] Colaptes_punctigula_Split_491
# shorter_clips[j] 441161
#
# i 23
# j 607
# file_names[j] Oryzoborus_angolensis_Split_494
# shorter_clips[j] 441161
#
# i 23
# j 608
# file_names[j] Oryzoborus_angolensis_Split_495
# shorter_clips[j] 441161
#
# i 23
# j 609
# file_names[j] Oryzoborus_angolensis_Split_496
# shorter_clips[j] 441161
#
# i 23
# j 610
# file_names[j] Oryzoborus_angolensis_Split_497
# shorter_clips[j] 441161
#
# i 23
# j 611
# file_names[j] Oryzoborus_angolensis8_Ammodramus_aurifrons_Split
# shorter_clips[j] 441161
#
# i 23
# j 612
# file_names[j] Ammodramus_aurifrons_Split_498
# shorter_clips[j] 441161
#
# i 24
# j 414
# file_names[j] Hypocnemis_subflava_Split_343
# shorter_clips[j] 441161
#
# i 24
# j 416
# file_names[j] Hypocnemis_subflava5_Cercomacroides_fuscicauda_Split
# shorter_clips[j] 441161
#
# i 24
# j 751
# file_names[j] Veniliornis_passerinus_Split_624
# shorter_clips[j] 441161
#
# i 24
# j 847
# file_names[j] Cyanocorax_violaceus_(1)_Split_705
# shorter_clips[j] 441161
#
# i 24
# j 848
# file_names[j] Cyanocorax_violaceus_(1)_Split_706
# shorter_clips[j] 441161
#
# i 24
# j 849
# file_names[j] Cyanocorax_violaceus_(1)_Split_707
# shorter_clips[j] 441161
#
# i 24
# j 852
# file_names[j] Cyanocorax_violaceus_Split_709
# shorter_clips[j] 441161
#
# i 24
# j 856
# file_names[j] Cyanocorax_violaceus_Split_713
# shorter_clips[j] 441161
#
# i 24
# j 857
# file_names[j] Cyanocorax_violaceus_Split_714
# shorter_clips[j] 441161
#
# i 24
# j 858
# file_names[j] Cyanocorax_violaceus_Split_715
# shorter_clips[j] 441161
#
# i 24
# j 859
# file_names[j] Cyanocorax_violaceus4_Anurolimnas_castaneiceps_Split
# shorter_clips[j] 441161
#
# i 24
# j 868
# file_names[j] Myrmotherula_sclateri_Split_723
# shorter_clips[j] 441161
#
# i 24
# j 870
# file_names[j] Myrmotherula_sclateri_Split_724
# shorter_clips[j] 441161
#
# i 24
# j 871
# file_names[j] Myrmotherula_sclateri_Split_725
# shorter_clips[j] 441161
#
# i 25
# j 490
# file_names[j] Hypocnemis_subflava_Split_395
# shorter_clips[j] 441161
#
# i 25
# j 491
# file_names[j] Hypocnemis_subflava_Split_396
# shorter_clips[j] 441161
#
# i 25
# j 492
# file_names[j] Hypocnemis_subflava4_Jacamerops_aureus_Split
# shorter_clips[j] 441161
#
# i 25
# j 545
# file_names[j] Neocrex_erythrops_Split_438
# shorter_clips[j] 441161
#
# i 25
# j 546
# file_names[j] Neocrex_erythrops_Split_439
# shorter_clips[j] 441161
#
# i 25
# j 547
# file_names[j] Neocrex_erythrops_Split_440
# shorter_clips[j] 441161
#
# i 25
# j 548
# file_names[j] Neocrex_erythrops_Split_441
# shorter_clips[j] 441161
#
# i 25
# j 549
# file_names[j] Neocrex_erythrops_Split_442
# shorter_clips[j] 441161
#
# i 25
# j 1003
# file_names[j] Poecilotriccus_latirostris4_Saltator_coerulescens_Split
# shorter_clips[j] 441161
#
# i 25
# j 1004
# file_names[j] Saltator_coerulescens9_Conioptilon_mcilhennyi_Split
# shorter_clips[j] 441161
#
# i 26
# j 529
# file_names[j] Poecilotriccus_latirostris_Split_424
# shorter_clips[j] 441161
#
# i 26
# j 530
# file_names[j] Poecilotriccus_latirostris1_Myiozetetes_cayanensis_Split
# shorter_clips[j] 441161
#
# i 26
# j 672
# file_names[j] Saltator_coerulescens_Split_551
# shorter_clips[j] 441161
#
# i 26
# j 673
# file_names[j] Saltator_coerulescens2_Neocrex_erythrops_Split
# shorter_clips[j] 441161
#
# i 26
# j 679
# file_names[j] Sporophila_caerulescens_Split_556
# shorter_clips[j] 441161
#
# i 26
# j 1127
# file_names[j] Sporophila_lineola_Split_948
# shorter_clips[j] 441161
#
# i 26
# j 1128
# file_names[j] Sporophila_lineola_Split_949
# shorter_clips[j] 441161
#
# i 26
# j 1129
# file_names[j] Sporophila_lineola_Split_950
# shorter_clips[j] 441161
#
# i 26
# j 1130
# file_names[j] Sporophila_lineola_Split_951
# shorter_clips[j] 441161
#
# i 26
# j 1131
# file_names[j] Sporophila_lineola_Split_952
# shorter_clips[j] 441161
#
# i 26
# j 1132
# file_names[j] Sporophila_lineola_Split_953
# shorter_clips[j] 441161
#
# i 26
# j 1133
# file_names[j] Sporophila_lineola_Split_954
# shorter_clips[j] 441161
#
# i 26
# j 1134
# file_names[j] Sporophila_lineola_Split_955
# shorter_clips[j] 441161
#
# i 26
# j 1135
# file_names[j] Sporophila_lineola_Split_956
# shorter_clips[j] 441161
#
# i 26
# j 1136
# file_names[j] Sporophila_lineola_Split_957
# shorter_clips[j] 441161
#
# i 26
# j 1138
# file_names[j] Sporophila_lineola4_Megarynchus_pitangua_Split
# shorter_clips[j] 441161
#
# i 26
# j 1139
# file_names[j] Megarynchus_pitangua_Split_959
# shorter_clips[j] 441161
#
# i 27
# j 893
# file_names[j] Rhynchocyclus_olivaceus_Split_747
# shorter_clips[j] 441161
#
# i 27
# j 894
# file_names[j] Rhynchocyclus_olivaceus_Split_748
# shorter_clips[j] 441161
#
# i 27
# j 895
# file_names[j] Rhynchocyclus_olivaceus_Split_749
# shorter_clips[j] 441161
#
# i 27
# j 896
# file_names[j] Rhynchocyclus_olivaceus_Split_750
# shorter_clips[j] 441161
#
# i 27
# j 897
# file_names[j] Rhynchocyclus_olivaceus_Split_751
# shorter_clips[j] 441161
#
# i 27
# j 898
# file_names[j] Rhynchocyclus_olivaceus_Split_752
# shorter_clips[j] 441161
#
# i 27
# j 901
# file_names[j] Hylocharis_cyanus2_Phaethornis_hispidus_Split
# shorter_clips[j] 441161
#
# i 27
# j 902
# file_names[j] Phaethornis_hispidus9_Phaethornis_hispidus_Split
# shorter_clips[j] 441161
#
# i 27
# j 903
# file_names[j] Phaethornis_hispidus_Split_754
# shorter_clips[j] 441161
#
# i 27
# j 930
# file_names[j] Vireo_olivaceus2_Tyrannopsis_sulphurea_Split
# shorter_clips[j] 441161
#
# i 27
# j 931
# file_names[j] Tyrannopsis_sulphurea_Split_778
# shorter_clips[j] 441161
#
# i 28
# j 504
# file_names[j] Attila_spadiceus_Split_404
# shorter_clips[j] 441161
#
# i 28
# j 513
# file_names[j] Chaetura_viridipennis_Split_410
# shorter_clips[j] 441161
#
# i 28
# j 514
# file_names[j] Chaetura_viridipennis_Split_411
# shorter_clips[j] 441161
#
# i 28
# j 515
# file_names[j] Chaetura_viridipennis_Split_412
# shorter_clips[j] 441161
#
# i 28
# j 518
# file_names[j] Chaetura_viridipennis_Split_415
# shorter_clips[j] 441161
#
# i 28
# j 519
# file_names[j] Chaetura_viridipennis6_Tyrannus_melancholicus_Split
# shorter_clips[j] 441161
#
# i 28
# j 520
# file_names[j] Phaeomyias_murina_wagae_Split_416
# shorter_clips[j] 441161
#
# i 28
# j 1083
# file_names[j] Tolmomyias_poliocephalus_Split_910
# shorter_clips[j] 441161
#
# i 28
# j 1137
# file_names[j] Sporophila_lineola_Split_958
# shorter_clips[j] 441161
#
# i 29
# j 776
# file_names[j] Liosceles_thoracicus_Split_648
# shorter_clips[j] 441161
#
# i 29
# j 781
# file_names[j] Liosceles_thoracicus_Split_653
# shorter_clips[j] 441161
#
# i 29
# j 782
# file_names[j] Liosceles_thoracicus_Split_654
# shorter_clips[j] 441161
#
# i 29
# j 783
# file_names[j] Liosceles_thoracicus_Split_655
# shorter_clips[j] 441161
#
# i 29
# j 784
# file_names[j] Liosceles_thoracicus_Split_656
# shorter_clips[j] 441161
#
# i 29
# j 785
# file_names[j] Liosceles_thoracicus_Split_657
# shorter_clips[j] 441161
#
# i 29
# j 786
# file_names[j] Liosceles_thoracicus4_Campephilus_rubricollis_Split
# shorter_clips[j] 441161
#
# i 29
# j 787
# file_names[j] Campephilus_rubricollis8_Conioptilon_mcilhennyi_Split
# shorter_clips[j] 441161
#
# i 30
# j 84
# file_names[j] Colaptes_punctigula7_Volatinia_jacarina_Split
# shorter_clips[j] 441161
#
# i 30
# j 96
# file_names[j] Volatinia_jacarina3_Sporophila_castaneiventris_Split
# shorter_clips[j] 441161
#
# i 30
# j 97
# file_names[j] Sporophila_castaneiventris_Split_83
# shorter_clips[j] 441161
#
# i 30
# j 98
# file_names[j] Sporophila_castaneiventris_Split_84
# shorter_clips[j] 441161
#
# i 30
# j 99
# file_names[j] Sporophila_castaneiventris_Split_85
# shorter_clips[j] 441161
#
# i 30
# j 100
# file_names[j] Sporophila_castaneiventris6_Volatinia_jacarina_Split
# shorter_clips[j] 441161
#
# i 30
# j 108
# file_names[j] Volatinia_jacarina5_Taraba_major_Split
# shorter_clips[j] 441161
#
# i 31
# j 380
# file_names[j] Galbula_cyanescens_Split_315
# shorter_clips[j] 441161
#
# i 31
# j 434
# file_names[j] Buteo_nitidus_Split_357
# shorter_clips[j] 441161
#
# i 31
# j 435
# file_names[j] Buteo_nitidus_Split_358
# shorter_clips[j] 441161
#
# i 31
# j 436
# file_names[j] Hemitriccus_iohannis_Split_359
# shorter_clips[j] 441161
#
# i 31
# j 1313
# file_names[j] Cnipodectes_superrufus_Split_1110
# shorter_clips[j] 441161
#
# i 31
# j 1318
# file_names[j] Cnipodectes_superrufus_Split_1114
# shorter_clips[j] 441161
#
# i 31
# j 1319
# file_names[j] Cnipodectes_superrufus_Split_1115
# shorter_clips[j] 441161
#
# i 31
# j 1320
# file_names[j] Cnipodectes_superrufus_Split_1116
# shorter_clips[j] 441161
#
# i 31
# j 1321
# file_names[j] Cnipodectes_superrufus_Split_1117
# shorter_clips[j] 441161
#
# i 31
# j 1322
# file_names[j] Cnipodectes_superrufus_Split_1118
# shorter_clips[j] 441161
#
# i 31
# j 1323
# file_names[j] Cnipodectes_superrufus_Split_1119
# shorter_clips[j] 441161
#
# i 31
# j 1324
# file_names[j] Cnipodectes_superrufus_Split_1120
# shorter_clips[j] 441161
#
# i 31
# j 1325
# file_names[j] Cnipodectes_superrufus_Split_1121
# shorter_clips[j] 441161
#
# i 31
# j 1326
# file_names[j] Cnipodectes_superrufus_Split_1122
# shorter_clips[j] 441161
#
# i 31
# j 1327
# file_names[j] Cnipodectes_superrufus7_Cnipodectes_superrufus_Split
# shorter_clips[j] 441161
#
# i 31
# j 1328
# file_names[j] Cnipodectes_superrufus_Split_1123
# shorter_clips[j] 441161
#
# i 31
# j 1329
# file_names[j] Cnipodectes_superrufus_Split_1124
# shorter_clips[j] 441161
#
# i 32
# j 289
# file_names[j] Picumnus_subtilis_Split_238
# shorter_clips[j] 441161
#
# i 32
# j 290
# file_names[j] Picumnus_subtilis_Split_239
# shorter_clips[j] 441161
#
# i 32
# j 291
# file_names[j] Picumnus_subtilis_Split_240
# shorter_clips[j] 441161
#
# i 32
# j 292
# file_names[j] Picumnus_subtilis_Split_241
# shorter_clips[j] 441161
#
# i 32
# j 293
# file_names[j] Picumnus_subtilis_Split_242
# shorter_clips[j] 441161
#
# i 32
# j 294
# file_names[j] Picumnus_subtilis_Split_243
# shorter_clips[j] 441161
#
# i 32
# j 295
# file_names[j] Picumnus_subtilis_Split_244
# shorter_clips[j] 441161
#
# i 32
# j 296
# file_names[j] Picumnus_subtilis_Split_245
# shorter_clips[j] 441161
#
# i 32
# j 297
# file_names[j] Picumnus_subtilis_Split_246
# shorter_clips[j] 441161
#
# i 32
# j 298
# file_names[j] Picumnus_subtilis_Split_247
# shorter_clips[j] 441161
#
# i 32
# j 299
# file_names[j] Picumnus_subtilis_Split_248
# shorter_clips[j] 441161
#
# i 32
# j 300
# file_names[j] Picumnus_subtilis_Split_249
# shorter_clips[j] 441161
#
# i 32
# j 301
# file_names[j] Picumnus_subtilis8_Brachygalba_albogularis_Split
# shorter_clips[j] 441161
#
# i 33
# j 329
# file_names[j] Helicolestes_hamatus_Split_272
# shorter_clips[j] 441161
#
# i 33
# j 619
# file_names[j] Eurypyga_helias_helias_Split_503
# shorter_clips[j] 441161
#
# i 33
# j 1238
# file_names[j] Neopelma_sulphureiventer_Split_1044
# shorter_clips[j] 441161
#
# i 33
# j 1239
# file_names[j] Neopelma_sulphureiventer_Split_1045
# shorter_clips[j] 441161
#
# i 33
# j 1240
# file_names[j] Neopelma_sulphureiventer_Split_1046
# shorter_clips[j] 441161
#
# i 33
# j 1241
# file_names[j] Neopelma_sulphureiventer_Split_1047
# shorter_clips[j] 441161
#
# i 33
# j 1242
# file_names[j] Neopelma_sulphureiventer5_Neopelma_sulphureiventer_Split
# shorter_clips[j] 441161
#
# i 33
# j 1243
# file_names[j] Neopelma_sulphureiventer_Split_1048
# shorter_clips[j] 441161
#
# i 33
# j 1302
# file_names[j] Formicarius_rufifrons_Split_1101
# shorter_clips[j] 441161
#
# i 33
# j 1353
# file_names[j] Cnipodectes_superrufus_Split_1146
# shorter_clips[j] 441161
#
# i 33
# j 1354
# file_names[j] Cnipodectes_superrufus_Split_1147
# shorter_clips[j] 441161
#
# i 33
# j 1355
# file_names[j] Cnipodectes_superrufus_Split_1148
# shorter_clips[j] 441161
#
# i 33
# j 1356
# file_names[j] Cnipodectes_superrufus_Split_1149
# shorter_clips[j] 441161
#
# i 33
# j 1357
# file_names[j] Cnipodectes_superrufus_Split_1150
# shorter_clips[j] 441161
# i 33
# j 1358
# file_names[j] Cnipodectes_superrufus_Split_1151
# shorter_clips[j] 441161
#
# i 33
# j 1359
# file_names[j] Cnipodectes_superrufus_Split_1152
# shorter_clips[j] 441161
#
# i 33
# j 1360
# file_names[j] Cnipodectes_superrufus_Split_1153
# shorter_clips[j] 441161
#
# i 33
# j 1361
# file_names[j] Cnipodectes_superrufus_Split_1154
# shorter_clips[j] 441161
#
# i 33
# j 1362
# file_names[j] Cnipodectes_superrufus_Split_1155
# shorter_clips[j] 441161
#
# i 33
# j 1363
# file_names[j] Cnipodectes_superrufus_Split_1156
# shorter_clips[j] 441161
#
# i 33
# j 1364
# file_names[j] Cnipodectes_superrufus_Split_1157
# shorter_clips[j] 441161
#
# i 33
# j 1365
# file_names[j] Cnipodectes_superrufus_Split_1158
# shorter_clips[j] 441161
#
# i 33
# j 1366
# file_names[j] Cnipodectes_superrufus_Split_1159
# shorter_clips[j] 441161
#
# i 33
# j 1368
# file_names[j] Cnipodectes_superrufus_Split_1161
# shorter_clips[j] 441161
#
# i 33
# j 1369
# file_names[j] Cnipodectes_superrufus3_Phyllomyias_weedeni_Split
# shorter_clips[j] 441161
#
# i 33
# j 1370
# file_names[j] Phyllomyias_weedeni_Split_1162
# shorter_clips[j] 441161
#
# i 34
# j 978
# file_names[j] Formicarius_rufifrons_Split_821
# shorter_clips[j] 441161
#
# i 34
# j 982
# file_names[j] Formicarius_rufifrons_Split_825
# shorter_clips[j] 441161
#
# i 34
# j 983
# file_names[j] Formicarius_rufifrons_Split_826
# shorter_clips[j] 441161
#
# i 34
# j 985
# file_names[j] Formicarius_rufifrons_Split_828
# shorter_clips[j] 441161
#
# i 34
# j 986
# file_names[j] Formicarius_rufifrons_Split_829
# shorter_clips[j] 441161
#
# i 34
# j 987
# file_names[j] Formicarius_rufifrons_Split_830
# shorter_clips[j] 441161
#
# i 34
# j 988
# file_names[j] Formicarius_rufifrons_Split_831
# shorter_clips[j] 441161
#
# i 35
# j 559
# file_names[j] Neocrex_erythrops_Split_451
# shorter_clips[j] 441161
#
# i 35
# j 579
# file_names[j] Myrmotherula_longicauda_Split_469
# shorter_clips[j] 441161
#
# i 35
# j 1191
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_1004
# shorter_clips[j] 441161
#
# i 35
# j 1290
# file_names[j] Neocrex_erythrops_Split_1090
# shorter_clips[j] 441161
#
# i 35
# j 1291
# file_names[j] Neocrex_erythrops_Split_1091
# shorter_clips[j] 441161
#
# i 35
# j 1292
# file_names[j] Neocrex_erythrops_Split_1092
# shorter_clips[j] 441161
#
# i 35
# j 1293
# file_names[j] Neocrex_erythrops9_Formicarius_rufifrons_Split
# shorter_clips[j] 441161
#
# i 35
# j 1294
# file_names[j] Formicarius_rufifrons_Split_1093
# shorter_clips[j] 441161
#
# i 35
# j 1295
# file_names[j] Formicarius_rufifrons_Split_1094
# shorter_clips[j] 441161
#
# i 36
# j 321
# file_names[j] Akletos_goeldii_Split_266
# shorter_clips[j] 441161
#
# i 36
# j 816
# file_names[j] Myrmotherula_iheringi_Split_679
# shorter_clips[j] 441161
#
# i 36
# j 1231
# file_names[j] Formicarius_rufifrons_Split_1038
# shorter_clips[j] 441161
#
# i 36
# j 1233
# file_names[j] Formicarius_rufifrons_Split_1040
# shorter_clips[j] 441161
#
# i 37
# j 285
# file_names[j] Cnipodectes_superrufus_Split_235
# shorter_clips[j] 441161
#
# i 37
# j 286
# file_names[j] Cnipodectes_superrufus_Split_236
# shorter_clips[j] 441161
#
# i 37
# j 287
# file_names[j] Cnipodectes_superrufus_Split_237
# shorter_clips[j] 441161
#
# i 37
# j 288
# file_names[j] Cnipodectes_superrufus1_Cnipodectes_superrufus5_Picumnus_subtilis_Split
# shorter_clips[j] 441161
#
# i 37
# j 830
# file_names[j] Spizaetus_tyrannus2_Capsiempis_flaveola_flaveola__Split
# shorter_clips[j] 441161
#
# i 37
# j 991
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_833
# shorter_clips[j] 441161
#
# i 37
# j 992
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_834
# shorter_clips[j] 441161
#
# i 37
# j 993
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_835
# shorter_clips[j] 441161
#
# i 37
# j 994
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_836
# shorter_clips[j] 441161
#
# i 37
# j 995
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_837
# shorter_clips[j] 441161
#
# i 37
# j 996
# file_names[j] Ramphocaenus_sticturus_obscurus8_Hemitriccus_flammulatus_Split
# shorter_clips[j] 441161
#
# i 37
# j 997
# file_names[j] Hemitriccus_flammulatus_Split_838
# shorter_clips[j] 441161
#
# i 38
# j 27
# file_names[j] Psarocolius_bifasciatus_yuracares3_Chaetura_viridipennis_Split
# shorter_clips[j] 441161
#
# i 38
# j 791
# file_names[j] Conioptilon_mcilhennyi_Split_661
# shorter_clips[j] 441161
#
# i 38
# j 792
# file_names[j] Conioptilon_mcilhennyi_Split_662
# shorter_clips[j] 441161
#
# i 38
# j 793
# file_names[j] Conioptilon_mcilhennyi_Split_663
# shorter_clips[j] 441161
#
# i 38
# j 796
# file_names[j] Cotinga_maynana3_Conioptilon_mcilhennyi_Split
# shorter_clips[j] 441161
#
# i 38
# j 974
# file_names[j] Ictinia_plumbea_Split_818
# shorter_clips[j] 441161
#
# i 38
# j 1063
# file_names[j] Psarocolius_decumanus_Split_892
# shorter_clips[j] 441161
#
# i 38
# j 1065
# file_names[j] Psarocolius_decumanus_Split_894
# shorter_clips[j] 441161
#
# i 38
# j 1068
# file_names[j] Cymbilaimus_sanctaemariae_Split_896
# shorter_clips[j] 441161
#
# i 38
# j 1069
# file_names[j] Cymbilaimus_sanctaemariae_Split_897
# shorter_clips[j] 441161
#
# i 38
# j 1070
# file_names[j] Cymbilaimus_sanctaemariae_Split_898
# shorter_clips[j] 441161
#
# i 38
# j 1299
# file_names[j] Formicarius_rufifrons_Split_1098
# shorter_clips[j] 441161
#
# i 38
# j 1303
# file_names[j] Formicarius_rufifrons_Split_1102
# shorter_clips[j] 441161
#
# i 38
# j 1367
# file_names[j] Cnipodectes_superrufus_Split_1160
# shorter_clips[j] 441161
#
# i 39
# j 869
# file_names[j] Myrmotherula_sclateri9_Myrmotherula_sclateri_Split
# shorter_clips[j] 441161
#
# i 39
# j 874
# file_names[j] Myrmotherula_sclateri_Split_728
# shorter_clips[j] 441161
#
# i 39
# j 876
# file_names[j] Myrmotherula_sclateri_Split_730
# shorter_clips[j] 441161
#
# i 39
# j 877
# file_names[j] Myrmotherula_sclateri_Split_731
# shorter_clips[j] 441161
#
# i 39
# j 878
# file_names[j] Myrmotherula_sclateri_Split_732
# shorter_clips[j] 441161
#
# i 39
# j 882
# file_names[j] Myrmotherula_sclateri_Split_736
# shorter_clips[j] 441161
#
# i 39
# j 883
# file_names[j] Myrmotherula_sclateri_Split_737
# shorter_clips[j] 441161
#
# i 39
# j 884
# file_names[j] Rhynchocyclus_olivaceus_Split_738
# shorter_clips[j] 441161
#
# i 39
# j 885
# file_names[j] Rhynchocyclus_olivaceus_Split_739
# shorter_clips[j] 441161
#
# i 39
# j 886
# file_names[j] Rhynchocyclus_olivaceus_Split_740
# shorter_clips[j] 441161
#
# i 40
# j 376
# file_names[j] Myrmophylax_atrothorax_Split_312
# shorter_clips[j] 441161
#
# i 40
# j 377
# file_names[j] Myrmophylax_atrothorax_Split_313
# shorter_clips[j] 441161
#
# i 40
# j 378
# file_names[j] Myrmophylax_atrothorax8_Galbula_cyanescens_Split
# shorter_clips[j] 441161
#
# i 40
# j 482
# file_names[j] Cyanocorax_violaceus3_Glaucis_hirsutus_Split
# shorter_clips[j] 441161
#
# i 40
# j 1164
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_980
# shorter_clips[j] 441161
#
# i 40
# j 1166
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_981
# shorter_clips[j] 441161
#
# i 40
# j 1171
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_986
# shorter_clips[j] 441161
#
# i 40
# j 1172
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_987
# shorter_clips[j] 441161
#
# i 40
# j 1173
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_988
# shorter_clips[j] 441161
#
# i 40
# j 1174
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_989
# shorter_clips[j] 441161
#
# i 40
# j 1175
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_990
# shorter_clips[j] 441161
#
# i 40
# j 1176
# file_names[j] Ramphocaenus_sticturus_obscurus_Split_991
# shorter_clips[j] 441161
#
# i 41
# j 1071
# file_names[j] Cymbilaimus_sanctaemariae_Split_899
# shorter_clips[j] 441161
#
# i 41
# j 1072
# file_names[j] Cymbilaimus_sanctaemariae_Split_900
# shorter_clips[j] 441161
#
# i 41
# j 1073
# file_names[j] Cymbilaimus_sanctaemariae_Split_901
# shorter_clips[j] 441161
#
# i 41
# j 1074
# file_names[j] Cymbilaimus_sanctaemariae_Split_902
# shorter_clips[j] 441161
#
# i 41
# j 1075
# file_names[j] Cymbilaimus_sanctaemariae_Split_903
# shorter_clips[j] 441161
#
# i 41
# j 1076
# file_names[j] Cymbilaimus_sanctaemariae_Split_904
# shorter_clips[j] 441161
#
# i 41
# j 1077
# file_names[j] Cymbilaimus_sanctaemariae_Split_905
# shorter_clips[j] 441161
#
# i 41
# j 1078
# file_names[j] Cymbilaimus_sanctaemariae_Split_906
# shorter_clips[j] 441161
#
# i 41
# j 1079
# file_names[j] Cymbilaimus_sanctaemariae_Split_907
# shorter_clips[j] 441161
#
# i 41
# j 1080
# file_names[j] Cymbilaimus_sanctaemariae_Split_908
# shorter_clips[j] 441161
#
# i 41
# j 1081
# file_names[j] Cymbilaimus_sanctaemariae6_Tolmomyias_poliocephalus_Split
# shorter_clips[j] 441161
#
# i 41
# j 1082
# file_names[j] Tolmomyias_poliocephalus_Split_909
# shorter_clips[j] 441161
#
# i 42
# j 129
# file_names[j] Laterallus_exilis_Split_112
# shorter_clips[j] 441161
#
# i 42
# j 443
# file_names[j] Myrmelastes_hyperythrus_Split_364
# shorter_clips[j] 441161
#
# i 42
# j 446
# file_names[j] Myrmelastes_hyperythrus3_Picumnus_rufiventris_Split
# shorter_clips[j] 441161
#
# i 43
# j 693
# file_names[j] Chaetura_egregia_Split_570
# shorter_clips[j] 441161
#
# i 43
# j 694
# file_names[j] Chaetura_egregia_Split_571
# shorter_clips[j] 441161
#
# i 43
# j 695
# file_names[j] Chaetura_egregia5_Tityra_cayana_Split
# shorter_clips[j] 441161
#
# i 43
# j 696
# file_names[j] Cacicus_cela_Split_572
# shorter_clips[j] 441161
#
# i 43
# j 697
# file_names[j] Cacicus_cela_Split_573
# shorter_clips[j] 441161
#
# i 43
# j 698
# file_names[j] Cacicus_cela_Split_574
# shorter_clips[j] 441161
#
# i 43
# j 699
# file_names[j] Cacicus_cela_Split_575
# shorter_clips[j] 441161
#
# i 43
# j 700
# file_names[j] Cacicus_cela_Split_576
# shorter_clips[j] 441161
#
# i 43
# j 701
# file_names[j] Cacicus_cela_Split_577
# shorter_clips[j] 441161
#
# i 43
# j 702
# file_names[j] Cacicus_cela_Split_578
# shorter_clips[j] 441161
#
# i 43
# j 703
# file_names[j] Cacicus_cela_Split_579
# shorter_clips[j] 441161
#
# i 43
# j 704
# file_names[j] Cacicus_cela_Split_580
# shorter_clips[j] 441161
#
# i 43
# j 705
# file_names[j] Cacicus_cela_Split_581
# shorter_clips[j] 441161
#
# i 43
# j 706
# file_names[j] Cacicus_cela_Split_582
# shorter_clips[j] 441161
#
# i 43
# j 707
# file_names[j] Cacicus_cela_Split_583
# shorter_clips[j] 441161
#
# i 43
# j 708
# file_names[j] Cacicus_cela3_Cacicus_cela_Split
# shorter_clips[j] 441161
#
# i 43
# j 836
# file_names[j] Capsiempis_flaveola_flaveola__Split_694
# shorter_clips[j] 441161
#
# i 43
# j 843
# file_names[j] Cyanocorax_violaceus_(1)_Split_701
# shorter_clips[j] 441161
#
# i 43
# j 1447
# file_names[j] Hemitriccus_cohnhafti_Split_1234
# shorter_clips[j] 441161
#
# i 44
# j 139
# file_names[j] Ramphocelus_carbo_Split_120
# shorter_clips[j] 441161
#
# i 44
# j 140
# file_names[j] Ramphocelus_carbo_Split_121
# shorter_clips[j] 441161
#
# i 44
# j 141
# file_names[j] Ramphocelus_carbo_Split_122
# shorter_clips[j] 441161
#
# i 44
# j 142
# file_names[j] Ramphocelus_carbo_Split_123
# shorter_clips[j] 441161
#
# i 44
# j 476
# file_names[j] Pachyramphus_polychopterus_nigriventris5_Ammodramus_aurifrons_Split
# shorter_clips[j] 441161
#
# i 44
# j 613
# file_names[j] Ammodramus_aurifrons_Split_499
# shorter_clips[j] 441161
#
# i 44
# j 614
# file_names[j] Ammodramus_aurifrons_Split_500
# shorter_clips[j] 441161
#
# i 44
# j 615
# file_names[j] Ammodramus_aurifrons_Split_501
# shorter_clips[j] 441161
#
# i 44
# j 616
# file_names[j] Ammodramus_aurifrons_Split_502
# shorter_clips[j] 441161
#
# i 44
# j 617
# file_names[j] Ammodramus_aurifrons5_Melanerpes_cruentatus_Split
# shorter_clips[j] 441161
#
# i 44
# j 618
# file_names[j] Melanerpes_cruentatus9_Eurypyga_helias_helias_Split
# shorter_clips[j] 441161
#
# i 44
# j 973
# file_names[j] Ictinia_plumbea_Split_817
# shorter_clips[j] 441161
#
# i 44
# j 975
# file_names[j] Ictinia_plumbea_Split_819
# shorter_clips[j] 441161
#
# i 44
# j 976
# file_names[j] Ictinia_plumbea3_Formicarius_rufifrons_Split
# ...
# file_names[j] Conioptilon_mcilhennyi_Split_845
# shorter_clips[j] 441161
#
# i 74
# j 1008
# file_names[j] Conioptilon_mcilhennyi_Split_846
# shorter_clips[j] 441161
#
# i 74
# j 1009
# file_names[j] Conioptilon_mcilhennyi_Split_847
# shorter_clips[j] 441161
#
# i 74
# j 1010
# file_names[j] Conioptilon_mcilhennyi_Split_848
# shorter_clips[j] 441161
#
# i 74
# j 1011
# file_names[j] Conioptilon_mcilhennyi_Split_849
# shorter_clips[j] 441161
#
# i 74
# j 1012
# file_names[j] Conioptilon_mcilhennyi_Split_850
# shorter_clips[j] 441161
#
# i 74
# j 1013
# file_names[j] Amazona_ochrocephala_Split_851
# shorter_clips[j] 441161
#
# i 74
# j 1014
# file_names[j] Amazona_ochrocephala_Split_852
# shorter_clips[j] 441161
#
# i 74
# j 1048
# file_names[j] Capsiempis_flaveola_flaveola__Split_879
# shorter_clips[j] 441161
#
# i 74
# j 1050
# file_names[j] Capsiempis_flaveola_flaveola__Split_881
# shorter_clips[j] 441161
#
# i 74
# j 1059
# file_names[j] Capsiempis_flaveola_flaveola_2_Contopus_cooperi_Split
# shorter_clips[j] 441161
#
# i 74
# j 1439
# file_names[j] Hemitriccus_cohnhafti_Split_1226
# shorter_clips[j] 441161
#
# i 75
# j 620
# file_names[j] Eurypyga_helias_helias_Split_504
# shorter_clips[j] 441161
#
# i 75
# j 621
# file_names[j] Eurypyga_helias_helias_Split_505
# shorter_clips[j] 441161
#
# i 75
# j 622
# file_names[j] Eurypyga_helias_helias_Split_506
# shorter_clips[j] 441161
#
# i 75
# j 623
# file_names[j] Eurypyga_helias_helias_Split_507
# shorter_clips[j] 441161
#
# i 75
# j 624
# file_names[j] Eurypyga_helias_helias_Split_508
# shorter_clips[j] 441161
#
# i 75
# j 625
# file_names[j] Eurypyga_helias_helias_Split_509
# shorter_clips[j] 441161
#
# i 75
# j 626
# file_names[j] Eurypyga_helias_helias_Split_510
# shorter_clips[j] 441161
#
# i 75
# j 627
# file_names[j] Eurypyga_helias_helias_Split_511
# shorter_clips[j] 441161
#
# i 75
# j 628
# file_names[j] Eurypyga_helias_helias_Split_512
# shorter_clips[j] 441161
#
# i 75
# j 629
# file_names[j] Eurypyga_helias_helias_Split_513
# shorter_clips[j] 441161
#
# i 75
# j 630
# file_names[j] Eurypyga_helias_helias_Split_514
# shorter_clips[j] 441161
#
# i 75
# j 631
# file_names[j] Cnipodectes_superrufus_Split_515
# shorter_clips[j] 441161
#
# i 76
# j 418
# file_names[j] Cercomacroides_fuscicauda3_Myrmophylax_atrothorax_Split
# shorter_clips[j] 441161
#
# i 76
# j 861
# file_names[j] Anurolimnas_castaneiceps_Split_717
# shorter_clips[j] 441161
#
# i 76
# j 862
# file_names[j] Anurolimnas_castaneiceps_Split_718
# shorter_clips[j] 441161
#
# i 76
# j 863
# file_names[j] Anurolimnas_castaneiceps_Split_719
# shorter_clips[j] 441161
#
# i 76
# j 864
# file_names[j] Anurolimnas_castaneiceps8_Thalurania_furcata_Split
# shorter_clips[j] 441161
#
# i 76
# j 865
# file_names[j] Thalurania_furcata_Split_720
# shorter_clips[j] 441161
#
# i 76
# j 1005
# file_names[j] Conioptilon_mcilhennyi_Split_843
# shorter_clips[j] 441161
#
# i 77
# j 1410
# file_names[j] Hemitriccus_cohnhafti_Split_1199
# shorter_clips[j] 441161
#
# i 77
# j 1411
# file_names[j] Hemitriccus_cohnhafti_Split_1200
# shorter_clips[j] 441161
#
# i 77
# j 1412
# file_names[j] Hemitriccus_cohnhafti_Split_1201
# shorter_clips[j] 441161
#
# i 77
# j 1413
# file_names[j] Hemitriccus_cohnhafti_Split_1202
# shorter_clips[j] 441161
#
# i 77
# j 1414
# file_names[j] Hemitriccus_cohnhafti_Split_1203
# shorter_clips[j] 441161
#
# i 77
# j 1415
# file_names[j] Hemitriccus_cohnhafti_Split_1204
# shorter_clips[j] 441161
#
# i 77
# j 1416
# file_names[j] Hemitriccus_cohnhafti_Split_1205
# shorter_clips[j] 441161
#
# i 77
# j 1417
# file_names[j] Hemitriccus_cohnhafti_Split_1206
# shorter_clips[j] 441161
#
# i 77
# j 1418
# file_names[j] Hemitriccus_cohnhafti_Split_1207
# shorter_clips[j] 441161
#
# i 77
# j 1419
# file_names[j] Hemitriccus_cohnhafti7_Hemitriccus_cohnhafti_Split
# shorter_clips[j] 441161
#
# i 77
# j 1420
# file_names[j] Hemitriccus_cohnhafti_Split_1208
# shorter_clips[j] 441161
#
# i 78
# j 832
# file_names[j] Capsiempis_flaveola_flaveola__Split_690
# shorter_clips[j] 441161
#
# i 78
# j 905
# file_names[j] Phaethornis_hispidus_Split_756
# shorter_clips[j] 441161
#
# i 78
# j 906
# file_names[j] Phaethornis_hispidus_Split_757
# shorter_clips[j] 441161
#
# i 78
# j 907
# file_names[j] Phaethornis_hispidus_Split_758
# shorter_clips[j] 441161
#
# i 78
# j 908
# file_names[j] Phaethornis_hispidus_Split_759
# shorter_clips[j] 441161
#
# i 78
# j 909
# file_names[j] Phaethornis_hispidus_Split_760
# shorter_clips[j] 441161
#
# i 78
# j 910
# file_names[j] Phaethornis_hispidus_Split_761
# shorter_clips[j] 441161
#
# i 78
# j 911
# file_names[j] Phaethornis_hispidus_Split_762
# shorter_clips[j] 441161
#
# i 78
# j 912
# file_names[j] Phaethornis_hispidus_Split_763
# shorter_clips[j] 441161
#
# i 78
# j 913
# file_names[j] Phaethornis_hispidus1_Phaethornis_hispidus_Split
# shorter_clips[j] 441161
#
# i 78
# j 914
# file_names[j] Phaethornis_hispidus_Split_764
# shorter_clips[j] 441161
#
# i 78
# j 915
# file_names[j] Phaethornis_hispidus_Split_765
# shorter_clips[j] 441161
#
# i 78
# j 916
# file_names[j] Phaethornis_hispidus_Split_766
# shorter_clips[j] 441161
#
# i 78
# j 917
# file_names[j] Phaethornis_hispidus_Split_767
# shorter_clips[j] 441161
#
# i 78
# j 924
# file_names[j] Rhynchocyclus_olivaceus_Split_773
# shorter_clips[j] 441161
#
# i 78
# j 1025
# file_names[j] Sporophila_schistacea_Split_860
# shorter_clips[j] 441161
#
# i 78
# j 1026
# file_names[j] Sporophila_schistacea_Split_861
# shorter_clips[j] 441161
#
# i 78
# j 1027
# file_names[j] Sporophila_schistacea_Split_862
# shorter_clips[j] 441161
#
# i 78
# j 1287
# file_names[j] Mesembrinibis_cayennensis_Split_1087
# shorter_clips[j] 441161
#
# i 79
# j 961
# file_names[j] Brotogeris_sanctithomae_Split_806
# shorter_clips[j] 441161
#
# i 79
# j 962
# file_names[j] Brotogeris_sanctithomae_Split_807
# shorter_clips[j] 441161
#
# i 79
# j 963
# file_names[j] Brotogeris_sanctithomae_Split_808
# shorter_clips[j] 441161
#
# i 79
# j 964
# file_names[j] Brotogeris_sanctithomae_Split_809
# shorter_clips[j] 441161
#
# i 79
# j 965
# file_names[j] Brotogeris_sanctithomae_Split_810
# shorter_clips[j] 441161
#
# i 79
# j 966
# file_names[j] Brotogeris_sanctithomae_Split_811
# shorter_clips[j] 441161
#
# i 79
# j 967
# file_names[j] Brotogeris_sanctithomae_Split_812
# shorter_clips[j] 441161
#
# i 79
# j 968
# file_names[j] Brotogeris_sanctithomae_Split_813
# shorter_clips[j] 441161
#
# i 79
# j 969
# file_names[j] Brotogeris_sanctithomae_Split_814
# shorter_clips[j] 441161
#
# i 79
# j 970
# file_names[j] Brotogeris_sanctithomae_Split_815
# shorter_clips[j] 441161
#
# i 79
# j 971
# file_names[j] Brotogeris_sanctithomae6_Ictinia_plumbea_Split
# shorter_clips[j] 441161
#
# i 79
# j 972
# file_names[j] Ictinia_plumbea_Split_816
# shorter_clips[j] 441161
# i 80
# j 85
# file_names[j] Volatinia_jacarina_Split_72
# shorter_clips[j] 441161
#
# i 80
# j 86
# file_names[j] Volatinia_jacarina_Split_73
# shorter_clips[j] 441161
#
# i 80
# j 87
# file_names[j] Volatinia_jacarina_Split_74
# shorter_clips[j] 441161
#
# i 80
# j 88
# file_names[j] Volatinia_jacarina_Split_75
# shorter_clips[j] 441161
#
# i 80
# j 89
# file_names[j] Volatinia_jacarina_Split_76
# shorter_clips[j] 441161
#
# i 80
# j 90
# file_names[j] Volatinia_jacarina_Split_77
# shorter_clips[j] 441161
#
# i 80
# j 91
# file_names[j] Volatinia_jacarina_Split_78
# shorter_clips[j] 441161
#
# i 80
# j 92
# file_names[j] Volatinia_jacarina_Split_79
# shorter_clips[j] 441161
#
# i 80
# j 93
# file_names[j] Volatinia_jacarina_Split_80
# shorter_clips[j] 441161
#
# i 80
# j 94
# file_names[j] Volatinia_jacarina_Split_81
# shorter_clips[j] 441161
#
# i 80
# j 95
# file_names[j] Volatinia_jacarina_Split_82
# shorter_clips[j] 441161
#
# i 80
# j 101
# file_names[j] Volatinia_jacarina_Split_86
# shorter_clips[j] 441161
#
# i 80
# j 102
# file_names[j] Volatinia_jacarina_Split_87
# shorter_clips[j] 441161
#
# i 80
# j 103
# file_names[j] Volatinia_jacarina_Split_88
# shorter_clips[j] 441161
#
# i 80
# j 104
# file_names[j] Volatinia_jacarina_Split_89
# shorter_clips[j] 441161
#
# i 80
# j 105
# file_names[j] Volatinia_jacarina_Split_90
# shorter_clips[j] 441161
#
# i 80
# j 106
# file_names[j] Volatinia_jacarina_Split_91
# shorter_clips[j] 441161
#
# i 80
# j 107
# file_names[j] Volatinia_jacarina_Split_92
# shorter_clips[j] 441161
#
# i 81
# j 207
# file_names[j] Trogon_curucui1_Hemitriccus_griseipectus_Split
# shorter_clips[j] 441161
#
# i 81
# j 208
# file_names[j] Hemitriccus_griseipectus5_Amazilia_lactea_Split
# shorter_clips[j] 441161
#
# i 81
# j 210
# file_names[j] Ramphastos_vitellinus6_Antrostomus_sericocaudatus_Split
# shorter_clips[j] 441161
#
# i 81
# j 211
# file_names[j] Antrostomus_sericocaudatus_Split_183
# shorter_clips[j] 441161
#
# i 81
# j 213
# file_names[j] Hemitriccus_griseipectus_Split_184
# shorter_clips[j] 441161
#
# i 81
# j 216
# file_names[j] Platyrinchus_platyrhynchos_Split_185
# shorter_clips[j] 441161
#
# i 81
# j 217
# file_names[j] Platyrinchus_platyrhynchos7_Hemitriccus_griseipectus_Split
# shorter_clips[j] 441161
#
# i 81
# j 218
# file_names[j] Hemitriccus_griseipectus_Split_186
# shorter_clips[j] 441161
#
# i 81
# j 219
# file_names[j] Hemitriccus_griseipectus_Split_187
# shorter_clips[j] 441161
#
# i 81
# j 220
# file_names[j] Hemitriccus_griseipectus_Split_188
# shorter_clips[j] 441161
#
# i 81
# j 221
# file_names[j] Hemitriccus_griseipectus7_Platyrinchus_platyrhynchos_Split
# shorter_clips[j] 441161
#
# i 81
# j 226
# file_names[j] Epinecrophylla_leucophthalma_Split_190
# shorter_clips[j] 441161
#
# i 81
# j 227
# file_names[j] Epinecrophylla_leucophthalma5_Myrmoborus_myotherinus_Split
# shorter_clips[j] 441161
#
# i 81
# j 239
# file_names[j] Lanio_versicolor1_Lanio_versicolor_Split
# shorter_clips[j] 441161
#
# i 81
# j 240
# file_names[j] Lanio_versicolor_Split_197
# shorter_clips[j] 441161
#
# i 81
# j 241
# file_names[j] Lanio_versicolor5_Tangara_chilensis_Split
# shorter_clips[j] 441161
#
# i 82
# j 244
# file_names[j] Psarocolius_angustifrons_Split_199
# shorter_clips[j] 441161
#
# i 82
# j 245
# file_names[j] Psarocolius_angustifrons_Split_200
# shorter_clips[j] 441161
#
# i 82
# j 246
# file_names[j] Psarocolius_angustifrons_Split_201
# shorter_clips[j] 441161
#
# i 82
# j 247
# file_names[j] Psarocolius_angustifrons8_Cnipodectes_superrufus_Split
# shorter_clips[j] 441161
#
# i 83
# j 330
# file_names[j] Helicolestes_hamatus_Split_273
# shorter_clips[j] 441161
#
# i 83
# j 331
# file_names[j] Helicolestes_hamatus_Split_274
# shorter_clips[j] 441161
#
# i 83
# j 332
# file_names[j] Helicolestes_hamatus_Split_275
# shorter_clips[j] 441161
#
# i 83
# j 333
# file_names[j] Helicolestes_hamatus_Split_276
# shorter_clips[j] 441161
#
# i 83
# j 334
# file_names[j] Helicolestes_hamatus_Split_277
# shorter_clips[j] 441161
#
# i 83
# j 335
# file_names[j] Helicolestes_hamatus_Split_278
# shorter_clips[j] 441161
#
# i 83
# j 336
# file_names[j] Helicolestes_hamatus_Split_279
# shorter_clips[j] 441161
#
# i 83
# j 337
# file_names[j] Helicolestes_hamatus_Split_280
# shorter_clips[j] 441161
#
# i 83
# j 338
# file_names[j] Helicolestes_hamatus_Split_281
# shorter_clips[j] 441161
#
# i 83
# j 339
# file_names[j] Helicolestes_hamatus7_Cymbilaimus_sanctaemariae_Split
# shorter_clips[j] 441161
#
# i 83
# j 940
# file_names[j] Tyrannopsis_sulphurea_Split_786
# shorter_clips[j] 441161
#
# i 84
# j 167
# file_names[j] Ramphocaenus_sticturus_obscurus4_Hemitriccus_iohannis_Split
# shorter_clips[j] 441161
#
# i 84
# j 168
# file_names[j] Hemitriccus_iohannis_Split_147
# shorter_clips[j] 441161
#
# i 84
# j 169
# file_names[j] Hemitriccus_iohannis_Split_148
# shorter_clips[j] 441161
#
# i 84
# j 170
# file_names[j] Hemitriccus_iohannis_Split_149
# shorter_clips[j] 441161
#
# i 84
# j 171
# file_names[j] Hemitriccus_iohannis_Split_150
# shorter_clips[j] 441161
#
# i 84
# j 172
# file_names[j] Hemitriccus_iohannis_Split_151
# shorter_clips[j] 441161
#
# i 84
# j 173
# file_names[j] Hemitriccus_iohannis_Split_152
# shorter_clips[j] 441161
#
# i 84
# j 174
# file_names[j] Hemitriccus_iohannis_Split_153
# shorter_clips[j] 441161
#
# i 84
# j 175
# file_names[j] Hemitriccus_iohannis_Split_154
# shorter_clips[j] 441161
#
# i 84
# j 176
# file_names[j] Hemitriccus_iohannis_Split_155
# shorter_clips[j] 441161
#
# i 84
# j 581
# file_names[j] Myrmotherula_longicauda_Split_471
# shorter_clips[j] 441161
#
# i 84
# j 647
# file_names[j] Cnipodectes_superrufus_Split_530
# shorter_clips[j] 441161
#
# i 84
# j 652
# file_names[j] Cnipodectes_superrufus_Split_535
# shorter_clips[j] 441161
#
# i 84
# j 653
# file_names[j] Cnipodectes_superrufus_Split_536
# shorter_clips[j] 441161
#
# i 84
# j 665
# file_names[j] Heliomaster_longirostris_Split_546
# shorter_clips[j] 441161
#
# i 85
# j 800
# file_names[j] Myrmotherula_iheringi_Split_666
# shorter_clips[j] 441161
#
# i 85
# j 801
# file_names[j] Myrmotherula_iheringi_Split_667
# shorter_clips[j] 441161
#
# i 85
# j 802
# file_names[j] Myrmotherula_iheringi_Split_668
# shorter_clips[j] 441161
#
# i 85
# j 803
# file_names[j] Myrmotherula_iheringi_Split_669
# shorter_clips[j] 441161
#
# i 85
# j 806
# file_names[j] Myrmotherula_iheringi5_Myrmotherula_iheringi_Split
# shorter_clips[j] 441161
#
# i 85
# j 818
# file_names[j] Myrmotherula_iheringi_Split_681
# shorter_clips[j] 441161
#
# i 85
# j 820
# file_names[j] Myrmotherula_iheringi_Split_683
# shorter_clips[j] 441161
#
# i 85
# j 821
# file_names[j] Myrmotherula_iheringi_Split_684
# shorter_clips[j] 441161
#
# i 85
# j 822
# file_names[j] Myrmotherula_iheringi_Split_685
# shorter_clips[j] 441161
#
# i 85
# j 823
# file_names[j] Myrmotherula_iheringi2_Pyrrhura_rupicola_lowlands_Split
# shorter_clips[j] 441161
#
# i 86
# j 323
# file_names[j] Myrmoborus_lophotes_Split_267
# shorter_clips[j] 441161
#
# i 86
# j 324
# file_names[j] Myrmoborus_lophotes_Split_268
# shorter_clips[j] 441161
#
# i 86
# j 325
# file_names[j] Myrmoborus_lophotes_Split_269
# shorter_clips[j] 441161
#
# i 86
# j 326
# file_names[j] Myrmoborus_lophotes_Split_270
# shorter_clips[j] 441161
#
# i 86
# j 327
# file_names[j] Myrmoborus_lophotes5_Helicolestes_hamatus_Split
# shorter_clips[j] 441161
#
# i 87
# j 177
# file_names[j] Cercomacra_manu_Split_156
# shorter_clips[j] 441161
#
# i 87
# j 178
# file_names[j] Cercomacra_manu_Split_157
# shorter_clips[j] 441161
#
# i 87
# j 179
# file_names[j] Cercomacra_manu_Split_158
# shorter_clips[j] 441161
#
# i 87
# j 180
# file_names[j] Cercomacra_manu_Split_159
# shorter_clips[j] 441161
#
# i 87
# j 181
# file_names[j] Cercomacra_manu_Split_160
# shorter_clips[j] 441161
#
# i 87
# j 182
# file_names[j] Cercomacra_manu_Split_161
# shorter_clips[j] 441161
#
# i 87
# j 183
# file_names[j] Cercomacra_manu_Split_162
# shorter_clips[j] 441161
#
# i 87
# j 184
# file_names[j] Cercomacra_manu_Split_163
# shorter_clips[j] 441161
#
# i 87
# j 185
# file_names[j] Cercomacra_manu_Split_164
# shorter_clips[j] 441161
#
# i 87
# j 186
# file_names[j] Cercomacra_manu_Split_165
# shorter_clips[j] 441161
#
# i 88
# j 923
# file_names[j] Rhynchocyclus_olivaceus_Split_772
# shorter_clips[j] 441161
#
# i 88
# j 925
# file_names[j] Rhynchocyclus_olivaceus_Split_774
# shorter_clips[j] 441161
#
# i 88
# j 926
# file_names[j] Rhynchocyclus_olivaceus_Split_775
# shorter_clips[j] 441161
#
# i 88
# j 927
# file_names[j] Rhynchocyclus_olivaceus_Split_776
# shorter_clips[j] 441161
#
# i 88
# j 929
# file_names[j] Vireo_olivaceus_Split_777
# shorter_clips[j] 441161
#
# i 89
# j 196
# file_names[j] Hemitriccus_cohnhafti_Split_173
# shorter_clips[j] 441161
#
# i 89
# j 197
# file_names[j] Hemitriccus_cohnhafti_Split_174
# shorter_clips[j] 441161
#
# i 89
# j 198
# file_names[j] Hemitriccus_cohnhafti_Split_175
# shorter_clips[j] 441161
#
# i 89
# j 199
# file_names[j] Hemitriccus_cohnhafti_Split_176
# shorter_clips[j] 441161
#
# i 89
# j 200
# file_names[j] Hemitriccus_cohnhafti_Split_177
# shorter_clips[j] 441161
#
# i 89
# j 201
# file_names[j] Hemitriccus_cohnhafti_Split_178
# shorter_clips[j] 441161
#
# i 89
# j 202
# file_names[j] Hemitriccus_cohnhafti_Split_179
# shorter_clips[j] 441161
#
# i 89
# j 203
# file_names[j] Hemitriccus_cohnhafti_Split_180
# shorter_clips[j] 441161
#
# i 90
# j 1452
# file_names[j] Hemitriccus_cohnhafti_Split_1238
# shorter_clips[j] 441161
#
# i 90
# j 1453
# file_names[j] Hemitriccus_cohnhafti_Split_1239
# shorter_clips[j] 441161
#
# i 90
# j 1454
# file_names[j] Hemitriccus_cohnhafti_Split_1240
# shorter_clips[j] 441161
#
# i 90
# j 1455
# file_names[j] Hemitriccus_cohnhafti_Split_1241
# shorter_clips[j] 441161
#
# i 90
# j 1456
# file_names[j] Hemitriccus_cohnhafti_Split_1242
# shorter_clips[j] 441161
#
# i 90
# j 1457
# file_names[j] Hemitriccus_cohnhafti_Split_1243
# shorter_clips[j] 441161
#
# i 90
# j 1458
# file_names[j] Hemitriccus_cohnhafti_Split_1244
# shorter_clips[j] 441161
#
# i 90
# j 1459
# file_names[j] Hemitriccus_cohnhafti_Split_1245
# shorter_clips[j] 441161
#
# i 90
# j 1460
# file_names[j] Hemitriccus_cohnhafti_Split_1246
# shorter_clips[j] 441161
#
# i 90
# j 1461
# file_names[j] Hemitriccus_cohnhafti_Split_1247
# shorter_clips[j] 441161
#
# i 90
# j 1462
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-54-5c60ba0bf71b> in <module>
#       7         print("i",i)
#       8         print('j', j)
# ----> 9         print("file_names[j]", file_names[j])
#      10         print("shorter_clips[j]", len(shorter_clips[j]))
#      11         print()
#
# IndexError: list index out of range

# %%
print(len(np.unique(clusters)))
print(len(get_clip_indexes(i, clusters)))
print(len(file_names))
print(len(get_clip_indexes(i, clusters))*len(np.unique(clusters)))
# Out:
# 90
# 42
# 1462
# 3780

# %%
# Plot spectrogram of all clips in a cluster appended together
plot_spectrogram_of_cluster(samplerate, shorter_clips, 7, clusters, separate_channels=False)

# %% [markdown]
# # Visualization

# %%
num_clips = len(shorter_clips)
num_minutes = num_clips / 6
num_hours = num_minutes / 60

def clip_i_to_bin_i(clip_i):
    return int(clip_i / (num_clips/num_minutes))

def time_hist_for_cluster(cluster_i, clusters):
    hist_data = []
    for index in get_clip_indexes(cluster_i, clusters):
        index = clip_i_to_bin_i(index)
        hist_data.append(index)

    plt.ylim(0, (num_clips/num_minutes))
    plt.title('Cluster: %d (%s)' % (cluster_i, cluster_names[cluster_i]))
    plt.hist(hist_data, bins=int(num_minutes), range=[0, num_minutes])
    plt.show()
    
def colors(n):
    ret = []
    r = int(random.random() * 256)
    g = int(random.random() * 256)
    b = int(random.random() * 256)
    step = 256 / n
    for i in range(n):
        r += step
        g += step
        b += step
        r = int(r) % 256
        g = int(g) % 256
        b = int(b) % 256
        ret.append((r,g,b)) 
    return ret

def get_clusters_by_cluster_names(clusters, cluster_names):
    uniq_names = np.unique(cluster_names)
    print(uniq_names)
    new_clusters = [-1] * len(clusters)
    for uniq_name_i, uniq_name in enumerate(uniq_names):
        for name_i, name in enumerate(cluster_names):
            if name == uniq_name:
                # Assign name_i to each index in the cluster that has the same index
                for index in range(len(clusters)):
                    if clusters[index] == name_i:
                        new_clusters[index] = uniq_name_i
    return new_clusters

# %%
named_clusters = get_clusters_by_cluster_names(clusters, cluster_names)
Counter(named_clusters).most_common() 
cluster_names_to_plot = np.unique(cluster_names)

# Colors for visualization
jet = pl.get_cmap('jet', len(cluster_names_to_plot))
cluster_colors = {}
for i, name in enumerate(cluster_names_to_plot):
    cluster_colors[name] = jet(i)

# %% [markdown]
# Note: These are not real labels for the clusters, this is just a demonstration of the code. The histogram visualization will be replaced with better visualizations for cluster/time data such as Rose Plots.

# %%
def plot_all_histograms(clusters, cluster_names):
    plt.figure(figsize=(15,8))

    for cluster_i in range(len(cluster_names)):
        hist_data = []
        for index in get_clip_indexes(cluster_i, clusters):
            index = clip_i_to_bin_i(index)
            hist_data.append(index)

        cluster_name = cluster_names[cluster_i]
        c = cluster_colors[cluster_name]
        plt.hist(hist_data, bins=int(num_minutes), range=[0, num_minutes], alpha=0.5, color=c, label=cluster_name)

        plt.ylabel('Number of 10-second audio clips')
        plt.xlabel('Time in Minutes')
        plt.legend(bbox_to_anchor=(1.2, 1.05))
        plt.show()
    
clusters_to_plot = named_clusters
cluster_names_to_plot = np.unique(cluster_names)
plot_all_histograms(named_clusters, np.unique(cluster_names))
