# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
def get_species_list(num_species=-1):
    #print("getting species list")
    #get page of all xento-canto species
    url = 'https://xeno-canto.org/collection/species/all'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'lxml')
    species_table = soup.find_all("table", {"class": "results"})[0]
    
    #get headers of table
    headers = []
    for i in species_table.find_all('thead'):
         title = i.text
         headers.append(title)
    headers = headers[0].strip().split("\n")
    
    #add header for url and create DF
    headers.append('url')
    species_list = pd.DataFrame(columns = headers)
    
    #Get data from each row
    for j in species_table.find_all('tr'):
         #get row data
         row_data = j.find_all('td')
        
         #get all text from row
         row = [i.text for i in row_data]
        
         #get the link
         row.append(row_data[0].a["href"])
        
         #add to dataframe
         length = len(species_list)
         species_list.loc[length] = row

    #Decide to return full list or do RS     
    if (num_species == -1 or num_species > species_list.shape[0]):
        return species_list
    return species_list.sample(num_species).reset_index(drop=True)

#get_species_list()
#test1 = get_species_list(5)
#test1

# %%
def get_species_data(link_to_XC):
    #print("getting species file metadata for: " + link_to_XC)
    #get soup for Species
    url = 'https://xeno-canto.org' + link_to_XC
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'lxml')
    species_table = soup.find_all("table", {"class": "results"})[0]
    
    # Obtain every title of columns with tag <th>
    headers = []
    for i in species_table.find_all('thead'):
     title = i.text
     headers.append(title)

    headers = headers[0].strip()
    headers = headers.split("\n")
    headers[1] = "Common name / Scientific"
    headers.append("copyright")
    headers.append("filename")
    headers.append("download url")


    species_list = pd.DataFrame(columns = headers[1:])
    
    
    page_count = 1
    while len(species_table.find_all('tr')) != 1:
        
        #print(len(species_table.find_all('tr')))
        
        #Get data from each row
        for j in species_table.find_all('tr'):
            #get row data
            row_data = j.find_all('td')

            if (row_data == []):
                   continue

            #print(row_data) 
            #get all text from row
            row = [i.text.strip() for i in row_data][1:]

            #get copyright, download link and filename
            copyright = row_data[12].a.span["title"]
            try:
                 filename = row_data[11].a["download"]
            except:
                filename = "PROTECTED SPECIES"
            download_url = row_data[11].a["href"]
            row.append(copyright)
            row.append(filename)
            row.append(download_url)

            #add to dataframe
            length = len(species_list)
            species_list.loc[length] = row
        
        ## Get data for next page of audio data
        page_count += 1
        url = 'https://xeno-canto.org' + link_to_XC + "?pg=" + str(page_count)
        page = requests.get(url)
        soup = BeautifulSoup(page.text, 'lxml')
        species_table = soup.find_all("table", {"class": "results"})[0]
    return species_list

#test2 = get_species_data(test1.iloc[0]["url"])
#test2

# %%
def download_by_url(file_data, download_folder):
    print(file_data)
    url = file_data[1]
    url = 'https://xeno-canto.org' + url
    r = requests.get(url, allow_redirects=True)
    path = download_folder+file_data[0]
    open(path, "wb").write(r.content)
    return path

def download_data(species_df, num_of_files, download_folder):
    print("downloading data")
    if (num_of_files != -1 and species_df.shape[0] > num_of_files):
        species_df = species_df.sample(num_of_files, replace=False)
    species_df["file_location"] = species_df[["filename","download url"]].apply(download_by_url,axis=1, args=(tuple([download_folder])))
    return species_df

#download_data(test2, 100, "./data/")

# %%
def download_xento_canto_data(num_species, num_of_files, download_folder, species_list=pd.DataFrame()):
    file_df = pd.DataFrame()
    if (species_list.empty):
        species_list = get_species_list(num_species)
    for url in species_list["url"]:
        try:
            species_files = get_species_data(url)
            temp_file_df = download_data(species_files, num_of_files, download_folder)
            if (file_df.empty):
                file_df = temp_file_df.reset_index(drop=True)
            else:
                file_df = file_df.append(temp_file_df.reset_index(drop=True)).reset_index(drop=True)
        except Exception as e:
            print(url + " did not download")
            print(e)
    return file_df

# %%
all_species = get_species_list()

# %%
nips_birds = pd.read_csv("./nips/nips4b_birdchallenge_espece_list.csv")

# %%
species_list = all_species.merge(nips_birds.groupby("Scientific_name").count(), left_on="Scientific name", right_index=True)

# %%
species_list.shape
# Out:
# (49, 10)

# %%
species_list = all_species.merge(nips_birds.groupby("Scientific_name").count(), left_on="Scientific name", right_index=True)

# %%
species_list.groupby("Scientific name").count().shape
# Out:
# (49, 9)

# %%
nips_birds.groupby("Scientific_name")

# %%
nips_birds[~nips_birds["Scientific_name"].isin(species_list["Scientific name"])]
# Out:
#    class number   class name          English_name         Scientific_name  \
# 0          none        Empty                 Empty            noise sample
# 13           13  Cicatr_song          Black Cicada          Cicadatra atra
# 14           14  Cicorn_song           Grey Cicada             Cicada orni
# 35           35  Lularb_song              Woodlark         lullula arborea
# 38           38  Lyrple_song         Common Cicada       Lyristes plebejus
# 50           50  Pelgra_call    Graf's Hybrid Frog    Pelophylax kl. grafi
# 53           53  Phofem_song   Fallow Bush-cricket   Pholidoptera femorata
# 57           57  Plaaff_song  Coastal Bush-cricket      Platycleis affinis
# 58           58  Plasab_song     Sand Bush-Cricket     Platycleis sabulosa
# 62           62  Ptehey_song         Marsh Cricket  Pteronemobius heydenii
# 64           64  Regign_call      Common Firecrest    Regulus ignicapillus
# 65           65  Regign_song      Common Firecrest    Regulus ignicapillus
# 81           81  Tetpyg_song          Pygmy Cicada     Tettigettula pygmea
# 82           82  Tibtom_song      Tomentous Cicada      Tibicina tomentosa
#
#          type
# 0       noise
# 13     insect
# 14     insect
# 35       bird
# 38     insect
# 50  amphibian
# 53     insect
# 57     insect
# 58     insect
# 62     insect
# 64       bird
# 65       bird
# 81     insect
# 82     insect

# %%
species_list
# Out:
#                             Common name          Scientific name Status   No.  \
# 1369         \n\nCommon Wood Pigeon\n\n         Columba palumbus          689
# 1416       \n\nEuropean Turtle Dove\n\n      Streptopelia turtur          339
# 1421     \n\nEurasian Collared Dove\n\n    Streptopelia decaocto          831
# 2948             \n\nCommon Buzzard\n\n              Buteo buteo          824
# 3715           \n\nEurasian Wryneck\n\n           Jynx torquilla          535
# 3855   \n\nGreat Spotted Woodpecker\n\n        Dendrocopos major         2174
# 6607     \n\nEurasian Golden Oriole\n\n          Oriolus oriolus         1140
# 6837               \n\nEurasian Jay\n\n      Garrulus glandarius         1705
# 6861            \n\nEurasian Magpie\n\n                Pica pica         1029
# 6907               \n\nCarrion Crow\n\n            Corvus corone         1448
# 7058                   \n\nCoal Tit\n\n           Periparus ater         2373
# 7062       \n\nEuropean Crested Tit\n\n    Lophophanes cristatus          841
# 7085                  \n\nMarsh Tit\n\n        Poecile palustris         1278
# 7090          \n\nEurasian Blue Tit\n\n      Cyanistes caeruleus         3893
# 7093                  \n\nGreat Tit\n\n              Parus major         6887
# 7202           \n\nEurasian Skylark\n\n          Alauda arvensis         2204
# 7206              \n\nThekla's Lark\n\n         Galerida theklae          238
# 7207               \n\nCrested Lark\n\n        Galerida cristata          463
# 7430               \n\nBarn Swallow\n\n          Hirundo rustica         1554
# 7518            \n\nCetti's Warbler\n\n             Cettia cetti         1405
# 7533            \n\nLong-tailed Tit\n\n      Aegithalos caudatus         1539
# 7572          \n\nCommon Chiffchaff\n\n   Phylloscopus collybita         5098
# 7806          \n\nZitting Cisticola\n\n       Cisticola juncidis          798
# 8189          \n\nEurasian Blackcap\n\n       Sylvia atricapilla         4218
# 8201           \n\nDartford Warbler\n\n            Sylvia undata          337
# 8206          \n\nSubalpine Warbler\n\n        Sylvia cantillans          475
# 8208          \n\nSardinian Warbler\n\n     Sylvia melanocephala         1160
# 8475              \n\nEurasian Wren\n\n  Troglodytes troglodytes         3629
# 8521          \n\nEurasian Nuthatch\n\n           Sitta europaea         1696
# 8553     \n\nShort-toed Treecreeper\n\n    Certhia brachydactyla         1104
# 8665            \n\nCommon Starling\n\n         Sturnus vulgaris         1503
# 8825           \n\nCommon Blackbird\n\n            Turdus merula         5959
# 8843                \n\nSong Thrush\n\n        Turdus philomelos         4245
# 8933         \n\nSpotted Flycatcher\n\n        Muscicapa striata         1115
# 9007             \n\nEuropean Robin\n\n       Erithacus rubecula         4727
# 9065         \n\nCommon Nightingale\n\n    Luscinia megarhynchos         2094
# 9435              \n\nHouse Sparrow\n\n        Passer domesticus         2282
# 9463               \n\nRock Sparrow\n\n        Petronia petronia          230
# 9765                    \n\nDunnock\n\n       Prunella modularis         2045
# 9775               \n\nGrey Wagtail\n\n        Motacilla cinerea          725
# 9806                 \n\nTree Pipit\n\n         Anthus trivialis         1724
# 9838           \n\nCommon Chaffinch\n\n        Fringilla coelebs         5646
# 9857         \n\nEurasian Bullfinch\n\n        Pyrrhula pyrrhula         1341
# 9942        \n\nEuropean Greenfinch\n\n          Chloris chloris         1861
# 9990              \n\nCommon Linnet\n\n        Linaria cannabina         1403
# 9998              \n\nRed Crossbill\n\n        Loxia curvirostra         4030
# 10003        \n\nEuropean Goldfinch\n\n      Carduelis carduelis         1843
# 10007            \n\nEuropean Serin\n\n          Serinus serinus         1168
# 10087              \n\nCirl Bunting\n\n          Emberiza cirlus          748
#
#       No. Back                               url  class number  class name  \
# 1369      9204         /species/Columba-palumbus             1           1
# 1416       238      /species/Streptopelia-turtur             1           1
# 1421      4534    /species/Streptopelia-decaocto             1           1
# 2948       638              /species/Buteo-buteo             1           1
# 3715       266           /species/Jynx-torquilla             1           1
# 3855      3419        /species/Dendrocopos-major             2           2
# 6607      1132          /species/Oriolus-oriolus             2           2
# 6837      1644      /species/Garrulus-glandarius             1           1
# 6861      1644                /species/Pica-pica             1           1
# 6907      9928            /species/Corvus-corone             1           1
# 7058      2877           /species/Periparus-ater             2           2
# 7062      1422    /species/Lophophanes-cristatus             1           1
# 7085       763        /species/Poecile-palustris             2           2
# 7090      7809      /species/Cyanistes-caeruleus             2           2
# 7093     10435              /species/Parus-major             2           2
# 7202      7170          /species/Alauda-arvensis             1           1
# 7206       207         /species/Galerida-theklae             2           2
# 7207       955        /species/Galerida-cristata             2           2
# 7430      1309          /species/Hirundo-rustica             1           1
# 7518      1581             /species/Cettia-cetti             1           1
# 7533      1963      /species/Aegithalos-caudatus             1           1
# 7572      7215   /species/Phylloscopus-collybita             2           2
# 7806       985       /species/Cisticola-juncidis             1           1
# 8189      8412       /species/Sylvia-atricapilla             2           2
# 8201        65            /species/Sylvia-undata             2           2
# 8206       186        /species/Sylvia-cantillans             2           2
# 8208      2213     /species/Sylvia-melanocephala             2           2
# 8475     11765  /species/Troglodytes-troglodytes             1           1
# 8521      2870           /species/Sitta-europaea             2           2
# 8553      2244    /species/Certhia-brachydactyla             2           2
# 8665      2774         /species/Sturnus-vulgaris             1           1
# 8825     20795            /species/Turdus-merula             2           2
# 8843      9447        /species/Turdus-philomelos             2           2
# 8933       317        /species/Muscicapa-striata             1           1
# 9007     11203       /species/Erithacus-rubecula             2           2
# 9065      2119    /species/Luscinia-megarhynchos             2           2
# 9435      5313        /species/Passer-domesticus             1           1
# 9463       229        /species/Petronia-petronia             2           2
# 9765      4437       /species/Prunella-modularis             1           1
# 9775       423        /species/Motacilla-cinerea             1           1
# 9806       886         /species/Anthus-trivialis             1           1
# 9838     19754        /species/Fringilla-coelebs             2           2
# 9857       937        /species/Pyrrhula-pyrrhula             1           1
# 9942      3870          /species/Chloris-chloris             1           1
# 9990      3220        /species/Linaria-cannabina             2           2
# 9998       902        /species/Loxia-curvirostra             1           1
# 10003     3370      /species/Carduelis-carduelis             2           2
# 10007     1884          /species/Serinus-serinus             2           2
# 10087      799          /species/Emberiza-cirlus             2           2
#
#        English_name  type
# 1369              1     1
# 1416              1     1
# 1421              1     1
# 2948              1     1
# 3715              1     1
# 3855              2     2
# 6607              2     2
# 6837              1     1
# 6861              1     1
# 6907              1     1
# 7058              2     2
# 7062              1     1
# 7085              2     2
# 7090              2     2
# 7093              2     2
# 7202              1     1
# 7206              2     2
# 7207              2     2
# 7430              1     1
# 7518              1     1
# 7533              1     1
# 7572              2     2
# 7806              1     1
# 8189              2     2
# 8201              2     2
# 8206              2     2
# 8208              2     2
# 8475              1     1
# 8521              2     2
# 8553              2     2
# 8665              1     1
# 8825              2     2
# 8843              2     2
# 8933              1     1
# 9007              2     2
# 9065              2     2
# 9435              1     1
# 9463              2     2
# 9765              1     1
# 9775              1     1
# 9806              1     1
# 9838              2     2
# 9857              1     1
# 9942              1     1
# 9990              2     2
# 9998              1     1
# 10003             2     2
# 10007             2     2
# 10087             2     2

# %%
file_meta = download_xento_canto_data(-1, -1, "./nips/data/", species_list=species_list)
file_meta.to_csv("./nips/meta.csv")
# Out:
# downloading data
# filename        XC744882 - Common Wood Pigeon - Columba palumb...
# download url                                     /744882/download
# Name: 0, dtype: object
# filename        XC742898 - Common Wood Pigeon - Columba palumb...
# download url                                     /742898/download
# Name: 1, dtype: object
# filename        XC742189 - Common Wood Pigeon - Columba palumb...
# download url                                     /742189/download
# Name: 2, dtype: object
# filename        XC742088 - Common Wood Pigeon - Columba palumb...
# download url                                     /742088/download
# Name: 3, dtype: object
# filename        XC741277 - Common Wood Pigeon - Columba palumb...
# download url                                     /741277/download
# Name: 4, dtype: object
# filename        XC740290 - Common Wood Pigeon - Columba palumb...
# download url                                     /740290/download
# Name: 5, dtype: object
# filename        XC738916 - Common Wood Pigeon - Columba palumb...
# download url                                     /738916/download
# Name: 6, dtype: object
# filename        XC738410 - Common Wood Pigeon - Columba palumb...
# download url                                     /738410/download
# Name: 7, dtype: object
# filename        XC737619 - Common Wood Pigeon - Columba palumb...
# download url                                     /737619/download
# Name: 8, dtype: object
# filename        XC736920 - Common Wood Pigeon - Columba palumb...
# download url                                     /736920/download
# Name: 9, dtype: object
# filename        XC736889 - Common Wood Pigeon - Columba palumb...
# download url                                     /736889/download
# Name: 10, dtype: object
# filename        XC735638 - Common Wood Pigeon - Columba palumb...
# download url                                     /735638/download
# Name: 11, dtype: object
# filename        XC735637 - Common Wood Pigeon - Columba palumb...
# download url                                     /735637/download
# Name: 12, dtype: object
# filename        XC735104 - Common Wood Pigeon - Columba palumb...
# download url                                     /735104/download
# Name: 13, dtype: object
# filename        XC733752 - Common Wood Pigeon - Columba palumb...
# download url                                     /733752/download
# Name: 14, dtype: object
# filename        XC731683 - Common Wood Pigeon - Columba palumb...
# download url                                     /731683/download
# Name: 15, dtype: object
# filename        XC729380 - Common Wood Pigeon - Columba palumb...
# download url                                     /729380/download
# Name: 16, dtype: object
# filename        XC728544 - Common Wood Pigeon - Columba palumb...
# download url                                     /728544/download
# Name: 17, dtype: object
# filename        XC725799 - Common Wood Pigeon - Columba palumb...
# download url                                     /725799/download
# Name: 18, dtype: object
# filename        XC725733 - Common Wood Pigeon - Columba palumb...
# download url                                     /725733/download
# Name: 19, dtype: object
# filename        XC725396 - Common Wood Pigeon - Columba palumb...
# download url                                     /725396/download
# Name: 20, dtype: object
# filename        XC725384 - Common Wood Pigeon - Columba palumb...
# download url                                     /725384/download
# Name: 21, dtype: object
# filename        XC725376 - Common Wood Pigeon - Columba palumb...
# download url                                     /725376/download
# Name: 22, dtype: object
# filename        XC721678 - Common Wood Pigeon - Columba palumb...
# download url                                     /721678/download
# Name: 23, dtype: object
# filename        XC721533 - Common Wood Pigeon - Columba palumb...
# download url                                     /721533/download
# Name: 24, dtype: object
# filename        XC720864 - Common Wood Pigeon - Columba palumb...
# download url                                     /720864/download
# Name: 25, dtype: object
# filename        XC720862 - Common Wood Pigeon - Columba palumb...
# download url                                     /720862/download
# Name: 26, dtype: object
# filename        XC720861 - Common Wood Pigeon - Columba palumb...
# download url                                     /720861/download
# Name: 27, dtype: object
# filename        XC719579 - Common Wood Pigeon - Columba palumb...
# download url                                     /719579/download
# Name: 28, dtype: object
# filename        XC716978 - Common Wood Pigeon - Columba palumb...
# download url                                     /716978/download
# Name: 29, dtype: object
# filename        XC716757 - Common Wood Pigeon - Columba palumb...
# download url                                     /716757/download
# Name: 30, dtype: object
# filename        XC716333 - Common Wood Pigeon - Columba palumb...
# download url                                     /716333/download
# Name: 31, dtype: object
# filename        XC716295 - Common Wood Pigeon - Columba palumb...
# download url                                     /716295/download
# Name: 32, dtype: object
# filename        XC715716 - Common Wood Pigeon - Columba palumb...
# download url                                     /715716/download
# Name: 33, dtype: object
# filename        XC712671 - Common Wood Pigeon - Columba palumb...
# download url                                     /712671/download
# Name: 34, dtype: object
# filename        XC711597 - Common Wood Pigeon - Columba palumb...
# download url                                     /711597/download
# Name: 35, dtype: object
# filename        XC710830 - Common Wood Pigeon - Columba palumb...
# download url                                     /710830/download
# Name: 36, dtype: object
# filename        XC710571 - Common Wood Pigeon - Columba palumb...
# download url                                     /710571/download
# Name: 37, dtype: object
# filename        XC705328 - Common Wood Pigeon - Columba palumb...
# download url                                     /705328/download
# Name: 38, dtype: object
# filename        XC705168 - Common Wood Pigeon - Columba palumb...
# download url                                     /705168/download
# Name: 39, dtype: object
# filename        XC704755 - Common Wood Pigeon - Columba palumb...
# download url                                     /704755/download
# Name: 40, dtype: object
# filename        XC704520 - Common Wood Pigeon - Columba palumb...
# download url                                     /704520/download
# Name: 41, dtype: object
# filename        XC703840 - Common Wood Pigeon - Columba palumb...
# download url                                     /703840/download
# Name: 42, dtype: object
# filename        XC698381 - Common Wood Pigeon - Columba palumb...
# download url                                     /698381/download
# Name: 43, dtype: object
# filename        XC692119 - Common Wood Pigeon - Columba palumb...
# download url                                     /692119/download
# Name: 44, dtype: object
# filename        XC679882 - Common Wood Pigeon - Columba palumb...
# download url                                     /679882/download
# Name: 45, dtype: object
# filename        XC673236 - Common Wood Pigeon - Columba palumb...
# download url                                     /673236/download
# Name: 46, dtype: object
# filename        XC672922 - Common Wood Pigeon - Columba palumb...
# download url                                     /672922/download
# Name: 47, dtype: object
# filename        XC669640 - Common Wood Pigeon - Columba palumb...
# download url                                     /669640/download
# Name: 48, dtype: object
# filename        XC668677 - Common Wood Pigeon - Columba palumb...
# download url                                     /668677/download
# Name: 49, dtype: object
# filename        XC665444 - Common Wood Pigeon - Columba palumb...
# download url                                     /665444/download
# Name: 50, dtype: object
# filename        XC665254 - Common Wood Pigeon - Columba palumb...
# download url                                     /665254/download
# Name: 51, dtype: object
# filename        XC664084 - Common Wood Pigeon - Columba palumb...
# download url                                     /664084/download
# Name: 52, dtype: object
# filename        XC662356 - Common Wood Pigeon - Columba palumb...
# download url                                     /662356/download
# Name: 53, dtype: object
# filename        XC656200 - Common Wood Pigeon - Columba palumb...
# download url                                     /656200/download
# Name: 54, dtype: object
# filename        XC655097 - Common Wood Pigeon - Columba palumb...
# download url                                     /655097/download
# Name: 55, dtype: object
# filename        XC653672 - Common Wood Pigeon - Columba palumb...
# download url                                     /653672/download
# Name: 56, dtype: object
# filename        XC651508 - Common Wood Pigeon - Columba palumb...
# download url                                     /651508/download
# Name: 57, dtype: object
# filename        XC650254 - Common Wood Pigeon - Columba palumb...
# download url                                     /650254/download
# Name: 58, dtype: object
# filename        XC648829 - Common Wood Pigeon - Columba palumb...
# download url                                     /648829/download
# Name: 59, dtype: object
# filename        XC648349 - Common Wood Pigeon - Columba palumb...
# download url                                     /648349/download
# Name: 60, dtype: object
# filename        XC644851 - Common Wood Pigeon - Columba palumb...
# download url                                     /644851/download
# Name: 61, dtype: object
# filename        XC644844 - Common Wood Pigeon - Columba palumb...
# download url                                     /644844/download
# Name: 62, dtype: object
# filename        XC644843 - Common Wood Pigeon - Columba palumb...
# download url                                     /644843/download
# Name: 63, dtype: object
# filename        XC642885 - Common Wood Pigeon - Columba palumb...
# download url                                     /642885/download
# Name: 64, dtype: object
# filename        XC637609 - Common Wood Pigeon - Columba palumb...
# download url                                     /637609/download
# Name: 65, dtype: object
# filename        XC637400 - Common Wood Pigeon - Columba palumb...
# download url                                     /637400/download
# Name: 66, dtype: object
# filename        XC637396 - Common Wood Pigeon - Columba palumb...
# download url                                     /637396/download
# Name: 67, dtype: object
# filename        XC635101 - Common Wood Pigeon - Columba palumb...
# download url                                     /635101/download
# Name: 68, dtype: object
# filename        XC632023 - Common Wood Pigeon - Columba palumb...
# download url                                     /632023/download
# Name: 69, dtype: object
# filename        XC631299 - Common Wood Pigeon - Columba palumb...
# download url                                     /631299/download
# Name: 70, dtype: object
# filename        XC631222 - Common Wood Pigeon - Columba palumb...
# download url                                     /631222/download
# Name: 71, dtype: object
# filename        XC631064 - Common Wood Pigeon - Columba palumb...
# download url                                     /631064/download
# Name: 72, dtype: object
# filename        XC629629 - Common Wood Pigeon - Columba palumb...
# download url                                     /629629/download
# Name: 73, dtype: object
# filename        XC629531 - Common Wood Pigeon - Columba palumb...
# download url                                     /629531/download
# Name: 74, dtype: object
# filename        XC626966 - Common Wood Pigeon - Columba palumb...
# download url                                     /626966/download
# Name: 75, dtype: object
# filename        XC626965 - Common Wood Pigeon - Columba palumb...
# download url                                     /626965/download
# Name: 76, dtype: object
# filename        XC623912 - Common Wood Pigeon - Columba palumb...
# download url                                     /623912/download
# Name: 77, dtype: object
# filename        XC622417 - Common Wood Pigeon - Columba palumb...
# download url                                     /622417/download
# Name: 78, dtype: object
# filename        XC621415 - Common Wood Pigeon - Columba palumb...
# download url                                     /621415/download
# Name: 79, dtype: object
# filename        XC621395 - Common Wood Pigeon - Columba palumb...
# download url                                     /621395/download
# Name: 80, dtype: object
# filename        XC619407 - Common Wood Pigeon - Columba palumb...
# download url                                     /619407/download
# Name: 81, dtype: object
# filename        XC619211 - Common Wood Pigeon - Columba palumb...
# download url                                     /619211/download
# Name: 82, dtype: object
# filename        XC616757 - Common Wood Pigeon - Columba palumb...
# download url                                     /616757/download
# Name: 83, dtype: object
# filename        XC615143 - Common Wood Pigeon - Columba palumb...
# download url                                     /615143/download
# Name: 84, dtype: object
# filename        XC610587 - Common Wood Pigeon - Columba palumb...
# download url                                     /610587/download
# Name: 85, dtype: object
# filename        XC607664 - Common Wood Pigeon - Columba palumb...
# download url                                     /607664/download
# Name: 86, dtype: object
# filename        XC603043 - Common Wood Pigeon - Columba palumb...
# download url                                     /603043/download
# Name: 87, dtype: object
# filename        XC599692 - Common Wood Pigeon - Columba palumb...
# download url                                     /599692/download
# Name: 88, dtype: object
# filename        XC599691 - Common Wood Pigeon - Columba palumb...
# download url                                     /599691/download
# Name: 89, dtype: object
# filename        XC596505 - Common Wood Pigeon - Columba palumb...
# download url                                     /596505/download
# Name: 90, dtype: object
# filename        XC595406 - Common Wood Pigeon - Columba palumb...
# download url                                     /595406/download
# Name: 91, dtype: object
# filename        XC595388 - Common Wood Pigeon - Columba palumb...
# download url                                     /595388/download
# Name: 92, dtype: object
# filename        XC590935 - Common Wood Pigeon - Columba palumb...
# download url                                     /590935/download
# Name: 93, dtype: object
# filename        XC590895 - Common Wood Pigeon - Columba palumb...
# download url                                     /590895/download
# Name: 94, dtype: object
# filename        XC590890 - Common Wood Pigeon - Columba palumb...
# download url                                     /590890/download
# Name: 95, dtype: object
# filename        XC590885 - Common Wood Pigeon - Columba palumb...
# download url                                     /590885/download
# Name: 96, dtype: object
# filename        XC590880 - Common Wood Pigeon - Columba palumb...
# download url                                     /590880/download
# Name: 97, dtype: object
# filename        XC587985 - Common Wood Pigeon - Columba palumb...
# download url                                     /587985/download
# Name: 98, dtype: object
# filename        XC587646 - Common Wood Pigeon - Columba palumb...
# download url                                     /587646/download
# Name: 99, dtype: object
# filename        XC587645 - Common Wood Pigeon - Columba palumb...
# download url                                     /587645/download
# Name: 100, dtype: object
# filename        XC587539 - Common Wood Pigeon - Columba palumb...
# download url                                     /587539/download
# Name: 101, dtype: object
# filename        XC584011 - Common Wood Pigeon - Columba palumb...
# download url                                     /584011/download
# Name: 102, dtype: object
# filename        XC581645 - Common Wood Pigeon - Columba palumb...
# download url                                     /581645/download
# Name: 103, dtype: object
# filename        XC574126 - Common Wood Pigeon - Columba palumb...
# download url                                     /574126/download
# Name: 104, dtype: object
# filename        XC571303 - Common Wood Pigeon - Columba palumb...
# download url                                     /571303/download
# Name: 105, dtype: object
# filename        XC571302 - Common Wood Pigeon - Columba palumb...
# download url                                     /571302/download
# Name: 106, dtype: object
# filename        XC564410 - Common Wood Pigeon - Columba palumb...
# download url                                     /564410/download
# Name: 107, dtype: object
# filename        XC564161 - Common Wood Pigeon - Columba palumb...
# download url                                     /564161/download
# Name: 108, dtype: object
# filename        XC561877 - Common Wood Pigeon - Columba palumb...
# download url                                     /561877/download
# Name: 109, dtype: object
# filename        XC560633 - Common Wood Pigeon - Columba palumb...
# download url                                     /560633/download
# Name: 110, dtype: object
# filename        XC559737 - Common Wood Pigeon - Columba palumb...
# download url                                     /559737/download
# Name: 111, dtype: object
# filename        XC559727 - Common Wood Pigeon - Columba palumb...
# download url                                     /559727/download
# Name: 112, dtype: object
# filename        XC559249 - Common Wood Pigeon - Columba palumb...
# download url                                     /559249/download
# Name: 113, dtype: object
# filename        XC559127 - Common Wood Pigeon - Columba palumb...
# download url                                     /559127/download
# Name: 114, dtype: object
# filename        XC558840 - Common Wood Pigeon - Columba palumb...
# download url                                     /558840/download
# Name: 115, dtype: object
# filename        XC558782 - Common Wood Pigeon - Columba palumb...
# download url                                     /558782/download
# Name: 116, dtype: object
# filename        XC554653 - Common Wood Pigeon - Columba palumb...
# download url                                     /554653/download
# Name: 117, dtype: object
# filename        XC553207 - Common Wood Pigeon - Columba palumb...
# download url                                     /553207/download
# Name: 118, dtype: object
# filename        XC552810 - Common Wood Pigeon - Columba palumb...
# download url                                     /552810/download
# Name: 119, dtype: object
# filename        XC550864 - Common Wood Pigeon - Columba palumb...
# download url                                     /550864/download
# Name: 120, dtype: object
# filename        XC548936 - Common Wood Pigeon - Columba palumb...
# download url                                     /548936/download
# Name: 121, dtype: object
# filename        XC548932 - Common Wood Pigeon - Columba palumb...
# download url                                     /548932/download
# Name: 122, dtype: object
# filename        XC548931 - Common Wood Pigeon - Columba palumb...
# download url                                     /548931/download
# Name: 123, dtype: object
# filename        XC548925 - Common Wood Pigeon - Columba palumb...
# download url                                     /548925/download
# Name: 124, dtype: object
# filename        XC548891 - Common Wood Pigeon - Columba palumb...
# download url                                     /548891/download
# Name: 125, dtype: object
# filename        XC545846 - Common Wood Pigeon - Columba palumb...
# download url                                     /545846/download
# Name: 126, dtype: object
# filename        XC545506 - Common Wood Pigeon - Columba palumb...
# download url                                     /545506/download
# Name: 127, dtype: object
# filename        XC543713 - Common Wood Pigeon - Columba palumb...
# download url                                     /543713/download
# Name: 128, dtype: object
# filename        XC542725 - Common Wood Pigeon - Columba palumb...
# download url                                     /542725/download
# Name: 129, dtype: object
# filename        XC538770 - Common Wood Pigeon - Columba palumb...
# download url                                     /538770/download
# Name: 130, dtype: object
# filename        XC537957 - Common Wood Pigeon - Columba palumb...
# download url                                     /537957/download
# Name: 131, dtype: object
# filename        XC537222 - Common Wood Pigeon - Columba palumb...
# download url                                     /537222/download
# Name: 132, dtype: object
# filename        XC536577 - Common Wood Pigeon - Columba palumb...
# download url                                     /536577/download
# Name: 133, dtype: object
# filename        XC536549 - Common Wood Pigeon - Columba palumb...
# download url                                     /536549/download
# Name: 134, dtype: object
# filename        XC534761 - Common Wood Pigeon - Columba palumb...
# download url                                     /534761/download
# Name: 135, dtype: object
# filename        XC528315 - Common Wood Pigeon - Columba palumb...
# download url                                     /528315/download
# Name: 136, dtype: object
# filename        XC512607 - Common Wood Pigeon - Columba palumb...
# download url                                     /512607/download
# Name: 137, dtype: object
# filename        XC512606 - Common Wood Pigeon - Columba palumb...
# download url                                     /512606/download
# Name: 138, dtype: object
# filename        XC511689 - Common Wood Pigeon - Columba palumb...
# download url                                     /511689/download
# Name: 139, dtype: object
# filename        XC507549 - Common Wood Pigeon - Columba palumb...
# download url                                     /507549/download
# Name: 140, dtype: object
# filename        XC507548 - Common Wood Pigeon - Columba palumb...
# download url                                     /507548/download
# Name: 141, dtype: object
# filename        XC502415 - Common Wood Pigeon - Columba palumb...
# download url                                     /502415/download
# Name: 142, dtype: object
# filename        XC500201 - Common Wood Pigeon - Columba palumb...
# download url                                     /500201/download
# Name: 143, dtype: object
# filename        XC492797 - Common Wood Pigeon - Columba palumb...
# download url                                     /492797/download
# Name: 144, dtype: object
# filename        XC489280 - Common Wood Pigeon - Columba palumb...
# download url                                     /489280/download
# Name: 145, dtype: object
# filename        XC489279 - Common Wood Pigeon - Columba palumb...
# download url                                     /489279/download
# Name: 146, dtype: object
# filename        XC488799 - Common Wood Pigeon - Columba palumb...
# download url                                     /488799/download
# Name: 147, dtype: object
# filename        XC487835 - Common Wood Pigeon - Columba palumb...
# download url                                     /487835/download
# Name: 148, dtype: object
# filename        XC487371 - Common Wood Pigeon - Columba palumb...
# download url                                     /487371/download
# Name: 149, dtype: object
# filename        XC486181 - Common Wood Pigeon - Columba palumb...
# download url                                     /486181/download
# Name: 150, dtype: object
# filename        XC484710 - Common Wood Pigeon - Columba palumb...
# download url                                     /484710/download
# Name: 151, dtype: object
# filename        XC484081 - Common Wood Pigeon - Columba palumb...
# download url                                     /484081/download
# Name: 152, dtype: object
# filename        XC481100 - Common Wood Pigeon - Columba palumb...
# download url                                     /481100/download
# Name: 153, dtype: object
# filename        XC481099 - Common Wood Pigeon - Columba palumb...
# download url                                     /481099/download
# Name: 154, dtype: object
# filename        XC479021 - Common Wood Pigeon - Columba palumb...
# download url                                     /479021/download
# Name: 155, dtype: object
# filename        XC476914 - Common Wood Pigeon - Columba palumb...
# download url                                     /476914/download
# Name: 156, dtype: object
# filename        XC475458 - Common Wood Pigeon - Columba palumb...
# download url                                     /475458/download
# Name: 157, dtype: object
# filename        XC474485 - Common Wood Pigeon - Columba palumb...
# download url                                     /474485/download
# Name: 158, dtype: object
# filename        XC473724 - Common Wood Pigeon - Columba palumb...
# download url                                     /473724/download
# Name: 159, dtype: object
# filename        XC469724 - Common Wood Pigeon - Columba palumb...
# download url                                     /469724/download
# Name: 160, dtype: object
# filename        XC467203 - Common Wood Pigeon - Columba palumb...
# download url                                     /467203/download
# Name: 161, dtype: object
# filename        XC465541 - Common Wood Pigeon - Columba palumb...
# download url                                     /465541/download
# Name: 162, dtype: object
# filename        XC462990 - Common Wood Pigeon - Columba palumb...
# download url                                     /462990/download
# Name: 163, dtype: object
# filename        XC462348 - Common Wood Pigeon - Columba palumb...
# download url                                     /462348/download
# Name: 164, dtype: object
# filename        XC462148 - Common Wood Pigeon - Columba palumb...
# download url                                     /462148/download
# Name: 165, dtype: object
# filename        XC460355 - Common Wood Pigeon - Columba palumb...
# download url                                     /460355/download
# Name: 166, dtype: object
# filename        XC449642 - Common Wood Pigeon - Columba palumb...
# download url                                     /449642/download
# Name: 167, dtype: object
# filename        XC449641 - Common Wood Pigeon - Columba palumb...
# download url                                     /449641/download
# Name: 168, dtype: object
# filename        XC449639 - Common Wood Pigeon - Columba palumb...
# download url                                     /449639/download
# Name: 169, dtype: object
# filename        XC449638 - Common Wood Pigeon - Columba palumb...
# download url                                     /449638/download
# Name: 170, dtype: object
# filename        XC434462 - Common Wood Pigeon - Columba palumb...
# download url                                     /434462/download
# Name: 171, dtype: object
# filename        XC429089 - Common Wood Pigeon - Columba palumb...
# download url                                     /429089/download
# Name: 172, dtype: object
# filename        XC418023 - Common Wood Pigeon - Columba palumb...
# download url                                     /418023/download
# Name: 173, dtype: object
# filename        XC410908 - Common Wood Pigeon - Columba palumb...
# download url                                     /410908/download
# Name: 174, dtype: object
# filename        XC406467 - Common Wood Pigeon - Columba palumb...
# download url                                     /406467/download
# Name: 175, dtype: object
# filename        XC394506 - Common Wood Pigeon - Columba palumb...
# download url                                     /394506/download
# Name: 176, dtype: object
# filename        XC394505 - Common Wood Pigeon - Columba palumb...
# download url                                     /394505/download
# Name: 177, dtype: object
# filename        XC394504 - Common Wood Pigeon - Columba palumb...
# download url                                     /394504/download
# Name: 178, dtype: object
# filename        XC394164 - Common Wood Pigeon - Columba palumb...
# download url                                     /394164/download
# Name: 179, dtype: object
# filename        XC381956 - Common Wood Pigeon - Columba palumb...
# download url                                     /381956/download
# Name: 180, dtype: object
# filename        XC381358 - Common Wood Pigeon - Columba palumb...
# download url                                     /381358/download
# Name: 181, dtype: object
# filename        XC380502 - Common Wood Pigeon - Columba palumb...
# download url                                     /380502/download
# Name: 182, dtype: object
# filename        XC380054 - Common Wood Pigeon - Columba palumb...
# download url                                     /380054/download
# Name: 183, dtype: object
# filename        XC379281 - Common Wood Pigeon - Columba palumb...
# download url                                     /379281/download
# Name: 184, dtype: object
# filename        XC378844 - Common Wood Pigeon - Columba palumb...
# download url                                     /378844/download
# Name: 185, dtype: object
# filename        XC376905 - Common Wood Pigeon - Columba palumb...
# download url                                     /376905/download
# Name: 186, dtype: object
# filename        XC376904 - Common Wood Pigeon - Columba palumb...
# download url                                     /376904/download
# Name: 187, dtype: object
# filename        XC371138 - Common Wood Pigeon - Columba palumb...
# download url                                     /371138/download
# Name: 188, dtype: object
# filename        XC368101 - Common Wood Pigeon - Columba palumb...
# download url                                     /368101/download
# Name: 189, dtype: object
# filename        XC367689 - Common Wood Pigeon - Columba palumb...
# download url                                     /367689/download
# Name: 190, dtype: object
# filename        XC362380 - Common Wood Pigeon - Columba palumb...
# download url                                     /362380/download
# Name: 191, dtype: object
# filename        XC359142 - Common Wood Pigeon - Columba palumb...
# download url                                     /359142/download
# Name: 192, dtype: object
# filename        XC343133 - Common Wood Pigeon - Columba palumb...
# download url                                     /343133/download
# Name: 193, dtype: object
# filename        XC315418 - Common Wood Pigeon - Columba palumb...
# download url                                     /315418/download
# Name: 194, dtype: object
# filename        XC314368 - Common Wood Pigeon - Columba palumb...
# download url                                     /314368/download
# Name: 195, dtype: object
# filename        XC312493 - Common Wood Pigeon - Columba palumb...
# download url                                     /312493/download
# Name: 196, dtype: object
# filename        XC308199 - Common Wood Pigeon - Columba palumb...
# download url                                     /308199/download
# Name: 197, dtype: object
# filename        XC308198 - Common Wood Pigeon - Columba palumb...
# download url                                     /308198/download
# Name: 198, dtype: object
# filename        XC308197 - Common Wood Pigeon - Columba palumb...
# download url                                     /308197/download
# Name: 199, dtype: object
# filename        XC308195 - Common Wood Pigeon - Columba palumb...
# download url                                     /308195/download
# Name: 200, dtype: object
# filename        XC302450 - Common Wood Pigeon - Columba palumb...
# download url                                     /302450/download
# Name: 201, dtype: object
# filename        XC281220 - Common Wood Pigeon - Columba palumb...
# download url                                     /281220/download
# Name: 202, dtype: object
# filename        XC281219 - Common Wood Pigeon - Columba palumb...
# download url                                     /281219/download
# Name: 203, dtype: object
# filename        XC281218 - Common Wood Pigeon - Columba palumb...
# download url                                     /281218/download
# Name: 204, dtype: object
# filename        XC281217 - Common Wood Pigeon - Columba palumb...
# download url                                     /281217/download
# Name: 205, dtype: object
# filename        XC281216 - Common Wood Pigeon - Columba palumb...
# download url                                     /281216/download
# Name: 206, dtype: object
# filename        XC256724 - Common Wood Pigeon - Columba palumb...
# download url                                     /256724/download
# Name: 207, dtype: object
# filename        XC256677 - Common Wood Pigeon - Columba palumb...
# download url                                     /256677/download
# Name: 208, dtype: object
# filename        XC246657 - Common Wood Pigeon - Columba palumb...
# download url                                     /246657/download
# Name: 209, dtype: object
# filename        XC246655 - Common Wood Pigeon - Columba palumb...
# download url                                     /246655/download
# Name: 210, dtype: object
# filename        XC245681 - Common Wood Pigeon - Columba palumb...
# download url                                     /245681/download
# Name: 211, dtype: object
# filename        XC236815 - Common Wood Pigeon - Columba palumb...
# download url                                     /236815/download
# Name: 212, dtype: object
# filename        XC235149 - Common Wood Pigeon - Columba palumb...
# download url                                     /235149/download
# Name: 213, dtype: object
# filename        XC228541 - Common Wood Pigeon - Columba palumb...
# download url                                     /228541/download
# Name: 214, dtype: object
# filename        XC215787 - Common Wood Pigeon - Columba palumb...
# download url                                     /215787/download
# Name: 215, dtype: object
# filename        XC213347 - Common Wood Pigeon - Columba palumb...
# download url                                     /213347/download
# Name: 216, dtype: object
# filename        XC213329 - Common Wood Pigeon - Columba palumb...
# download url                                     /213329/download
# Name: 217, dtype: object
# filename        XC211499 - Common Wood Pigeon - Columba palumb...
# download url                                     /211499/download
# Name: 218, dtype: object
# filename        XC209100 - Common Wood Pigeon - Columba palumb...
# download url                                     /209100/download
# Name: 219, dtype: object
# filename        XC208512 - Common Wood Pigeon - Columba palumb...
# download url                                     /208512/download
# Name: 220, dtype: object
# filename        XC207083 - Common Wood Pigeon - Columba palumb...
# download url                                     /207083/download
# Name: 221, dtype: object
# filename        XC183442 - Common Wood Pigeon - Columba palumb...
# download url                                     /183442/download
# Name: 222, dtype: object
# filename        XC183441 - Common Wood Pigeon - Columba palumb...
# download url                                     /183441/download
# Name: 223, dtype: object
# filename        XC169494 - Common Wood Pigeon - Columba palumb...
# download url                                     /169494/download
# Name: 224, dtype: object
# filename        XC163355 - Common Wood Pigeon - Columba palumb...
# download url                                     /163355/download
# Name: 225, dtype: object
# filename        XC145640 - Common Wood Pigeon - Columba palumb...
# download url                                     /145640/download
# Name: 226, dtype: object
# filename        XC138176 - Common Wood Pigeon - Columba palumb...
# download url                                     /138176/download
# Name: 227, dtype: object
# filename        XC130994 - Common Wood Pigeon - Columba palumb...
# download url                                     /130994/download
# Name: 228, dtype: object
# filename        XC130993 - Common Wood Pigeon - Columba palumb...
# download url                                     /130993/download
# Name: 229, dtype: object
# filename        XC130072 - Common Wood Pigeon - Columba palumb...
# download url                                     /130072/download
# Name: 230, dtype: object
# filename        XC121734 - Common Wood Pigeon - Columba palumb...
# download url                                     /121734/download
# Name: 231, dtype: object
# filename        XC121352 - Common Wood Pigeon - Columba palumb...
# download url                                     /121352/download
# Name: 232, dtype: object
# filename        XC105627 - Common Wood Pigeon - Columba palumb...
# download url                                     /105627/download
# Name: 233, dtype: object
# filename        XC104607 - Common Wood Pigeon - Columba palumb...
# download url                                     /104607/download
# Name: 234, dtype: object
# filename        XC103240 - Common Wood Pigeon - Columba palumb...
# download url                                     /103240/download
# Name: 235, dtype: object
# filename        XC103239 - Common Wood Pigeon - Columba palumb...
# download url                                     /103239/download
# Name: 236, dtype: object
# filename        XC101939 - Common Wood Pigeon - Columba palumb...
# download url                                     /101939/download
# Name: 237, dtype: object
# filename        XC101518 - Common Wood Pigeon - Columba palumb...
# download url                                     /101518/download
# Name: 238, dtype: object
# filename        XC96280 - Common Wood Pigeon - Columba palumbu...
# download url                                      /96280/download
# Name: 239, dtype: object
# filename        XC94615 - Common Wood Pigeon - Columba palumbu...
# download url                                      /94615/download
# Name: 240, dtype: object
# filename        XC94614 - Common Wood Pigeon - Columba palumbu...
# download url                                      /94614/download
# Name: 241, dtype: object
# filename        XC94613 - Common Wood Pigeon - Columba palumbu...
# download url                                      /94613/download
# Name: 242, dtype: object
# filename        XC91236 - Common Wood Pigeon - Columba palumbu...
# download url                                      /91236/download
# Name: 243, dtype: object
# filename        XC91235 - Common Wood Pigeon - Columba palumbu...
# download url                                      /91235/download
# Name: 244, dtype: object
# filename        XC77498 - Common Wood Pigeon - Columba palumbu...
# download url                                      /77498/download
# Name: 245, dtype: object
# filename        XC77395 - Common Wood Pigeon - Columba palumbu...
# download url                                      /77395/download
# Name: 246, dtype: object
# filename        XC76918 - Common Wood Pigeon - Columba palumbu...
# download url                                      /76918/download
# Name: 247, dtype: object
# filename        XC76849 - Common Wood Pigeon - Columba palumbu...
# download url                                      /76849/download
# Name: 248, dtype: object
# filename        XC72760 - Common Wood Pigeon - Columba palumbu...
# download url                                      /72760/download
# Name: 249, dtype: object
# filename        XC67245 - Common Wood Pigeon - Columba palumbu...
# download url                                      /67245/download
# Name: 250, dtype: object
# filename        XC67243 - Common Wood Pigeon - Columba palumbu...
# download url                                      /67243/download
# Name: 251, dtype: object
# filename        XC59770 - Common Wood Pigeon - Columba palumbu...
# download url                                      /59770/download
# Name: 252, dtype: object
# filename        XC42432 - Common Wood Pigeon - Columba palumbu...
# download url                                      /42432/download
# Name: 253, dtype: object
# filename        XC35082 - Common Wood Pigeon - Columba palumbu...
# download url                                      /35082/download
# Name: 254, dtype: object
# filename        XC26550 - Common Wood Pigeon - Columba palumbu...
# download url                                      /26550/download
# Name: 255, dtype: object
# filename        XC744094 - Common Wood Pigeon - Columba palumb...
# download url                                     /744094/download
# Name: 256, dtype: object
# filename        XC743781 - Common Wood Pigeon - Columba palumb...
# download url                                     /743781/download
# Name: 257, dtype: object
# filename        XC743111 - Common Wood Pigeon - Columba palumb...
# download url                                     /743111/download
# Name: 258, dtype: object
# filename        XC743110 - Common Wood Pigeon - Columba palumb...
# download url                                     /743110/download
# Name: 259, dtype: object
# filename        XC742897 - Common Wood Pigeon - Columba palumb...
# download url                                     /742897/download
# Name: 260, dtype: object
# filename        XC742124 - Common Wood Pigeon - Columba palumb...
# download url                                     /742124/download
# Name: 261, dtype: object
# filename        XC739150 - Common Wood Pigeon - Columba palumb...
# download url                                     /739150/download
# Name: 262, dtype: object
# filename        XC739095 - Common Wood Pigeon - Columba palumb...
# download url                                     /739095/download
# Name: 263, dtype: object
# filename        XC738042 - Common Wood Pigeon - Columba palumb...
# download url                                     /738042/download
# Name: 264, dtype: object
# filename        XC737726 - Common Wood Pigeon - Columba palumb...
# download url                                     /737726/download
# Name: 265, dtype: object
# filename        XC737643 - Common Wood Pigeon - Columba palumb...
# download url                                     /737643/download
# Name: 266, dtype: object
# filename        XC736477 - Common Wood Pigeon - Columba palumb...
# download url                                     /736477/download
# Name: 267, dtype: object
# filename        XC736357 - Common Wood Pigeon - Columba palumb...
# download url                                     /736357/download
# Name: 268, dtype: object
# filename        XC736136 - Common Wood Pigeon - Columba palumb...
# download url                                     /736136/download
# Name: 269, dtype: object
# filename        XC735239 - Common Wood Pigeon - Columba palumb...
# download url                                     /735239/download
# Name: 270, dtype: object
# filename        XC734770 - Common Wood Pigeon - Columba palumb...
# download url                                     /734770/download
# Name: 271, dtype: object
# filename        XC734075 - Common Wood Pigeon - Columba palumb...
# download url                                     /734075/download
# Name: 272, dtype: object
# filename        XC734074 - Common Wood Pigeon - Columba palumb...
# download url                                     /734074/download
# Name: 273, dtype: object
# filename        XC730992 - Common Wood Pigeon - Columba palumb...
# download url                                     /730992/download
# Name: 274, dtype: object
# filename        XC727441 - Common Wood Pigeon - Columba palumb...
# download url                                     /727441/download
# Name: 275, dtype: object
# filename        XC727439 - Common Wood Pigeon - Columba palumb...
# download url                                     /727439/download
# Name: 276, dtype: object
# filename        XC723645 - Common Wood Pigeon - Columba palumb...
# download url                                     /723645/download
# Name: 277, dtype: object
# filename        XC722448 - Common Wood Pigeon - Columba palumb...
# download url                                     /722448/download
# Name: 278, dtype: object
# filename        XC717082 - Common Wood Pigeon - Columba palumb...
# download url                                     /717082/download
# Name: 279, dtype: object
# filename        XC716754 - Common Wood Pigeon - Columba palumb...
# download url                                     /716754/download
# Name: 280, dtype: object
# filename        XC716249 - Common Wood Pigeon - Columba palumb...
# download url                                     /716249/download
# Name: 281, dtype: object
# filename        XC714549 - Common Wood Pigeon - Columba palumb...
# download url                                     /714549/download
# Name: 282, dtype: object
# filename        XC714454 - Common Wood Pigeon - Columba palumb...
# download url                                     /714454/download
# Name: 283, dtype: object
# filename        XC714407 - Common Wood Pigeon - Columba palumb...
# download url                                     /714407/download
# Name: 284, dtype: object
# filename        XC712520 - Common Wood Pigeon - Columba palumb...
# download url                                     /712520/download
# Name: 285, dtype: object
# filename        XC712513 - Common Wood Pigeon - Columba palumb...
# download url                                     /712513/download
# Name: 286, dtype: object
# filename        XC709386 - Common Wood Pigeon - Columba palumb...
# download url                                     /709386/download
# Name: 287, dtype: object
# filename        XC704548 - Common Wood Pigeon - Columba palumb...
# download url                                     /704548/download
# Name: 288, dtype: object
# filename        XC698337 - Common Wood Pigeon - Columba palumb...
# download url                                     /698337/download
# Name: 289, dtype: object
# filename        XC697865 - Common Wood Pigeon - Columba palumb...
# download url                                     /697865/download
# Name: 290, dtype: object
# filename        XC672313 - Common Wood Pigeon - Columba palumb...
# download url                                     /672313/download
# Name: 291, dtype: object
# filename        XC670039 - Common Wood Pigeon - Columba palumb...
# download url                                     /670039/download
# Name: 292, dtype: object
# filename        XC668720 - Common Wood Pigeon - Columba palumb...
# download url                                     /668720/download
# Name: 293, dtype: object
# filename        XC668696 - Common Wood Pigeon - Columba palumb...
# download url                                     /668696/download
# Name: 294, dtype: object
# filename        XC668694 - Common Wood Pigeon - Columba palumb...
# download url                                     /668694/download
# Name: 295, dtype: object
# filename        XC666581 - Common Wood Pigeon - Columba palumb...
# download url                                     /666581/download
# Name: 296, dtype: object
# filename        XC660866 - Common Wood Pigeon - Columba palumb...
# download url                                     /660866/download
# Name: 297, dtype: object
# filename        XC660561 - Common Wood Pigeon - Columba palumb...
# download url                                     /660561/download
# Name: 298, dtype: object
# filename        XC659737 - Common Wood Pigeon - Columba palumb...
# download url                                     /659737/download
# Name: 299, dtype: object
# filename        XC656115 - Common Wood Pigeon - Columba palumb...
# download url                                     /656115/download
# Name: 300, dtype: object
# filename        XC655599 - Common Wood Pigeon - Columba palumb...
# download url                                     /655599/download
# Name: 301, dtype: object
# filename        XC655025 - Common Wood Pigeon - Columba palumb...
# download url                                     /655025/download
# Name: 302, dtype: object
# filename        XC649826 - Common Wood Pigeon - Columba palumb...
# download url                                     /649826/download
# Name: 303, dtype: object
# filename        XC647356 - Common Wood Pigeon - Columba palumb...
# download url                                     /647356/download
# Name: 304, dtype: object
# filename        XC645299 - Common Wood Pigeon - Columba palumb...
# download url                                     /645299/download
# Name: 305, dtype: object
# ...
# Name: 477, dtype: object
# filename        XC177142 - Common Buzzard - Buteo buteo.mp3
# download url                               /177142/download
# Name: 478, dtype: object
# filename        XC176699 - Common Buzzard - Buteo buteo.mp3
# download url                               /176699/download
# Name: 479, dtype: object
# filename        XC176605 - Common Buzzard - Buteo buteo.mp3
# download url                               /176605/download
# Name: 480, dtype: object
# filename        XC170643 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /170643/download
# Name: 481, dtype: object
# filename        XC167120 - Common Buzzard - Buteo buteo.mp3
# download url                               /167120/download
# Name: 482, dtype: object
# filename        XC155409 - Common Buzzard - Buteo buteo.mp3
# download url                               /155409/download
# Name: 483, dtype: object
# filename        XC153194 - Common Buzzard - Buteo buteo.mp3
# download url                               /153194/download
# Name: 484, dtype: object
# filename        XC150342 - Common Buzzard - Buteo buteo.mp3
# download url                               /150342/download
# Name: 485, dtype: object
# filename        XC144284 - Common Buzzard - Buteo buteo.mp3
# download url                               /144284/download
# Name: 486, dtype: object
# filename        XC142599 - Common Buzzard - Buteo buteo.mp3
# download url                               /142599/download
# Name: 487, dtype: object
# filename        XC140833 - Common Buzzard - Buteo buteo.mp3
# download url                               /140833/download
# Name: 488, dtype: object
# filename        XC139550 - Common Buzzard - Buteo buteo.mp3
# download url                               /139550/download
# Name: 489, dtype: object
# filename        XC134215 - Common Buzzard - Buteo buteo.mp3
# download url                               /134215/download
# Name: 490, dtype: object
# filename        XC130591 - Common Buzzard - Buteo buteo.mp3
# download url                               /130591/download
# Name: 491, dtype: object
# filename        XC128575 - Common Buzzard - Buteo buteo.mp3
# download url                               /128575/download
# Name: 492, dtype: object
# filename        XC125314 - Common Buzzard - Buteo buteo.mp3
# download url                               /125314/download
# Name: 493, dtype: object
# filename        XC97404 - Common Buzzard - Buteo buteo.mp3
# download url                               /97404/download
# Name: 494, dtype: object
# filename        XC90506 - Common Buzzard - Buteo buteo.mp3
# download url                               /90506/download
# Name: 495, dtype: object
# filename        XC87679 - Common Buzzard - Buteo buteo.mp3
# download url                               /87679/download
# Name: 496, dtype: object
# filename        XC77239 - Common Buzzard - Buteo buteo.mp3
# download url                               /77239/download
# Name: 497, dtype: object
# filename        XC77238 - Common Buzzard - Buteo buteo.mp3
# download url                               /77238/download
# Name: 498, dtype: object
# filename        XC63083 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /63083/download
# Name: 499, dtype: object
# filename        XC30951 - Common Buzzard - Buteo buteo.mp3
# download url                               /30951/download
# Name: 500, dtype: object
# filename        XC30430 - Common Buzzard - Buteo buteo.mp3
# download url                               /30430/download
# Name: 501, dtype: object
# filename        XC742540 - Common Buzzard - Buteo buteo.mp3
# download url                               /742540/download
# Name: 502, dtype: object
# filename        XC742350 - Common Buzzard - Buteo buteo.mp3
# download url                               /742350/download
# Name: 503, dtype: object
# filename        XC739003 - Common Buzzard - Buteo buteo.mp3
# download url                               /739003/download
# Name: 504, dtype: object
# filename        XC732367 - Common Buzzard - Buteo buteo.mp3
# download url                               /732367/download
# Name: 505, dtype: object
# filename        XC725284 - Common Buzzard - Buteo buteo menetr...
# download url                                     /725284/download
# Name: 506, dtype: object
# filename        XC724085 - Common Buzzard - Buteo buteo.mp3
# download url                               /724085/download
# Name: 507, dtype: object
# filename        XC723836 - Common Buzzard - Buteo buteo.mp3
# download url                               /723836/download
# Name: 508, dtype: object
# filename        XC718226 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /718226/download
# Name: 509, dtype: object
# filename        XC705931 - Common Buzzard - Buteo buteo.mp3
# download url                               /705931/download
# Name: 510, dtype: object
# filename        XC702242 - Common Buzzard - Buteo buteo.mp3
# download url                               /702242/download
# Name: 511, dtype: object
# filename        XC697502 - Common Buzzard - Buteo buteo.mp3
# download url                               /697502/download
# Name: 512, dtype: object
# filename        XC693111 - Common Buzzard - Buteo buteo.mp3
# download url                               /693111/download
# Name: 513, dtype: object
# filename        XC672595 - Common Buzzard - Buteo buteo.mp3
# download url                               /672595/download
# Name: 514, dtype: object
# filename        XC669953 - Common Buzzard - Buteo buteo.mp3
# download url                               /669953/download
# Name: 515, dtype: object
# filename        XC669937 - Common Buzzard - Buteo buteo.mp3
# download url                               /669937/download
# Name: 516, dtype: object
# filename        XC667100 - Common Buzzard - Buteo buteo.mp3
# download url                               /667100/download
# Name: 517, dtype: object
# filename        XC666389 - Common Buzzard - Buteo buteo.mp3
# download url                               /666389/download
# Name: 518, dtype: object
# filename        XC663005 - Common Buzzard - Buteo buteo.mp3
# download url                               /663005/download
# Name: 519, dtype: object
# filename        XC662308 - Common Buzzard - Buteo buteo.mp3
# download url                               /662308/download
# Name: 520, dtype: object
# filename        XC658966 - Common Buzzard - Buteo buteo.mp3
# download url                               /658966/download
# Name: 521, dtype: object
# filename        XC651914 - Common Buzzard - Buteo buteo.mp3
# download url                               /651914/download
# Name: 522, dtype: object
# filename        XC650404 - Common Buzzard - Buteo buteo.mp3
# download url                               /650404/download
# Name: 523, dtype: object
# filename        XC628264 - Common Buzzard - Buteo buteo.mp3
# download url                               /628264/download
# Name: 524, dtype: object
# filename        XC626528 - Common Buzzard - Buteo buteo.mp3
# download url                               /626528/download
# Name: 525, dtype: object
# filename        XC624904 - Common Buzzard - Buteo buteo.mp3
# download url                               /624904/download
# Name: 526, dtype: object
# filename        XC624903 - Common Buzzard - Buteo buteo.mp3
# download url                               /624903/download
# Name: 527, dtype: object
# filename        XC623202 - Common Buzzard - Buteo buteo.mp3
# download url                               /623202/download
# Name: 528, dtype: object
# filename        XC623201 - Common Buzzard - Buteo buteo.mp3
# download url                               /623201/download
# Name: 529, dtype: object
# filename        XC623200 - Common Buzzard - Buteo buteo.mp3
# download url                               /623200/download
# Name: 530, dtype: object
# filename        XC621680 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /621680/download
# Name: 531, dtype: object
# filename        XC620287 - Common Buzzard - Buteo buteo.mp3
# download url                               /620287/download
# Name: 532, dtype: object
# filename        XC616303 - Common Buzzard - Buteo buteo.mp3
# download url                               /616303/download
# Name: 533, dtype: object
# filename        XC606998 - Common Buzzard - Buteo buteo.mp3
# download url                               /606998/download
# Name: 534, dtype: object
# filename        XC603500 - Common Buzzard - Buteo buteo.mp3
# download url                               /603500/download
# Name: 535, dtype: object
# filename        XC588272 - Common Buzzard - Buteo buteo.mp3
# download url                               /588272/download
# Name: 536, dtype: object
# filename        XC584693 - Common Buzzard - Buteo buteo.mp3
# download url                               /584693/download
# Name: 537, dtype: object
# filename        XC579130 - Common Buzzard - Buteo buteo.mp3
# download url                               /579130/download
# Name: 538, dtype: object
# filename        XC576544 - Common Buzzard - Buteo buteo.mp3
# download url                               /576544/download
# Name: 539, dtype: object
# filename        XC574208 - Common Buzzard - Buteo buteo.mp3
# download url                               /574208/download
# Name: 540, dtype: object
# filename        XC563178 - Common Buzzard - Buteo buteo.mp3
# download url                               /563178/download
# Name: 541, dtype: object
# filename        XC559182 - Common Buzzard - Buteo buteo.mp3
# download url                               /559182/download
# Name: 542, dtype: object
# filename        XC544315 - Common Buzzard - Buteo buteo.mp3
# download url                               /544315/download
# Name: 543, dtype: object
# filename        XC542010 - Common Buzzard - Buteo buteo.mp3
# download url                               /542010/download
# Name: 544, dtype: object
# filename        XC537432 - Common Buzzard - Buteo buteo.mp3
# download url                               /537432/download
# Name: 545, dtype: object
# filename        XC533690 - Common Buzzard - Buteo buteo.mp3
# download url                               /533690/download
# Name: 546, dtype: object
# filename        XC533689 - Common Buzzard - Buteo buteo.mp3
# download url                               /533689/download
# Name: 547, dtype: object
# filename        XC531031 - Common Buzzard - Buteo buteo.mp3
# download url                               /531031/download
# Name: 548, dtype: object
# filename        XC528559 - Common Buzzard - Buteo buteo.mp3
# download url                               /528559/download
# Name: 549, dtype: object
# filename        XC522513 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /522513/download
# Name: 550, dtype: object
# filename        XC520685 - Common Buzzard - Buteo buteo.mp3
# download url                               /520685/download
# Name: 551, dtype: object
# filename        XC513468 - Common Buzzard - Buteo buteo.mp3
# download url                               /513468/download
# Name: 552, dtype: object
# filename        XC509240 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /509240/download
# Name: 553, dtype: object
# filename        XC508175 - Common Buzzard - Buteo buteo.mp3
# download url                               /508175/download
# Name: 554, dtype: object
# filename        XC499654 - Common Buzzard - Buteo buteo.mp3
# download url                               /499654/download
# Name: 555, dtype: object
# filename        XC499648 - Common Buzzard - Buteo buteo.mp3
# download url                               /499648/download
# Name: 556, dtype: object
# filename        XC499455 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /499455/download
# Name: 557, dtype: object
# filename        XC496715 - Common Buzzard - Buteo buteo.mp3
# download url                               /496715/download
# Name: 558, dtype: object
# filename        XC494276 - Common Buzzard - Buteo buteo.mp3
# download url                               /494276/download
# Name: 559, dtype: object
# filename        XC490034 - Common Buzzard - Buteo buteo rothsc...
# download url                                     /490034/download
# Name: 560, dtype: object
# filename        XC488696 - Common Buzzard - Buteo buteo.mp3
# download url                               /488696/download
# Name: 561, dtype: object
# filename        XC486464 - Common Buzzard - Buteo buteo.mp3
# download url                               /486464/download
# Name: 562, dtype: object
# filename        XC462705 - Common Buzzard - Buteo buteo.mp3
# download url                               /462705/download
# Name: 563, dtype: object
# filename        XC458051 - Common Buzzard - Buteo buteo.mp3
# download url                               /458051/download
# Name: 564, dtype: object
# filename        XC453947 - Common Buzzard - Buteo buteo.mp3
# download url                               /453947/download
# Name: 565, dtype: object
# filename        XC452832 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /452832/download
# Name: 566, dtype: object
# filename        XC452830 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /452830/download
# Name: 567, dtype: object
# filename        XC448429 - Common Buzzard - Buteo buteo.mp3
# download url                               /448429/download
# Name: 568, dtype: object
# filename        XC446908 - Common Buzzard - Buteo buteo.mp3
# download url                               /446908/download
# Name: 569, dtype: object
# filename        XC443017 - Common Buzzard - Buteo buteo.mp3
# download url                               /443017/download
# Name: 570, dtype: object
# filename        XC438879 - Common Buzzard - Buteo buteo.mp3
# download url                               /438879/download
# Name: 571, dtype: object
# filename        XC430273 - Common Buzzard - Buteo buteo.mp3
# download url                               /430273/download
# Name: 572, dtype: object
# filename        XC424544 - Common Buzzard - Buteo buteo.mp3
# download url                               /424544/download
# Name: 573, dtype: object
# filename        XC424543 - Common Buzzard - Buteo buteo.mp3
# download url                               /424543/download
# Name: 574, dtype: object
# filename        XC411022 - Common Buzzard - Buteo buteo.mp3
# download url                               /411022/download
# Name: 575, dtype: object
# filename        XC409781 - Common Buzzard - Buteo buteo.mp3
# download url                               /409781/download
# Name: 576, dtype: object
# filename        XC409768 - Common Buzzard - Buteo buteo.mp3
# download url                               /409768/download
# Name: 577, dtype: object
# filename        XC406791 - Common Buzzard - Buteo buteo.mp3
# download url                               /406791/download
# Name: 578, dtype: object
# filename        XC405814 - Common Buzzard - Buteo buteo.mp3
# download url                               /405814/download
# Name: 579, dtype: object
# filename        XC403178 - Common Buzzard - Buteo buteo.mp3
# download url                               /403178/download
# Name: 580, dtype: object
# filename        XC402976 - Common Buzzard - Buteo buteo buteo.mp3
# download url                                     /402976/download
# Name: 581, dtype: object
# filename        XC402063 - Common Buzzard - Buteo buteo.mp3
# download url                               /402063/download
# Name: 582, dtype: object
# filename        XC388032 - Common Buzzard - Buteo buteo.mp3
# download url                               /388032/download
# Name: 583, dtype: object
# filename        XC384120 - Common Buzzard - Buteo buteo.mp3
# download url                               /384120/download
# Name: 584, dtype: object
# filename        XC382540 - Common Buzzard - Buteo buteo.mp3
# download url                               /382540/download
# Name: 585, dtype: object
# filename        XC382539 - Common Buzzard - Buteo buteo.mp3
# download url                               /382539/download
# Name: 586, dtype: object
